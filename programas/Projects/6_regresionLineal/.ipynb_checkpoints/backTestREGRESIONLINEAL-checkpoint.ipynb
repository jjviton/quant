# %% [markdown]
# # <font color='red'>Backtest vectorizado para una estrategia 'Regresion lineal' definida.</font>
#
# ### Hackeado by J3viton (learning BackTesting 2021).

# %% [markdown]
# ---

# %% [markdown]
# En este notebook vamos a automatizar el backtesting para estrategias. Previamente tenemos que definir **la estrategia** usando el template (import estrategia_XX as rg), donde definimos la clase estrategia que contiene los metodos de analisis, entreda y salida de mercado. Este módulo se programa y adapta para cada estrategia. Luego en el metodo 'analisis' se crea un fichero excel con las metricas y rendimientos para evaluar la estrategia.
#
# Vamos a usar el módulo Pandas, para realizar un backtest vectorizado, es decir calcular el resultado del backtest sin iterar sobre las filas (barras) de la serie temporal.

# %% [markdown]
# Posteriormente graficamos y mostramos los parametros generales que nos permiten analizar la estrategia.
#
# #### J3Viton  2021
#
# link a la base:
#
# https://github.com/Python-para-Trading/Webinars-Docs/blob/master/Webinar%202/Webinar%202%20-%20Backtest%20con%20Pandas%20v%202.ipynb.

# %% [markdown]
# ---

# %% [markdown]
# # DEFINICION DEL SISTEMA

# %% [markdown]
# Como es usual, importamos los módulos que vamos a necesitar para las distintas tareas, y preparamos Matplotlib para una mejor visualización de los gráficos en el notebook.
#
# Se importa un modulo llamado analisis, en realidad se trata de un archivo .py con algunas funciones de apoyo para el trabajo, debe estar guardado en la misma carpeta que este notebook.
# Se importa el módulo 'estrategia_XX', donde se define la estrategia de entreda y salida

# %% [markdown]
# Es importante tener clara la lógica del sistema, pues debemos plasmarla de forma sencilla y correcta en el dataframe para realizar el backtest del mismo.

# %%
import analisis
import regresionAMedia as rg  #cambiar segun el módulo con la estrategia implementado
import pandas as pd
import datetime as dt
from time import time
import yfinance as yf
import numpy as np
# Out:
# {'id': 1473252352, 'first_name': 'vital_bot', 'is_bot': True, 'username': 'vital_quant_bot', 'can_join_groups': True, 'can_read_all_group_messages': False, 'supports_inline_queries': False}

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = 18, 8
plt.style.use('ggplot')

from IPython.display import display, Markdown

# %% [markdown]
# ***0.- RECOGIDA DE DATOS INICIALES***
# Introducimos el instrumento y las fechas

# %%
instrumento_ = 'anet'   # ticker del valor en yahooFinance

Fecha_Cominezo_Backtesting = dt.datetime(2015,1,2)
Fecha_Final_Backtesting    = dt.datetime(2021,11,18)
Fecha_Final_Backtesting    = dt.datetime.today()

# %% [markdown]
# ***1.- Rango fechas a analizar***
#
# Definimos el rango global de datos historicos que vamos a evaluar.
# Definimos la ventana que vamos a ir desplazando por todo el espectro para ir analilazando como se comporta la estrategia. La funion 'analisis' nos vale para tiempo real y para backtesting, para back le pasamos la ventana como si la fecha de fin de la ventana fuera la fecha de hoy.
# Tener en cuenta que la 'ventana' tiene uqe tener una anchura que nos permita hacer los calculos en rolling (ejemplo EMA 200)

# %%
# Rango completo para backTesting
#start2 =dt.datetime(2008,1,2)
start2= Fecha_Cominezo_Backtesting 
#end2   =dt.datetime(2021,11,18)
end2= Fecha_Final_Backtesting 
start_G= start2.strftime("%Y-%m-%d")
end_G  =   end2.strftime("%Y-%m-%d")
TOTAL_len= (end2-start2).days
print('Tamaño timeseries global a analizar:  ', TOTAL_len, 'sesiones')

#ventana de analisis 200 sesiones
startWindow2 = start2  #dt.datetime(2008,1,5)
endWindow2   =startWindow2 + dt.timedelta(days=500) #ventana grande para que se puedan hacer los calculos de EMA200
startWindow= startWindow2.strftime("%Y-%m-%d")
endWindow  =   endWindow2.strftime("%Y-%m-%d")
window_len= (endWindow2-startWindow2).days
print('Tamaño de la ventana a analizar paso a paso:  ', window_len, 'sesiones')
# Out:
# Tamaño timeseries global a analizar:   2692 sesiones
# Tamaño de la ventana a analizar paso a paso:   500 sesiones

# %%
 #dff = pd.DataFrame(columns=('Close','Volume', 'Senal', 'Dif_Close', 'Retornos','Capital'))

# %% [markdown]
# ***2.- Descargamos los datos para el marco Global***

# %%
instrumento = instrumento_  # 'rovi.mc'  #Vamos título a título. Mejora: Conjunto de títulos

# %%
dff = yf.download(instrumento, start_G,end_G)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
dff.dropna(inplace=True)  
dff.head()
# Out:
#                Open       High        Low      Close  Adj Close   Volume
# Date
# 2015-01-02  15.1900  15.718750  15.040000  15.670000  15.670000  1482000
# 2015-01-05  15.7500  16.187500  15.512500  15.950000  15.950000  1876400
# 2015-01-06  16.0000  16.227501  15.552500  15.952500  15.952500  1442400
# 2015-01-07  16.0975  16.375000  15.995000  16.285000  16.285000  1640000
# 2015-01-08  16.4275  16.707500  16.214001  16.530001  16.530001  1898000

# %% [markdown]
# ***3.- Creamos la clase strategy que tiene toda la lógica***

# %%
regreMedia= rg.StrategyClass(back=True)    #Creamos la clase

# %% [markdown]
# ***4.- Recorremos el dataframe con valores buscando las señales de la estrategia***

# %%
dff.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2022-05-03', '2022-05-04', '2022-05-05', '2022-05-06',
#                '2022-05-09', '2022-05-10', '2022-05-11', '2022-05-12',
#                '2022-05-13', '2022-05-16'],
#               dtype='datetime64[ns]', name='Date', length=1856, freq=None)

# %% [markdown]
# ## Proceso de backTesting ##
#
# En este 'for' vamos recorriendo la muestra del historico de datos (TOTAL), desplazando una sesión hacia el futuro
# en cada iteracion. Vamos pasando la movilola del pasado sesión a sesión por el análisis descrito en Strategy class.
#
# Ouput:
# El sistema registra los siguientes parámetros:
#
# .-
# .-
# .-

# %%
startWindow
# Out:
# '2015-01-02'

# %%
tiempo_inicial = time()   # Tomamos tiempos para ver cuanto tarda en hacer la estrategia

# %%
dfe = pd.DataFrame({'A' : []})   #df empty

# %% [markdown]
# ***En este 'for' desplazamos la ventana sesión a sesión a lo largo de todo el rango de fechas. Dejamos que las funciones de la clase estrategia hagan el trabajo de comprar//vender y anotar***

# %%
#Para pruebas
#TOTAL_len =1000

for i in range(TOTAL_len):
    endWindow3   =endWindow2 + dt.timedelta(days=i) 
    endWindow    =endWindow3.strftime("%Y-%m-%d")
    print ('end date:', endWindow)
    
    if(endWindow in dff.index):
        df_aux= dff.loc[startWindow:endWindow]       #voy pasando los datos desplazando la ventana
        
        recogo = regreMedia.analisis(instrumento, startWindow, endWindow, df_aux) #Llamada a la clase estrategia. LA CLAVE DE TODO!!!
        
        print ('................................................Analizando, muestra', i, 'de', TOTAL_len, 'fecha', endWindow)
        
            
    else:
        print('..............Día sin sesión, next please')
# Out:
# end date: 2016-05-16
#  Datos desde archivo
# Coefficients:
#  [-0.0039348]
# Independent term:
#  17.90500248316755
# Coefficients:
#  [-0.0158286]
# Independent term:
#  18.44639584057367
# Coefficients:
#  [-0.00879192]
# Independent term:
#  17.882601346507148
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 0 de 2692 fecha 2016-05-16
# end date: 2016-05-17
#  Datos desde archivo
# Coefficients:
#  [-0.00392593]
# Independent term:
#  17.90398532541888
# Coefficients:
#  [-0.01521035]
# Independent term:
#  18.362917472213063
# Coefficients:
#  [-0.00878671]
# Independent term:
#  17.882347834961998
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 1 de 2692 fecha 2016-05-17
# end date: 2016-05-18
#  Datos desde archivo
# Coefficients:
#  [-0.00390298]
# Independent term:
#  17.90134611397961
# Coefficients:
#  [-0.01453732]
# Independent term:
#  18.27520069762842
# Coefficients:
#  [-0.00877828]
# Independent term:
#  17.881935029382365
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 2 de 2692 fecha 2016-05-18
# end date: 2016-05-19
#  Datos desde archivo
# Coefficients:
#  [-0.00387813]
# Independent term:
#  17.898480237914267
# Coefficients:
#  [-0.01391541]
# Independent term:
#  18.194895841968595
# Coefficients:
#  [-0.00876672]
# Independent term:
#  17.881364315270435
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 3 de 2692 fecha 2016-05-19
# end date: 2016-05-20
#  Datos desde archivo
# Coefficients:
#  [-0.00382994]
# Independent term:
#  17.892906028350943
# Coefficients:
#  [-0.01315415]
# Independent term:
#  18.101062644132927
# Coefficients:
#  [-0.00875094]
# Independent term:
#  17.880580583644708
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 4 de 2692 fecha 2016-05-20
# end date: 2016-05-21
# ..............Día sin sesión, next please
# end date: 2016-05-22
# ..............Día sin sesión, next please
# end date: 2016-05-23
#  Datos desde archivo
# Coefficients:
#  [-0.00376443]
# Independent term:
#  17.885307301485202
# Coefficients:
#  [-0.01244605]
# Independent term:
#  18.018119360226304
# Coefficients:
#  [-0.00873025]
# Independent term:
#  17.879546329569326
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 7 de 2692 fecha 2016-05-23
# end date: 2016-05-24
#  Datos desde archivo
# Coefficients:
#  [-0.00369099]
# Independent term:
#  17.87676397002259
# Coefficients:
#  [-0.01161274]
# Independent term:
#  17.920505545459577
# Coefficients:
#  [-0.00870449]
# Independent term:
#  17.87824985064756
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 8 de 2692 fecha 2016-05-24
# end date: 2016-05-25
#  Datos desde archivo
# Coefficients:
#  [-0.00362297]
# Independent term:
#  17.868827599211816
# Coefficients:
#  [-0.01080957]
# Independent term:
#  17.826139519250212
# Coefficients:
#  [-0.0086742]
# Independent term:
#  17.876714779102862
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 9 de 2692 fecha 2016-05-25
# end date: 2016-05-26
#  Datos desde archivo
# Coefficients:
#  [-0.0035552]
# Independent term:
#  17.860898455043177
# Coefficients:
#  [-0.01015057]
# Independent term:
#  17.751194394666758
# Coefficients:
#  [-0.0086396]
# Independent term:
#  17.874950398854306
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 10 de 2692 fecha 2016-05-26
# end date: 2016-05-27
#  Datos desde archivo
# Coefficients:
#  [-0.00347837]
# Independent term:
#  17.85188440049834
# Coefficients:
#  [-0.00942614]
# Independent term:
#  17.66975074369516
# Coefficients:
#  [-0.00860046]
# Independent term:
#  17.872941237899447
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 11 de 2692 fecha 2016-05-27
# end date: 2016-05-28
# ..............Día sin sesión, next please
# end date: 2016-05-29
# ..............Día sin sesión, next please
# end date: 2016-05-30
# ..............Día sin sesión, next please
# end date: 2016-05-31
#  Datos desde archivo
# Coefficients:
#  [-0.00339757]
# Independent term:
#  17.842376700653496
# Coefficients:
#  [-0.00864365]
# Independent term:
#  17.58176865463826
# Coefficients:
#  [-0.0085568]
# Independent term:
#  17.87068554991238
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 15 de 2692 fecha 2016-05-31
# end date: 2016-06-01
#  Datos desde archivo
# Coefficients:
#  [-0.00330864]
# Independent term:
#  17.83188270768389
# Coefficients:
#  [-0.00785089]
# Independent term:
#  17.494488783879067
# Coefficients:
#  [-0.00850844]
# Independent term:
#  17.868170711839728
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 16 de 2692 fecha 2016-06-01
# end date: 2016-06-02
#  Datos desde archivo
# Coefficients:
#  [-0.00321141]
# Independent term:
#  17.820377734976585
# Coefficients:
#  [-0.00698054]
# Independent term:
#  17.399038763046267
# Coefficients:
#  [-0.00845519]
# Independent term:
#  17.865384006738765
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 17 de 2692 fecha 2016-06-02
# end date: 2016-06-03
#  Datos desde archivo
# Coefficients:
#  [-0.00311356]
# Independent term:
#  17.80876555340187
# Coefficients:
#  [-0.00617996]
# Independent term:
#  17.313381309224596
# Coefficients:
#  [-0.00839726]
# Independent term:
#  17.862333082605694
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 18 de 2692 fecha 2016-06-03
# end date: 2016-06-04
# ..............Día sin sesión, next please
# end date: 2016-06-05
# ..............Día sin sesión, next please
# end date: 2016-06-06
#  Datos desde archivo
# Coefficients:
#  [-0.00302206]
# Independent term:
#  17.797877172595832
# Coefficients:
#  [-0.00540607]
# Independent term:
#  17.230279056634476
# Coefficients:
#  [-0.0083352]
# Independent term:
#  17.859043543450174
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 21 de 2692 fecha 2016-06-06
# end date: 2016-06-07
#  Datos desde archivo
# Coefficients:
#  [-0.00293286]
# Independent term:
#  17.787232805846767
# Coefficients:
#  [-0.00483874]
# Independent term:
#  17.17444175691747
# Coefficients:
#  [-0.00826931]
# Independent term:
#  17.8555295515653
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 22 de 2692 fecha 2016-06-07
# end date: 2016-06-08
#  Datos desde archivo
# Coefficients:
#  [-0.00284224]
# Independent term:
#  17.776389368801933
# Coefficients:
#  [-0.00426715]
# Independent term:
#  17.118631677058207
# Coefficients:
#  [-0.00819972]
# Independent term:
#  17.851795079660885
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 23 de 2692 fecha 2016-06-08
# end date: 2016-06-09
#  Datos desde archivo
# Coefficients:
#  [-0.00274957]
# Independent term:
#  17.765268442766956
# Coefficients:
#  [-0.00377326]
# Independent term:
#  17.07386449244485
# Coefficients:
#  [-0.00812652]
# Independent term:
#  17.84784223882686
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 24 de 2692 fecha 2016-06-09
# end date: 2016-06-10
#  Datos desde archivo
# Coefficients:
#  [-0.00268145]
# Independent term:
#  17.75707167569794
# Coefficients:
#  [-0.0033406]
# Independent term:
#  17.032101786172213
# Coefficients:
#  [-0.00805106]
# Independent term:
#  17.84374244167792
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 25 de 2692 fecha 2016-06-10
# end date: 2016-06-11
# ..............Día sin sesión, next please
# end date: 2016-06-12
# ..............Día sin sesión, next please
# end date: 2016-06-13
#  Datos desde archivo
# Coefficients:
#  [-0.00262415]
# Independent term:
#  17.750157570483616
# Coefficients:
#  [-0.00284204]
# Independent term:
#  16.97942008118131
# Coefficients:
#  [-0.00797399]
# Independent term:
#  17.839529098588898
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 28 de 2692 fecha 2016-06-13
# end date: 2016-06-14
#  Datos desde archivo
# Coefficients:
#  [-0.00256498]
# Independent term:
#  17.742997382759594
# Coefficients:
#  [-0.00231212]
# Independent term:
#  16.923205547190424
# Coefficients:
#  [-0.00789531]
# Independent term:
#  17.835201508647426
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 29 de 2692 fecha 2016-06-14
# end date: 2016-06-15
#  Datos desde archivo
# Coefficients:
#  [-0.00249962]
# Independent term:
#  17.73506700332825
# Coefficients:
#  [-0.00171505]
# Independent term:
#  16.85968537971155
# Coefficients:
#  [-0.00781482]
# Independent term:
#  17.830747729516258
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 30 de 2692 fecha 2016-06-15
# end date: 2016-06-16
#  Datos desde archivo
# Coefficients:
#  [-0.00244154]
# Independent term:
#  17.728000863526844
# Coefficients:
#  [-0.00119757]
# Independent term:
#  16.80534619075149
# Coefficients:
#  [-0.00773296]
# Independent term:
#  17.826191198151342
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 31 de 2692 fecha 2016-06-16
# end date: 2016-06-17
#  Datos desde archivo
# Coefficients:
#  [-0.00238927]
# Independent term:
#  17.721623549742848
# Coefficients:
#  [-0.00080457]
# Independent term:
#  16.766430133705708
# Coefficients:
#  [-0.0076501]
# Independent term:
#  17.82155078517108
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 32 de 2692 fecha 2016-06-17
# end date: 2016-06-18
# ..............Día sin sesión, next please
# end date: 2016-06-19
# ..............Día sin sesión, next please
# end date: 2016-06-20
#  Datos desde archivo
# Coefficients:
#  [-0.0023329]
# Independent term:
#  17.714728008933285
# Coefficients:
#  [-0.00034659]
# Independent term:
#  16.719986118914473
# Coefficients:
#  [-0.0075661]
# Independent term:
#  17.816819025402175
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 35 de 2692 fecha 2016-06-20
# end date: 2016-06-21
#  Datos desde archivo
# Coefficients:
#  [-0.00227603]
# Independent term:
#  17.70775183614243
# Coefficients:
#  [0.00014477]
# Independent term:
#  16.669420445000945
# Coefficients:
#  [-0.00748103]
# Independent term:
#  17.811997974025456
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 36 de 2692 fecha 2016-06-21
# end date: 2016-06-22
#  Datos desde archivo
# Coefficients:
#  [-0.00223367]
# Independent term:
#  17.702541477772872
# Coefficients:
#  [0.00062392]
# Independent term:
#  16.617357743249013
# Coefficients:
#  [-0.0073956]
# Independent term:
#  17.80712863836235
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 37 de 2692 fecha 2016-06-22
# end date: 2016-06-23
#  Datos desde archivo
# Coefficients:
#  [-0.0021653]
# Independent term:
#  17.69410904381205
# Coefficients:
#  [0.00132394]
# Independent term:
#  16.5421558676193
# Coefficients:
#  [-0.00730868]
# Independent term:
#  17.802145492818077
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 38 de 2692 fecha 2016-06-23
# end date: 2016-06-24
#  Datos desde archivo
# Coefficients:
#  [-0.00217502]
# Independent term:
#  17.69531174604068
# Coefficients:
#  [0.00159866]
# Independent term:
#  16.505595795218625
# Coefficients:
#  [-0.00722388]
# Independent term:
#  17.797255398858663
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 39 de 2692 fecha 2016-06-24
# end date: 2016-06-25
# ..............Día sin sesión, next please
# end date: 2016-06-26
# ..............Día sin sesión, next please
# end date: 2016-06-27
#  Datos desde archivo
# Coefficients:
#  [-0.00224568]
# Independent term:
#  17.704072792420416
# Coefficients:
#  [0.00150631]
# Independent term:
#  16.503596927585885
# Coefficients:
#  [-0.00714387]
# Independent term:
#  17.79261477425261
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 42 de 2692 fecha 2016-06-27
# end date: 2016-06-28
#  Datos desde archivo
# Coefficients:
#  [-0.00230373]
# Independent term:
#  17.711290419395937
# Coefficients:
#  [0.00125297]
# Independent term:
#  16.525729021812552
# Coefficients:
#  [-0.00706793]
# Independent term:
#  17.788184666137997
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 43 de 2692 fecha 2016-06-28
# end date: 2016-06-29
#  Datos desde archivo
# Coefficients:
#  [-0.00234214]
# Independent term:
#  17.716078569943026
# Coefficients:
#  [0.00101837]
# Independent term:
#  16.54978500309275
# Coefficients:
#  [-0.00699505]
# Independent term:
#  17.78390893987934
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 44 de 2692 fecha 2016-06-29
# end date: 2016-06-30
#  Datos desde archivo
# Coefficients:
#  [-0.00237331]
# Independent term:
#  17.719975439334014
# Coefficients:
#  [0.00081836]
# Independent term:
#  16.570785383110614
# Coefficients:
#  [-0.00692481]
# Independent term:
#  17.779765247997044
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 45 de 2692 fecha 2016-06-30
# end date: 2016-07-01
#  Datos desde archivo
# Coefficients:
#  [-0.00241143]
# Independent term:
#  17.72475338875528
# Coefficients:
#  [0.00059154]
# Independent term:
#  16.59354173517939
# Coefficients:
#  [-0.00685746]
# Independent term:
#  17.77576867461544
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 46 de 2692 fecha 2016-07-01
# end date: 2016-07-02
# ..............Día sin sesión, next please
# end date: 2016-07-03
# ..............Día sin sesión, next please
# end date: 2016-07-04
# ..............Día sin sesión, next please
# end date: 2016-07-05
#  Datos desde archivo
# Coefficients:
#  [-0.00245104]
# Independent term:
#  17.72973083480996
# Coefficients:
#  [0.00040281]
# Independent term:
#  16.61072082106747
# Coefficients:
#  [-0.00679295]
# Independent term:
#  17.771919724491294
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 50 de 2692 fecha 2016-07-05
# end date: 2016-07-06
#  Datos desde archivo
# Coefficients:
#  [-0.0024777]
# Independent term:
#  17.73308989737867
# Coefficients:
#  [0.00033961]
# Independent term:
#  16.614196214675903
# Coefficients:
#  [-0.00673064]
# Independent term:
#  17.768181433391426
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 51 de 2692 fecha 2016-07-06
# end date: 2016-07-07
#  Datos desde archivo
# Coefficients:
#  [-0.00248972]
# Independent term:
#  17.734608397121008
# Coefficients:
#  [0.00032046]
# Independent term:
#  16.615263761121835
# Coefficients:
#  [-0.00666985]
# Independent term:
#  17.764513454802017
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 52 de 2692 fecha 2016-07-07
# end date: 2016-07-08
#  Datos desde archivo
# Coefficients:
#  [-0.00248371]
# Independent term:
#  17.73384751607775
# Coefficients:
#  [0.00035444]
# Independent term:
#  16.613595839400787
# Coefficients:
#  [-0.00660976]
# Independent term:
#  17.76086773766549
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 53 de 2692 fecha 2016-07-08
# end date: 2016-07-09
# ..............Día sin sesión, next please
# end date: 2016-07-10
# ..............Día sin sesión, next please
# end date: 2016-07-11
#  Datos desde archivo
# Coefficients:
#  [-0.00245659]
# Independent term:
#  17.73040241582742
# Coefficients:
#  [0.00043348]
# Independent term:
#  16.61108129657916
# Coefficients:
#  [-0.00654946]
# Independent term:
#  17.757189484381204
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 56 de 2692 fecha 2016-07-11
# end date: 2016-07-12
#  Datos desde archivo
# Coefficients:
#  [-0.00242684]
# Independent term:
#  17.72661461578561
# Coefficients:
#  [0.00050214]
# Independent term:
#  16.61061227613421
# Coefficients:
#  [-0.00648887]
# Independent term:
#  17.753473327480478
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 57 de 2692 fecha 2016-07-12
# end date: 2016-07-13
#  Datos desde archivo
# Coefficients:
#  [-0.00239574]
# Independent term:
#  17.722644198793525
# Coefficients:
#  [0.0005187]
# Independent term:
#  16.617414509929826
# Coefficients:
#  [-0.00642796]
# Independent term:
#  17.74971731215202
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 58 de 2692 fecha 2016-07-13
# end date: 2016-07-14
#  Datos desde archivo
# Coefficients:
#  [-0.00236763]
# Independent term:
#  17.71904683548815
# Coefficients:
#  [0.00047553]
# Independent term:
#  16.631409277987125
# Coefficients:
#  [-0.00636689]
# Independent term:
#  17.74593079524057
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 59 de 2692 fecha 2016-07-14
# end date: 2016-07-15
#  Datos desde archivo
# Coefficients:
#  [-0.00233997]
# Independent term:
#  17.71549641563641
# Coefficients:
#  [0.00037745]
# Independent term:
#  16.652568244080044
# Coefficients:
#  [-0.00630569]
# Independent term:
#  17.742116241818493
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 60 de 2692 fecha 2016-07-15
# end date: 2016-07-16
# ..............Día sin sesión, next please
# end date: 2016-07-17
# ..............Día sin sesión, next please
# end date: 2016-07-18
#  Datos desde archivo
# Coefficients:
#  [-0.00229882]
# Independent term:
#  17.710202146068696
# Coefficients:
#  [0.00033988]
# Independent term:
#  16.669044377341198
# Coefficients:
#  [-0.00624383]
# Independent term:
#  17.73823993670932
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 63 de 2692 fecha 2016-07-18
# end date: 2016-07-19
#  Datos desde archivo
# Coefficients:
#  [-0.00226237]
# Independent term:
#  17.70549957470765
# Coefficients:
#  [0.00027565]
# Independent term:
#  16.687885051414145
# Coefficients:
#  [-0.00618155]
# Independent term:
#  17.73431615171235
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 64 de 2692 fecha 2016-07-19
# end date: 2016-07-20
#  Datos desde archivo
# Coefficients:
#  [-0.00222314]
# Independent term:
#  17.700425669169597
# Coefficients:
#  [0.00028784]
# Independent term:
#  16.6972846799822
# Coefficients:
#  [-0.00611876]
# Independent term:
#  17.730339400409996
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 65 de 2692 fecha 2016-07-20
# end date: 2016-07-21
#  Datos desde archivo
# Coefficients:
#  [-0.00219342]
# Independent term:
#  17.696572529547236
# Coefficients:
#  [0.00030435]
# Independent term:
#  16.703716763738377
# Coefficients:
#  [-0.00605588]
# Independent term:
#  17.726336197473046
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 66 de 2692 fecha 2016-07-21
# end date: 2016-07-22
#  Datos desde archivo
# Coefficients:
#  [-0.0021632]
# Independent term:
#  17.692643291539056
# Coefficients:
#  [0.00045258]
# Independent term:
#  16.692818272576403
# Coefficients:
#  [-0.00599292]
# Independent term:
#  17.7223063693963
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 67 de 2692 fecha 2016-07-22
# end date: 2016-07-23
# ..............Día sin sesión, next please
# end date: 2016-07-24
# ..............Día sin sesión, next please
# end date: 2016-07-25
#  Datos desde archivo
# Coefficients:
#  [-0.00212647]
# Independent term:
#  17.687856461893066
# Coefficients:
#  [0.00061069]
# Independent term:
#  16.682336181811433
# Coefficients:
#  [-0.00592962]
# Independent term:
#  17.718234189443557
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 70 de 2692 fecha 2016-07-25
# end date: 2016-07-26
#  Datos desde archivo
# Coefficients:
#  [-0.00209195]
# Independent term:
#  17.683346081619543
# Coefficients:
#  [0.00075222]
# Independent term:
#  16.673554097787658
# Coefficients:
#  [-0.0058661]
# Independent term:
#  17.714126906814016
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 71 de 2692 fecha 2016-07-26
# end date: 2016-07-27
#  Datos desde archivo
# Coefficients:
#  [-0.00206065]
# Independent term:
#  17.679246332126876
# Coefficients:
#  [0.00089867]
# Independent term:
#  16.66334440857617
# Coefficients:
#  [-0.00580252]
# Independent term:
#  17.709994201164115
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 72 de 2692 fecha 2016-07-27
# end date: 2016-07-28
#  Datos desde archivo
# Coefficients:
#  [-0.00204006]
# Independent term:
#  17.67654110828896
# Coefficients:
#  [0.00098053]
# Independent term:
#  16.658974633430365
# Coefficients:
#  [-0.00573932]
# Independent term:
#  17.705864885994348
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 73 de 2692 fecha 2016-07-28
# end date: 2016-07-29
#  Datos desde archivo
# Coefficients:
#  [-0.00200403]
# Independent term:
#  17.67179718724719
# Coefficients:
#  [0.00108777]
# Independent term:
#  16.655304128732254
# Coefficients:
#  [-0.00567588]
# Independent term:
#  17.701699269298786
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 74 de 2692 fecha 2016-07-29
# end date: 2016-07-30
# ..............Día sin sesión, next please
# end date: 2016-07-31
# ..............Día sin sesión, next please
# end date: 2016-08-01
#  Datos desde archivo
# Coefficients:
#  [-0.00196043]
# Independent term:
#  17.66604278163915
# Coefficients:
#  [0.00119674]
# Independent term:
#  16.653449269906798
# Coefficients:
#  [-0.00561194]
# Independent term:
#  17.697479037081386
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 77 de 2692 fecha 2016-08-01
# end date: 2016-08-02
#  Datos desde archivo
# Coefficients:
#  [-0.00193556]
# Independent term:
#  17.662750816500573
# Coefficients:
#  [0.00132032]
# Independent term:
#  16.644765666847796
# Coefficients:
#  [-0.00554296]
# Independent term:
#  17.687004277178566
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 78 de 2692 fecha 2016-08-02
# end date: 2016-08-03
#  Datos desde archivo
# Coefficients:
#  [-0.0019006]
# Independent term:
#  17.65811309037958
# Coefficients:
#  [0.00149554]
# Independent term:
#  16.631956338882446
# Coefficients:
#  [-0.00547293]
# Independent term:
#  17.676506287742782
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 79 de 2692 fecha 2016-08-03
# end date: 2016-08-04
#  Datos desde archivo
# Coefficients:
#  [-0.00185967]
# Independent term:
#  17.652669601598035
# Coefficients:
#  [0.00163293]
# Independent term:
#  16.625835837463836
# Coefficients:
#  [-0.00540222]
# Independent term:
#  17.6660518554017
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 80 de 2692 fecha 2016-08-04
# end date: 2016-08-05
#  Datos desde archivo
# Coefficients:
#  [-0.0018215]
# Independent term:
#  17.64758061496743
# Coefficients:
#  [0.00171049]
# Independent term:
#  16.62698171515963
# Coefficients:
#  [-0.00533145]
# Independent term:
#  17.655712849031133
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 81 de 2692 fecha 2016-08-05
# end date: 2016-08-06
# ..............Día sin sesión, next please
# end date: 2016-08-07
# ..............Día sin sesión, next please
# end date: 2016-08-08
#  Datos desde archivo
# Coefficients:
#  [-0.00178089]
# Independent term:
#  17.642151439459063
# Coefficients:
#  [0.00179016]
# Independent term:
#  16.628554098214675
# Coefficients:
#  [-0.00526059]
# Independent term:
#  17.645492363948385
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 84 de 2692 fecha 2016-08-08
# end date: 2016-08-09
#  Datos desde archivo
# Coefficients:
#  [-0.00172256]
# Independent term:
#  17.634335781953514
# Coefficients:
#  [0.00204149]
# Independent term:
#  16.612209342130974
# Coefficients:
#  [-0.00518793]
# Independent term:
#  17.635210940845724
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 85 de 2692 fecha 2016-08-09
# end date: 2016-08-10
#  Datos desde archivo
# Coefficients:
#  [-0.00166558]
# Independent term:
#  17.626681266387493
# Coefficients:
#  [0.00233585]
# Independent term:
#  16.589920901967517
# Coefficients:
#  [-0.00511307]
# Independent term:
#  17.62481004493649
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 86 de 2692 fecha 2016-08-10
# end date: 2016-08-11
#  Datos desde archivo
# Coefficients:
#  [-0.00159612]
# Independent term:
#  17.617327681859894
# Coefficients:
#  [0.00266637]
# Independent term:
#  16.56639589836348
# Coefficients:
#  [-0.00503566]
# Independent term:
#  17.614278560890988
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 87 de 2692 fecha 2016-08-11
# end date: 2016-08-12
#  Datos desde archivo
# Coefficients:
#  [-0.00152473]
# Independent term:
#  17.60769048418022
# Coefficients:
#  [0.00292802]
# Independent term:
#  16.55271231181586
# Coefficients:
#  [-0.00495642]
# Independent term:
#  17.603715712641485
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 88 de 2692 fecha 2016-08-12
# end date: 2016-08-13
# ..............Día sin sesión, next please
# end date: 2016-08-14
# ..............Día sin sesión, next please
# end date: 2016-08-15
#  Datos desde archivo
# Coefficients:
#  [-0.00143213]
# Independent term:
#  17.59515869065964
# Coefficients:
#  [0.00328227]
# Independent term:
#  16.532764540003306
# Coefficients:
#  [-0.00487444]
# Independent term:
#  17.593059482067968
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 91 de 2692 fecha 2016-08-15
# end date: 2016-08-16
#  Datos desde archivo
# Coefficients:
#  [-0.00134665]
# Independent term:
#  17.583561281680463
# Coefficients:
#  [0.00357564]
# Independent term:
#  16.519124226925978
# Coefficients:
#  [-0.00479036]
# Independent term:
#  17.582373559131234
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 92 de 2692 fecha 2016-08-16
# end date: 2016-08-17
#  Datos desde archivo
# Coefficients:
#  [-0.00126468]
# Independent term:
#  17.572412925388797
# Coefficients:
#  [0.00383014]
# Independent term:
#  16.509838404157268
# Coefficients:
#  [-0.00470459]
# Independent term:
#  17.571701567539456
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 93 de 2692 fecha 2016-08-17
# end date: 2016-08-18
#  Datos desde archivo
# Coefficients:
#  [-0.00116888]
# Independent term:
#  17.559352498573435
# Coefficients:
#  [0.00404453]
# Independent term:
#  16.50991936925632
# Coefficients:
#  [-0.00461753]
# Independent term:
#  17.561136570541613
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 94 de 2692 fecha 2016-08-18
# end date: 2016-08-19
#  Datos desde archivo
# Coefficients:
#  [-0.00107363]
# Independent term:
#  17.546335813639857
# Coefficients:
#  [0.00426829]
# Independent term:
#  16.50876787171435
# Coefficients:
#  [-0.00452911]
# Independent term:
#  17.550665240205028
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 95 de 2692 fecha 2016-08-19
# end date: 2016-08-20
# ..............Día sin sesión, next please
# end date: 2016-08-21
# ..............Día sin sesión, next please
# end date: 2016-08-22
#  Datos desde archivo
# Coefficients:
#  [-0.00099412]
# Independent term:
#  17.535441952947775
# Coefficients:
#  [0.00445354]
# Independent term:
#  16.50843540035077
# Coefficients:
#  [-0.00443973]
# Independent term:
#  17.540294794037322
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 98 de 2692 fecha 2016-08-22
# end date: 2016-08-23
#  Datos desde archivo
# Coefficients:
#  [-0.00091082]
# Independent term:
#  17.524002885726894
# Coefficients:
#  [0.00461506]
# Independent term:
#  16.512464133732355
# Coefficients:
#  [-0.00434964]
# Independent term:
#  17.53006762328802
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 99 de 2692 fecha 2016-08-23
# end date: 2016-08-24
#  Datos desde archivo
# Coefficients:
#  [-0.00083313]
# Independent term:
#  17.513306713601413
# Coefficients:
#  [0.00507187]
# Independent term:
#  16.475848842592384
# Coefficients:
#  [-0.00425589]
# Independent term:
#  17.519577884176623
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 100 de 2692 fecha 2016-08-24
# end date: 2016-08-25
#  Datos desde archivo
# Coefficients:
#  [-0.00074562]
# Independent term:
#  17.501231039203724
# Coefficients:
#  [0.00551425]
# Independent term:
#  16.44419435486865
# Coefficients:
#  [-0.00415868]
# Independent term:
#  17.508877550551667
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 101 de 2692 fecha 2016-08-25
# end date: 2016-08-26
#  Datos desde archivo
# Coefficients:
#  [-0.00065762]
# Independent term:
#  17.48905789968817
# Coefficients:
#  [0.00596039]
# Independent term:
#  16.412416367174977
# Coefficients:
#  [-0.00405799]
# Independent term:
#  17.497967489025534
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 102 de 2692 fecha 2016-08-26
# end date: 2016-08-27
# ..............Día sin sesión, next please
# end date: 2016-08-28
# ..............Día sin sesión, next please
# end date: 2016-08-29
#  Datos desde archivo
# Coefficients:
#  [-0.00056418]
# Independent term:
#  17.476100289743076
# Coefficients:
#  [0.00636966]
# Independent term:
#  16.387343986995184
# Coefficients:
#  [-0.00395423]
# Independent term:
#  17.48691650890583
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 105 de 2692 fecha 2016-08-29
# end date: 2016-08-30
#  Datos desde archivo
# Coefficients:
#  [-0.00047273]
# Independent term:
#  17.46338874541815
# Coefficients:
#  [0.00671962]
# Independent term:
#  16.36978578524803
# Coefficients:
#  [-0.00384802]
# Independent term:
#  17.47580078031222
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 106 de 2692 fecha 2016-08-30
# end date: 2016-08-31
#  Datos desde archivo
# Coefficients:
#  [-0.00038265]
# Independent term:
#  17.45083746939759
# Coefficients:
#  [0.00703802]
# Independent term:
#  16.356217488388516
# Coefficients:
#  [-0.0037397]
# Independent term:
#  17.464660648054274
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 107 de 2692 fecha 2016-08-31
# end date: 2016-09-01
#  Datos desde archivo
# Coefficients:
#  [-0.00029392]
# Independent term:
#  17.438444612279337
# Coefficients:
#  [0.00745199]
# Independent term:
#  16.329764521157564
# Coefficients:
#  [-0.00362834]
# Independent term:
#  17.453368149279186
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 108 de 2692 fecha 2016-09-01
# end date: 2016-09-02
#  Datos desde archivo
# Coefficients:
#  [-0.00019567]
# Independent term:
#  17.424690751739963
# Coefficients:
#  [0.00795717]
# Independent term:
#  16.29424922217184
# Coefficients:
#  [-0.00351307]
# Independent term:
#  17.441834627616426
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 109 de 2692 fecha 2016-09-02
# end date: 2016-09-03
# ..............Día sin sesión, next please
# end date: 2016-09-04
# ..............Día sin sesión, next please
# end date: 2016-09-05
# ..............Día sin sesión, next please
# end date: 2016-09-06
#  Datos desde archivo
# Coefficients:
#  [-9.68062096e-05]
# Independent term:
#  17.410816170411135
# Coefficients:
#  [0.00848723]
# Independent term:
#  16.255883158641076
# Coefficients:
#  [-0.00339366]
# Independent term:
#  17.43003411548732
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 113 de 2692 fecha 2016-09-06
# end date: 2016-09-07
#  Datos desde archivo
# Coefficients:
#  [2.00508259e-06]
# Independent term:
#  17.396916715312877
# Coefficients:
#  [0.00908453]
# Independent term:
#  16.20885219018851
# Coefficients:
#  [-0.0032695]
# Independent term:
#  17.417883051554
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 114 de 2692 fecha 2016-09-07
# end date: 2016-09-08
#  Datos desde archivo
# Coefficients:
#  [9.94278746e-05]
# Independent term:
#  17.38318010164275
# Coefficients:
#  [0.00967772]
# Independent term:
#  16.162241381602502
# Coefficients:
#  [-0.00314067]
# Independent term:
#  17.40538910458931
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 115 de 2692 fecha 2016-09-08
# end date: 2016-09-09
#  Datos desde archivo
# Coefficients:
#  [0.00018237]
# Independent term:
#  17.3714575811609
# Coefficients:
#  [0.01030398]
# Independent term:
#  16.107166742780315
# Coefficients:
#  [-0.00300689]
# Independent term:
#  17.392471469148422
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 116 de 2692 fecha 2016-09-09
# end date: 2016-09-10
# ..............Día sin sesión, next please
# end date: 2016-09-11
# ..............Día sin sesión, next please
# end date: 2016-09-12
#  Datos desde archivo
# Coefficients:
#  [0.0002735]
# Independent term:
#  17.358547060479584
# Coefficients:
#  [0.01099735]
# Independent term:
#  16.045950692162585
# Coefficients:
#  [-0.00286755]
# Independent term:
#  17.379073252462
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 119 de 2692 fecha 2016-09-12
# end date: 2016-09-13
#  Datos desde archivo
# Coefficients:
#  [0.00036197]
# Independent term:
#  17.345985207134785
# Coefficients:
#  [0.01164738]
# Independent term:
#  15.989985374194472
# Coefficients:
#  [-0.00272312]
# Independent term:
#  17.365251482528993
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 120 de 2692 fecha 2016-09-13
# end date: 2016-09-14
#  Datos desde archivo
# Coefficients:
#  [0.0004687]
# Independent term:
#  17.33079314481833
# Coefficients:
#  [0.01235571]
# Independent term:
#  15.932169708849777
# Coefficients:
#  [-0.00257308]
# Independent term:
#  17.350991962392882
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 121 de 2692 fecha 2016-09-14
# end date: 2016-09-15
#  Datos desde archivo
# Coefficients:
#  [0.00058446]
# Independent term:
#  17.314278051812398
# Coefficients:
#  [0.01312834]
# Independent term:
#  15.868930545209059
# Coefficients:
#  [-0.00241685]
# Independent term:
#  17.336245082619907
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 122 de 2692 fecha 2016-09-15
# end date: 2016-09-16
#  Datos desde archivo
# Coefficients:
#  [0.00070343]
# Independent term:
#  17.297265224003183
# Coefficients:
#  [0.01394866]
# Independent term:
#  15.80072083103123
# Coefficients:
#  [-0.00225401]
# Independent term:
#  17.320966234345395
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 123 de 2692 fecha 2016-09-16
# end date: 2016-09-17
# ..............Día sin sesión, next please
# end date: 2016-09-18
# ..............Día sin sesión, next please
# end date: 2016-09-19
#  Datos desde archivo
# Coefficients:
#  [0.00079668]
# Independent term:
#  17.283899884698695
# Coefficients:
#  [0.01469146]
# Independent term:
#  15.735199566314469
# Coefficients:
#  [-0.0020854]
# Independent term:
#  17.305187461529172
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 126 de 2692 fecha 2016-09-19
# end date: 2016-09-20
#  Datos desde archivo
# Coefficients:
#  [0.00088694]
# Independent term:
#  17.270932710799645
# Coefficients:
#  [0.01542014]
# Independent term:
#  15.670945828992927
# Coefficients:
#  [-0.00191121]
# Independent term:
#  17.288926350757663
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 127 de 2692 fecha 2016-09-20
# end date: 2016-09-21
#  Datos desde archivo
# Coefficients:
#  [0.00099142]
# Independent term:
#  17.255887322340218
# Coefficients:
#  [0.01618067]
# Independent term:
#  15.607236150343025
# Coefficients:
#  [-0.00173119]
# Independent term:
#  17.272193114932644
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 128 de 2692 fecha 2016-09-21
# end date: 2016-09-22
#  Datos desde archivo
# Coefficients:
#  [0.00110677]
# Independent term:
#  17.239237910816467
# Coefficients:
#  [0.01699657]
# Independent term:
#  15.539941736050507
# Coefficients:
#  [-0.00154485]
# Independent term:
#  17.254956782804467
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 129 de 2692 fecha 2016-09-22
# end date: 2016-09-23
#  Datos desde archivo
# Coefficients:
#  [0.00122358]
# Independent term:
#  17.2223395118912
# Coefficients:
#  [0.01778441]
# Independent term:
#  15.47720144912378
# Coefficients:
#  [-0.00135252]
# Independent term:
#  17.237267675006652
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 130 de 2692 fecha 2016-09-23
# end date: 2016-09-24
# ..............Día sin sesión, next please
# end date: 2016-09-25
# ..............Día sin sesión, next please
# end date: 2016-09-26
#  Datos desde archivo
# Coefficients:
#  [0.00133382]
# Independent term:
#  17.20635511768951
# Coefficients:
#  [0.01849279]
# Independent term:
#  15.423279834149486
# Coefficients:
#  [-0.00115505]
# Independent term:
#  17.219218044749365
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 133 de 2692 fecha 2016-09-26
# end date: 2016-09-27
#  Datos desde archivo
# Coefficients:
#  [0.00145211]
# Independent term:
#  17.189163976345476
# Coefficients:
#  [0.0191916]
# Independent term:
#  15.373523491105034
# Coefficients:
#  [-0.0009526]
# Independent term:
#  17.200852924812608
#   Instrumento  long_short_out       date  precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10     123        NaN       NaN
# ................................................Analizando, muestra 134 de 2692 fecha 2016-09-27
# ...
# ..............Día sin sesión, next please
# end date: 2023-01-19
# ..............Día sin sesión, next please
# end date: 2023-01-20
# ..............Día sin sesión, next please
# end date: 2023-01-21
# ..............Día sin sesión, next please
# end date: 2023-01-22
# ..............Día sin sesión, next please
# end date: 2023-01-23
# ..............Día sin sesión, next please
# end date: 2023-01-24
# ..............Día sin sesión, next please
# end date: 2023-01-25
# ..............Día sin sesión, next please
# end date: 2023-01-26
# ..............Día sin sesión, next please
# end date: 2023-01-27
# ..............Día sin sesión, next please
# end date: 2023-01-28
# ..............Día sin sesión, next please
# end date: 2023-01-29
# ..............Día sin sesión, next please
# end date: 2023-01-30
# ..............Día sin sesión, next please
# end date: 2023-01-31
# ..............Día sin sesión, next please
# end date: 2023-02-01
# ..............Día sin sesión, next please
# end date: 2023-02-02
# ..............Día sin sesión, next please
# end date: 2023-02-03
# ..............Día sin sesión, next please
# end date: 2023-02-04
# ..............Día sin sesión, next please
# end date: 2023-02-05
# ..............Día sin sesión, next please
# end date: 2023-02-06
# ..............Día sin sesión, next please
# end date: 2023-02-07
# ..............Día sin sesión, next please
# end date: 2023-02-08
# ..............Día sin sesión, next please
# end date: 2023-02-09
# ..............Día sin sesión, next please
# end date: 2023-02-10
# ..............Día sin sesión, next please
# end date: 2023-02-11
# ..............Día sin sesión, next please
# end date: 2023-02-12
# ..............Día sin sesión, next please
# end date: 2023-02-13
# ..............Día sin sesión, next please
# end date: 2023-02-14
# ..............Día sin sesión, next please
# end date: 2023-02-15
# ..............Día sin sesión, next please
# end date: 2023-02-16
# ..............Día sin sesión, next please
# end date: 2023-02-17
# ..............Día sin sesión, next please
# end date: 2023-02-18
# ..............Día sin sesión, next please
# end date: 2023-02-19
# ..............Día sin sesión, next please
# end date: 2023-02-20
# ..............Día sin sesión, next please
# end date: 2023-02-21
# ..............Día sin sesión, next please
# end date: 2023-02-22
# ..............Día sin sesión, next please
# end date: 2023-02-23
# ..............Día sin sesión, next please
# end date: 2023-02-24
# ..............Día sin sesión, next please
# end date: 2023-02-25
# ..............Día sin sesión, next please
# end date: 2023-02-26
# ..............Día sin sesión, next please
# end date: 2023-02-27
# ..............Día sin sesión, next please
# end date: 2023-02-28
# ..............Día sin sesión, next please
# end date: 2023-03-01
# ..............Día sin sesión, next please
# end date: 2023-03-02
# ..............Día sin sesión, next please
# end date: 2023-03-03
# ..............Día sin sesión, next please
# end date: 2023-03-04
# ..............Día sin sesión, next please
# end date: 2023-03-05
# ..............Día sin sesión, next please
# end date: 2023-03-06
# ..............Día sin sesión, next please
# end date: 2023-03-07
# ..............Día sin sesión, next please
# end date: 2023-03-08
# ..............Día sin sesión, next please
# end date: 2023-03-09
# ..............Día sin sesión, next please
# end date: 2023-03-10
# ..............Día sin sesión, next please
# end date: 2023-03-11
# ..............Día sin sesión, next please
# end date: 2023-03-12
# ..............Día sin sesión, next please
# end date: 2023-03-13
# ..............Día sin sesión, next please
# end date: 2023-03-14
# ..............Día sin sesión, next please
# end date: 2023-03-15
# ..............Día sin sesión, next please
# end date: 2023-03-16
# ..............Día sin sesión, next please
# end date: 2023-03-17
# ..............Día sin sesión, next please
# end date: 2023-03-18
# ..............Día sin sesión, next please
# end date: 2023-03-19
# ..............Día sin sesión, next please
# end date: 2023-03-20
# ..............Día sin sesión, next please
# end date: 2023-03-21
# ..............Día sin sesión, next please
# end date: 2023-03-22
# ..............Día sin sesión, next please
# end date: 2023-03-23
# ..............Día sin sesión, next please
# end date: 2023-03-24
# ..............Día sin sesión, next please
# end date: 2023-03-25
# ..............Día sin sesión, next please
# end date: 2023-03-26
# ..............Día sin sesión, next please
# end date: 2023-03-27
# ..............Día sin sesión, next please
# end date: 2023-03-28
# ..............Día sin sesión, next please
# end date: 2023-03-29
# ..............Día sin sesión, next please
# end date: 2023-03-30
# ..............Día sin sesión, next please
# end date: 2023-03-31
# ..............Día sin sesión, next please
# end date: 2023-04-01
# ..............Día sin sesión, next please
# end date: 2023-04-02
# ..............Día sin sesión, next please
# end date: 2023-04-03
# ..............Día sin sesión, next please
# end date: 2023-04-04
# ..............Día sin sesión, next please
# end date: 2023-04-05
# ..............Día sin sesión, next please
# end date: 2023-04-06
# ..............Día sin sesión, next please
# end date: 2023-04-07
# ..............Día sin sesión, next please
# end date: 2023-04-08
# ..............Día sin sesión, next please
# end date: 2023-04-09
# ..............Día sin sesión, next please
# end date: 2023-04-10
# ..............Día sin sesión, next please
# end date: 2023-04-11
# ..............Día sin sesión, next please
# end date: 2023-04-12
# ..............Día sin sesión, next please
# end date: 2023-04-13
# ..............Día sin sesión, next please
# end date: 2023-04-14
# ..............Día sin sesión, next please
# end date: 2023-04-15
# ..............Día sin sesión, next please
# end date: 2023-04-16
# ..............Día sin sesión, next please
# end date: 2023-04-17
# ..............Día sin sesión, next please
# end date: 2023-04-18
# ..............Día sin sesión, next please
# end date: 2023-04-19
# ..............Día sin sesión, next please
# end date: 2023-04-20
# ..............Día sin sesión, next please
# end date: 2023-04-21
# ..............Día sin sesión, next please
# end date: 2023-04-22
# ..............Día sin sesión, next please
# end date: 2023-04-23
# ..............Día sin sesión, next please
# end date: 2023-04-24
# ..............Día sin sesión, next please
# end date: 2023-04-25
# ..............Día sin sesión, next please
# end date: 2023-04-26
# ..............Día sin sesión, next please
# end date: 2023-04-27
# ..............Día sin sesión, next please
# end date: 2023-04-28
# ..............Día sin sesión, next please
# end date: 2023-04-29
# ..............Día sin sesión, next please
# end date: 2023-04-30
# ..............Día sin sesión, next please
# end date: 2023-05-01
# ..............Día sin sesión, next please
# end date: 2023-05-02
# ..............Día sin sesión, next please
# end date: 2023-05-03
# ..............Día sin sesión, next please
# end date: 2023-05-04
# ..............Día sin sesión, next please
# end date: 2023-05-05
# ..............Día sin sesión, next please
# end date: 2023-05-06
# ..............Día sin sesión, next please
# end date: 2023-05-07
# ..............Día sin sesión, next please
# end date: 2023-05-08
# ..............Día sin sesión, next please
# end date: 2023-05-09
# ..............Día sin sesión, next please
# end date: 2023-05-10
# ..............Día sin sesión, next please
# end date: 2023-05-11
# ..............Día sin sesión, next please
# end date: 2023-05-12
# ..............Día sin sesión, next please
# end date: 2023-05-13
# ..............Día sin sesión, next please
# end date: 2023-05-14
# ..............Día sin sesión, next please
# end date: 2023-05-15
# ..............Día sin sesión, next please
# end date: 2023-05-16
# ..............Día sin sesión, next please
# end date: 2023-05-17
# ..............Día sin sesión, next please
# end date: 2023-05-18
# ..............Día sin sesión, next please
# end date: 2023-05-19
# ..............Día sin sesión, next please
# end date: 2023-05-20
# ..............Día sin sesión, next please
# end date: 2023-05-21
# ..............Día sin sesión, next please
# end date: 2023-05-22
# ..............Día sin sesión, next please
# end date: 2023-05-23
# ..............Día sin sesión, next please
# end date: 2023-05-24
# ..............Día sin sesión, next please
# end date: 2023-05-25
# ..............Día sin sesión, next please
# end date: 2023-05-26
# ..............Día sin sesión, next please
# end date: 2023-05-27
# ..............Día sin sesión, next please
# end date: 2023-05-28
# ..............Día sin sesión, next please
# end date: 2023-05-29
# ..............Día sin sesión, next please
# end date: 2023-05-30
# ..............Día sin sesión, next please
# end date: 2023-05-31
# ..............Día sin sesión, next please
# end date: 2023-06-01
# ..............Día sin sesión, next please
# end date: 2023-06-02
# ..............Día sin sesión, next please
# end date: 2023-06-03
# ..............Día sin sesión, next please
# end date: 2023-06-04
# ..............Día sin sesión, next please
# end date: 2023-06-05
# ..............Día sin sesión, next please
# end date: 2023-06-06
# ..............Día sin sesión, next please
# end date: 2023-06-07
# ..............Día sin sesión, next please
# end date: 2023-06-08
# ..............Día sin sesión, next please
# end date: 2023-06-09
# ..............Día sin sesión, next please
# end date: 2023-06-10
# ..............Día sin sesión, next please
# end date: 2023-06-11
# ..............Día sin sesión, next please
# end date: 2023-06-12
# ..............Día sin sesión, next please
# end date: 2023-06-13
# ..............Día sin sesión, next please
# end date: 2023-06-14
# ..............Día sin sesión, next please
# end date: 2023-06-15
# ..............Día sin sesión, next please
# end date: 2023-06-16
# ..............Día sin sesión, next please
# end date: 2023-06-17
# ..............Día sin sesión, next please
# end date: 2023-06-18
# ..............Día sin sesión, next please
# end date: 2023-06-19
# ..............Día sin sesión, next please
# end date: 2023-06-20
# ..............Día sin sesión, next please
# end date: 2023-06-21
# ..............Día sin sesión, next please
# end date: 2023-06-22
# ..............Día sin sesión, next please
# end date: 2023-06-23
# ..............Día sin sesión, next please
# end date: 2023-06-24
# ..............Día sin sesión, next please
# end date: 2023-06-25
# ..............Día sin sesión, next please
# end date: 2023-06-26
# ..............Día sin sesión, next please
# end date: 2023-06-27
# ..............Día sin sesión, next please
# end date: 2023-06-28
# ..............Día sin sesión, next please
# end date: 2023-06-29
# ..............Día sin sesión, next please
# end date: 2023-06-30
# ..............Día sin sesión, next please
# end date: 2023-07-01
# ..............Día sin sesión, next please
# end date: 2023-07-02
# ..............Día sin sesión, next please
# end date: 2023-07-03
# ..............Día sin sesión, next please
# end date: 2023-07-04
# ..............Día sin sesión, next please
# end date: 2023-07-05
# ..............Día sin sesión, next please
# end date: 2023-07-06
# ..............Día sin sesión, next please
# end date: 2023-07-07
# ..............Día sin sesión, next please
# end date: 2023-07-08
# ..............Día sin sesión, next please
# end date: 2023-07-09
# ..............Día sin sesión, next please
# end date: 2023-07-10
# ..............Día sin sesión, next please
# end date: 2023-07-11
# ..............Día sin sesión, next please
# end date: 2023-07-12
# ..............Día sin sesión, next please
# end date: 2023-07-13
# ..............Día sin sesión, next please
# end date: 2023-07-14
# ..............Día sin sesión, next please
# end date: 2023-07-15
# ..............Día sin sesión, next please
# end date: 2023-07-16
# ..............Día sin sesión, next please
# end date: 2023-07-17
# ..............Día sin sesión, next please
# end date: 2023-07-18
# ..............Día sin sesión, next please
# end date: 2023-07-19
# ..............Día sin sesión, next please
# end date: 2023-07-20
# ..............Día sin sesión, next please
# end date: 2023-07-21
# ..............Día sin sesión, next please
# end date: 2023-07-22
# ..............Día sin sesión, next please
# end date: 2023-07-23
# ..............Día sin sesión, next please
# end date: 2023-07-24
# ..............Día sin sesión, next please
# end date: 2023-07-25
# ..............Día sin sesión, next please
# end date: 2023-07-26
# ..............Día sin sesión, next please
# end date: 2023-07-27
# ..............Día sin sesión, next please
# end date: 2023-07-28
# ..............Día sin sesión, next please
# end date: 2023-07-29
# ..............Día sin sesión, next please
# end date: 2023-07-30
# ..............Día sin sesión, next please
# end date: 2023-07-31
# ..............Día sin sesión, next please
# end date: 2023-08-01
# ..............Día sin sesión, next please
# end date: 2023-08-02
# ..............Día sin sesión, next please
# end date: 2023-08-03
# ..............Día sin sesión, next please
# end date: 2023-08-04
# ..............Día sin sesión, next please
# end date: 2023-08-05
# ..............Día sin sesión, next please
# end date: 2023-08-06
# ..............Día sin sesión, next please
# end date: 2023-08-07
# ..............Día sin sesión, next please
# end date: 2023-08-08
# ..............Día sin sesión, next please
# end date: 2023-08-09
# ..............Día sin sesión, next please
# end date: 2023-08-10
# ..............Día sin sesión, next please
# end date: 2023-08-11
# ..............Día sin sesión, next please
# end date: 2023-08-12
# ..............Día sin sesión, next please
# end date: 2023-08-13
# ..............Día sin sesión, next please
# end date: 2023-08-14
# ..............Día sin sesión, next please
# end date: 2023-08-15
# ..............Día sin sesión, next please
# end date: 2023-08-16
# ..............Día sin sesión, next please
# end date: 2023-08-17
# ..............Día sin sesión, next please
# end date: 2023-08-18
# ..............Día sin sesión, next please
# end date: 2023-08-19
# ..............Día sin sesión, next please
# end date: 2023-08-20
# ..............Día sin sesión, next please
# end date: 2023-08-21
# ..............Día sin sesión, next please
# end date: 2023-08-22
# ..............Día sin sesión, next please
# end date: 2023-08-23
# ..............Día sin sesión, next please
# end date: 2023-08-24
# ..............Día sin sesión, next please
# end date: 2023-08-25
# ..............Día sin sesión, next please
# end date: 2023-08-26
# ..............Día sin sesión, next please
# end date: 2023-08-27
# ..............Día sin sesión, next please
# end date: 2023-08-28
# ..............Día sin sesión, next please
# end date: 2023-08-29
# ..............Día sin sesión, next please
# end date: 2023-08-30
# ..............Día sin sesión, next please
# end date: 2023-08-31
# ..............Día sin sesión, next please
# end date: 2023-09-01
# ..............Día sin sesión, next please
# end date: 2023-09-02
# ..............Día sin sesión, next please
# end date: 2023-09-03
# ..............Día sin sesión, next please
# end date: 2023-09-04
# ..............Día sin sesión, next please
# end date: 2023-09-05
# ..............Día sin sesión, next please
# end date: 2023-09-06
# ..............Día sin sesión, next please
# end date: 2023-09-07
# ..............Día sin sesión, next please
# end date: 2023-09-08
# ..............Día sin sesión, next please
# end date: 2023-09-09
# ..............Día sin sesión, next please
# end date: 2023-09-10
# ..............Día sin sesión, next please
# end date: 2023-09-11
# ..............Día sin sesión, next please
# end date: 2023-09-12
# ..............Día sin sesión, next please
# end date: 2023-09-13
# ..............Día sin sesión, next please
# end date: 2023-09-14
# ..............Día sin sesión, next please
# end date: 2023-09-15
# ..............Día sin sesión, next please
# end date: 2023-09-16
# ..............Día sin sesión, next please
# end date: 2023-09-17
# ..............Día sin sesión, next please
# end date: 2023-09-18
# ..............Día sin sesión, next please
# end date: 2023-09-19
# ..............Día sin sesión, next please
# end date: 2023-09-20
# ..............Día sin sesión, next please
# end date: 2023-09-21
# ..............Día sin sesión, next please
# end date: 2023-09-22
# ..............Día sin sesión, next please
# end date: 2023-09-23
# ..............Día sin sesión, next please
# end date: 2023-09-24
# ..............Día sin sesión, next please
# end date: 2023-09-25
# ..............Día sin sesión, next please
# end date: 2023-09-26
# ..............Día sin sesión, next please
# end date: 2023-09-27
# ..............Día sin sesión, next please
# end date: 2023-09-28
# ..............Día sin sesión, next please

# %% [markdown]
# ***Recogemos los datos de las entradas que ha realizado la Estrategia***

# %%
data=rg.StrategyClass.dfLog
#data.dropna(inplace=True)

# %%
data.tail()
# Out:
#                   Date Senal       Price Objetivo ExitReason  Beneficio
# 2022-05-10  2022-05-10     0  105.110001      NaN        NaN        NaN
# 2022-05-11  2022-05-11     0  102.910004      NaN        NaN        NaN
# 2022-05-12  2022-05-12     0  101.669998      NaN        NaN        NaN
# 2022-05-13  2022-05-13     0  108.650002      NaN        NaN        NaN
# 2022-05-16  2022-05-16     0       105.0      NaN        NaN        NaN

# %%
data['Senal'].plot(title = 'Señales de compra de la estrategia ' )
# Ploteando una parte
#data.loc['2010':'2022','Senal'].plot(title = 'Señales Regresión a la media ' +instrumento,xlim=('2010','2022'))
# Out:
# <AxesSubplot:title={'center':'Señales de compra de la estrategia '}>

# %%
tiempo_final = time() 
 
tiempo_ejecucion = (tiempo_final - tiempo_inicial)/60
 
print ('El tiempo de ejecucion fue:',tiempo_ejecucion,"minutos") #En segundos
# Out:
# El tiempo de ejecucion fue: 11.170028845469156 minutos

# %%
data.loc['2011-01-04':'2019-11-04']
# Out:
#                   Date Senal      Price Objetivo ExitReason  Beneficio
# 2016-05-16  2016-05-16     0  17.002501      NaN        NaN        NaN
# 2016-05-17  2016-05-17     0     16.725      NaN        NaN        NaN
# 2016-05-18  2016-05-18     0    17.0075      NaN        NaN        NaN
# 2016-05-19  2016-05-19     0  17.049999      NaN        NaN        NaN
# 2016-05-20  2016-05-20     0  17.530001      NaN        NaN        NaN
# ...                ...   ...        ...      ...        ...        ...
# 2019-10-29  2019-10-29     0  61.490002      NaN        NaN        NaN
# 2019-10-30  2019-10-30     0  61.567501      NaN        NaN        NaN
# 2019-10-31  2019-10-31     0  61.142502      NaN        NaN        NaN
# 2019-11-01  2019-11-01     0  46.325001      NaN        NaN        NaN
# 2019-11-04  2019-11-04     0  47.817501      NaN        NaN        NaN
#
# [875 rows x 6 columns]

# %%
#Guardamos el resultado del analisis en un pickle
#dff.to_pickle("./primerBack_IBE.pkl")

# %% [markdown]
# ***3.- Ingeniería de datos para calcular la bondad de la estrategia***

# %%
data['Dif_Close'] = data.Price.pct_change()
data['Retornos'] = data.Dif_Close * data.Senal.shift(1)   
data['Capital'] = (data.Retornos + 1).cumprod() * 100
    
rg.StrategyClass.dfLog=data  #Ojo a esta liena, no me cuadra.

#quant_j.salvarExcel(StrategyClass.dfLog, "log"+instrumento)   
#data.to_pickle('almacen')    #df = pd.read_pickle(file_name)

# %% [markdown]
# >Para calcular los retornos del sistema, calculamos la diferencia relativativa entre el precio de cierre y el del día anterior. Para posteriormente multiplicarlo por la señal que del día anterior que nos indicaba la posición a tomar (si estaba comprado, sumo beneficio).

# %%
data.tail()
# Out:
#                   Date Senal       Price Objetivo ExitReason  Beneficio  \
# 2022-05-10  2022-05-10     0  105.110001      NaN        NaN        NaN
# 2022-05-11  2022-05-11     0  102.910004      NaN        NaN        NaN
# 2022-05-12  2022-05-12     0  101.669998      NaN        NaN        NaN
# 2022-05-13  2022-05-13     0  108.650002      NaN        NaN        NaN
# 2022-05-16  2022-05-16     0       105.0      NaN        NaN        NaN
#
#             Dif_Close Retornos     Capital
# 2022-05-10   0.025664      0.0  185.539904
# 2022-05-11  -0.020930     -0.0  185.539904
# 2022-05-12  -0.012049     -0.0  185.539904
# 2022-05-13   0.068654      0.0  185.539904
# 2022-05-16  -0.033594     -0.0  185.539904

# %%
data[60:]
# Out:
#                   Date Senal       Price Objetivo ExitReason  Beneficio  \
# 2016-08-10  2016-08-10     0        18.5      NaN        NaN        NaN
# 2016-08-11  2016-08-11     0      18.865      NaN        NaN        NaN
# 2016-08-12  2016-08-12     0      18.945      NaN        NaN        NaN
# 2016-08-15  2016-08-15     0     19.5625      NaN        NaN        NaN
# 2016-08-16  2016-08-16     0        19.4      NaN        NaN        NaN
# ...                ...   ...         ...      ...        ...        ...
# 2022-05-10  2022-05-10     0  105.110001      NaN        NaN        NaN
# 2022-05-11  2022-05-11     0  102.910004      NaN        NaN        NaN
# 2022-05-12  2022-05-12     0  101.669998      NaN        NaN        NaN
# 2022-05-13  2022-05-13     0  108.650002      NaN        NaN        NaN
# 2022-05-16  2022-05-16     0       105.0      NaN        NaN        NaN
#
#             Dif_Close Retornos     Capital
# 2016-08-10  -0.000810     -0.0       100.0
# 2016-08-11   0.019730      0.0       100.0
# 2016-08-12   0.004241      0.0       100.0
# 2016-08-15   0.032594      0.0       100.0
# 2016-08-16  -0.008307     -0.0       100.0
# ...               ...      ...         ...
# 2022-05-10   0.025664      0.0  185.539904
# 2022-05-11  -0.020930     -0.0  185.539904
# 2022-05-12  -0.012049     -0.0  185.539904
# 2022-05-13   0.068654      0.0  185.539904
# 2022-05-16  -0.033594     -0.0  185.539904
#
# [1452 rows x 9 columns]

# %% [markdown]
# >El capital, por comodidad, lo calcularemos en base 100, es decir como si iniciaramos la inversión con 100 unidades monetarias. Para su calculo arrastramos el producto acumulado de los retornos mas 1, multiplicados como dijimos por 100.

# %% [markdown]
# Pero para observar gráficamente la evolución del sistema necesitamos un gráfico con mas información. Para ello definimos una función que nos mostrará un gráfico con la evolución de nuestra estrategia, comparandola con la del activo. En un subgráfico se visualizará el drawdown del sistema, comparado de nuevo con el del activo. Y por útlimo las posiciones que toma el sistema.

# %%
def grafico (df):
    estudio = df.copy()
    
    DD_bh, maxDD, maxDD_ini, maxDD_fin = analisis.DrawDown(estudio.Dif_Close[60:], info = False) 
    
    DD, maxDD, maxDD_ini, maxDD_fin = analisis.DrawDown(estudio.Retornos.fillna(0), info = False) 

    fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True, figsize=(18, 12), gridspec_kw = {'height_ratios':[3, 1, 1]})
    fig.suptitle('Estrategia vs B & H', fontsize=20)

    #Primer plot analiza la evolcuion de una inversion de 100€ en buy&hold y la estrategia)
    ax1.plot(estudio.Capital)
    ax1.plot((estudio.Price) * (100/estudio.Price[1]))
    ax1.set_title('Capital')
    ax1.legend(['Estrategia','Buy & Hold'])

    ax2.plot(DD*100, c='0.5')
    ax2.plot(DD_bh*100, c='y')
    ax2.fill_between(DD.index, 0, DD*100, color='0.7')
    ax2.set_title('Drawdown')
    ax2.legend(['Estrategia','Buy & Hold'])

    ax3.plot(estudio.Senal, c='orange')
    #ax3.fill_between(estudio.index, 0, estudio.Senal*100, color='orange')
    ax3.set_title('Posición')

    plt.show()
    return

# %%
print(instrumento)
# Out:
# anet

# %%
grafico(data)

# %% [markdown]
# ---

# %%
#data[55:70]

# %% [markdown]
# ---

# %% [markdown]
# # ANALISIS DEL SISTEMA

# %%
Beneficio_Bruto = data.Capital[-1] - data.Capital[1]
print ('Beneficio Bruto : {:.2f} €  con una inverison de 100€'.format(Beneficio_Bruto))
# Out:
# Beneficio Bruto : 85.54 €  con una inverison de 100€

# %%
#Rentabilidad anual compuesta. Calculamos lo que la inversion se ha incrementado cada año con el interes compuesto
CAGR = analisis.CAGR(data.Retornos)
print ('CAGR : {:.2f}%'.format(CAGR * 100))
# Out:
# CAGR : 10.85%

# %%
#Ratio calculado restando una rentabilidad segura a nuestra rentabilidad de estrategia y dividido por el riego (=volatilidad)
data.Retornos=data.Retornos.replace(0,np.e)  #Quito los cero (no sepuede hacer logariotmo de cero), pero no se que poner
Sharpe = CAGR / (np.log(data.Retornos + 1).std(skipna=True) * 252 ** 0.5)
print ('Sharpe : {:.3f}'.format(CAGR ))
# Out:
# Sharpe : 0.109

# %%
# Actualizo la excel con los economic
regreMedia.analisisEconomics(instrumento)

# %% [markdown]
# ---

# %%
#

# %% [markdown]
# ### Cálculo esperanza matemática
#
#  (%Aciertos * beneficioMedio )-(%Errores * perdidaMedia)
#  Nos da idea el benefcio esperado por entrada

# %%
print("Numero operaciones con beneficio ->", 
      data[data['ExitReason'] > 0]['ExitReason'].count()) 
print("Numero operaciones con perdidas ->", 
      data[data['ExitReason'] < 0]['ExitReason'].count()) 
  
data[data['ExitReason']>0]['ExitReason'] 

data[data['Senal']>0][1:10]
data[data['Senal']>0].index[1]
# Out:
# Numero operaciones con beneficio -> 7
# Numero operaciones con perdidas -> 11
# '2017-01-18'

# %%
# ENTRADAS
print (data[(data['Senal']>0) & (data['Beneficio']>0)].index[0])
data[(data['Senal']>0) & (data['Beneficio']>0) ][0:5] 
# SALIDA PERDIDAS
print (data[(data['Senal'].shift(1) >0) & (data['ExitReason']== -1)].index[0])
data[(data['Senal'].shift(1) >0) & (data['ExitReason']== -1)][0:5]
# SALIDA GANANCIAS
data[(data['Senal'].shift(1) >0) & (data['ExitReason']== 1)][0:5]
# Out:
# 2017-01-17
# 2018-10-09
#                   Date Senal      Price Objetivo ExitReason  Beneficio  \
# 2017-02-08  2017-02-08     0     24.365      NaN          1        NaN
# 2017-08-04  2017-08-04     0  43.012501      NaN          1        NaN
# 2017-11-03  2017-11-03     0  50.372501      NaN          1        NaN
# 2018-08-24  2018-08-24     0  77.144997      NaN          1        NaN
# 2021-03-26  2021-03-26     0  77.817497      NaN          1        NaN
#
#             Dif_Close  Retornos     Capital
# 2017-02-08   0.015314  0.015314  110.461289
# 2017-08-04   0.194377  0.194377  132.475005
# 2017-11-03   0.112160   0.11216  147.333387
# 2018-08-24   0.091893  0.091893  179.204317
# 2021-03-26   0.065993  0.065993  185.713301

# %%
#serieIndicesENTRADA=data[(data['Senal']>0) & (data['Beneficio']>0)].index

print(serieIndicesENTRADA.size)

serieIndicesENTRADA

serieIndicesEXIT=data[(data['ExitReason']==1) | (data['ExitReason']==-1)].index

print(serieIndicesEXIT.size)

#data['ExitReason'][serieIndicesEXIT[2]]
# Out:
# 9
# 9

# %%
#Cálculo Esperanza Matemática
countGanando=0
countPerdiendo=0

bolsaGanando=0
bolsaPerdiendo=0

for i in range(serieIndicesEXIT.size):
    if(data['ExitReason'][serieIndicesEXIT[i]] == -1):
        ref1  = data['Price'][serieIndicesEXIT[i]]
        ref2 = data['Price'][serieIndicesENTRADA[i]]
        print (ref1, ref2)
        countPerdiendo= 1+countPerdiendo
        bolsaPerdiendo= bolsaPerdiendo + (ref1-ref2)

    
    if(data['ExitReason'][serieIndicesEXIT[i]] == 1):
        ref1  = data['Price'][serieIndicesEXIT[i]]
        ref2 = data['Price'][serieIndicesENTRADA[i]]
        print (ref1, ref2)
        countGanando= 1+countGanando
        bolsaGanando= bolsaGanando + (ref1-ref2)
    
#(%Aciertos * beneficioMedio )-(%Errores * perdidaMedia)

count=countGanando+countPerdiendo


print ("bolsa ganando   --> ", bolsaGanando, "   numero operaciones ganando   ", countGanando)   
print ("bolsa perdiendo -->", bolsaPerdiendo, "   numero operaciones perdiendo", countPerdiendo) 
print ("media perdiendo --> ", (bolsaPerdiendo/countPerdiendo), "  media ganando", (bolsaGanando/countGanando)) 


esperanza = (countGanando/count *(bolsaGanando/countGanando))+(countPerdiendo/count *(bolsaPerdiendo/countPerdiendo))
print("ESPERANZA MATEMATICA ES: ", esperanza)


countGanando/count
countPerdiendo/count
bolsaGanando/countGanando

(bolsaPerdiendo/countPerdiendo)
# Out:
# 24.364999771118164 22.0575008392334
# 43.01250076293945 35.8650016784668
# 50.372501373291016 45.29249954223633
# 77.1449966430664 63.42499923706055
# 59.662498474121094 64.0374984741211
# 77.81749725341797 69.95999908447266
# 81.81500244140625 76.38500213623047
# 95.97250366210938 87.7300033569336
# 102.4800033569336 120.19000244140625
# bolsa ganando   -->  49.784996032714844    numero operaciones ganando    7
# bolsa perdiendo --> -22.084999084472656    numero operaciones perdiendo 2
# media perdiendo -->  -11.042499542236328   media ganando 7.112142290387835
# ESPERANZA MATEMATICA ES:  3.0777774386935772
# -11.042499542236328

# %% [markdown]
# ---
