# %% [markdown]
# # <font color='red'>Backtest vectorizado para una estrategia 'Regresion lineal' definida.</font>
#
# ### Hackeado by J3viton (learning BackTesting 2021).

# %% [markdown]
# ---

# %% [markdown]
# En este notebook vamos a automatizar el backtesting para estrategias. Previamente tenemos que definir **la estrategia** usando el template (import estrategia_XX as rg), donde definimos la clase estrategia que contiene los metodos de analisis, entreda y salida de mercado. Este módulo se programa y adapta para cada estrategia. Luego en el metodo 'analisis' se crea un fichero excel con las metricas y rendimientos para evaluar la estrategia.
#
# Vamos a usar el módulo Pandas, para realizar un backtest vectorizado, es decir calcular el resultado del backtest sin iterar sobre las filas (barras) de la serie temporal.

# %% [markdown]
# Posteriormente graficamos y mostramos los parametros generales que nos permiten analizar la estrategia.
#
# #### J3Viton  2021
#
# link a la base:
#
# https://github.com/Python-para-Trading/Webinars-Docs/blob/master/Webinar%202/Webinar%202%20-%20Backtest%20con%20Pandas%20v%202.ipynb.

# %% [markdown]
# ---

# %% [markdown]
# # DEFINICION DEL SISTEMA

# %% [markdown]
# Como es usual, importamos los módulos que vamos a necesitar para las distintas tareas, y preparamos Matplotlib para una mejor visualización de los gráficos en el notebook.
#
# Se importa un modulo llamado analisis, en realidad se trata de un archivo .py con algunas funciones de apoyo para el trabajo, debe estar guardado en la misma carpeta que este notebook.
# Se importa el módulo 'estrategia_XX', donde se define la estrategia de entreda y salida

# %% [markdown]
# Es importante tener clara la lógica del sistema, pues debemos plasmarla de forma sencilla y correcta en el dataframe para realizar el backtest del mismo.

# %%
import analisis
import regresionAMedia as rg  #cambiar segun el módulo con la estrategia implementado
import pandas as pd
import datetime as dt
from time import time
import yfinance as yf
import numpy as np
# Out:
# {'id': 1473252352, 'first_name': 'vital_bot', 'is_bot': True, 'username': 'vital_quant_bot', 'can_join_groups': True, 'can_read_all_group_messages': False, 'supports_inline_queries': False}

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = 18, 8
plt.style.use('ggplot')

from IPython.display import display, Markdown

# %% [markdown]
# ***0.- RECOGIDA DE DATOS INICIALES***
# Introducimos el instrumento y las fechas

# %%
instrumento_ = 'HSY'   # ticker del valor en yahooFinance

Fecha_Cominezo_Backtesting = dt.datetime(2015,1,2)
Fecha_Final_Backtesting    = dt.datetime(2021,11,18)
Fecha_Final_Backtesting    = dt.datetime.today()

# %% [markdown]
# ***1.- Rango fechas a analizar***
#
# Definimos el rango global de datos historicos que vamos a evaluar.
# Definimos la ventana que vamos a ir desplazando por todo el espectro para ir analilazando como se comporta la estrategia. La funion 'analisis' nos vale para tiempo real y para backtesting, para back le pasamos la ventana como si la fecha de fin de la ventana fuera la fecha de hoy.
# Tener en cuenta que la 'ventana' tiene uqe tener una anchura que nos permita hacer los calculos en rolling (ejemplo EMA 200)

# %%
# Rango completo para backTesting
#start2 =dt.datetime(2008,1,2)
start2= Fecha_Cominezo_Backtesting 
#end2   =dt.datetime(2021,11,18)
end2= Fecha_Final_Backtesting 
start_G= start2.strftime("%Y-%m-%d")
end_G  =   end2.strftime("%Y-%m-%d")
TOTAL_len= (end2-start2).days
print('Tamaño timeseries global a analizar:  ', TOTAL_len, 'sesiones')

#ventana de analisis 200 sesiones
startWindow2 = start2  #dt.datetime(2008,1,5)
endWindow2   =startWindow2 + dt.timedelta(days=500) #ventana grande para que se puedan hacer los calculos de EMA200
startWindow= startWindow2.strftime("%Y-%m-%d")
endWindow  =   endWindow2.strftime("%Y-%m-%d")
window_len= (endWindow2-startWindow2).days
print('Tamaño de la ventana a analizar paso a paso:  ', window_len, 'sesiones')
# Out:
# Tamaño timeseries global a analizar:   2695 sesiones
# Tamaño de la ventana a analizar paso a paso:   500 sesiones

# %%
 #dff = pd.DataFrame(columns=('Close','Volume', 'Senal', 'Dif_Close', 'Retornos','Capital'))

# %% [markdown]
# ***2.- Descargamos los datos para el marco Global***

# %%
instrumento = instrumento_  # 'rovi.mc'  #Vamos título a título. Mejora: Conjunto de títulos

# %%
dff = yf.download(instrumento, start_G,end_G)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
dff.dropna(inplace=True)  
dff.head()
# Out:
#                   Open        High         Low       Close  Adj Close   Volume
# Date
# 2015-01-02  104.330002  104.589996  102.930000  103.709999  87.301659   786500
# 2015-01-05  103.150002  104.000000  102.500000  102.980003  86.687164   857800
# 2015-01-06  103.349998  104.300003  102.900002  103.320000  86.973366  1241200
# 2015-01-07  104.199997  105.489998  103.830002  105.139999  88.505432  1020600
# 2015-01-08  105.930000  107.500000  105.510002  107.169998  90.214256  1245800

# %% [markdown]
# ***3.- Creamos la clase strategy que tiene toda la lógica***

# %%
regreMedia= rg.StrategyClass(back=True)    #Creamos la clase

# %% [markdown]
# ***4.- Recorremos el dataframe con valores buscando las señales de la estrategia***

# %%
dff.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2022-05-06', '2022-05-09', '2022-05-10', '2022-05-11',
#                '2022-05-12', '2022-05-13', '2022-05-16', '2022-05-17',
#                '2022-05-18', '2022-05-19'],
#               dtype='datetime64[ns]', name='Date', length=1859, freq=None)

# %% [markdown]
# ## Proceso de backTesting ##
#
# En este 'for' vamos recorriendo la muestra del historico de datos (TOTAL), desplazando una sesión hacia el futuro
# en cada iteracion. Vamos pasando la movilola del pasado sesión a sesión por el análisis descrito en Strategy class.
#
# Ouput:
# El sistema registra los siguientes parámetros:
#
# .-
# .-
# .-

# %%
startWindow
# Out:
# '2015-01-02'

# %%
tiempo_inicial = time()   # Tomamos tiempos para ver cuanto tarda en hacer la estrategia

# %%
dfe = pd.DataFrame({'A' : []})   #df empty

# %% [markdown]
# ***En este 'for' desplazamos la ventana sesión a sesión a lo largo de todo el rango de fechas. Dejamos que las funciones de la clase estrategia hagan el trabajo de comprar//vender y anotar***

# %%
#Para pruebas
#TOTAL_len =1000

for i in range(TOTAL_len):
    endWindow3   =endWindow2 + dt.timedelta(days=i) 
    endWindow    =endWindow3.strftime("%Y-%m-%d")
    print ('end date:', endWindow)
    
    if(endWindow in dff.index):
        df_aux= dff.loc[startWindow:endWindow]       #voy pasando los datos desplazando la ventana
        
        recogo = regreMedia.analisis(instrumento, startWindow, endWindow, df_aux) #Llamada a la clase estrategia. LA CLAVE DE TODO!!!
        
        print ('................................................Analizando, muestra', i, 'de', TOTAL_len, 'fecha', endWindow)
        
            
    else:
        print('..............Día sin sesión, next please')
# Out:
# end date: 2016-05-16
# fichero no existe
# aqui estoy en out
#  datos desde archivo
# ................................................Analizando, muestra 0 de 2695 fecha 2016-05-16
# end date: 2016-05-17
#  Datos desde archivo
# Coefficients:
#  [-0.04325733]
# Independent term:
#  100.98555965327948
# Coefficients:
#  [0.00193612]
# Independent term:
#  90.03540553761951
# Coefficients:
#  [-0.028127]
# Independent term:
#  94.32777779977307
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 1 de 2695 fecha 2016-05-17
# end date: 2016-05-18
#  Datos desde archivo
# Coefficients:
#  [-0.04306546]
# Independent term:
#  100.96349518685055
# Coefficients:
#  [0.0022297]
# Independent term:
#  89.99299517958912
# Coefficients:
#  [-0.02778748]
# Independent term:
#  94.31114155946763
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 2 de 2695 fecha 2016-05-18
# end date: 2016-05-19
#  Datos desde archivo
# Coefficients:
#  [-0.04283722]
# Independent term:
#  100.93717044586211
# Coefficients:
#  [0.00268287]
# Independent term:
#  89.9371040754176
# Coefficients:
#  [-0.02745609]
# Independent term:
#  94.29479279614569
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 3 de 2695 fecha 2016-05-19
# end date: 2016-05-20
#  Datos desde archivo
# Coefficients:
#  [-0.04260438]
# Independent term:
#  100.91023894476686
# Coefficients:
#  [0.00313759]
# Independent term:
#  89.88241000047371
# Coefficients:
#  [-0.02713221]
# Independent term:
#  94.27870670151228
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 4 de 2695 fecha 2016-05-20
# end date: 2016-05-21
# ..............Día sin sesión, next please
# end date: 2016-05-22
# ..............Día sin sesión, next please
# end date: 2016-05-23
#  Datos desde archivo
# Coefficients:
#  [-0.04238075]
# Independent term:
#  100.88429861588064
# Coefficients:
#  [0.0035034]
# Independent term:
#  89.83811152102342
# Coefficients:
#  [-0.02681599]
# Independent term:
#  94.26289561307803
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 7 de 2695 fecha 2016-05-23
# end date: 2016-05-24
#  Datos desde archivo
# Coefficients:
#  [-0.04212391]
# Independent term:
#  100.85441892723196
# Coefficients:
#  [0.00360669]
# Independent term:
#  89.83588461918616
# Coefficients:
#  [-0.02650535]
# Independent term:
#  94.2472600790767
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 8 de 2695 fecha 2016-05-24
# end date: 2016-05-25
#  Datos desde archivo
# Coefficients:
#  [-0.04186842]
# Independent term:
#  100.82461150073833
# Coefficients:
#  [0.00402411]
# Independent term:
#  89.79210107376328
# Coefficients:
#  [-0.02620011]
# Independent term:
#  94.23179465813818
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 9 de 2695 fecha 2016-05-25
# end date: 2016-05-26
#  Datos desde archivo
# Coefficients:
#  [-0.0415773]
# Independent term:
#  100.7905509301439
# Coefficients:
#  [0.00450434]
# Independent term:
#  89.74786816838963
# Coefficients:
#  [-0.0258982]
# Independent term:
#  94.2163971507531
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 10 de 2695 fecha 2016-05-26
# end date: 2016-05-27
#  Datos desde archivo
# Coefficients:
#  [-0.04126762]
# Independent term:
#  100.75421521589107
# Coefficients:
#  [0.00517428]
# Independent term:
#  89.6829084333733
# Coefficients:
#  [-0.02559851]
# Independent term:
#  94.20101336818594
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 11 de 2695 fecha 2016-05-27
# end date: 2016-05-28
# ..............Día sin sesión, next please
# end date: 2016-05-29
# ..............Día sin sesión, next please
# end date: 2016-05-30
# ..............Día sin sesión, next please
# end date: 2016-05-31
#  Datos desde archivo
# Coefficients:
#  [-0.04094932]
# Independent term:
#  100.71676156849476
# Coefficients:
#  [0.00561269]
# Independent term:
#  89.65113673309781
# Coefficients:
#  [-0.02530052]
# Independent term:
#  94.18561689435784
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 15 de 2695 fecha 2016-05-31
# end date: 2016-06-01
#  Datos desde archivo
# Coefficients:
#  [-0.04062734]
# Independent term:
#  100.67876756041552
# Coefficients:
#  [0.00620109]
# Independent term:
#  89.60084123412176
# Coefficients:
#  [-0.02500394]
# Independent term:
#  94.17019509736241
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 16 de 2695 fecha 2016-06-01
# end date: 2016-06-02
#  Datos desde archivo
# Coefficients:
#  [-0.04032009]
# Independent term:
#  100.64241056784165
# Coefficients:
#  [0.00689592]
# Independent term:
#  89.5339561804017
# Coefficients:
#  [-0.02470946]
# Independent term:
#  94.15478393983928
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 17 de 2695 fecha 2016-06-02
# end date: 2016-06-03
#  Datos desde archivo
# Coefficients:
#  [-0.03998154]
# Independent term:
#  100.60223591917396
# Coefficients:
#  [0.00787087]
# Independent term:
#  89.4372486626924
# Coefficients:
#  [-0.02441542]
# Independent term:
#  94.13929787754697
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 18 de 2695 fecha 2016-06-03
# end date: 2016-06-04
# ..............Día sin sesión, next please
# end date: 2016-06-05
# ..............Día sin sesión, next please
# end date: 2016-06-06
#  Datos desde archivo
# Coefficients:
#  [-0.03965651]
# Independent term:
#  100.56355728815305
# Coefficients:
#  [0.00860936]
# Independent term:
#  89.3698187597474
# Coefficients:
#  [-0.02412247]
# Independent term:
#  94.12377115903004
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 21 de 2695 fecha 2016-06-06
# end date: 2016-06-07
#  Datos desde archivo
# Coefficients:
#  [-0.03933873]
# Independent term:
#  100.52563545976135
# Coefficients:
#  [0.00926022]
# Independent term:
#  89.31315764128273
# Coefficients:
#  [-0.02383089]
# Independent term:
#  94.10822060795839
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 22 de 2695 fecha 2016-06-07
# end date: 2016-06-08
#  Datos desde archivo
# Coefficients:
#  [-0.03900098]
# Independent term:
#  100.4852180349599
# Coefficients:
#  [0.00967272]
# Independent term:
#  89.29311440652876
# Coefficients:
#  [-0.02353967]
# Independent term:
#  94.09259148641533
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 23 de 2695 fecha 2016-06-08
# end date: 2016-06-09
#  Datos desde archivo
# Coefficients:
#  [-0.03854374]
# Independent term:
#  100.43034857113358
# Coefficients:
#  [0.0100221]
# Independent term:
#  89.30810096171365
# Coefficients:
#  [-0.02324299]
# Independent term:
#  94.07657103078856
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 24 de 2695 fecha 2016-06-09
# end date: 2016-06-10
#  Datos desde archivo
# Coefficients:
#  [-0.03809316]
# Independent term:
#  100.3761298020522
# Coefficients:
#  [0.01015156]
# Independent term:
#  89.35156965227269
# Coefficients:
#  [-0.02294141]
# Independent term:
#  94.06018492211952
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 25 de 2695 fecha 2016-06-10
# end date: 2016-06-11
# ..............Día sin sesión, next please
# end date: 2016-06-12
# ..............Día sin sesión, next please
# end date: 2016-06-13
#  Datos desde archivo
# Coefficients:
#  [-0.03768303]
# Independent term:
#  100.32664055974301
# Coefficients:
#  [0.0106105]
# Independent term:
#  89.34310544597568
# Coefficients:
#  [-0.02263704]
# Independent term:
#  94.04354604714652
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 28 de 2695 fecha 2016-06-13
# end date: 2016-06-14
#  Datos desde archivo
# Coefficients:
#  [-0.03723525]
# Independent term:
#  100.272458291798
# Coefficients:
#  [0.01150911]
# Independent term:
#  89.28539352416992
# Coefficients:
#  [-0.02232821]
# Independent term:
#  94.02656039695714
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 29 de 2695 fecha 2016-06-14
# end date: 2016-06-15
#  Datos desde archivo
# Coefficients:
#  [-0.03681677]
# Independent term:
#  100.2216832741481
# Coefficients:
#  [0.01231308]
# Independent term:
#  89.2346487734211
# Coefficients:
#  [-0.02201647]
# Independent term:
#  94.00931113766316
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 30 de 2695 fecha 2016-06-15
# end date: 2016-06-16
#  Datos desde archivo
# Coefficients:
#  [-0.03637103]
# Independent term:
#  100.16745188235954
# Coefficients:
#  [0.01311471]
# Independent term:
#  89.19118616132594
# Coefficients:
#  [-0.02170067]
# Independent term:
#  93.99173164962626
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 31 de 2695 fecha 2016-06-16
# end date: 2016-06-17
#  Datos desde archivo
# Coefficients:
#  [-0.03591633]
# Independent term:
#  100.11197876719545
# Coefficients:
#  [0.01358687]
# Independent term:
#  89.1943562635735
# Coefficients:
#  [-0.02138055]
# Independent term:
#  93.97380485712337
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 32 de 2695 fecha 2016-06-17
# end date: 2016-06-18
# ..............Día sin sesión, next please
# end date: 2016-06-19
# ..............Día sin sesión, next please
# end date: 2016-06-20
#  Datos desde archivo
# Coefficients:
#  [-0.03548807]
# Independent term:
#  100.0595873506429
# Coefficients:
#  [0.014206]
# Independent term:
#  89.17285322502478
# Coefficients:
#  [-0.0210575]
# Independent term:
#  93.95560622081877
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 35 de 2695 fecha 2016-06-20
# end date: 2016-06-21
#  Datos desde archivo
# Coefficients:
#  [-0.03502931]
# Independent term:
#  100.00331362595568
# Coefficients:
#  [0.0151797]
# Independent term:
#  89.11206968962256
# Coefficients:
#  [-0.02073023]
# Independent term:
#  93.9370609446011
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 36 de 2695 fecha 2016-06-21
# end date: 2016-06-22
#  Datos desde archivo
# Coefficients:
#  [-0.0345812]
# Independent term:
#  99.94819553615051
# Coefficients:
#  [0.01604776]
# Independent term:
#  89.06384728730615
# Coefficients:
#  [-0.02039939]
# Independent term:
#  93.91820327303714
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 37 de 2695 fecha 2016-06-22
# end date: 2016-06-23
#  Datos desde archivo
# Coefficients:
#  [-0.03414872]
# Independent term:
#  99.89485687156449
# Coefficients:
#  [0.01723036]
# Independent term:
#  88.97122933231182
# Coefficients:
#  [-0.02006584]
# Independent term:
#  93.89907943372586
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 38 de 2695 fecha 2016-06-23
# end date: 2016-06-24
#  Datos desde archivo
# Coefficients:
#  [-0.03368514]
# Independent term:
#  99.8375270529748
# Coefficients:
#  [0.0182715]
# Independent term:
#  88.90558608667175
# Coefficients:
#  [-0.01972827]
# Independent term:
#  93.87961282218433
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 39 de 2695 fecha 2016-06-24
# end date: 2016-06-25
# ..............Día sin sesión, next please
# end date: 2016-06-26
# ..............Día sin sesión, next please
# end date: 2016-06-27
#  Datos desde archivo
# Coefficients:
#  [-0.03326003]
# Independent term:
#  99.78481297261446
# Coefficients:
#  [0.01923756]
# Independent term:
#  88.84196222903122
# Coefficients:
#  [-0.01938856]
# Independent term:
#  93.85990973116365
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 42 de 2695 fecha 2016-06-27
# end date: 2016-06-28
#  Datos desde archivo
# Coefficients:
#  [-0.03288197]
# Independent term:
#  99.73780735237717
# Coefficients:
#  [0.02012299]
# Independent term:
#  88.77896220990081
# Coefficients:
#  [-0.01904889]
# Independent term:
#  93.84009574096764
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 43 de 2695 fecha 2016-06-28
# end date: 2016-06-29
#  Datos desde archivo
# Coefficients:
#  [-0.03247]
# Independent term:
#  99.68644842355258
# Coefficients:
#  [0.02098746]
# Independent term:
#  88.72754726239104
# Coefficients:
#  [-0.01870776]
# Independent term:
#  93.82008266420127
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 44 de 2695 fecha 2016-06-29
# end date: 2016-06-30
#  Datos desde archivo
# Coefficients:
#  [-0.03137479]
# Independent term:
#  99.54954751609657
# Coefficients:
#  [0.02436175]
# Independent term:
#  88.50550548838146
# Coefficients:
#  [-0.01833515]
# Independent term:
#  93.79809873528353
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 45 de 2695 fecha 2016-06-30
# end date: 2016-07-01
#  Datos desde archivo
# Coefficients:
#  [-0.03036006]
# Independent term:
#  99.42236783240841
# Coefficients:
#  [0.02792283]
# Independent term:
#  88.24222794490073
# Coefficients:
#  [-0.01793579]
# Independent term:
#  93.7744033559641
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 46 de 2695 fecha 2016-07-01
# end date: 2016-07-02
# ..............Día sin sesión, next please
# end date: 2016-07-03
# ..............Día sin sesión, next please
# end date: 2016-07-04
# ..............Día sin sesión, next please
# end date: 2016-07-05
#  Datos desde archivo
# Coefficients:
#  [-0.02941836]
# Independent term:
#  99.30402859238978
# Coefficients:
#  [0.03118131]
# Independent term:
#  88.00425919262331
# Coefficients:
#  [-0.01751388]
# Independent term:
#  93.74922927771222
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 50 de 2695 fecha 2016-07-05
# end date: 2016-07-06
#  Datos desde archivo
# Coefficients:
#  [-0.02854246]
# Independent term:
#  99.19366484988639
# Coefficients:
#  [0.03409922]
# Independent term:
#  87.79807710789922
# Coefficients:
#  [-0.01707312]
# Independent term:
#  93.72278388423328
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 51 de 2695 fecha 2016-07-06
# end date: 2016-07-07
#  Datos desde archivo
# Coefficients:
#  [-0.02764819]
# Independent term:
#  99.08068788431491
# Coefficients:
#  [0.03715207]
# Independent term:
#  87.58061891014896
# Coefficients:
#  [-0.01661345]
# Independent term:
#  93.69505037322206
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 52 de 2695 fecha 2016-07-07
# end date: 2016-07-08
#  Datos desde archivo
# Coefficients:
#  [-0.02673968]
# Independent term:
#  98.96561069380842
# Coefficients:
#  [0.04011623]
# Independent term:
#  87.38063537256042
# Coefficients:
#  [-0.01613498]
# Independent term:
#  93.66602297172192
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 53 de 2695 fecha 2016-07-08
# end date: 2016-07-09
# ..............Día sin sesión, next please
# end date: 2016-07-10
# ..............Día sin sesión, next please
# end date: 2016-07-11
#  Datos desde archivo
# Coefficients:
#  [-0.02586709]
# Independent term:
#  98.85479165586418
# Coefficients:
#  [0.04298942]
# Independent term:
#  87.18620256907904
# Coefficients:
#  [-0.01563994]
# Independent term:
#  93.63582595557962
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 56 de 2695 fecha 2016-07-11
# end date: 2016-07-12
#  Datos desde archivo
# Coefficients:
#  [-0.02506383]
# Independent term:
#  98.75251000959636
# Coefficients:
#  [0.0456624]
# Independent term:
#  87.00349071901236
# Coefficients:
#  [-0.01513191]
# Independent term:
#  93.60466681324093
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 57 de 2695 fecha 2016-07-12
# end date: 2016-07-13
#  Datos desde archivo
# Coefficients:
#  [-0.02428857]
# Independent term:
#  98.65353460859285
# Coefficients:
#  [0.04832007]
# Independent term:
#  86.81790268627564
# Coefficients:
#  [-0.01461256]
# Independent term:
#  93.57264018240006
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 58 de 2695 fecha 2016-07-13
# end date: 2016-07-14
#  Datos desde archivo
# Coefficients:
#  [-0.02353396]
# Independent term:
#  98.55694434918298
# Coefficients:
#  [0.0507253]
# Independent term:
#  86.66263259432209
# Coefficients:
#  [-0.01408319]
# Independent term:
#  93.53981904391023
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 59 de 2695 fecha 2016-07-14
# end date: 2016-07-15
#  Datos desde archivo
# Coefficients:
#  [-0.02268735]
# Independent term:
#  98.44829655631044
# Coefficients:
#  [0.05365623]
# Independent term:
#  86.46235495496153
# Coefficients:
#  [-0.01354035]
# Independent term:
#  93.50598220692503
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 60 de 2695 fecha 2016-07-15
# end date: 2016-07-16
# ..............Día sin sesión, next please
# end date: 2016-07-17
# ..............Día sin sesión, next please
# end date: 2016-07-18
#  Datos desde archivo
# Coefficients:
#  [-0.02190415]
# Independent term:
#  98.34752454988445
# Coefficients:
#  [0.05629033]
# Independent term:
#  86.28771169634008
# Coefficients:
#  [-0.01298719]
# Independent term:
#  93.47131711214605
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 63 de 2695 fecha 2016-07-18
# end date: 2016-07-19
#  Datos desde archivo
# Coefficients:
#  [-0.02113328]
# Independent term:
#  98.24808317172756
# Coefficients:
#  [0.05891935]
# Independent term:
#  86.11257435585136
# Coefficients:
#  [-0.01242459]
# Independent term:
#  93.43587379788097
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 64 de 2695 fecha 2016-07-19
# end date: 2016-07-20
#  Datos desde archivo
# Coefficients:
#  [-0.02038204]
# Independent term:
#  98.15092278590038
# Coefficients:
#  [0.0618303]
# Independent term:
#  85.8969848222875
# Coefficients:
#  [-0.01185374]
# Independent term:
#  93.39971979548757
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 65 de 2695 fecha 2016-07-20
# end date: 2016-07-21
#  Datos desde archivo
# Coefficients:
#  [-0.01962308]
# Independent term:
#  98.05251003609638
# Coefficients:
#  [0.06496708]
# Independent term:
#  85.65537594353974
# Coefficients:
#  [-0.01127463]
# Independent term:
#  93.36284987864185
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 66 de 2695 fecha 2016-07-21
# end date: 2016-07-22
#  Datos desde archivo
# Coefficients:
#  [-0.01886088]
# Independent term:
#  97.95342473126512
# Coefficients:
#  [0.06793743]
# Independent term:
#  85.43872526140355
# Coefficients:
#  [-0.01068746]
# Independent term:
#  93.32527052550269
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 67 de 2695 fecha 2016-07-22
# end date: 2016-07-23
# ..............Día sin sesión, next please
# end date: 2016-07-24
# ..............Día sin sesión, next please
# end date: 2016-07-25
#  Datos desde archivo
# Coefficients:
#  [-0.01806962]
# Independent term:
#  97.85029719022808
# Coefficients:
#  [0.07126398]
# Independent term:
#  85.18428347117866
# Coefficients:
#  [-0.01009135]
# Independent term:
#  93.28692094550222
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 70 de 2695 fecha 2016-07-25
# end date: 2016-07-26
#  Datos desde archivo
# Coefficients:
#  [-0.01734517]
# Independent term:
#  97.7556355238681
# Coefficients:
#  [0.07455315]
# Independent term:
#  84.91971181841039
# Coefficients:
#  [-0.00948933]
# Independent term:
#  93.24799042719025
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 71 de 2695 fecha 2016-07-26
# end date: 2016-07-27
#  Datos desde archivo
# Coefficients:
#  [-0.01668279]
# Independent term:
#  97.66886315325644
# Coefficients:
#  [0.07755567]
# Independent term:
#  84.67911034882958
# Coefficients:
#  [-0.00888411]
# Independent term:
#  93.20865112618557
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 72 de 2695 fecha 2016-07-27
# end date: 2016-07-28
#  Datos desde archivo
# Coefficients:
#  [-0.01590915]
# Independent term:
#  97.56725883149035
# Coefficients:
#  [0.08108928]
# Independent term:
#  84.39891633902023
# Coefficients:
#  [-0.00827141]
# Independent term:
#  93.16862128202932
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 73 de 2695 fecha 2016-07-28
# end date: 2016-07-29
#  Datos desde archivo
# Coefficients:
#  [-0.01516895]
# Independent term:
#  97.46979870070776
# Coefficients:
#  [0.08431291]
# Independent term:
#  84.15326561315734
# Coefficients:
#  [-0.00765283]
# Independent term:
#  93.12800136647725
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 74 de 2695 fecha 2016-07-29
# end date: 2016-07-30
# ..............Día sin sesión, next please
# end date: 2016-07-31
# ..............Día sin sesión, next please
# end date: 2016-08-01
#  Datos desde archivo
# Coefficients:
#  [-0.01443436]
# Independent term:
#  97.37283342635081
# Coefficients:
#  [0.08731632]
# Independent term:
#  83.93737600525813
# Coefficients:
#  [-0.00702883]
# Independent term:
#  93.08681712671748
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 77 de 2695 fecha 2016-08-01
# end date: 2016-08-02
#  Datos desde archivo
# Coefficients:
#  [-0.0136621]
# Independent term:
#  97.27063806395185
# Coefficients:
#  [0.09055072]
# Independent term:
#  83.70275356691275
# Coefficients:
#  [-0.00605789]
# Independent term:
#  92.99344335995325
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 78 de 2695 fecha 2016-08-02
# end date: 2016-08-03
#  Datos desde archivo
# Coefficients:
#  [-0.01296408]
# Independent term:
#  97.17803336726163
# Coefficients:
#  [0.09358963]
# Independent term:
#  83.47638191450888
# Coefficients:
#  [-0.00506637]
# Independent term:
#  92.89874623114287
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 79 de 2695 fecha 2016-08-03
# end date: 2016-08-04
#  Datos desde archivo
# Coefficients:
#  [-0.01226703]
# Independent term:
#  97.08532593219836
# Coefficients:
#  [0.09663704]
# Independent term:
#  83.25051473702958
# Coefficients:
#  [-0.00405439]
# Independent term:
#  92.80274392771886
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 80 de 2695 fecha 2016-08-04
# end date: 2016-08-05
#  Datos desde archivo
# Coefficients:
#  [-0.01154544]
# Independent term:
#  96.9891134247745
# Coefficients:
#  [0.09964326]
# Independent term:
#  83.03859533623084
# Coefficients:
#  [-0.00302258]
# Independent term:
#  92.70558822034084
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 81 de 2695 fecha 2016-08-05
# end date: 2016-08-06
# ..............Día sin sesión, next please
# end date: 2016-08-07
# ..............Día sin sesión, next please
# end date: 2016-08-08
#  Datos desde archivo
# Coefficients:
#  [-0.01086948]
# Independent term:
#  96.89876131571748
# Coefficients:
#  [0.10245592]
# Independent term:
#  82.84193554892468
# Coefficients:
#  [-0.00197304]
# Independent term:
#  92.60744242261534
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 84 de 2695 fecha 2016-08-08
# end date: 2016-08-09
#  Datos desde archivo
# Coefficients:
#  [-0.01021853]
# Independent term:
#  96.81153288009973
# Coefficients:
#  [0.10546435]
# Independent term:
#  82.61429676909944
# Coefficients:
#  [-0.00090401]
# Independent term:
#  92.50800813750574
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 85 de 2695 fecha 2016-08-09
# end date: 2016-08-10
#  Datos desde archivo
# Coefficients:
#  [-0.00952242]
# Independent term:
#  96.71802279337736
# Coefficients:
#  [0.10863447]
# Independent term:
#  82.37932066390763
# Coefficients:
#  [0.00018592]
# Independent term:
#  92.40722517756944
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 86 de 2695 fecha 2016-08-10
# end date: 2016-08-11
#  Datos desde archivo
# Coefficients:
#  [-0.00882604]
# Independent term:
#  96.62424351544256
# Coefficients:
#  [0.1117152]
# Independent term:
#  82.15818783660433
# Coefficients:
#  [0.00129567]
# Independent term:
#  92.30524470651505
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 87 de 2695 fecha 2016-08-11
# end date: 2016-08-12
#  Datos desde archivo
# Coefficients:
#  [-0.00816015]
# Independent term:
#  96.53434856793564
# Coefficients:
#  [0.11459026]
# Independent term:
#  81.95781913074096
# Coefficients:
#  [0.00242298]
# Independent term:
#  92.20228524804963
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 88 de 2695 fecha 2016-08-12
# end date: 2016-08-13
# ..............Día sin sesión, next please
# end date: 2016-08-14
# ..............Día sin sesión, next please
# end date: 2016-08-15
#  Datos desde archivo
# Coefficients:
#  [-0.00749113]
# Independent term:
#  96.44380762414865
# Coefficients:
#  [0.11657376]
# Independent term:
#  81.8783609669244
# Coefficients:
#  [0.00355881]
# Independent term:
#  92.09955963331207
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 91 de 2695 fecha 2016-08-15
# end date: 2016-08-16
#  Datos desde archivo
# Coefficients:
#  [-0.00684306]
# Independent term:
#  96.35588565607803
# Coefficients:
#  [0.11858267]
# Independent term:
#  81.79117441775195
# Coefficients:
#  [0.00470332]
# Independent term:
#  91.99698863614233
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 92 de 2695 fecha 2016-08-16
# end date: 2016-08-17
#  Datos desde archivo
# Coefficients:
#  [-0.00613546]
# Independent term:
#  96.2596521585039
# Coefficients:
#  [0.12080513]
# Independent term:
#  81.6937400373772
# Coefficients:
#  [0.00585856]
# Independent term:
#  91.89446874958745
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 93 de 2695 fecha 2016-08-17
# end date: 2016-08-18
#  Datos desde archivo
# Coefficients:
#  [-0.00545068]
# Independent term:
#  96.16629370285084
# Coefficients:
#  [0.12282669]
# Independent term:
#  81.61814453580487
# Coefficients:
#  [0.00702243]
# Independent term:
#  91.79221676736076
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 94 de 2695 fecha 2016-08-18
# end date: 2016-08-19
#  Datos desde archivo
# Coefficients:
#  [-0.00475623]
# Independent term:
#  96.07138650914297
# Coefficients:
#  [0.12490775]
# Independent term:
#  81.53887888552538
# Coefficients:
#  [0.00819541]
# Independent term:
#  91.69019350485495
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 95 de 2695 fecha 2016-08-19
# end date: 2016-08-20
# ..............Día sin sesión, next please
# end date: 2016-08-21
# ..............Día sin sesión, next please
# end date: 2016-08-22
#  Datos desde archivo
# Coefficients:
#  [-0.00406219]
# Independent term:
#  95.97630243635714
# Coefficients:
#  [0.12693801]
# Independent term:
#  81.46776846245153
# Coefficients:
#  [0.00937693]
# Independent term:
#  91.58847783279124
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 98 de 2695 fecha 2016-08-22
# end date: 2016-08-23
#  Datos desde archivo
# Coefficients:
#  [-0.003407]
# Independent term:
#  95.88632294397458
# Coefficients:
#  [0.12880511]
# Independent term:
#  81.40874163955004
# Coefficients:
#  [0.01056527]
# Independent term:
#  91.4871869253958
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 99 de 2695 fecha 2016-08-23
# end date: 2016-08-24
#  Datos desde archivo
# Coefficients:
#  [-0.00283653]
# Independent term:
#  95.80778895573444
# Coefficients:
#  [0.13007664]
# Independent term:
#  81.40587440832337
# Coefficients:
#  [0.01175444]
# Independent term:
#  91.38687535806176
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 100 de 2695 fecha 2016-08-24
# end date: 2016-08-25
#  Datos desde archivo
# Coefficients:
#  [-0.00227035]
# Independent term:
#  95.7296562276628
# Coefficients:
#  [0.13117071]
# Independent term:
#  81.42641465144371
# Coefficients:
#  [0.01294266]
# Independent term:
#  91.28776629630435
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 101 de 2695 fecha 2016-08-25
# end date: 2016-08-26
#  Datos desde archivo
# Coefficients:
#  [-0.00171634]
# Independent term:
#  95.65301691973836
# Coefficients:
#  [0.13231056]
# Independent term:
#  81.43839969122588
# Coefficients:
#  [0.0141304]
# Independent term:
#  91.18976264849265
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY               0 2019-10-16  151.529999  11.336146  5.002031
# ................................................Analizando, muestra 102 de 2695 fecha 2016-08-26
# end date: 2016-08-27
# ..............Día sin sesión, next please
# end date: 2016-08-28
# ..............Día sin sesión, next please
# end date: 2016-08-29
#  Datos desde archivo
# Coefficients:
#  [-0.00114311]
# Independent term:
#  95.57352941345592
# Coefficients:
#  [0.13364979]
# Independent term:
#  81.43054604943119
# Coefficients:
#  [0.01531965]
# Independent term:
#  91.09265601566615
#   Instrumento  long_short_out       date      precio  beneficio  stoploss
# 0      IBE.MC               1 2011-08-10  123.000000        NaN       NaN
# 1         HSY
# %%
data.loc['2011-01-04':'2019-11-04']

# %%
#Guardamos el resultado del analisis en un pickle
#dff.to_pickle("./primerBack_IBE.pkl")

# %% [markdown]
# ***3.- Ingeniería de datos para calcular la bondad de la estrategia***

# %%
data['Dif_Close'] = data.Price.pct_change()
data['Retornos'] = data.Dif_Close * data.Senal.shift(1)   
data['Capital'] = (data.Retornos + 1).cumprod() * 100
    
rg.StrategyClass.dfLog=data  #Ojo a esta liena, no me cuadra.

#quant_j.salvarExcel(StrategyClass.dfLog, "log"+instrumento)   
#data.to_pickle('almacen')    #df = pd.read_pickle(file_name)

# %% [markdown]
# >Para calcular los retornos del sistema, calculamos la diferencia relativativa entre el precio de cierre y el del día anterior. Para posteriormente multiplicarlo por la señal que del día anterior que nos indicaba la posición a tomar (si estaba comprado, sumo beneficio).

# %%
data.tail()

# %%
data[60:]

# %% [markdown]
# >El capital, por comodidad, lo calcularemos en base 100, es decir como si iniciaramos la inversión con 100 unidades monetarias. Para su calculo arrastramos el producto acumulado de los retornos mas 1, multiplicados como dijimos por 100.

# %% [markdown]
# Pero para observar gráficamente la evolución del sistema necesitamos un gráfico con mas información. Para ello definimos una función que nos mostrará un gráfico con la evolución de nuestra estrategia, comparandola con la del activo. En un subgráfico se visualizará el drawdown del sistema, comparado de nuevo con el del activo. Y por útlimo las posiciones que toma el sistema.

# %%
def grafico (df):
    estudio = df.copy()
    
    DD_bh, maxDD, maxDD_ini, maxDD_fin = analisis.DrawDown(estudio.Dif_Close[60:], info = False) 
    
    DD, maxDD, maxDD_ini, maxDD_fin = analisis.DrawDown(estudio.Retornos.fillna(0), info = False) 

    fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True, figsize=(18, 12), gridspec_kw = {'height_ratios':[3, 1, 1]})
    fig.suptitle('Estrategia vs B & H', fontsize=20)

    #Primer plot analiza la evolcuion de una inversion de 100€ en buy&hold y la estrategia)
    ax1.plot(estudio.Capital)
    ax1.plot((estudio.Price) * (100/estudio.Price[1]))
    ax1.set_title('Capital')
    ax1.legend(['Estrategia','Buy & Hold'])

    ax2.plot(DD*100, c='0.5')
    ax2.plot(DD_bh*100, c='y')
    ax2.fill_between(DD.index, 0, DD*100, color='0.7')
    ax2.set_title('Drawdown')
    ax2.legend(['Estrategia','Buy & Hold'])

    ax3.plot(estudio.Senal, c='orange')
    #ax3.fill_between(estudio.index, 0, estudio.Senal*100, color='orange')
    ax3.set_title('Posición')

    plt.show()
    return

# %%
print(instrumento)

# %%
grafico(data)

# %% [markdown]
# ---

# %%
#data[55:70]

# %% [markdown]
# ---

# %% [markdown]
# # ANALISIS DEL SISTEMA

# %%
Beneficio_Bruto = data.Capital[-1] - data.Capital[1]
print ('Beneficio Bruto : {:.2f} €  con una inverison de 100€'.format(Beneficio_Bruto))

# %%
#Rentabilidad anual compuesta. Calculamos lo que la inversion se ha incrementado cada año con el interes compuesto
CAGR = analisis.CAGR(data.Retornos)
print ('CAGR : {:.2f}%'.format(CAGR * 100))

# %%
#Ratio calculado restando una rentabilidad segura a nuestra rentabilidad de estrategia y dividido por el riego (=volatilidad)
data.Retornos=data.Retornos.replace(0,np.e)  #Quito los cero (no sepuede hacer logariotmo de cero), pero no se que poner
Sharpe = CAGR / (np.log(data.Retornos + 1).std(skipna=True) * 252 ** 0.5)
print ('Sharpe : {:.3f}'.format(CAGR ))

# %%
# Actualizo la excel con los economic
regreMedia.analisisEconomics(instrumento)

# %% [markdown]
# ---

# %%
#

# %% [markdown]
# ### Cálculo esperanza matemática
#
#  (%Aciertos * beneficioMedio )-(%Errores * perdidaMedia)
#  Nos da idea el benefcio esperado por entrada

# %%
print("Numero operaciones con beneficio ->", 
      data[data['ExitReason'] > 0]['ExitReason'].count()) 
print("Numero operaciones con perdidas ->", 
      data[data['ExitReason'] < 0]['ExitReason'].count()) 
  
data[data['ExitReason']>0]['ExitReason'] 

data[data['Senal']>0][1:10]
data[data['Senal']>0].index[1]

# %%
# ENTRADAS
print (data[(data['Senal']>0) & (data['Beneficio']>0)].index[0])
data[(data['Senal']>0) & (data['Beneficio']>0) ][0:5] 
# SALIDA PERDIDAS
print (data[(data['Senal'].shift(1) >0) & (data['ExitReason']== -1)].index[0])
data[(data['Senal'].shift(1) >0) & (data['ExitReason']== -1)][0:5]
# SALIDA GANANCIAS
data[(data['Senal'].shift(1) >0) & (data['ExitReason']== 1)][0:5]

# %%
serieIndicesENTRADA=data[(data['Senal']>0) & (data['Beneficio']>0)].index

print(serieIndicesENTRADA.size)

serieIndicesENTRADA

serieIndicesEXIT=data[(data['ExitReason']==1) | (data['ExitReason']==-1)].index

print(serieIndicesEXIT.size)

#data['ExitReason'][serieIndicesEXIT[2]]

# %%
serieIndicesENTRADA

# %%
#Cálculo Esperanza Matemática
countGanando=0
countPerdiendo=0

bolsaGanando=0
bolsaPerdiendo=0

for i in range(serieIndicesEXIT.size):
    if(data['ExitReason'][serieIndicesEXIT[i]] == -1):
        ref1  = data['Price'][serieIndicesEXIT[i]]
        ref2 = data['Price'][serieIndicesENTRADA[i]]
        #print ("-1",ref1, ref2)
        countPerdiendo= 1+countPerdiendo
        bolsaPerdiendo= bolsaPerdiendo + (ref1-ref2)

    
    if(data['ExitReason'][serieIndicesEXIT[i]] == 1):
        ref1  = data['Price'][serieIndicesEXIT[i]]
        ref2 = data['Price'][serieIndicesENTRADA[i]]
        print ("+1",ref1, ref2)
        countGanando= 1+countGanando
        bolsaGanando= bolsaGanando + (ref1-ref2)
    
#(%Aciertos * beneficioMedio )-(%Errores * perdidaMedia)

count=countGanando+countPerdiendo


print ("total ganado   --> ", bolsaGanando, "   numero operaciones ganando   ", countGanando)   
print ("total perdido -->", bolsaPerdiendo, "   numero operaciones perdiendo", countPerdiendo) 
print ("media perdiendo --> ", (bolsaPerdiendo/countPerdiendo), "  media ganando", (bolsaGanando/countGanando)) 


esperanza = (countGanando/count *(bolsaGanando/countGanando))+(countPerdiendo/count *(bolsaPerdiendo/countPerdiendo))
print("")
print("ESPERANZA MATEMATICA ES: ", esperanza)

# %% [markdown]
# ---

# %%
serieIndicesEXIT

# %%
serieIndicesENTRADA
