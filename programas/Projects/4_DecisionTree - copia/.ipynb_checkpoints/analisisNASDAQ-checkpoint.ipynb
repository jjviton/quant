# %% [markdown]
# # <font color='red'>Backtest vectorizado para una estrategia 'X' definida.</font>
#
# ### Hackeado by J3viton (learning BackTesting 2021).

# %% [markdown]
# ---

# %% [markdown]
# En este notebook vamos a automatizar el backtesting para estrategias. Previamente tenemos que definir **la estrategia** usando el template (import estrategia_XX as rg), donde definimos la clase estrategia que contiene los metodos de analisis, entreda y salida de mercado. Este módulo se programa y adapta para cada estrategia. Luego en el metodo 'analisis' se crea un fichero excel con las metricas y rendimientos para evaluar la estrategia.
#
# Vamos a usar el módulo Pandas, para realizar un backtest vectorizado, es decir calcular el resultado del backtest sin iterar sobre las filas (barras) de la serie temporal.

# %% [markdown]
# Posteriormente graficamos y mostramos los parametros generales que nos permiten analizar la estrategia.
#
# #### J3Viton  2021
#
# link a la base:
#
# https://github.com/Python-para-Trading/Webinars-Docs/blob/master/Webinar%202/Webinar%202%20-%20Backtest%20con%20Pandas%20v%202.ipynb.

# %% [markdown]
# ---

# %% [markdown]
# # DEFINICION DEL SISTEMA

# %% [markdown]
# Como es usual, importamos los módulos que vamos a necesitar para las distintas tareas, y preparamos Matplotlib para una mejor visualización de los gráficos en el notebook.
#
# Se importa un modulo llamado analisis, en realidad se trata de un archivo .py con algunas funciones de apoyo para el trabajo, debe estar guardado en la misma carpeta que este notebook.
# Se importa el módulo 'estrategia_XX', donde se define la estrategia de entreda y salida

# %% [markdown]
# Es importante tener clara la lógica del sistema, pues debemos plasmarla de forma sencilla y correcta en el dataframe para realizar el backtest del mismo.

# %%
import analisis
import estrategia_XX as rg  #cambiar segun el módulo con la estrategia implementado
import pandas as pd
import datetime as dt
from time import time
import yfinance as yf
import numpy as np
# Out:
# {'can_read_all_group_messages': False, 'can_join_groups': True, 'supports_inline_queries': False, 'is_bot': True, 'username': 'vital_quant_bot', 'first_name': 'vital_bot', 'id': 1473252352}

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = 18, 8
plt.style.use('ggplot')

from IPython.display import display, Markdown

# %% [markdown]
# ***1.- Rango fechas a analizar***
#
# Definimos el rango global de datos historicos que vamos a evaluar.
# Definimos la ventana que vamos a ir desplazando por todo el espectro para ir analilazando como se comporta la estrategia. La funion 'analisis' nos vale para tiempo real y para backtesting, para back le pasamos la ventana como si la fecha de fin de la ventana fuera la fecha de hoy.
# Tener en cuenta que la 'ventana' tiene uqe tener una anchura que nos permita hacer los calculos en rolling (ejemplo EMA 200)

# %%
# Rango completo para backTesting
start2 =dt.datetime(2008,1,2)
end2   =dt.datetime(2021,11,18)
start_G= start2.strftime("%Y-%m-%d")
end_G  =   end2.strftime("%Y-%m-%d")
TOTAL_len= (end2-start2).days
print('Tamaño timeseries global a analizar:  ', TOTAL_len, 'sesiones')

#ventana de analisis 200 sesiones
startWindow2 =dt.datetime(2008,1,5)
endWindow2   =startWindow2 + dt.timedelta(days=1000) #ventana grande para que se puedan hacer los calculos de EMA200
startWindow= startWindow2.strftime("%Y-%m-%d")
endWindow  =   endWindow2.strftime("%Y-%m-%d")
window_len= (endWindow2-startWindow2).days
print('Tamaño de la ventana a analizar paso a paso:  ', window_len, 'sesiones')
# Out:
# Tamaño timeseries global a analizar:   5069 sesiones
# Tamaño de la ventana a analizar paso a paso:   1000 sesiones

# %%
 #dff = pd.DataFrame(columns=('Close','Volume', 'Senal', 'Dif_Close', 'Retornos','Capital'))

# %% [markdown]
# ***2.- Descargamos los datos para el marco Global***

# %%
instrumento = '^IXIC'  #Vamos título a título. Mejora: Conjunto de títulos

# %%
dff = yf.download(instrumento, start_G,end_G)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
dff.dropna(inplace=True)  
dff.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2008-01-02  2653.909912  2661.500000  2597.810059  2609.629883  2609.629883
# 2008-01-03  2611.959961  2624.270020  2592.179932  2602.679932  2602.679932
# 2008-01-04  2571.080078  2571.080078  2502.679932  2504.649902  2504.649902
# 2008-01-07  2514.149902  2521.620117  2471.229980  2499.459961  2499.459961
# 2008-01-08  2506.969971  2527.419922  2440.510010  2440.510010  2440.510010
#
#                 Volume
# Date
# 2008-01-02  2076690000
# 2008-01-03  1970200000
# 2008-01-04  2516310000
# 2008-01-07  2600100000
# 2008-01-08  2566480000

# %% [markdown]
# ***3.- Creamos la clase strategy que tiene toda la lógica***

# %%
regreMedia= rg.StrategyClass()    #Creamos la clase

# %% [markdown]
# ***4.- Recorremos el dataframe con valores buscando las señales de la estrategia***

# %%
dff.index
# Out:
# DatetimeIndex(['2008-01-02', '2008-01-03', '2008-01-04', '2008-01-07',
#                '2008-01-08', '2008-01-09', '2008-01-10', '2008-01-11',
#                '2008-01-14', '2008-01-15',
#                ...
#                '2021-11-04', '2021-11-05', '2021-11-08', '2021-11-09',
#                '2021-11-10', '2021-11-11', '2021-11-12', '2021-11-15',
#                '2021-11-16', '2021-11-17'],
#               dtype='datetime64[ns]', name='Date', length=3496, freq=None)

# %% [markdown]
# ## Proceso de backTesting ##
#
# En este 'for' vamos recorriendo la muestra del historico de datos (TOTAL), desplazando una sesión hacia el futuro
# en cada iteracion. Vamos pasando la movilola del pasado sesión a sesión por el análisis descrito en Strategy class.
#
# Ouput:
# El sistema registra los siguientes parámetros:
#
# .-
# .-
# .-

# %%
startWindow
# Out:
# '2008-01-05'

# %%
tiempo_inicial = time()   # Tomamos tiempos para ver cuanto tarda en hacer la estrategia

# %%
dfe = pd.DataFrame({'A' : []})   #df empty

# %% [markdown]
# ***En este 'for' desplazamos la ventana sesión a sesión a lo largo de todo el rango de fechas. Dejamos que las funciones de la clase estrategia hagan el trabajo de comprar//vender y anotar***

# %%
#Para pruebas
#TOTAL_len =1000

for i in range(TOTAL_len):
    endWindow3   =endWindow2 + dt.timedelta(days=i) 
    endWindow    =endWindow3.strftime("%Y-%m-%d")
    print ('end date:', endWindow)
    
    if(endWindow in dff.index):
        df_aux= dff.loc[startWindow:endWindow]       #voy pasando los datos desplazando la ventana
        
        recogo = regreMedia.analisis(instrumento, startWindow, endWindow, df_aux) #Llamada a la clase estrategia. LA CLAVE DE TODO!!!
        
        print ('................................................Analizando, muestra', i, 'de', TOTAL_len, 'fecha', endWindow)
        
        """
        Tratamiento de los returns, mejor en las funciones de analisis que hacer aquí.
        if(recogo['senal'] == 1 ):
            dff.loc[[endWindow],['Senal']]= 1
        elif(recogo['senal'] == 0 ):
            dff.loc[[endWindow],['Senal']]= 0
        elif(recogo['senal'] == -1 ):
            dff.loc[[endWindow],['Senal']]= -1            
        elif(recogo['senal'] == 503 ):
            dff.loc[[endWindow],['Senal']]= 0          
        """
            
    else:
        print('..............Día sin sesión, next please')
# Out:
# end date: 2010-10-01
# fichero no existe
#  datos desde archivo
# Coefficients:
#  [0.13048627]
# Independent term:
#  2033.7925026928724
# Coefficients:
#  [-0.22744009]
# Independent term:
#  2307.7093868426423
# Coefficients:
#  [1.23706048]
# Independent term:
#  2036.8452541711424
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 0 de 5069 fecha 2010-10-01
# end date: 2010-10-02
# ..............Día sin sesión, next please
# end date: 2010-10-03
# ..............Día sin sesión, next please
# end date: 2010-10-04
#  datos desde archivo
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# Coefficients:
#  [0.13324584]
# Independent term:
#  2033.1578012609664
# Coefficients:
#  [-0.23035261]
# Independent term:
#  2308.687233121502
# Coefficients:
#  [1.22245935]
# Independent term:
#  2039.5501494840812
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 3 de 5069 fecha 2010-10-04
# end date: 2010-10-05
#  datos desde archivo
# Coefficients:
#  [0.13666994]
# Independent term:
#  2032.3691152455265
# Coefficients:
#  [-0.22926554]
# Independent term:
#  2309.6779701346786
# Coefficients:
#  [1.20801433]
# Independent term:
#  2042.23798849553
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 4 de 5069 fecha 2010-10-05
# end date: 2010-10-06
#  datos desde archivo
# Coefficients:
#  [0.13982436]
# Independent term:
#  2031.6414958166524
# Coefficients:
#  [-0.22659954]
# Independent term:
#  2310.2575527270874
# Coefficients:
#  [1.19373957]
# Independent term:
#  2044.9048498311674
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 5 de 5069 fecha 2010-10-06
# end date: 2010-10-07
#  datos desde archivo
# Coefficients:
#  [0.14298723]
# Independent term:
#  2030.9108735970544
# Coefficients:
#  [-0.21982267]
# Independent term:
#  2310.313304461579
# Coefficients:
#  [1.17967427]
# Independent term:
#  2047.5457299767438
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 6 de 5069 fecha 2010-10-07
# end date: 2010-10-08
#  datos desde archivo
# Coefficients:
#  [0.14634674]
# Independent term:
#  2030.133707492057
# Coefficients:
#  [-0.20827962]
# Independent term:
#  2309.9109710237876
# Coefficients:
#  [1.16586378]
# Independent term:
#  2050.156329390147
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 7 de 5069 fecha 2010-10-08
# end date: 2010-10-09
# ..............Día sin sesión, next please
# end date: 2010-10-10
# ..............Día sin sesión, next please
# end date: 2010-10-11
#  datos desde archivo
# Coefficients:
#  [0.14968079]
# Independent term:
#  2029.361319758582
# Coefficients:
#  [-0.19433944]
# Independent term:
#  2309.1873738485306
# Coefficients:
#  [1.15232942]
# Independent term:
#  2052.733752718091
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 10 de 5069 fecha 2010-10-11
# end date: 2010-10-12
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#  datos desde archivo
# Coefficients:
#  [0.15317613]
# Independent term:
#  2028.5503993623863
# Coefficients:
#  [-0.17585185]
# Independent term:
#  2308.009008606868
# Coefficients:
#  [1.13911369]
# Independent term:
#  2055.2738050154926
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 11 de 5069 fecha 2010-10-12
# end date: 2010-10-13
#  datos desde archivo
# Coefficients:
#  [0.15692552]
# Independent term:
#  2027.6792914104012
# Coefficients:
#  [-0.15327092]
# Independent term:
#  2306.5129549760964
# Coefficients:
#  [1.12625414]
# Independent term:
#  2057.7736970549017
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 12 de 5069 fecha 2010-10-13
# end date: 2010-10-14
#  datos desde archivo
# Coefficients:
#  [0.16056941]
# Independent term:
#  2026.8314791538637
# Coefficients:
#  [-0.13219241]
# Independent term:
#  2305.1505431217934
# Coefficients:
#  [1.11373228]
# Independent term:
#  2060.2351582097963
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 13 de 5069 fecha
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# 2010-10-14
# end date: 2010-10-15
#  datos desde archivo
# Coefficients:
#  [0.16458736]
# Independent term:
#  2025.8952975259701
# Coefficients:
#  [-0.10591658]
# Independent term:
#  2303.423548274254
# Coefficients:
#  [1.10159647]
# Independent term:
#  2062.654943185562
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 14 de 5069 fecha 2010-10-15
# end date: 2010-10-16
# ..............Día sin sesión, next please
# end date: 2010-10-17
# ..............Día sin sesión, next please
# end date: 2010-10-18
#  datos desde archivo
# Coefficients:
#  [0.16871362]
# Independent term:
#  2024.9325039125742
# Coefficients:
#  [-0.08146858]
# Independent term:
#  2302.0485226941464
# Coefficients:
#  [1.08982468]
# Independent term:
#  2065.036968852314
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 17 de 5069 fecha 2010-10-18
# end date: 2010-10-19
#  datos desde archivo
# Coefficients:
#  [0.1722728]
# Independent term:
#  2024.100841227716
# Coefficients:
#  [-0.05794163]
# Independent term:
#  2300.3502411161962
# Coefficients:
#  [1.07840412]
# Independent term:
#  2067.3783944469797
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 18 de 5069 fecha 2010-10-19
# end date: 2010-10-20
#  datos desde archivo
# Coefficients:
#  [0.17604675]
# Independent term:
#  2023.217736568488
# Coefficients:
#  [-0.03151302]
# Independent term:
#  2298.463993666919
# Coefficients:
#  [1.06736017]
# Independent term:
#  2069.677753643198
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 19 de 5069 fecha 2010-10-20
# end date: 2010-10-21
#  datos desde archivo
# Coefficients:
#  [0.17981404]
# Independent term:
#  2022.3349357126274
# Coefficients:
#  [-0.00611585]
# Independent term:
#  2296.7298747230643
# Coefficients:
#  [1.05667882]
# Independent term:
#  2071.9369787285696
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 20 de 5069 fecha 2010-10-21
# end date: 2010-10-22
#  datos desde archivo
# Coefficients:
#  [0.18378429]
# Independent term:
#  2021.4032514032363
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# Coefficients:
#  [0.02182993]
# Independent term:
#  2294.8459687645754
# Coefficients:
#  [1.04638181]
# Independent term:
#  2074.1549786294254
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 21 de 5069 fecha 2010-10-22
# end date: 2010-10-23
# ..............Día sin sesión, next please
# end date: 2010-10-24
# ..............Día sin sesión, next please
# end date: 2010-10-25
#  datos desde archivo
# Coefficients:
#  [0.1878561]
# Independent term:
#  2020.4463751552414
# Coefficients:
#  [0.05379806]
# Independent term:
#  2292.5335409135964
# Coefficients:
#  [1.03650536]
# Independent term:
#  2076.3278996471786
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 24 de 5069 fecha 2010-10-25
# end date: 2010-10-26
#  datos desde archivo
# Coefficients:
#  [0.19196824]
# Independent term:
#  2019.478652824121
# Coefficients:
#  [0.08574926]
# Independent term:
#  2290.278797443447
# Coefficients:
#  [1.0270451]
# Independent term:
#  2078.456764301868
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 25 de 5069 fecha 2010-10-26
# end date: 2010-10-27
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#  datos desde archivo
# Coefficients:
#  [0.19611454]
# Independent term:
#  2018.5015075987926
# Coefficients:
#  [0.1137765]
# Independent term:
#  2288.594836425781
# Coefficients:
#  [1.01795785]
# Independent term:
#  2080.5476903926533
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 26 de 5069 fecha 2010-10-27
# end date: 2010-10-28
#  datos desde archivo
# Coefficients:
#  [0.20027242]
# Independent term:
#  2017.5202474451635
# Coefficients:
#  [0.14594352]
# Independent term:
#  2286.3915685124184
# Coefficients:
#  [1.00928109]
# Independent term:
#  2082.59588818489
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 27 de 5069 fecha 2010-10-28
# end date: 2010-10-29
#  datos desde archivo
# Coefficients:
#  [0.20439341]
# Independent term:
#  2016.546319921429
# Coefficients:
#  [0.17914995]
# Independent term:
#  2284.040878505422
# Coefficients:
#  [1.00102108]
# Independent term:
#  2084.6003159492734
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 28 de 5069 fecha 2010-10-29
# end date: 2010-10-30
# ..............Día sin sesión, next please
# end date: 2010-10-31
# ..............Día sin sesión, next please
# end date: 2010-11-01
#  datos desde archivo
# Coefficients:
#  [0.20844698]
# Independent term:
#  2015.5869744676543
# Coefficients:
#  [0.20735264]
# Independent term:
#  2282.3189613820546
# Coefficients:
#  [0.99312388]
# Independent term:
#  2086.5676656550722
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 31 de 5069 fecha 2010-11-01
# end date: 2010-11-02
#  datos desde archivo
# Coefficients:
#  [0.2128021]
# Independent term:
#  2014.5548112320237
# Coefficients:
#  [0.24439655]
# Independent term:
#  2279.698692973123
# Coefficients:
#  [0.98567386]
# Independent term:
#  2088.489367419431
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 32 de 5069 fecha 2010-11-02
# end date: 2010-11-03
#  datos desde archivo
# Coefficients:
#  [0.21719756]
# Independent term:
#  2013.5116231864795
# Coefficients:
#  [0.27773378]
# Independent term:
#  2277.626739046467
# Coefficients:
#  [0.97862968]
# Independent term:
#  2090.3713313162175
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 33 de 5069 fecha 2010-11-03
# end date: 2010-11-04
#  datos desde archivo
# Coefficients:
#  [0.22198815]
# Independent term:
#  2012.373058789696
# Coefficients:
#  [0.31237855]
# Independent term:
#  2275.737785425898
# Coefficients:
#  [0.97200031]
# Independent term:
#  2092.215773645667
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 34 de 5069 fecha 2010-11-04
# end date: 2010-11-05
#  datos desde archivo
# Coefficients:
#  [0.22675528]
# Independent term:
#  2011.2384812460327
# Coefficients:
#  [0.33769358]
# Independent term:
#  2275.087389335063
# Coefficients:
#  [0.9656888]
# Independent term:
#  2094.0353917122284
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 35 de 5069 fecha 2010-11-05
# end date: 2010-11-06
# ..............Día sin sesión, next please
# end date: 2010-11-07
# ..............Día sin sesión, next please
# end date: 2010-11-08
#  datos desde archivo
# Coefficients:
#  [0.23149246]
# Independent term:
#  2010.1094533355997
# Coefficients:
#  [0.36343843]
# Independent term:
#  2274.3720266951377
# Coefficients:
#  [0.95969626]
# Independent term:
#  2095.829786090168
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 38 de 5069 fecha 2010-11-08
# end date: 2010-11-09
#  datos desde archivo
# Coefficients:
#  [0.23598908]
# Independent term:
#  2009.0362607295092
# Coefficients:
#  [0.38501578]
# Independent term:
#  2274.0213302748953
# Coefficients:
#  [0.95397805]
# Independent term:
#  2097.6028362810603
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 39 de 5069 fecha 2010-11-09
# end date: 2010-11-10
#  datos desde archivo
# Coefficients:
#  [0.24062867]
# Independent term:
#  2007.9273993183076
# Coefficients:
#  [0.41107778]
# Independent term:
#  2273.2150123527867
# Coefficients:
#  [0.94857605]
# Independent term:
#  2099.3502211175955
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 40 de 5069 fecha 2010-11-10
# end date: 2010-11-11
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#  datos desde archivo
# Coefficients:
#  [0.24495808]
# Independent term:
#  2006.891227039532
# Coefficients:
#  [0.4267386]
# Independent term:
#  2273.5393599507347
# Coefficients:
#  [0.94338364]
# Independent term:
#  2101.083446379617
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 41 de 5069 fecha 2010-11-11
# end date: 2010-11-12
#  datos desde archivo
# Coefficients:
#  [0.2488187]
# Independent term:
#  2005.9659644513406
# Coefficients:
#  [0.43149463]
# Independent term:
#  2274.9204345338735
# Coefficients:
#  [0.93829022]
# Independent term:
#  2102.8131676547837
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 42 de 5069 fecha 2010-11-12
# end date: 2010-11-13
# ..............Día sin sesión, next please
# end date: 2010-11-14
# ..............Día sin sesión, next please
# end date: 2010-11-15
#  datos desde archivo
# Coefficients:
#  [0.25259401]
# Independent term:
#  2005.0598898440057
# Coefficients:
#  [0.4386346]
# Independent term:
#  2275.9231079830342
# Coefficients:
#  [0.93331852]
# Independent term:
#  2104.535654623224
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 45 de 5069 fecha 2010-11-15
# end date: 2010-11-16
#  datos desde archivo
# Coefficients:
#  [0.25583107]
# Independent term:
#  2004.2819171596902
# Coefficients:
#  [0.44153969]
# Independent term:
#  2277.032952243179
# Coefficients:
#  [0.9284252]
# Independent term:
#  2106.252045644318
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 46 de 5069 fecha 2010-11-16
# end date: 2010-11-17
#  datos desde archivo
# Coefficients:
#  [0.25910898]
# Independent term:
#  2003.4930342107575
# Coefficients:
#  [0.44507409]
# Independent term:
#  2278.1067793114507
# Coefficients:
#  [0.92361574]
# Independent term:
#  2107.9620429942397
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 47 de 5069 fecha 2010-11-17
# end date: 2010-11-18
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#  datos desde archivo
# Coefficients:
#  [0.26279449]
# Independent term:
#  2002.6048246389864
# Coefficients:
#  [0.44403932]
# Independent term:
#  2280.154589151411
# Coefficients:
#  [0.91884383]
# Independent term:
#  2109.67540166247
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 48 de 5069 fecha 2010-11-18
# end date: 2010-11-19
#  datos desde archivo
# Coefficients:
#  [0.26648894]
# Independent term:
#  2001.7132317970477
# Coefficients:
#  [0.44534169]
# Independent term:
#  2281.910003607451
# Coefficients:
#  [0.91413237]
# Independent term:
#  2111.389178796251
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 49 de 5069 fecha 2010-11-19
# end date: 2010-11-20
# ..............Día sin sesión, next please
# end date: 2010-11-21
# ..............Día sin sesión, next please
# end date: 2010-11-22
#  datos desde archivo
# Coefficients:
#  [0.27030753]
# Independent term:
#  2000.790404399754
# Coefficients:
#  [0.44588128]
# Independent term:
#  2283.8861636762476
# Coefficients:
#  [0.90947315]
# Independent term:
#  2113.105566705505
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\template_B0\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 52 de 5069 fecha 2010-11-22
# end date: 2010-11-23
#  datos desde archivo
# Coefficients:
#  [0.27367259]
# Independent term:
#  1999.976060749227
# Coefficients:
#  [0.44402078]
# Independent term:
#  2285.7916827483673
# Coefficients:
#  [0.90484179]
# Independent term:
#  2114.8238365168772
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1      MTS.MC               1  2021-09-21   24.670000   5.460217      99.0
# 2        nvda               0  2021-09-28  206.990005  11.337221      99.0
# ................................................Analizando, muestra 53 de 5069 fecha 2010-11-23
# end date: 2010-11-24
#  datos desde archivo
# Coefficients:
#  [0.27755004]
# Independent term:
#  1999.036425413321
# Coefficients:
#  [0.44838146]
# Independent term:
#  2287.3340449364505
# Coefficients:
#  [0.90029989]
# Independent term:
#  2116.540356003639
# ...
# ..............Día sin sesión, next please
# end date: 2023-12-08
# ..............Día sin sesión, next please
# end date: 2023-12-09
# ..............Día sin sesión, next please
# end date: 2023-12-10
# ..............Día sin sesión, next please
# end date: 2023-12-11
# ..............Día sin sesión, next please
# end date: 2023-12-12
# ..............Día sin sesión, next please
# end date: 2023-12-13
# ..............Día sin sesión, next please
# end date: 2023-12-14
# ..............Día sin sesión, next please
# end date: 2023-12-15
# ..............Día sin sesión, next please
# end date: 2023-12-16
# ..............Día sin sesión, next please
# end date: 2023-12-17
# ..............Día sin sesión, next please
# end date: 2023-12-18
# ..............Día sin sesión, next please
# end date: 2023-12-19
# ..............Día sin sesión, next please
# end date: 2023-12-20
# ..............Día sin sesión, next please
# end date: 2023-12-21
# ..............Día sin sesión, next please
# end date: 2023-12-22
# ..............Día sin sesión, next please
# end date: 2023-12-23
# ..............Día sin sesión, next please
# end date: 2023-12-24
# ..............Día sin sesión, next please
# end date: 2023-12-25
# ..............Día sin sesión, next please
# end date: 2023-12-26
# ..............Día sin sesión, next please
# end date: 2023-12-27
# ..............Día sin sesión, next please
# end date: 2023-12-28
# ..............Día sin sesión, next please
# end date: 2023-12-29
# ..............Día sin sesión, next please
# end date: 2023-12-30
# ..............Día sin sesión, next please
# end date: 2023-12-31
# ..............Día sin sesión, next please
# end date: 2024-01-01
# ..............Día sin sesión, next please
# end date: 2024-01-02
# ..............Día sin sesión, next please
# end date: 2024-01-03
# ..............Día sin sesión, next please
# end date: 2024-01-04
# ..............Día sin sesión, next please
# end date: 2024-01-05
# ..............Día sin sesión, next please
# end date: 2024-01-06
# ..............Día sin sesión, next please
# end date: 2024-01-07
# ..............Día sin sesión, next please
# end date: 2024-01-08
# ..............Día sin sesión, next please
# end date: 2024-01-09
# ..............Día sin sesión, next please
# end date: 2024-01-10
# ..............Día sin sesión, next please
# end date: 2024-01-11
# ..............Día sin sesión, next please
# end date: 2024-01-12
# ..............Día sin sesión, next please
# end date: 2024-01-13
# ..............Día sin sesión, next please
# end date: 2024-01-14
# ..............Día sin sesión, next please
# end date: 2024-01-15
# ..............Día sin sesión, next please
# end date: 2024-01-16
# ..............Día sin sesión, next please
# end date: 2024-01-17
# ..............Día sin sesión, next please
# end date: 2024-01-18
# ..............Día sin sesión, next please
# end date: 2024-01-19
# ..............Día sin sesión, next please
# end date: 2024-01-20
# ..............Día sin sesión, next please
# end date: 2024-01-21
# ..............Día sin sesión, next please
# end date: 2024-01-22
# ..............Día sin sesión, next please
# end date: 2024-01-23
# ..............Día sin sesión, next please
# end date: 2024-01-24
# ..............Día sin sesión, next please
# end date: 2024-01-25
# ..............Día sin sesión, next please
# end date: 2024-01-26
# ..............Día sin sesión, next please
# end date: 2024-01-27
# ..............Día sin sesión, next please
# end date: 2024-01-28
# ..............Día sin sesión, next please
# end date: 2024-01-29
# ..............Día sin sesión, next please
# end date: 2024-01-30
# ..............Día sin sesión, next please
# end date: 2024-01-31
# ..............Día sin sesión, next please
# end date: 2024-02-01
# ..............Día sin sesión, next please
# end date: 2024-02-02
# ..............Día sin sesión, next please
# end date: 2024-02-03
# ..............Día sin sesión, next please
# end date: 2024-02-04
# ..............Día sin sesión, next please
# end date: 2024-02-05
# ..............Día sin sesión, next please
# end date: 2024-02-06
# ..............Día sin sesión, next please
# end date: 2024-02-07
# ..............Día sin sesión, next please
# end date: 2024-02-08
# ..............Día sin sesión, next please
# end date: 2024-02-09
# ..............Día sin sesión, next please
# end date: 2024-02-10
# ..............Día sin sesión, next please
# end date: 2024-02-11
# ..............Día sin sesión, next please
# end date: 2024-02-12
# ..............Día sin sesión, next please
# end date: 2024-02-13
# ..............Día sin sesión, next please
# end date: 2024-02-14
# ..............Día sin sesión, next please
# end date: 2024-02-15
# ..............Día sin sesión, next please
# end date: 2024-02-16
# ..............Día sin sesión, next please
# end date: 2024-02-17
# ..............Día sin sesión, next please
# end date: 2024-02-18
# ..............Día sin sesión, next please
# end date: 2024-02-19
# ..............Día sin sesión, next please
# end date: 2024-02-20
# ..............Día sin sesión, next please
# end date: 2024-02-21
# ..............Día sin sesión, next please
# end date: 2024-02-22
# ..............Día sin sesión, next please
# end date: 2024-02-23
# ..............Día sin sesión, next please
# end date: 2024-02-24
# ..............Día sin sesión, next please
# end date: 2024-02-25
# ..............Día sin sesión, next please
# end date: 2024-02-26
# ..............Día sin sesión, next please
# end date: 2024-02-27
# ..............Día sin sesión, next please
# end date: 2024-02-28
# ..............Día sin sesión, next please
# end date: 2024-02-29
# ..............Día sin sesión, next please
# end date: 2024-03-01
# ..............Día sin sesión, next please
# end date: 2024-03-02
# ..............Día sin sesión, next please
# end date: 2024-03-03
# ..............Día sin sesión, next please
# end date: 2024-03-04
# ..............Día sin sesión, next please
# end date: 2024-03-05
# ..............Día sin sesión, next please
# end date: 2024-03-06
# ..............Día sin sesión, next please
# end date: 2024-03-07
# ..............Día sin sesión, next please
# end date: 2024-03-08
# ..............Día sin sesión, next please
# end date: 2024-03-09
# ..............Día sin sesión, next please
# end date: 2024-03-10
# ..............Día sin sesión, next please
# end date: 2024-03-11
# ..............Día sin sesión, next please
# end date: 2024-03-12
# ..............Día sin sesión, next please
# end date: 2024-03-13
# ..............Día sin sesión, next please
# end date: 2024-03-14
# ..............Día sin sesión, next please
# end date: 2024-03-15
# ..............Día sin sesión, next please
# end date: 2024-03-16
# ..............Día sin sesión, next please
# end date: 2024-03-17
# ..............Día sin sesión, next please
# end date: 2024-03-18
# ..............Día sin sesión, next please
# end date: 2024-03-19
# ..............Día sin sesión, next please
# end date: 2024-03-20
# ..............Día sin sesión, next please
# end date: 2024-03-21
# ..............Día sin sesión, next please
# end date: 2024-03-22
# ..............Día sin sesión, next please
# end date: 2024-03-23
# ..............Día sin sesión, next please
# end date: 2024-03-24
# ..............Día sin sesión, next please
# end date: 2024-03-25
# ..............Día sin sesión, next please
# end date: 2024-03-26
# ..............Día sin sesión, next please
# end date: 2024-03-27
# ..............Día sin sesión, next please
# end date: 2024-03-28
# ..............Día sin sesión, next please
# end date: 2024-03-29
# ..............Día sin sesión, next please
# end date: 2024-03-30
# ..............Día sin sesión, next please
# end date: 2024-03-31
# ..............Día sin sesión, next please
# end date: 2024-04-01
# ..............Día sin sesión, next please
# end date: 2024-04-02
# ..............Día sin sesión, next please
# end date: 2024-04-03
# ..............Día sin sesión, next please
# end date: 2024-04-04
# ..............Día sin sesión, next please
# end date: 2024-04-05
# ..............Día sin sesión, next please
# end date: 2024-04-06
# ..............Día sin sesión, next please
# end date: 2024-04-07
# ..............Día sin sesión, next please
# end date: 2024-04-08
# ..............Día sin sesión, next please
# end date: 2024-04-09
# ..............Día sin sesión, next please
# end date: 2024-04-10
# ..............Día sin sesión, next please
# end date: 2024-04-11
# ..............Día sin sesión, next please
# end date: 2024-04-12
# ..............Día sin sesión, next please
# end date: 2024-04-13
# ..............Día sin sesión, next please
# end date: 2024-04-14
# ..............Día sin sesión, next please
# end date: 2024-04-15
# ..............Día sin sesión, next please
# end date: 2024-04-16
# ..............Día sin sesión, next please
# end date: 2024-04-17
# ..............Día sin sesión, next please
# end date: 2024-04-18
# ..............Día sin sesión, next please
# end date: 2024-04-19
# ..............Día sin sesión, next please
# end date: 2024-04-20
# ..............Día sin sesión, next please
# end date: 2024-04-21
# ..............Día sin sesión, next please
# end date: 2024-04-22
# ..............Día sin sesión, next please
# end date: 2024-04-23
# ..............Día sin sesión, next please
# end date: 2024-04-24
# ..............Día sin sesión, next please
# end date: 2024-04-25
# ..............Día sin sesión, next please
# end date: 2024-04-26
# ..............Día sin sesión, next please
# end date: 2024-04-27
# ..............Día sin sesión, next please
# end date: 2024-04-28
# ..............Día sin sesión, next please
# end date: 2024-04-29
# ..............Día sin sesión, next please
# end date: 2024-04-30
# ..............Día sin sesión, next please
# end date: 2024-05-01
# ..............Día sin sesión, next please
# end date: 2024-05-02
# ..............Día sin sesión, next please
# end date: 2024-05-03
# ..............Día sin sesión, next please
# end date: 2024-05-04
# ..............Día sin sesión, next please
# end date: 2024-05-05
# ..............Día sin sesión, next please
# end date: 2024-05-06
# ..............Día sin sesión, next please
# end date: 2024-05-07
# ..............Día sin sesión, next please
# end date: 2024-05-08
# ..............Día sin sesión, next please
# end date: 2024-05-09
# ..............Día sin sesión, next please
# end date: 2024-05-10
# ..............Día sin sesión, next please
# end date: 2024-05-11
# ..............Día sin sesión, next please
# end date: 2024-05-12
# ..............Día sin sesión, next please
# end date: 2024-05-13
# ..............Día sin sesión, next please
# end date: 2024-05-14
# ..............Día sin sesión, next please
# end date: 2024-05-15
# ..............Día sin sesión, next please
# end date: 2024-05-16
# ..............Día sin sesión, next please
# end date: 2024-05-17
# ..............Día sin sesión, next please
# end date: 2024-05-18
# ..............Día sin sesión, next please
# end date: 2024-05-19
# ..............Día sin sesión, next please
# end date: 2024-05-20
# ..............Día sin sesión, next please
# end date: 2024-05-21
# ..............Día sin sesión, next please
# end date: 2024-05-22
# ..............Día sin sesión, next please
# end date: 2024-05-23
# ..............Día sin sesión, next please
# end date: 2024-05-24
# ..............Día sin sesión, next please
# end date: 2024-05-25
# ..............Día sin sesión, next please
# end date: 2024-05-26
# ..............Día sin sesión, next please
# end date: 2024-05-27
# ..............Día sin sesión, next please
# end date: 2024-05-28
# ..............Día sin sesión, next please
# end date: 2024-05-29
# ..............Día sin sesión, next please
# end date: 2024-05-30
# ..............Día sin sesión, next please
# end date: 2024-05-31
# ..............Día sin sesión, next please
# end date: 2024-06-01
# ..............Día sin sesión, next please
# end date: 2024-06-02
# ..............Día sin sesión, next please
# end date: 2024-06-03
# ..............Día sin sesión, next please
# end date: 2024-06-04
# ..............Día sin sesión, next please
# end date: 2024-06-05
# ..............Día sin sesión, next please
# end date: 2024-06-06
# ..............Día sin sesión, next please
# end date: 2024-06-07
# ..............Día sin sesión, next please
# end date: 2024-06-08
# ..............Día sin sesión, next please
# end date: 2024-06-09
# ..............Día sin sesión, next please
# end date: 2024-06-10
# ..............Día sin sesión, next please
# end date: 2024-06-11
# ..............Día sin sesión, next please
# end date: 2024-06-12
# ..............Día sin sesión, next please
# end date: 2024-06-13
# ..............Día sin sesión, next please
# end date: 2024-06-14
# ..............Día sin sesión, next please
# end date: 2024-06-15
# ..............Día sin sesión, next please
# end date: 2024-06-16
# ..............Día sin sesión, next please
# end date: 2024-06-17
# ..............Día sin sesión, next please
# end date: 2024-06-18
# ..............Día sin sesión, next please
# end date: 2024-06-19
# ..............Día sin sesión, next please
# end date: 2024-06-20
# ..............Día sin sesión, next please
# end date: 2024-06-21
# ..............Día sin sesión, next please
# end date: 2024-06-22
# ..............Día sin sesión, next please
# end date: 2024-06-23
# ..............Día sin sesión, next please
# end date: 2024-06-24
# ..............Día sin sesión, next please
# end date: 2024-06-25
# ..............Día sin sesión, next please
# end date: 2024-06-26
# ..............Día sin sesión, next please
# end date: 2024-06-27
# ..............Día sin sesión, next please
# end date: 2024-06-28
# ..............Día sin sesión, next please
# end date: 2024-06-29
# ..............Día sin sesión, next please
# end date: 2024-06-30
# ..............Día sin sesión, next please
# end date: 2024-07-01
# ..............Día sin sesión, next please
# end date: 2024-07-02
# ..............Día sin sesión, next please
# end date: 2024-07-03
# ..............Día sin sesión, next please
# end date: 2024-07-04
# ..............Día sin sesión, next please
# end date: 2024-07-05
# ..............Día sin sesión, next please
# end date: 2024-07-06
# ..............Día sin sesión, next please
# end date: 2024-07-07
# ..............Día sin sesión, next please
# end date: 2024-07-08
# ..............Día sin sesión, next please
# end date: 2024-07-09
# ..............Día sin sesión, next please
# end date: 2024-07-10
# ..............Día sin sesión, next please
# end date: 2024-07-11
# ..............Día sin sesión, next please
# end date: 2024-07-12
# ..............Día sin sesión, next please
# end date: 2024-07-13
# ..............Día sin sesión, next please
# end date: 2024-07-14
# ..............Día sin sesión, next please
# end date: 2024-07-15
# ..............Día sin sesión, next please
# end date: 2024-07-16
# ..............Día sin sesión, next please
# end date: 2024-07-17
# ..............Día sin sesión, next please
# end date: 2024-07-18
# ..............Día sin sesión, next please
# end date: 2024-07-19
# ..............Día sin sesión, next please
# end date: 2024-07-20
# ..............Día sin sesión, next please
# end date: 2024-07-21
# ..............Día sin sesión, next please
# end date: 2024-07-22
# ..............Día sin sesión, next please
# end date: 2024-07-23
# ..............Día sin sesión, next please
# end date: 2024-07-24
# ..............Día sin sesión, next please
# end date: 2024-07-25
# ..............Día sin sesión, next please
# end date: 2024-07-26
# ..............Día sin sesión, next please
# end date: 2024-07-27
# ..............Día sin sesión, next please
# end date: 2024-07-28
# ..............Día sin sesión, next please
# end date: 2024-07-29
# ..............Día sin sesión, next please
# end date: 2024-07-30
# ..............Día sin sesión, next please
# end date: 2024-07-31
# ..............Día sin sesión, next please
# end date: 2024-08-01
# ..............Día sin sesión, next please
# end date: 2024-08-02
# ..............Día sin sesión, next please
# end date: 2024-08-03
# ..............Día sin sesión, next please
# end date: 2024-08-04
# ..............Día sin sesión, next please
# end date: 2024-08-05
# ..............Día sin sesión, next please
# end date: 2024-08-06
# ..............Día sin sesión, next please
# end date: 2024-08-07
# ..............Día sin sesión, next please
# end date: 2024-08-08
# ..............Día sin sesión, next please
# end date: 2024-08-09
# ..............Día sin sesión, next please
# end date: 2024-08-10
# ..............Día sin sesión, next please
# end date: 2024-08-11
# ..............Día sin sesión, next please
# end date: 2024-08-12
# ..............Día sin sesión, next please
# end date: 2024-08-13
# ..............Día sin sesión, next please
# end date: 2024-08-14
# ..............Día sin sesión, next please
# end date: 2024-08-15
# ..............Día sin sesión, next please
# end date: 2024-08-16
# ..............Día sin sesión, next please

# %% [markdown]
# ***Regogemos los datos de las entradas que ha realizado la Estrategia***

# %%
data=rg.StrategyClass.dfLog
#data.dropna(inplace=True)

# %%
data.tail()
# Out:
#                   Date Senal         Price Objetivo ExitReason  Beneficio
# 2021-11-11  2021-11-11     0  15704.280273      NaN        NaN        NaN
# 2021-11-12  2021-11-12     0  15860.959961      NaN        NaN        NaN
# 2021-11-15  2021-11-15     0  15853.849609      NaN        NaN        NaN
# 2021-11-16  2021-11-16     0  15973.860352      NaN        NaN        NaN
# 2021-11-17  2021-11-17     0  15921.570312      NaN        NaN        NaN

# %%
data['Senal'].plot(title = 'Señales de compra de la estrategia ' )
# Ploteando una parte
#data.loc['2010':'2022','Senal'].plot(title = 'Señales Regresión a la media ' +instrumento,xlim=('2010','2022'))
# Out:
# <AxesSubplot:title={'center':'Señales de compra de la estrategia '}>

# %%
tiempo_final = time() 
 
tiempo_ejecucion = tiempo_final - tiempo_inicial
 
print ('El tiempo de ejecucion fue:',tiempo_ejecucion,"segundos") #En segundos
# Out:
# El tiempo de ejecucion fue: 1378.9089975357056 segundos

# %%
data.loc['2011-01-04':'2019-11-04']
# Out:
#                   Date Senal        Price Objetivo ExitReason  Beneficio
# 2011-01-04  2011-01-04     0      2681.25      NaN        NaN        NaN
# 2011-01-05  2011-01-05     0  2702.199951      NaN        NaN        NaN
# 2011-01-06  2011-01-06     0  2709.889893      NaN        NaN        NaN
# 2011-01-07  2011-01-07     0  2703.169922      NaN        NaN        NaN
# 2011-01-10  2011-01-10     0  2707.800049      NaN        NaN        NaN
# ...                ...   ...          ...      ...        ...        ...
# 2019-10-29  2019-10-29     0  8276.849609      NaN        NaN        NaN
# 2019-10-30  2019-10-30     0  8303.980469      NaN        NaN        NaN
# 2019-10-31  2019-10-31     0  8292.360352      NaN        NaN        NaN
# 2019-11-01  2019-11-01     0  8386.400391      NaN        NaN        NaN
# 2019-11-04  2019-11-04     0  8433.200195      NaN        NaN        NaN
#
# [2224 rows x 6 columns]

# %%
#Guardamos el resultado del analisis en un pickle
#dff.to_pickle("./primerBack_IBE.pkl")

# %% [markdown]
# ***3.- Ingeniería de datos para calcular la bondad de la estrategia***

# %%
data['Dif_Close'] = data.Price.pct_change()
data['Retornos'] = data.Dif_Close * data.Senal.shift(1)   
data['Capital'] = (data.Retornos + 1).cumprod() * 100
    
rg.StrategyClass.dfLog=data  #Ojo a esta liena, no me cuadra.

#quant_j.salvarExcel(StrategyClass.dfLog, "log"+instrumento)   
#data.to_pickle('almacen')    #df = pd.read_pickle(file_name)

# %% [markdown]
# >Para calcular los retornos del sistema, calculamos la diferencia relativativa entre el precio de cierre y el del día anterior. Para posteriormente multiplicarlo por la señal que del día anterior que nos indicaba la posición a tomar (si estaba comprado, sumo beneficio).

# %%
data.tail()
# Out:
#                   Date Senal         Price Objetivo ExitReason  Beneficio  \
# 2021-11-11  2021-11-11     0  15704.280273      NaN        NaN        NaN
# 2021-11-12  2021-11-12     0  15860.959961      NaN        NaN        NaN
# 2021-11-15  2021-11-15     0  15853.849609      NaN        NaN        NaN
# 2021-11-16  2021-11-16     0  15973.860352      NaN        NaN        NaN
# 2021-11-17  2021-11-17     0  15921.570312      NaN        NaN        NaN
#
#             Dif_Close Retornos     Capital
# 2021-11-11   0.005221      0.0  261.260117
# 2021-11-12   0.009977      0.0  261.260117
# 2021-11-15  -0.000448     -0.0  261.260117
# 2021-11-16   0.007570      0.0  261.260117
# 2021-11-17  -0.003273     -0.0  261.260117

# %%
data[60:]
# Out:
#                   Date Senal         Price Objetivo ExitReason  Beneficio  \
# 2010-12-28  2010-12-28     0   2662.879883      NaN        NaN        NaN
# 2010-12-29  2010-12-29     0   2666.929932      NaN        NaN        NaN
# 2010-12-30  2010-12-30     0    2662.97998      NaN        NaN        NaN
# 2010-12-31  2010-12-31     0   2652.870117      NaN        NaN        NaN
# 2011-01-03  2011-01-03     0    2691.52002      NaN        NaN        NaN
# ...                ...   ...           ...      ...        ...        ...
# 2021-11-11  2021-11-11     0  15704.280273      NaN        NaN        NaN
# 2021-11-12  2021-11-12     0  15860.959961      NaN        NaN        NaN
# 2021-11-15  2021-11-15     0  15853.849609      NaN        NaN        NaN
# 2021-11-16  2021-11-16     0  15973.860352      NaN        NaN        NaN
# 2021-11-17  2021-11-17     0  15921.570312      NaN        NaN        NaN
#
#             Dif_Close Retornos     Capital
# 2010-12-28  -0.001646     -0.0       100.0
# 2010-12-29   0.001521      0.0       100.0
# 2010-12-30  -0.001481     -0.0       100.0
# 2010-12-31  -0.003796     -0.0       100.0
# 2011-01-03   0.014569      0.0       100.0
# ...               ...      ...         ...
# 2021-11-11   0.005221      0.0  261.260117
# 2021-11-12   0.009977      0.0  261.260117
# 2021-11-15  -0.000448     -0.0  261.260117
# 2021-11-16   0.007570      0.0  261.260117
# 2021-11-17  -0.003273     -0.0  261.260117
#
# [2743 rows x 9 columns]

# %% [markdown]
# >El capital, por comodidad, lo calcularemos en base 100, es decir como si iniciaramos la inversión con 100 unidades monetarias. Para su calculo arrastramos el producto acumulado de los retornos mas 1, multiplicados como dijimos por 100.

# %% [markdown]
# Pero para observar gráficamente la evolución del sistema necesitamos un gráfico con mas información. Para ello definimos una función que nos mostrará un gráfico con la evolución de nuestra estrategia, comparandola con la del activo. En un subgráfico se visualizará el drawdown del sistema, comparado de nuevo con el del activo. Y por útlimo las posiciones que toma el sistema.

# %%
def grafico (df):
    estudio = df.copy()
    DD_bh, maxDD, maxDD_ini, maxDD_fin = analisis.DrawDown(estudio.Dif_Close[60:], info = False) 
    DD, maxDD, maxDD_ini, maxDD_fin = analisis.DrawDown(estudio.Retornos.fillna(0), info = False) 

    fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True, figsize=(18, 12), gridspec_kw = {'height_ratios':[3, 1, 1]})
    fig.suptitle('Estrategia vs B & H', fontsize=20)

    #Primer plot analiza la evolcuion de una inversion de 100€ en buy&hold y la estrategia)
    ax1.plot(estudio.Capital)
    ax1.plot((estudio.Price) * (100/estudio.Price[1]))
    ax1.set_title('Capital')
    ax1.legend(['Estrategia','Buy & Hold'])

    ax2.plot(DD*100, c='0.5')
    ax2.plot(DD_bh*100, c='y')
    ax2.fill_between(DD.index, 0, DD*100, color='0.7')
    ax2.set_title('Drawdown')
    ax2.legend(['Estrategia','Buy & Hold'])

    ax3.plot(estudio.Senal, c='orange')
    #ax3.fill_between(estudio.index, 0, estudio.Senal*100, color='orange')
    ax3.set_title('Posición')

    plt.show()
    return

# %%
grafico(data)

# %% [markdown]
# ---

# %%
#data[55:70]

# %% [markdown]
# ---

# %% [markdown]
# # ANALISIS DEL SISTEMA

# %% [markdown]
# retornos=data.Retornos
# retornos
# retorno_acumulado = retornos.fillna(0).add(1).cumprod()
# retorno_acumulado
# dt_inicial = dt.datetime.strptime(retornos.index[1], '%Y-%m-%d')
# dt_final = dt.datetime.strptime(retornos.index[-1], '%Y-%m-%d')
# cagr = (retorno_acumulado[-1] / retorno_acumulado[1]) ** (365 / (dt_final - dt_inicial).days ) - 1
# cagr

# %%
Beneficio_Bruto = data.Capital[-1] - data.Capital[1]
print ('Beneficio Bruto : {:.2f} €  con una inverison de 100€'.format(Beneficio_Bruto))
# Out:
# Beneficio Bruto : 161.26 €  con una inverison de 100€

# %%
#Rentabilidad anual compuesta. Calculamos lo que la inversion se ha incrementado cada año con el interes compuesto
CAGR = analisis.CAGR(data.Retornos)
print ('CAGR : {:.2f}%'.format(CAGR * 100))
# Out:
# CAGR : 9.01%

# %%
#Ratio calculado restando una rentabilidad segura a nuestra rentabilidad de estrategia y dividido por el riego (=volatilidad)
data.Retornos=data.Retornos.replace(0,np.e)  #Quito los cero (no sepuede hacer logariotmo de cero), pero no se que poner
Sharpe = CAGR / (np.log(data.Retornos + 1).std(skipna=True) * 252 ** 0.5)
print ('Sharpe : {:.3f}'.format(CAGR ))
# Out:
# Sharpe : 0.090

# %% [markdown]
# ---

# %% [markdown]
# # PRUEBA FUERA DE LA MUESTRA

# %% [markdown]
# periodo_rapido = 5
#
# periodo_lento = 140
#
# out_sample= qd_data[data.shape[0]:].copy()
#
# out_sample['Dif_Close'] = out_sample.Close.pct_change()
# out_sample['Dif_Open'] = out_sample.Close.pct_change()  #era Cloe
#
#
# out_estr, out_resultado = estrategia_medias (out_sample, periodo_rapido, periodo_lento)

# %% [markdown]
# grafico(out_estr)

# %% [markdown]
# ---
