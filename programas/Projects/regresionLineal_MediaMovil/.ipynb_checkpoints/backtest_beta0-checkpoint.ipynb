# %% [markdown]
# # Backtest vectorizado y optimización de parametros con Pandas.
#
# ## Hackeado by J3viton (learning BackTesting 2021).

# %% [markdown]
# ---

# %% [markdown]
# En este Notebook vamos a realizar un backtest de una estrategia sencilla. Se trata de un cruce de medias, que se puede considerar el "Hello World!" de los sistemas automáticos.
#
# Vamos a usar el módulo Pandas, para realizar un backtest vectorizado, es decir calcular el resultado del backtest sin iterar sobre las filas (barras) de la serie temporal.

# %% [markdown]
# Posteriormente realizarmos una optimización de los parametros del sistema, y veremos como el calculo vectorizador nos permite hacer un gran número de backtests para la optimización en un tiempo muy breve.

# %% [markdown]
# ---

# %% [markdown]
# # IMPORTACIÓN DE MODULOS Y CARGA DE DATOS

# %% [markdown]
# Como es usual, importamos los módulos que vamos a necesitar para las distintas tareas, y preparamos Matplotlib para una mejor visualización de los gráficos en el notebook.
#
# Se importa un modulo llamado **analisis**, en realidad se trata de un archivo .py con algunas funciones de apoyo para el trabajo, debe estar guardado en la misma carpeta que este notebook.

# %%
import pandas as pd
import analisis   
import numpy as np
import itertools
import seaborn as sns
import yfinance as yf

# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = 18, 8
plt.style.use('ggplot')

from IPython.display import display, Markdown

# %% [markdown]
# Importamos el modulo **quandl** que nos proporcionará una descarga de los datos que vamos a necesitar, en este caso la cotización diaria de las acciones de Apple.

# %%
# import quandl
# quandl.ApiConfig.api_key = "Aquí va tu API KEY" # Para una descarga ocasional no necesitas la API KEY.
# qd_data = quandl.get("WIKI/AAPL", start_date= "2000-01-01", end_date= "2018-06-15")

qd_data = yf.download('MTS.MC', '2015-1-1','2021-1-1')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Tambien puedes cargar los datos desde el archivo pickle.

# %%
# qd_data = pd.read_pickle('apple_qd.pkl')

# %% [markdown]
# Veamos la cabecera del dataframe que acabamos de crear con los datos descargados.

# %%
qd_data.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2015-01-02  18.666080  18.892052  18.313890  18.340355  17.308128  571717
# 2015-01-05  18.279282  18.466574  17.629868  17.650225  16.656836  584564
# 2015-01-06  17.739799  18.051273  17.576937  17.646154  16.652998  428394
# 2015-01-07  17.788658  18.026846  17.530113  17.627832  16.635706  440488
# 2015-01-08  17.756086  18.324068  17.713335  18.293531  17.263937  525319

# %% [markdown]
# La tabla muestra que tenemos datos sin ajustar y ajustados. Tomaremos solo los datos OHLCV ajustados y el volumen, prescindiremos del resto de columnas, y eliminaremos el prefijo __Adj.__ para mas comodidad de uso.
#
# Estudiar las posibildades de Python en vectorizado ...

# %%
ajustadas = [f for f in qd_data.columns if f.startswith('Adj')]  # guardamos una lista con las cabeceras de las columnas
qd_data = qd_data[ajustadas].copy()    # guardamos la tabla con las cabeceras selecionas arriba
qd_data.columns = [f[4:] for f in qd_data.columns]  #quitamos los literales
qd_data.head()
# Out:
#                 Close
# Date
# 2015-01-02  17.308128
# 2015-01-05  16.656836
# 2015-01-06  16.652998
# 2015-01-07  16.635706
# 2015-01-08  17.263937

# %% [markdown]
# Para usarlo en nuestro backtest vamos a hacer una copia del dataframe pero solo hasta 2017.

# %%
data = qd_data[:-1].copy()

# %%
data.head()
# Out:
#                 Close
# Date
# 2015-01-02  17.308128
# 2015-01-05  16.656836
# 2015-01-06  16.652998
# 2015-01-07  16.635706
# 2015-01-08  17.263937

# %% [markdown]
# ---

# %% [markdown]
# # DEFINICION DEL SISTEMA

# %% [markdown]
# Es importante tener clara la lógica del sistema, pues debemos plasmarla de forma sencilla y correcta en el dataframe para realizar el backtest del mismo.
#
# Esta estrategia utiliza dos medias simples del precio de cierre, de 20 y 60 periodos. Calculemoslas y asignamos sus valores a nuevas columnas de nuestro dataframe.
#
# Para ello usamos la función **rolling** de Pandas, que va _rodando_ una ventana de N valores, sobre la que realiza un calculo, en este caso la media.
# https://github.com/Python-para-Trading/Webinars-Docs/blob/master/Webinar%202/Webinar%202%20-%20Backtest%20con%20Pandas%20v%202.ipynb.

# %%
import analisis
import regresionAMedia_v2 as rg
import pandas as pd
import datetime as dt
from time import time
# Out:
# {'first_name': 'vital_bot', 'username': 'vital_quant_bot', 'id': 1473252352, 'supports_inline_queries': False, 'can_join_groups': True, 'can_read_all_group_messages': False, 'is_bot': True}

# %%
# Rango completo para backTesting
start2 =dt.datetime(2005,1,2)
end2   =dt.datetime(2021,11,10)
start_G= start2.strftime("%Y-%m-%d")
end_G  =   end2.strftime("%Y-%m-%d")
TOTAL_len= (end2-start2).days
print('Tamaño timeseries a analizar:  ', TOTAL_len, 'sesiones')

#ventana de analisis 200 sesiones
startWindow2 =dt.datetime(2010,1,5)
endWindow2   =startWindow2 + dt.timedelta(days=200) 
startWindow= startWindow2.strftime("%Y-%m-%d")
endWindow  =   endWindow2.strftime("%Y-%m-%d")
window_len= (endWindow2-startWindow2).days
print('Tamaño de la ventana a analizar paso a paso:  ', window_len, 'sesiones')
# Out:
# Tamaño timeseries a analizar:   6156 sesiones
# Tamaño de la ventana a analizar paso a paso:   200 sesiones

# %%
 #dff = pd.DataFrame(columns=('Close','Volume', 'Senal', 'Dif_Close', 'Retornos','Capital'))

# %%
dff = yf.download('MTS.MC', start_G,end_G)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#dff['Close']= Total_data['Close']
#dff.dropna(inplace=True)  
dff.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2006-07-28  57.001884  57.001884  52.767456  52.767456  40.342461    1273
# 2006-07-31  56.981525  56.981525  53.337475  53.968567  41.260754   23281
# 2006-08-01  54.151787  55.454689  53.948212  54.742165  41.852192   42782
# 2006-08-02  55.006817  55.006817  53.744633  53.887138  41.198502  453870
# 2006-08-03  54.029640  54.660732  53.744633  54.558945  41.712120   72482

# %%
regreMedia= rg.StrategyClass()    #Creamos la clase

# %%
#recogo = regreMedia.analisis_IN('MTS.MC', startWindow, endWindow, dff)
#type(recogo)

# %% [markdown]
# ### Miro si el resultado de la estrategia me da la señal de compra (100) y lo marco en la tabla
# if(recogo['senal'] == 100 ):
#     dff.loc[[start],['Senal']]=100
# else:
#     dff.loc[[start],['Senal']]=1
#
# dff.head()
# dff.tail()

# %% [markdown]
# ## 4.- Recorremos el datafrema con valores buscando las señales de la estrategia

# %%
dff.index
# Out:
# DatetimeIndex(['2006-07-28', '2006-07-31', '2006-08-01', '2006-08-02',
#                '2006-08-03', '2006-08-04', '2006-08-07', '2006-08-08',
#                '2006-08-09', '2006-08-10',
#                ...
#                '2021-10-27', '2021-10-28', '2021-10-29', '2021-11-01',
#                '2021-11-02', '2021-11-03', '2021-11-04', '2021-11-05',
#                '2021-11-08', '2021-11-09'],
#               dtype='datetime64[ns]', name='Date', length=3906, freq=None)

# %% [markdown]
# start ='2010-1-5'
# #dff.loc[start]
# if((start in dff.index)and(end in dff.index)) :
#     print('si')

# %%
#dff.loc[[endWindow],['Close']]

# %% [markdown]
# # Proceso de backTesting
# En este 'for' vamos recorriendo la muestra del historico de datos (TOTAL), desplaznado una sesion hacia el futuro
# en cada iteracion. Marcamos en la columna 'senal' las entradas como 100.

# %%
startWindow
# Out:
# '2010-01-05'

# %%
tiempo_inicial = time()

# %%
dfe = pd.DataFrame({'A' : []})   #df empty

# %%
for i in range  (TOTAL_len):
    endWindow3   =endWindow2 + dt.timedelta(days=i) 
    endWindow    =endWindow3.strftime("%Y-%m-%d")
    print (endWindow)
    
    if(endWindow in dff.index):
        df_aux= dff.loc[startWindow:endWindow]    #voy pasando los datos desplazando la ventana
        recogo = regreMedia.analisis_IN('MTS.MC', startWindow, endWindow, df_aux) #Llamada a la clase estrategia. LA CLAVE DE TODO!!!
        print ('.............Analizando, muestra', i, 'fecha', endWindow)
        if(recogo['senal'] == 1 ):
            dff.loc[[endWindow],['Senal']]= 1
        elif(recogo['senal'] == 0 ):
            dff.loc[[endWindow],['Senal']]= 0
        elif(recogo['senal'] == -1 ):
            dff.loc[[endWindow],['Senal']]= -1            
        elif(recogo['senal'] == 503 ):
            dff.loc[[endWindow],['Senal']]= 0          
            
    else:
        print('..............Día sin sesión, next please')
# Out:
# 2010-07-24
# ..............Día sin sesión, next please
# 2010-07-25
# ..............Día sin sesión, next please
# 2010-07-26
#  datos desde archivo
# Coefficients:
#  [-0.13189286]
# Independent term:
#  66.76460528985048
# Coefficients:
#  [-0.13189286]
# Independent term:
#  66.76460528985048
# DataFrame is empty!
# .............Analizando, muestra 2 fecha 2010-07-26
# 2010-07-27
#  datos desde archivo
# Coefficients:
#  [-0.13119436]
# Independent term:
#  66.73154306923293
# Coefficients:
#  [-0.13119436]
# Independent term:
#  66.73154306923293
# DataFrame is empty!
# .............Analizando, muestra 3 fecha 2010-07-27
# 2010-07-28
#  datos desde archivo
# Coefficients:
#  [-0.13081607]
# Independent term:
#  66.71351106559887
# Coefficients:
#  [-0.13081607]
# Independent term:
#  66.71351106559887
# DataFrame is empty!
# .............Analizando, muestra 4 fecha 2010-07-28
# 2010-07-29
#  datos desde archivo
# Coefficients:
#  [-0.13071818]
# Independent term:
#  66.70881229770693
# Coefficients:
#  [-0.13071818]
# Independent term:
#  66.70881229770693
# DataFrame is empty!
# .............Analizando, muestra 5 fecha 2010-07-29
# 2010-07-30
#  datos desde archivo
# Coefficients:
#  [-0.13073977]
# Independent term:
#  66.70985575488525
# Coefficients:
#  [-0.13073977]
# Independent term:
#  66.70985575488525
# DataFrame is empty!
# .............Analizando, muestra 6 fecha 2010-07-30
# 2010-07-31
# ..............Día sin sesión, next please
# 2010-08-01
# ..............Día sin sesión, next please
# 2010-08-02
#  datos desde archivo
# Coefficients:
#  [-0.12995223]
# Independent term:
#  66.67152865448081
# Coefficients:
#  [-0.12995223]
# Independent term:
#  66.67152865448081
# DataFrame is empty!
# .............Analizando, muestra 9 fecha 2010-08-02
# 2010-08-03
#  datos desde archivo
# Coefficients:
#  [-0.12911463]
# Independent term:
#  66.63048656489225
# Coefficients:
#  [-0.12911463]
# Independent term:
#  66.63048656489225
# DataFrame is empty!
# .............Analizando, muestra 10 fecha 2010-08-03
# 2010-08-04
#  datos desde archivo
# Coefficients:
#  [-0.12809524]
# Independent term:
#  66.58019644966714
# Coefficients:
#  [-0.12809524]
# Independent term:
#  66.58019644966714
# DataFrame is empty!
# .............Analizando, muestra 11 fecha 2010-08-04
# 2010-08-05
#  datos desde archivo
# Coefficients:
#  [-0.1270025]
# Independent term:
#  66.52592394833118
# Coefficients:
#  [-0.1270025]
# Independent term:
#  66.52592394833118
# DataFrame is empty!
# .............Analizando, muestra 12 fecha 2010-08-05
# 2010-08-06
#  datos desde archivo
# Coefficients:
#  [-0.1259931]
# Independent term:
#  66.47545397121716
# Coefficients:
#  [-0.1259931]
# Independent term:
#  66.47545397121716
# DataFrame is empty!
# .............Analizando, muestra 13 fecha 2010-08-06
# 2010-08-07
# ..............Día sin sesión, next please
# 2010-08-08
# ..............Día sin sesión, next please
# 2010-08-09
#  datos desde archivo
# Coefficients:
#  [-0.12491293]
# Independent term:
#  66.42108521843167
# Coefficients:
#  [-0.12491293]
# Independent term:
#  66.42108521843167
# DataFrame is empty!
# .............Analizando, muestra 16 fecha 2010-08-09
# 2010-08-10
#  datos desde archivo
# Coefficients:
#  [-0.12402712]
# Independent term:
#  66.3762040376763
# Coefficients:
#  [-0.12402712]
# Independent term:
#  66.3762040376763
# DataFrame is empty!
# .............Analizando, muestra 17 fecha 2010-08-10
# 2010-08-11
#  datos desde archivo
# Coefficients:
#  [-0.12362933]
# Independent term:
#  66.35591686901915
# Coefficients:
#  [-0.12362933]
# Independent term:
#  66.35591686901915
# DataFrame is empty!
# .............Analizando, muestra 18 fecha 2010-08-11
# 2010-08-12
#  datos desde archivo
# Coefficients:
#  [-0.123356]
# Independent term:
#  66.34188606122652
# Coefficients:
#  [-0.123356]
# Independent term:
#  66.34188606122652
# DataFrame is empty!
# .............Analizando, muestra 19 fecha 2010-08-12
# 2010-08-13
#  datos desde archivo
# Coefficients:
#  [-0.12305823]
# Independent term:
#  66.32650100036292
# Coefficients:
#  [-0.12305823]
# Independent term:
#  66.32650100036292
# DataFrame is empty!
# .............Analizando, muestra 20 fecha 2010-08-13
# 2010-08-14
# ..............Día sin sesión, next please
# 2010-08-15
# ..............Día sin sesión, next please
# 2010-08-16
#  datos desde archivo
# Coefficients:
#  [-0.12271791]
# Independent term:
#  66.30880480106445
# Coefficients:
#  [-0.12271791]
# Independent term:
#  66.30880480106445
# DataFrame is empty!
# .............Analizando, muestra 23 fecha 2010-08-16
# 2010-08-17
#  datos desde archivo
# Coefficients:
#  [-0.12205405]
# Independent term:
#  66.27406277506607
# Coefficients:
#  [-0.12205405]
# Independent term:
#  66.27406277506607
# DataFrame is empty!
# .............Analizando, muestra 24 fecha 2010-08-17
# 2010-08-18
#  datos desde archivo
# Coefficients:
#  [-0.12149067]
# Independent term:
#  66.2443911362879
# Coefficients:
#  [-0.12149067]
# Independent term:
#  66.2443911362879
# DataFrame is empty!
# .............Analizando, muestra 25 fecha 2010-08-18
# 2010-08-19
#  datos desde archivo
# Coefficients:
#  [-0.12110506]
# Independent term:
#  66.22395374639461
# Coefficients:
#  [-0.12110506]
# Independent term:
#  66.22395374639461
# DataFrame is empty!
# .............Analizando, muestra 26 fecha 2010-08-19
# 2010-08-20
#  datos desde archivo
# Coefficients:
#  [-0.12093963]
# Independent term:
#  66.21513117326712
# Coefficients:
#  [-0.12093963]
# Independent term:
#  66.21513117326712
# DataFrame is empty!
# .............Analizando, muestra 27 fecha 2010-08-20
# 2010-08-21
# ..............Día sin sesión, next please
# 2010-08-22
# ..............Día sin sesión, next please
# 2010-08-23
#  datos desde archivo
# Coefficients:
#  [-0.12076679]
# Independent term:
#  66.20585514167354
# Coefficients:
#  [-0.12076679]
# Independent term:
#  66.20585514167354
# DataFrame is empty!
# .............Analizando, muestra 30 fecha 2010-08-23
# 2010-08-24
#  datos desde archivo
# Coefficients:
#  [-0.12081717]
# Independent term:
#  66.2085754715947
# Coefficients:
#  [-0.12081717]
# Independent term:
#  66.2085754715947
# DataFrame is empty!
# .............Analizando, muestra 31 fecha 2010-08-24
# 2010-08-25
#  datos desde archivo
# Coefficients:
#  [-0.12111353]
# Independent term:
#  66.2246778512532
# Coefficients:
#  [-0.12111353]
# Independent term:
#  66.2246778512532
# DataFrame is empty!
# .............Analizando, muestra 32 fecha 2010-08-25
# 2010-08-26
#  datos desde archivo
# Coefficients:
#  [-0.12122989]
# Independent term:
#  66.23103918498423
# Coefficients:
#  [-0.12122989]
# Independent term:
#  66.23103918498423
# DataFrame is empty!
# .............Analizando, muestra 33 fecha 2010-08-26
# 2010-08-27
#  datos desde archivo
# Coefficients:
#  [-0.1211007]
# Independent term:
#  66.22393330067422
# Coefficients:
#  [-0.1211007]
# Independent term:
#  66.22393330067422
# DataFrame is empty!
# .............Analizando, muestra 34 fecha 2010-08-27
# 2010-08-28
# ..............Día sin sesión, next please
# 2010-08-29
# ..............Día sin sesión, next please
# 2010-08-30
#  datos desde archivo
# Coefficients:
#  [-0.12097628]
# Independent term:
#  66.21704887880276
# Coefficients:
#  [-0.12097628]
# Independent term:
#  66.21704887880276
# DataFrame is empty!
# .............Analizando, muestra 37 fecha 2010-08-30
# 2010-08-31
#  datos desde archivo
# Coefficients:
#  [-0.1208012]
# Independent term:
#  66.20730287795527
# Coefficients:
#  [-0.1208012]
# Independent term:
#  66.20730287795527
# DataFrame is empty!
# .............Analizando, muestra 38 fecha 2010-08-31
# 2010-09-01
#  datos desde archivo
# Coefficients:
#  [-0.12022493]
# Independent term:
#  66.17503176867285
# Coefficients:
#  [-0.12022493]
# Independent term:
#  66.17503176867285
# DataFrame is empty!
# .............Analizando, muestra 39 fecha 2010-09-01
# 2010-09-02
#  datos desde archivo
# Coefficients:
#  [-0.119478]
# Independent term:
#  66.13295477191785
# Coefficients:
#  [-0.119478]
# Independent term:
#  66.13295477191785
# DataFrame is empty!
# .............Analizando, muestra 40 fecha 2010-09-02
# 2010-09-03
#  datos desde archivo
# Coefficients:
#  [-0.11866295]
# Independent term:
#  66.0867686181287
# Coefficients:
#  [-0.11866295]
# Independent term:
#  66.0867686181287
# DataFrame is empty!
# .............Analizando, muestra 41 fecha 2010-09-03
# 2010-09-04
# ..............Día sin sesión, next please
# 2010-09-05
# ..............Día sin sesión, next please
# 2010-09-06
#  datos desde archivo
# Coefficients:
#  [-0.11775075]
# Independent term:
#  66.03477302309477
# Coefficients:
#  [-0.11775075]
# Independent term:
#  66.03477302309477
# DataFrame is empty!
# .............Analizando, muestra 44 fecha 2010-09-06
# 2010-09-07
#  datos desde archivo
# Coefficients:
#  [-0.11680833]
# Independent term:
#  65.98074103620056
# Coefficients:
#  [-0.11680833]
# Independent term:
#  65.98074103620056
# DataFrame is empty!
# .............Analizando, muestra 45 fecha 2010-09-07
# 2010-09-08
#  datos desde archivo
# Coefficients:
#  [-0.11568474]
# Independent term:
#  65.91594750292889
# Coefficients:
#  [-0.11568474]
# Independent term:
#  65.91594750292889
# DataFrame is empty!
# .............Analizando, muestra 46 fecha 2010-09-08
# 2010-09-09
#  datos desde archivo
# Coefficients:
#  [-0.11458851]
# Independent term:
#  65.85236590962931
# Coefficients:
#  [-0.11458851]
# Independent term:
#  65.85236590962931
# DataFrame is empty!
# .............Analizando, muestra 47 fecha 2010-09-09
# 2010-09-10
#  datos desde archivo
# Coefficients:
#  [-0.11346455]
# Independent term:
#  65.78680155462351
# Coefficients:
#  [-0.11346455]
# Independent term:
#  65.78680155462351
# DataFrame is empty!
# .............Analizando, muestra 48 fecha 2010-09-10
# 2010-09-11
# ..............Día sin sesión, next please
# 2010-09-12
# ..............Día sin sesión, next please
# 2010-09-13
#  datos desde archivo
# Coefficients:
#  [-0.11224551]
# Independent term:
#  65.71528461823377
# Coefficients:
#  [-0.11224551]
# Independent term:
#  65.71528461823377
# DataFrame is empty!
# .............Analizando, muestra 51 fecha 2010-09-13
# 2010-09-14
#  datos desde archivo
# Coefficients:
#  [-0.11120899]
# Independent term:
#  65.65412997453572
# Coefficients:
#  [-0.11120899]
# Independent term:
#  65.65412997453572
# DataFrame is empty!
# .............Analizando, muestra 52 fecha 2010-09-14
# 2010-09-15
#  datos desde archivo
# Coefficients:
#  [-0.11022178]
# Independent term:
#  65.59555524728867
# Coefficients:
#  [-0.11022178]
# Independent term:
#  65.59555524728867
# DataFrame is empty!
# .............Analizando, muestra 53 fecha 2010-09-15
# 2010-09-16
#  datos desde archivo
# Coefficients:
#  [-0.10937848]
# Independent term:
#  65.5452387848373
# Coefficients:
#  [-0.10937848]
# Independent term:
#  65.5452387848373
# DataFrame is empty!
# .............Analizando, muestra 54 fecha 2010-09-16
# 2010-09-17
#  datos desde archivo
# Coefficients:
#  [-0.10835044]
# Independent term:
#  65.48355646190117
# Coefficients:
#  [-0.10835044]
# Independent term:
#  65.48355646190117
# DataFrame is empty!
# .............Analizando, muestra 55 fecha 2010-09-17
# 2010-09-18
# ..............Día sin sesión, next please
# 2010-09-19
# ..............Día sin sesión, next please
# 2010-09-20
#  datos desde archivo
# Coefficients:
#  [-0.10735639]
# Independent term:
#  65.42358182280385
# Coefficients:
#  [-0.10735639]
# Independent term:
#  65.42358182280385
# DataFrame is empty!
# .............Analizando, muestra 58 fecha 2010-09-20
# 2010-09-21
#  datos desde archivo
# Coefficients:
#  [-0.10640059]
# Independent term:
#  65.36559693395881
# Coefficients:
#  [-0.10640059]
# Independent term:
#  65.36559693395881
# DataFrame is empty!
# .............Analizando, muestra 59 fecha 2010-09-21
# 2010-09-22
#  datos desde archivo
# Coefficients:
#  [-0.10554566]
# Independent term:
#  65.31344568373956
# Coefficients:
#  [-0.10554566]
# Independent term:
#  65.31344568373956
# DataFrame is empty!
# .............Analizando, muestra 60 fecha 2010-09-22
# 2010-09-23
#  datos desde archivo
# Coefficients:
#  [-0.10486836]
# Independent term:
#  65.27190487194648
# Coefficients:
#  [-0.10486836]
# Independent term:
#  65.27190487194648
# DataFrame is empty!
# .............Analizando, muestra 61 fecha 2010-09-23
# 2010-09-24
#  datos desde archivo
# Coefficients:
#  [-0.10411128]
# Independent term:
#  65.22521827603136
# Coefficients:
#  [-0.10411128]
# Independent term:
#  65.22521827603136
# DataFrame is empty!
# .............Analizando, muestra 62 fecha 2010-09-24
# 2010-09-25
# ..............Día sin sesión, next please
# 2010-09-26
# ..............Día sin sesión, next please
# 2010-09-27
#  datos desde archivo
# Coefficients:
#  [-0.10341209]
# Independent term:
#  65.18186858826817
# Coefficients:
#  [-0.10341209]
# Independent term:
#  65.18186858826817
# DataFrame is empty!
# .............Analizando, muestra 65 fecha 2010-09-27
# 2010-09-28
#  datos desde archivo
# Coefficients:
#  [-0.10261894]
# Independent term:
#  65.13242908245141
# Coefficients:
#  [-0.10261894]
# Independent term:
#  65.13242908245141
# DataFrame is empty!
# .............Analizando, muestra 66 fecha 2010-09-28
# 2010-09-29
#  datos desde archivo
# Coefficients:
#  [-0.10199181]
# Independent term:
#  65.09312869145805
# Coefficients:
#  [-0.10199181]
# Independent term:
#  65.09312869145805
# DataFrame is empty!
# .............Analizando, muestra 67 fecha 2010-09-29
# 2010-09-30
#  datos desde archivo
# Coefficients:
#  [-0.10143577]
# Independent term:
#  65.0580978955274
# Coefficients:
#  [-0.10143577]
# Independent term:
#  65.0580978955274
# DataFrame is empty!
# .............Analizando, muestra 68 fecha 2010-09-30
# 2010-10-01
#  datos desde archivo
# Coefficients:
#  [-0.10084753]
# Independent term:
#  65.02084300225675
# Coefficients:
#  [-0.10084753]
# Independent term:
#  65.02084300225675
# DataFrame is empty!
# .............Analizando, muestra 69 fecha 2010-10-01
# 2010-10-02
# ..............Día sin sesión, next please
# 2010-10-03
# ..............Día sin sesión, next please
# 2010-10-04
#  datos desde archivo
# Coefficients:
#  [-0.10048307]
# Independent term:
#  64.99763897543859
# Coefficients:
#  [-0.10048307]
# Independent term:
#  64.99763897543859
# DataFrame is empty!
# .............Analizando, muestra 72 fecha 2010-10-04
# 2010-10-05
#  datos desde archivo
# Coefficients:
#  [-0.09996853]
# Independent term:
#  64.96470843261429
# Coefficients:
#  [-0.09996853]
# Independent term:
#  64.96470843261429
# DataFrame is empty!
# .............Analizando, muestra 73 fecha 2010-10-05
# 2010-10-06
#  datos desde archivo
# Coefficients:
#  [-0.09939484]
# Independent term:
#  64.92780126434917
# Coefficients:
#  [-0.09939484]
# Independent term:
#  64.92780126434917
# DataFrame is empty!
# .............Analizando, muestra 74 fecha 2010-10-06
# 2010-10-07
#  datos desde archivo
# Coefficients:
#  [-0.0987361]
# Independent term:
#  64.88520254496527
# Coefficients:
#  [-0.0987361]
# Independent term:
#  64.88520254496527
# DataFrame is empty!
# .............Analizando, muestra 75 fecha 2010-10-07
# 2010-10-08
#  datos desde archivo
# Coefficients:
#  [-0.09789258]
# Independent term:
#  64.8303733928958
# Coefficients:
#  [-0.09789258]
# Independent term:
#  64.8303733928958
# DataFrame is empty!
# .............Analizando, muestra 76 fecha 2010-10-08
# 2010-10-09
# ..............Día sin sesión, next please
# 2010-10-10
# ..............Día sin sesión, next please
# 2010-10-11
#  datos desde archivo
# Coefficients:
#  [-0.09712765]
# Independent term:
#  64.78039814524165
# Coefficients:
#  [-0.09712765]
# Independent term:
#  64.78039814524165
# DataFrame is empty!
# .............Analizando, muestra 79 fecha 2010-10-11
# 2010-10-12
#  datos desde archivo
# Coefficients:
#  [-0.09641695]
# Independent term:
#  64.73372871628958
# Coefficients:
#  [-0.09641695]
# Independent term:
#  64.73372871628958
# Coefficients:
#  [0.]
# Independent term:
#  54.38149053907409
# .............Analizando, muestra 80 fecha 2010-10-12
# 2010-10-13
#  datos desde archivo
# Coefficients:
#  [-0.09554281]
# Independent term:
#  64.67603557529735
# Coefficients:
#  [-0.09554281]
# Independent term:
#  64.67603557529735
# Coefficients:
#  [-0.0296319]
# Independent term:
#  54.38149053907409
# .............Analizando, muestra 81 fecha 2010-10-13
# 2010-10-14
#  datos desde archivo
# Coefficients:
#  [-0.09471047]
# Independent term:
#  64.62082381990942
# Coefficients:
#  [-0.09431841]
# Independent term:
#  64.4740997422631
# Coefficients:
#  [-0.03049731]
# Independent term:
#  54.38177900847134
# .............Analizando, muestra 82 fecha 2010-10-14
# 2010-10-15
#  datos desde archivo
# Coefficients:
#  [-0.09398258]
# Independent term:
#  64.57229807904446
# Coefficients:
#  [-0.09321479]
# Independent term:
#  64.28260404558324
# Coefficients:
#  [-0.03266409]
# Independent term:
#  54.38322352919316
# .............Analizando, muestra 83 fecha 2010-10-15
# 2010-10-16
# ..............Día sin sesión, next please
# 2010-10-17
# ..............Día sin sesión, next please
# 2010-10-18
#  datos desde archivo
# Coefficients:
#  [-0.09320634]
# Independent term:
#  64.52028990275478
# Coefficients:
#  [-0.09185093]
# Independent term:
#  64.06124475165979
# Coefficients:
#  [-0.03320668]
# Independent term:
#  54.383766116625615
# .............Analizando, muestra 86 fecha 2010-10-18
# 2010-10-19
#  datos desde archivo
# Coefficients:
#  [-0.09258684]
# Independent term:
#  64.4785764700599
# Coefficients:
#  [-0.09055958]
# Independent term:
#  63.84012690871509
# Coefficients:
#  [-0.03477637]
# Independent term:
#  54.38585904405011
# .............Analizando, muestra 87 fecha 2010-10-19
# 2010-10-20
#  datos desde archivo
# Coefficients:
#  [-0.09180871]
# Independent term:
#  64.42592322701616
# Coefficients:
#  [-0.08922835]
# Independent term:
#  63.626085751092255
# Coefficients:
#  [-0.0349576]
# Independent term:
#  54.38616108713297
# .............Analizando, muestra 88 fecha 2010-10-20
# 2010-10-21
#  datos desde archivo
# Coefficients:
#  [-0.09102435]
# Independent term:
#  64.372587110853
# Coefficients:
#  [-0.08813982]
# Independent term:
#  63.446168169050075
# Coefficients:
#  [-0.03460419]
# Independent term:
#  54.385454271430895
# .............Analizando, muestra 89 fecha 2010-10-21
# 2010-10-22
#  datos desde archivo
# Coefficients:
#  [-0.09031508]
# Independent term:
#  64.32412006703507
# Coefficients:
#  [-0.08708588]
# Independent term:
#  63.26689328207898
# Coefficients:
#  [-0.03441052]
# Independent term:
#  54.385002364769015
# .............Analizando, muestra 90 fecha 2010-10-22
# 2010-10-23
# ..............Día sin sesión, next please
# 2010-10-24
# ..............Día sin sesión, next please
# 2010-10-25
#  datos desde archivo
# Coefficients:
#  [-0.08956724]
# Independent term:
#  64.27276863646411
# Coefficients:
#  [-0.08573544]
# Independent term:
#  63.0523659270557
# Coefficients:
#  [-0.03409811]
# Independent term:
#  54.38416926499788
# .............Analizando, muestra 93 fecha 2010-10-25
# 2010-10-26
#  datos desde archivo
# Coefficients:
#  [-0.089193]
# Independent term:
#  64.24694606913985
# Coefficients:
#  [-0.08500452]
# Independent term:
#  62.894288946692626
# Coefficients:
#  [-0.03495612]
# Independent term:
#  54.38674329217403
# .............Analizando, muestra 94 fecha 2010-10-26
# 2010-10-27
#  datos desde archivo
# Coefficients:
#  [-0.08888206]
# Independent term:
#  64.22538719358037
# Coefficients:
#  [-0.08435008]
# Independent term:
#  62.742448539733886
# Coefficients:
#  [-0.0364497]
# Independent term:
#  54.3917219013144
# .............Analizando, muestra 95 fecha 2010-10-27
# 2010-10-28
#  datos desde archivo
# Coefficients:
#  [-0.08863622]
# Independent term:
#  64.20826015388839
# Coefficients:
#  [-0.08355838]
# Independent term:
#  62.56819626253043
# Coefficients:
#  [-0.03830606]
# Independent term:
#  54.398528575167695
# .............Analizando, muestra 96 fecha 2010-10-28
# 2010-10-29
#  datos desde archivo
# Coefficients:
#  [-0.08843147]
# Independent term:
#  64.19392819066266
# Coefficients:
#  [-0.08317639]
# Independent term:
#  62.445804810025805
# Coefficients:
#  [-0.04032618]
# Independent term:
#  54.4066090543717
# .............Analizando, muestra 97 fecha 2010-10-29
# 2010-10-30
# ..............Día sin sesión, next please
# 2010-10-31
# ..............Día sin sesión, next please
# 2010-11-01
#  datos desde archivo
# Coefficients:
#  [-0.08810692]
# Independent term:
#  64.17110099891234
# Coefficients:
#  [-0.08302051]
# Independent term:
#  62.36285888216389
# Coefficients:
#  [-0.04210318]
# Independent term:
#  54.414309366341314
# .............Analizando, muestra 100 fecha 2010-11-01
# 2010-11-02
#  datos desde archivo
# Coefficients:
#  [-0.08762856]
# Independent term:
#  64.13729724349263
# Coefficients:
#  [-0.08260981]
# Independent term:
#  62.25832603112975
# Coefficients:
#  [-0.04339472]
# Independent term:
#  54.420336545756044
# .............Analizando, muestra 101 fecha 2010-11-02
# 2010-11-03
#  datos desde archivo
# Coefficients:
#  [-0.08709293]
# Independent term:
#  64.09926749433966
# Coefficients:
#  [-0.08219298]
# Independent term:
#  62.15817012103636
# Coefficients:
#  [-0.04424838]
# Independent term:
#  54.424604876697295
# .............Analizando, muestra 102 fecha 2010-11-03
# 2010-11-04
#  datos desde archivo
# Coefficients:
#  [-0.08640844]
# Independent term:
#  64.05044078354868
# Coefficients:
#  [-0.08174806]
# Independent term:
#  62.06672096366313
# Coefficients:
#  [-0.04458805]
# Independent term:
#  54.42641641606677
# .............Analizando, muestra 103 fecha 2010-11-04
# 2010-11-05
#  datos desde archivo
# Coefficients:
#  [-0.08556133]
# Independent term:
#  63.98973124508968
# Coefficients:
#  [-0.08131402]
# Independent term:
#  61.99055384052333
# Coefficients:
#  [-0.04437663]
# Independent term:
#  54.425218374386816
# .............Analizando, muestra 104 fecha 2010-11-05
# 2010-11-06
# ..............Día sin sesión, next please
# 2010-11-07
# ..............Día sin sesión, next please
# 2010-11-08
#  datos desde archivo
# Coefficients:
#  [-0.08465622]
# Independent term:
#  63.92456270471745
# Coefficients:
#  [-0.0810704]
# Independent term:
#  61.94554940636479
# Coefficients:
#  [-0.04373253]
# Independent term:
#  54.421353804059564
# .............Analizando, muestra 107 fecha 2010-11-08
# 2010-11-09
#  datos desde archivo
# Coefficients:
#  [-0.08367386]
# Independent term:
#  63.8535055520773
# Coefficients:
#  [-0.08053317]
# Independent term:
#  61.869090637093166
# Coefficients:
#  [-0.04272258]
# Independent term:
#  54.41495745021035
# .............Analizando, muestra 108 fecha 2010-11-09
# 2010-11-10
#  datos desde archivo
# Coefficients:
#  [-0.08280068]
# Independent term:
#  63.79005450598255
# Coefficients:
#  [-0.07989891]
# Independent term:
#  61.77249280502547
# Coefficients:
#  [-0.04157786]
# Independent term:
#  54.40732597838657
# .............Analizando, muestra 109 fecha 2010-11-10
# 2010-11-11
#  datos desde archivo
# Coefficients:
#  [-0.08190477]
# Independent term:
#  63.72465287010638
# Coefficients:
#  [-0.07904788]
# Independent term:
#  61.65040819765917
# Coefficients:
#  [-0.04033223]
# Independent term:
#  54.3986065279373
# .............Analizando, muestra 110 fecha 2010-11-11
# 2010-11-12
#  datos desde archivo
# Coefficients:
#  [-0.08120427]
# Independent term:
#  63.67328323033229
# Coefficients:
#  [-0.078544]
# Independent term:
#  61.559861504853664
# Coefficients:
#  [-0.03918904]
# Independent term:
#  54.390223167861926
# .............Analizando, muestra 111 fecha 2010-11-12
# 2010-11-13
# ..............Día sin sesión, next please
# 2010-11-14
# ..............Día sin sesión, next please
# 2010-11-15
#  datos desde archivo
# Coefficients:
#  [-0.08044179]
# Independent term:
#  63.61711366416399
# Coefficients:
#  [-0.07828667]
# Independent term:
#  61.50830151742964
# Coefficients:
#  [-0.03808354]
# Independent term:
#  54.381747660753845
# .............Analizando, muestra 114 fecha 2010-11-15
# 2010-11-16
#  datos desde archivo
# Coefficients:
#  [-0.07999292]
# Independent term:
#  63.58389700117566
# Coefficients:
#  [-0.07861314]
# Independent term:
#  61.509127938569485
# Coefficients:
#  [-0.03723917]
# Independent term:
#  54.37499268810544
# .............Analizando, muestra 115 fecha 2010-11-16
# 2010-11-17
#  datos desde archivo
# Coefficients:
#  [-0.0794672]
# Independent term:
#  63.544818655068426
# Coefficients:
#  [-0.07863034]
# Independent term:
#  61.4759264499038
# Coefficients:
#  [-0.03654257]
# Independent term:
#  54.36918774378364
# .............Analizando, muestra 116 fecha 2010-11-17
# 2010-11-18
#  datos desde archivo
# Coefficients:
#  [-0.07883173]
# Independent term:
#  63.49737076716397
# Coefficients:
#  [-0.07833778]
# Independent term:
#  61.41169902459899
# Coefficients:
#  [-0.03589113]
# Independent term:
#  54.363541914057826
# .............Analizando, muestra 117 fecha 2010-11-18
# 2010-11-19
#  datos desde archivo
# Coefficients:
#  [-0.07824272]
# Independent term:
#  63.4531949138575
# Coefficients:
#  [-0.07870169]
# Independent term:
#  61.43157071355564
# Coefficients:
#  [-0.03530382]
# Independent term:
#  54.358256140072555
# .............Analizando, muestra 118 fecha 2010-11-19
# 2010-11-20
# ..............Día sin sesión, next please
# 2010-11-21
# ..............Día sin sesión, next please
# 2010-11-22
#  datos desde archivo
# Coefficients:
#  [-0.07778759]
# Independent term:
#  63.4189078305349
# Coefficients:
#  [-0.07908511]
# Independent term:
#  61.44315489014583
# Coefficients:
#  [-0.034842]
# Independent term:
#  54.35394577376302
# .............Analizando, muestra 121 fecha 2010-11-22
# 2010-11-23
#  datos desde archivo
# Coefficients:
#  [-0.07750238]
# Independent term:
#  63.39732742483393
# Coefficients:
#  [-0.07967321]
# Independent term:
#  61.46757056051226
# Coefficients:
#  [-0.03456733]
# Independent term:
#  54.35129068393307
# .............Analizando, muestra 122 fecha 2010-11-23
# 2010-11-24
#  datos desde archivo
# Coefficients:
#  [-0.07718017]
# Independent term:
#  63.372839093975664
# Coefficients:
#  [-0.08009349]
# Independent term:
#  61.47320240248495
# Coefficients:
#  [-0.03441893]
# Independent term:
#  54.34980664795628
# .............Analizando, muestra 123 fecha 2010-11-24
# 2010-11-25
#  datos desde archivo
# Coefficients:
#  [-0.07672769]
# Independent term:
#  63.3383003063461
# Coefficients:
#  [-0.07997985]
# Independent term:
#  61.41990742982324
# Coefficients:
#  [-0.0343057]
# Independent term:
#  54.348636637273295
# .............Analizando, muestra 124 fecha 2010-11-25
# 2010-11-26
#  datos desde archivo
# Coefficients:
#  [-0.07635174]
# Independent term:
#  63.30947746721724
# Coefficients:
#  [-0.08006285]
# Independent term:
#  61.38653429002904
# Coefficients:
#  [-0.03425248]
# Independent term:
#  54.34806896735691
# .............Analizando, muestra 125 fecha 2010-11-26
# 2010-11-27
# ..............Día sin sesión, next please
# 2010-11-28
# ..............Día sin sesión, next please
# 2010-11-29
#  datos desde archivo
# Coefficients:
#  [-0.0760218]
# Independent term:
#  63.28407151961177
# Coefficients:
#  [-0.07999771]
# Independent term:
#  61.32987117710399
# Coefficients:
#  [-0.0342643]
# Independent term:
#  54.348198895772555
# .............Analizando, muestra 128 fecha 2010-11-29
# 2010-11-30
#  datos desde archivo
# Coefficients:
#  [-0.07559754]
# Independent term:
#  63.25126227798365
# Coefficients:
#  [-0.07974542]
# Independent term:
#  61.257487002700124
# Coefficients:
#  [-0.03428671]
# Independent term:
#  54.34845293823998
# .............Analizando, muestra 129 fecha 2010-11-30
# 2010-12-01
#  datos desde archivo
# Coefficients:
#  [-0.07499524]
# Independent term:
#  63.20448400963096
# Coefficients:
#  [-0.07922365]
# Independent term:
#  61.1664328281915
# Coefficients:
#  [-0.03424494]
# Independent term:
#  54.34796562395309
# .............Analizando, muestra 130 fecha 2010-12-01
# 2010-12-02
#  datos desde archivo
# Coefficients:
#  [-0.07427124]
# Independent term:
#  63.14801171275583
# Coefficients:
#  [-0.07872876]
# Independent term:
#  61.091286677460175
# Coefficients:
#  [-0.03410278]
# Independent term:
#  54.346259652979896
# .............Analizando, muestra 131 fecha 2010-12-02
# 2010-12-03
#  datos desde archivo
# Coefficients:
#  [-0.07351961]
# Independent term:
#  63.089134406887915
# Coefficients:
#  [-0.07814071]
# Independent term:
#  61.00758257794736
# Coefficients:
#  [-0.03386668]
# Independent term:
#  54.3433478129607
# .............Analizando, muestra 132 fecha 2010-12-03
# 2010-12-04
# ..............Día sin sesión, next please
# 2010-12-05
# ..............Día sin sesión, next please
# 2010-12-06
#  datos desde archivo
# Coefficients:
#  [-0.07261797]
# Independent term:
#  63.018205173323835
# Coefficients:
#  [-0.07751517]
# Independent term:
#  60.934347611042995
# Coefficients:
#  [-0.03350029]
# Independent term:
#  54.33870680465603
# .............Analizando, muestra 135 fecha 2010-12-06
# 2010-12-07
#  datos desde archivo
# Coefficients:
#  [-0.07165345]
# Independent term:
#  62.94200824194872
# Coefficients:
#  [-0.0767033]
# Independent term:
#  60.84389660564821
# Coefficients:
#  [-0.03300467]
# Independent term:
#  54.33226383237835
# .............Analizando, muestra 136 fecha 2010-12-07
# 2010-12-08
#  datos desde archivo
# Coefficients:
#  [-0.07074448]
# Independent term:
#  62.86989662149305
# Coefficients:
#  [-0.0758588]
# Independent term:
#  60.74546653178201
# Coefficients:
#  [-0.03241937]
# Independent term:
#  54.32445979102436
# .............Analizando, muestra 137 fecha 2010-12-08
# 2010-12-09
#  datos desde archivo
# Coefficients:
#  [-0.0698067]
# Independent term:
#  62.79518630621442
# Coefficients:
#  [-0.07468225]
# Independent term:
#  60.60737977839228
# Coefficients:
#  [-0.03175079]
# Independent term:
#  54.31532252125146
# .............Analizando, muestra 138 fecha 2010-12-09
# 2010-12-10
#  datos desde archivo
# Coefficients:
#  [-0.06886927]
# Independent term:
#  62.720192099186775
# Coefficients:
#  [-0.07321266]
# Independent term:
#  60.432146047335955
# Coefficients:
#  [-0.03101324]
# Independent term:
#  54.304996760178426
# .............Analizando, muestra 139 fecha 2010-12-10
# 2010-12-11
# ..............Día sin sesión, next please
# 2010-12-12
# ..............Día sin sesión, next please
# 2010-12-13
#  datos desde archivo
# Coefficients:
#  [-0.06777478]
# Independent term:
#  62.63226825338638
# Coefficients:
#  [-0.07154359]
# Independent term:
#  60.24775135723513
# Coefficients:
#  [-0.03017383]
# Independent term:
#  54.29296525810445
# .............Analizando, muestra 142 fecha 2010-12-13
# 2010-12-14
#  datos desde archivo
# Coefficients:
#  [-0.0667717]
# Independent term:
#  62.55135300943547
# Coefficients:
#  [-0.06964545]
# Independent term:
#  60.02605933573709
# Coefficients:
#  [-0.02927469]
# Independent term:
#  54.27977781607855
# .............Analizando, muestra 143 fecha 2010-12-14
# 2010-12-15
#  datos desde archivo
# Coefficients:
#  [-0.06566068]
# Independent term:
#  62.46136069518526
# Coefficients:
#  [-0.06746007]
# Independent term:
#  59.77914639259452
# Coefficients:
#  [-0.02829759]
# Independent term:
#  54.26512146054186
# .............Analizando, muestra 144 fecha 2010-12-15
# 2010-12-16
#  datos desde archivo
# Coefficients:
#  [-0.06456102]
# Independent term:
#  62.371921070207236
# Coefficients:
#  [-0.06521535]
# Independent term:
#  59.525565518621185
# Coefficients:
#  [-0.0272586]
# Independent term:
#  54.24919015525709
# .............Analizando, muestra 145 fecha 2010-12-16
# 2010-12-17
#  datos desde archivo
# Coefficients:
#  [-0.06335091]
# Independent term:
#  62.273095919442305
# Coefficients:
#  [-0.06276561]
# Independent term:
#  59.25835402873025
# Coefficients:
#  [-0.02614091]
# Independent term:
#  54.231679720951306
# .............Analizando, muestra 146 fecha 2010-12-17
# 2010-12-18
# ..............Día sin sesión, next please
# 2010-12-19
# ..............Día sin sesión, next please
# 2010-12-20
#  datos desde archivo
# Coefficients:
#  [-0.06208853]
# Independent term:
#  62.16958054261962
# Coefficients:
#  [-0.06034989]
# Independent term:
#  59.00358657779979
# Coefficients:
#  [-0.02494494]
# Independent term:
#  54.21254414232148
# .............Analizando, muestra 149 fecha 2010-12-20
# 2010-12-21
#  datos desde archivo
# Coefficients:
#  [-0.06090332]
# Independent term:
#  62.07199809173217
# Coefficients:
#  [-0.05788913]
# Independent term:
#  58.7375175384977
# Coefficients:
#  [-0.02370154]
# Independent term:
#  54.19223541967934
# .............Analizando, muestra 150 fecha 2010-12-21
# 2010-12-22
#  datos desde archivo
# Coefficients:
#  [-0.0597843]
# Independent term:
#  61.97949249145995
# Coefficients:
#  [-0.05568064]
# Independent term:
#  58.50057079087442
# Coefficients:
#  [-0.02243423]
# Independent term:
#  54.17111354574643
# .............Analizando, muestra 151 fecha 2010-12-22
# 2010-12-23
#  datos desde archivo
# Coefficients:
#  [-0.05876725]
# Independent term:
#  61.89507762342267
# Coefficients:
#  [-0.05334909]
# Independent term:
#  58.23896070736558
# Coefficients:
#  [-0.02117065]
# Independent term:
#  54.14963263590262
# .............Analizando, muestra 152 fecha 2010-12-23
# 2010-12-24
# ..............Día sin sesión, next please
# 2010-12-25
# ..............Día sin sesión, next please
# 2010-12-26
# ..............Día sin sesión, next please
# 2010-12-27
#  datos desde archivo
# Coefficients:
#  [-0.05777349]
# Independent term:
#  61.812264005365556
# Coefficients:
#  [-0.05075998]
# Independent term:
#  57.9429701369556
# Coefficients:
#  [-0.01991723]
# Independent term:
#  54.12790678640553
# .............Analizando, muestra 156 fecha 2010-12-27
# 2010-12-28
#  datos desde archivo
# Coefficients:
#  [-0.05681482]
# Independent term:
#  61.73205538055134
# Coefficients:
#  [-0.04828338]
# Independent term:
#  57.66046438188695
# Coefficients:
#  [-0.0186818]
# Independent term:
#  54.106080789203155
# .............Analizando, muestra 157 fecha 2010-12-28
# 2010-12-29
#  datos desde archivo
# Coefficients:
#  [-0.05580547]
# Independent term:
#  61.647269607551024
# Coefficients:
#  [-0.04589373]
# Independent term:
#  57.397145136932835
# Coefficients:
#  [-0.01745355]
# Independent term:
#  54.08397226509331
# .............Analizando, muestra 158 fecha 2010-12-29
# 2010-12-30
#  datos desde archivo
# Coefficients:
#  [-0.0548529]
# Independent term:
#  61.566936912372995
# Coefficients:
#  [-0.04359707]
# Independent term:
#  57.142263792237245
# Coefficients:
#  [-0.01624433]
# Independent term:
#  54.06180326706986
# .............Analizando, muestra 159 fecha 2010-12-30
# 2010-12-31
# ..............Día sin sesión, next please
# 2011-01-01
# ..............Día sin sesión, next please
# 2011-01-02
# ..............Día sin sesión, next please
# 2011-01-03
#  datos desde archivo
# Coefficients:
#  [-0.05381538]
# Independent term:
#  61.47909328318292
# Coefficients:
#  [-0.04095045]
# Independent term:
#  56.85235784331364
# Coefficients:
#  [-0.01503705]
# Independent term:
#  54.039267367742355
# .............Analizando, muestra 163 fecha 2011-01-03
# 2011-01-04
#  datos desde archivo
# Coefficients:
#  [-0.05294624]
# Independent term:
#  61.40521616042982
# Coefficients:
#  [-0.03844376]
# Independent term:
#  56.56487354221629
# Coefficients:
#  [-0.01386423]
# Independent term:
#  54.016983744872064
# .............Analizando, muestra 164 fecha 2011-01-04
# 2011-01-05
#  datos desde archivo
# Coefficients:
#  [-0.05216277]
# Independent term:
#  61.3383605347109
# Coefficients:
#  [-0.03568817]
# Independent term:
#  56.23694755952749
# Coefficients:
#  [-0.01273865]
# Independent term:
#  53.99522263116816
# .............Analizando, muestra 165 fecha 2011-01-05
# 2011-01-06
#  datos desde archivo
# Coefficients:
#  [-0.0514353]
# Independent term:
#  61.27604011952576
# Coefficients:
#  [-0.03305691]
# Independent term:
#  55.92129056104973
# Coefficients:
#  [-0.01166592]
# Independent term:
#  53.97412556681683
# .............Analizando, muestra 166 fecha 2011-01-06
# 2011-01-07
#  datos desde archivo
# Coefficients:
#  [-0.05079733]
# Independent term:
#  61.221175162925014
# Coefficients:
#  [-0.03038823]
# Independent term:
#  55.59249517697007
# Coefficients:
#  [-0.01065649]
# Independent term:
#  53.95393690345549
# .............Analizando, muestra 167 fecha 2011-01-07
# 2011-01-08
# ..............Día sin sesión, next please
# 2011-01-09
# ..............Día sin sesión, next please
# 2011-01-10
#  datos desde archivo
# Coefficients:
#  [-0.05026324]
# Independent term:
#  61.17506537264923
# Coefficients:
#  [-0.02809487]
# Independent term:
#  55.30348714686152
# Coefficients:
#  [-0.00972165]
# Independent term:
#  53.93492843807645
# .............Analizando, muestra 170 fecha 2011-01-10
# 2011-01-11
#  datos desde archivo
# Coefficients:
#  [-0.04965537]
# Independent term:
#  61.12238320891052
# Coefficients:
#  [-0.02569414]
# Independent term:
#  55.01015725434716
# Coefficients:
#  [-0.00884171]
# Independent term:
#  53.91674313453822
# .............Analizando, muestra 171 fecha 2011-01-11
# 2011-01-12
#  datos desde archivo
# Coefficients:
#  [-0.04893734]
# Independent term:
#  61.059914859569986
# Coefficients:
#  [-0.02266688]
# Independent term:
#  54.648023674808336
# Coefficients:
#  [-0.00799354]
# Independent term:
#  53.898931426329675
# .............Analizando, muestra 172 fecha 2011-01-12
# 2011-01-13
#  datos desde archivo
# Coefficients:
#  [-0.04831425]
# Independent term:
#  61.00549783504916
# Coefficients:
#  [-0.01936362]
# Independent term:
#  54.2402596351282
# Coefficients:
#  [-0.0071891]
# Independent term:
#  53.88177018107879
# .............Analizando, muestra 173 fecha 2011-01-13
# 2011-01-14
#  datos desde archivo
# Coefficients:
#  [-0.04773223]
# Independent term:
#  60.95447446834215
# Coefficients:
#  [-0.01617726]
# Independent term:
#  53.84514485373426
# Coefficients:
#  [-0.0064305]
# Independent term:
#  53.865333731201886
# .............Analizando, muestra 174 fecha 2011-01-14
# 2011-01-15
# ..............Día sin sesión, next please
# 2011-01-16
# ..............Día sin sesión, next please
# 2011-01-17
#  datos desde archivo
# Coefficients:
#  [-0.04717469]
# Independent term:
#  60.905410979943596
# Coefficients:
#  [-0.01326183]
# Independent term:
#  53.484926927481126
# Coefficients:
#  [-0.00571694]
# Independent term:
#  53.84963539370339
# .............Analizando, muestra 177 fecha 2011-01-17
# 2011-01-18
#  datos desde archivo
# Coefficients:
#  [-0.04660344]
# Independent term:
#  60.854950505176205
# Coefficients:
#  [-0.01021835]
# Independent term:
#  53.111051136984756
# Coefficients:
#  [-0.005042]
# Independent term:
#  53.83456179464059
# .............Analizando, muestra 178 fecha 2011-01-18
# 2011-01-19
#  datos desde archivo
# Coefficients:
#  [-0.04613843]
# Independent term:
#  60.81371945434766
# Coefficients:
#  [-0.00739731]
# Independent term:
#  52.755746436047914
# Coefficients:
#  [-0.00441726]
# Independent term:
#  53.82040100468883
# .............Analizando, muestra 179 fecha 2011-01-19
# 2011-01-20
#  datos desde archivo
# Coefficients:
#  [-0.04567738]
# Independent term:
#  60.772685929951905
# Coefficients:
#  [-0.00458769]
# Independent term:
#  52.40300328895227
# Coefficients:
#  [-0.00383836]
# Independent term:
#  53.807086432346324
# .............Analizando, muestra 180 fecha 2011-01-20
# 2011-01-21
#  datos desde archivo
# Coefficients:
#  [-0.0451059]
# Independent term:
#  60.72163357100592
# Coefficients:
#  [-0.00141606]
# Independent term:
#  52.0171407078985
# Coefficients:
#  [-0.00328553]
# Independent term:
#  53.79418706720664
# .............Analizando, muestra 181 fecha 2011-01-21
# 2011-01-22
# ..............Día sin sesión, next please
# 2011-01-23
# ..............Día sin sesión, next please
# 2011-01-24
#  datos desde archivo
# Coefficients:
#  [-0.04452673]
# Independent term:
#  60.66970183405826
# Coefficients:
#  [0.00175026]
# Independent term:
#  51.634707001074034
# Coefficients:
#  [-0.00275515]
# Independent term:
#  53.781634559090925
# .............Analizando, muestra 184 fecha 2011-01-24
# 2011-01-25
#  datos desde archivo
# Coefficients:
#  [-0.04394678]
# Independent term:
#  60.61750635857265
# Coefficients:
#  [0.00454225]
# Independent term:
#  51.303821158907304
# Coefficients:
#  [-0.00224486]
# Independent term:
#  53.76938778170365
# .............Analizando, muestra 185 fecha 2011-01-25
# 2011-01-26
#  datos desde archivo
# Coefficients:
#  [-0.04329432]
# Independent term:
#  60.5585667051315
# Coefficients:
#  [0.0073333]
# Independent term:
#  50.9837172585103
# Coefficients:
#  [-0.00174321]
# Independent term:
#  53.757180811709446
# .............Analizando, muestra 186 fecha 2011-01-26
# 2011-01-27
#  datos desde archivo
# Coefficients:
#  [-0.04272553]
# Independent term:
#  60.50699692147096
# Coefficients:
#  [0.01024892]
# Independent term:
#  50.63839254920162
# Coefficients:
#  [-0.00125995]
# Independent term:
#  53.745260513480844
# .............Analizando, muestra 187 fecha 2011-01-27
# 2011-01-28
#  datos desde archivo
# Coefficients:
#  [-0.04225179]
# Independent term:
#  60.46388623505242
# Coefficients:
#  [0.01272699]
# Independent term:
#  50.34082813433747
# Coefficients:
#  [-0.00080522]
# Independent term:
#  53.73389214698797
# .............Analizando, muestra 188 fecha 2011-01-28
# 2011-01-29
# ..............Día sin sesión, next please
# 2011-01-30
# ..............Día sin sesión, next please
# 2011-01-31
#  datos desde archivo
# Coefficients:
#  [-0.04183528]
# Independent term:
#  60.42584518973896
# Coefficients:
#  [0.01490674]
# Independent term:
#  50.076966544763366
# Coefficients:
#  [-0.00038334]
# Independent term:
#  53.7232044963041
# .............Analizando, muestra 191 fecha 2011-01-31
# 2011-02-01
#  datos desde archivo
# Coefficients:
#  [-0.04138085]
# Independent term:
#  60.38418900591086
# Coefficients:
#  [0.01723019]
# Independent term:
#  49.800080512886616
# Coefficients:
#  [1.33968513e-05]
# Independent term:
#  53.71302167581108
# .............Analizando, muestra 192 fecha 2011-02-01
# 2011-02-02
#  datos desde archivo
# Coefficients:
#  [-0.04096445]
# Independent term:
#  60.34588036721974
# Coefficients:
#  [0.01985184]
# Independent term:
#  49.480035921353014
# Coefficients:
#  [0.00038288]
# Independent term:
#  53.703415163092764
# .............Analizando, muestra 193 fecha 2011-02-02
# 2011-02-03
#  datos desde archivo
# Coefficients:
#  [-0.04059445]
# Independent term:
#  60.311716988461484
# Coefficients:
#  [0.02203169]
# Independent term:
#  49.21392586437624
# Coefficients:
#  [0.00072227]
# Independent term:
#  53.69447772768086
# .............Analizando, muestra 194 fecha 2011-02-03
# 2011-02-04
#  datos desde archivo
# Coefficients:
#  [-0.04018964]
# Independent term:
#  60.27420446292118
# Coefficients:
#  [0.02419944]
# Independent term:
#  48.955076260353195
# Coefficients:
#  [0.00103842]
# Independent term:
#  53.68604725304632
# .............Analizando, muestra 195 fecha 2011-02-04
# 2011-02-05
# ..............Día sin sesión, next please
# 2011-02-06
# ..............Día sin sesión, next please
# 2011-02-07
#  datos desde archivo
# Coefficients:
#  [-0.03970096]
# Independent term:
#  60.2287576313933
# Coefficients:
#  [0.0264735]
# Independent term:
#  48.694300249014326
# Coefficients:
#  [0.00134303]
# Independent term:
#  53.67782265148637
# .............Analizando, muestra 198 fecha 2011-02-07
# 2011-02-08
#  datos desde archivo
# Coefficients:
#  [-0.03911325]
# Independent term:
#  60.17390471291303
# Coefficients:
#  [0.02865606]
# Independent term:
#  48.460086577685914
# Coefficients:
#  [0.00164839]
# Independent term:
#  53.669476208281594
# .............Analizando, muestra 199 fecha 2011-02-08
# 2011-02-09
#  datos desde archivo
# Coefficients:
#  [-0.03860415]
# Independent term:
#  60.1262182918141
# Coefficients:
#  [0.0306978]
# Independent term:
#  48.235506433515404
# Coefficients:
#  [0.00194613]
# Independent term:
#  53.661238689888336
# .............Analizando, muestra 200 fecha 2011-02-09
# 2011-02-10
#  datos desde archivo
# Coefficients:
#  [-0.03804249]
# Independent term:
#  60.07342289216966
# Coefficients:
#  [0.03242097]
# Independent term:
#  48.06150636530634
# Coefficients:
#  [0.00224282]
# Independent term:
#  53.65293136839252
# .............Analizando, muestra 201 fecha 2011-02-10
# 2011-02-11
#  datos desde archivo
# Coefficients:
#  [-0.0374733]
# Independent term:
#  60.01972872317898
# Coefficients:
#  [0.03425812]
# Independent term:
#  47.8746382886972
# Coefficients:
#  [0.00253963]
# Independent term:
#  53.644521713124064
# .............Analizando, muestra 202 fecha 2011-02-11
# 2011-02-12
# ..............Día sin sesión, next please
# 2011-02-13
# ..............Día sin sesión, next please
# 2011-02-14
#  datos desde archivo
# Coefficients:
#  [-0.03691768]
# Independent term:
#  59.96713071236476
# Coefficients:
#  [0.03599224]
# Independent term:
#  47.700872169608495
# Coefficients:
#  [0.00283542]
# Independent term:
#  53.63604243317148
# .............Analizando, muestra 205 fecha 2011-02-14
# 2011-02-15
#  datos desde archivo
# Coefficients:
#  [-0.0364123]
# Independent term:
#  59.91911960838841
# Coefficients:
#  [0.03713986]
# Independent term:
#  47.599254751632465
# Coefficients:
#  [0.00312538]
# Independent term:
#  53.62763351973706
# .............Analizando, muestra 206 fecha 2011-02-15
# 2011-02-16
#  datos desde archivo
# Coefficients:
#  [-0.03590008]
# Independent term:
#  59.870287533495706
# Coefficients:
#  [0.0390568]
# Independent term:
#  47.39747538153805
# Coefficients:
#  [0.00341093]
# Independent term:
#  53.61925752341737
# .............Analizando, muestra 207 fecha 2011-02-16
# 2011-02-17
#  datos desde archivo
# Coefficients:
#  [-0.03540168]
# Independent term:
#  59.822606902810364
# Coefficients:
#  [0.04075773]
# Independent term:
#  47.22365156828467
# Coefficients:
#  [0.00369128]
# Independent term:
#  53.610940396543356
# .............Analizando, muestra 208 fecha 2011-02-17
# 2011-02-18
#  datos desde archivo
# Coefficients:
#  [-0.03495152]
# Independent term:
#  59.779392270909646
# Coefficients:
#  [0.04231973]
# Independent term:
#  47.06263492982779
# Coefficients:
#  [0.00396236]
# Independent term:
#  53.60280811495845
# .............Analizando, muestra 209 fecha 2011-02-18
# 2011-02-19
# ..............Día sin sesión, next please
# 2011-02-20
# ..............Día sin sesión, next please
# 2011-02-21
#  datos desde archivo
# Coefficients:
#  [-0.03459796]
# Independent term:
#  59.745332743574636
# Coefficients:
#  [0.04375027]
# Independent term:
#  46.90645253878921
# Coefficients:
#  [0.00421576]
# Independent term:
#  53.5951214732739
# .............Analizando, muestra 212 fecha 2011-02-21
# 2011-02-22
#  datos desde archivo
# Coefficients:
#  [-0.03431273]
# Independent term:
#  59.71775971134925
# Coefficients:
#  [0.04442061]
# Independent term:
#  46.842247947579
# Coefficients:
#  [0.00444655]
# Independent term:
#  53.58804417068654
# .............Analizando, muestra 213 fecha 2011-02-22
# 2011-02-23
#  datos desde archivo
# Coefficients:
#  [-0.03409896]
# Independent term:
#  59.69702458645695
# Coefficients:
#  [0.04478015]
# Independent term:
#  46.80952655564493
# Coefficients:
#  [0.0046499]
# Independent term:
#  53.58174028637561
# .............Analizando, muestra 214 fecha 2011-02-23
# 2011-02-24
#  datos desde archivo
# Coefficients:
#  [-0.03388576]
# Independent term:
#  59.67627325287798
# Coefficients:
#  [0.04531983]
# Independent term:
#  46.753080730153556
# Coefficients:
#  [0.00482801]
# Independent term:
#  53.57615932567152
# ***************** Señal...
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# .............Analizando, muestra 215 fecha 2011-02-24
# 2011-02-25
#  datos desde archivo
# Coefficients:
#  [-0.03361999]
# Independent term:
#  59.650315889698405
# Coefficients:
#  [0.04556144]
# Independent term:
#  46.74410502931965
# Coefficients:
#  [0.00498778]
# Independent term:
#  53.57110008284684
# .............Analizando, muestra 216 fecha 2011-02-25
# 2011-02-26
# ..............Día sin sesión, next please
# 2011-02-27
# ..............Día sin sesión, next please
# 2011-02-28
#  datos desde archivo
# Coefficients:
#  [-0.03331489]
# Independent term:
#  59.62041650559126
# Coefficients:
#  [0.04560272]
# Independent term:
#  46.76773529565156
# Coefficients:
#  [0.00513432]
# Independent term:
#  53.56641071774351
# .............Analizando, muestra 219 fecha 2011-02-28
# 2011-03-01
#  datos desde archivo
# Coefficients:
#  [-0.03304333]
# Independent term:
#  59.59371309390519
# Coefficients:
#  [0.04565935]
# Independent term:
#  46.784697571939496
# Coefficients:
#  [0.00526587]
# Independent term:
#  53.56215727210694
# .............Analizando, muestra 220 fecha 2011-03-01
# 2011-03-02
#  datos desde archivo
# Coefficients:
#  [-0.03278594]
# Independent term:
#  59.56831757105207
# Coefficients:
#  [0.04555907]
# Independent term:
#  46.82063214999526
# Coefficients:
#  [0.00538251]
# Independent term:
#  53.55834707135961
# .............Analizando, muestra 221 fecha 2011-03-02
# 2011-03-03
#  datos desde archivo
# Coefficients:
#  [-0.03250494]
# Independent term:
#  59.54049825610923
# Coefficients:
#  [0.04532457]
# Independent term:
#  46.87806397566155
# Coefficients:
#  [0.00548759]
# Independent term:
#  53.554879299418175
# .............Analizando, muestra 222 fecha 2011-03-03
# 2011-03-04
#  datos desde archivo
# Coefficients:
#  [-0.03227606]
# Independent term:
#  59.517762451847794
# Coefficients:
#  [0.04531726]
# Independent term:
#  46.89772442091756
# Coefficients:
#  [0.00557774]
# Independent term:
#  53.5518744781849
# .............Analizando, muestra 223 fecha 2011-03-04
# 2011-03-05
# ..............Día sin sesión, next please
# 2011-03-06
# ..............Día sin sesión, next please
# 2011-03-07
#  datos desde archivo
# Coefficients:
#  [-0.03210198]
# Independent term:
#  59.50041279420661
# Coefficients:
#  [0.0454144]
# Independent term:
#  46.895437990444805
# Coefficients:
#  [0.00564961]
# Independent term:
#  53.54945492852505
# .............Analizando, muestra 226 fecha 2011-03-07
# 2011-03-08
#  datos desde archivo
# Coefficients:
#  [-0.03194459]
# Independent term:
#  59.4846732437427
# Coefficients:
#  [0.04537465]
# Independent term:
#  46.908910599893595
# Coefficients:
#  [0.00570331]
# Independent term:
#  53.547629055467276
# .............Analizando, muestra 227 fecha 2011-03-08
# 2011-03-09
#  datos desde archivo
# Coefficients:
#  [-0.0318492]
# Independent term:
#  59.47510338003527
# Coefficients:
#  [0.04525826]
# Independent term:
#  46.923138270022264
# Coefficients:
#  [0.00573522]
# Independent term:
# ...
# ..............Día sin sesión, next please
# 2026-08-04
# ..............Día sin sesión, next please
# 2026-08-05
# ..............Día sin sesión, next please
# 2026-08-06
# ..............Día sin sesión, next please
# 2026-08-07
# ..............Día sin sesión, next please
# 2026-08-08
# ..............Día sin sesión, next please
# 2026-08-09
# ..............Día sin sesión, next please
# 2026-08-10
# ..............Día sin sesión, next please
# 2026-08-11
# ..............Día sin sesión, next please
# 2026-08-12
# ..............Día sin sesión, next please
# 2026-08-13
# ..............Día sin sesión, next please
# 2026-08-14
# ..............Día sin sesión, next please
# 2026-08-15
# ..............Día sin sesión, next please
# 2026-08-16
# ..............Día sin sesión, next please
# 2026-08-17
# ..............Día sin sesión, next please
# 2026-08-18
# ..............Día sin sesión, next please
# 2026-08-19
# ..............Día sin sesión, next please
# 2026-08-20
# ..............Día sin sesión, next please
# 2026-08-21
# ..............Día sin sesión, next please
# 2026-08-22
# ..............Día sin sesión, next please
# 2026-08-23
# ..............Día sin sesión, next please
# 2026-08-24
# ..............Día sin sesión, next please
# 2026-08-25
# ..............Día sin sesión, next please
# 2026-08-26
# ..............Día sin sesión, next please
# 2026-08-27
# ..............Día sin sesión, next please
# 2026-08-28
# ..............Día sin sesión, next please
# 2026-08-29
# ..............Día sin sesión, next please
# 2026-08-30
# ..............Día sin sesión, next please
# 2026-08-31
# ..............Día sin sesión, next please
# 2026-09-01
# ..............Día sin sesión, next please
# 2026-09-02
# ..............Día sin sesión, next please
# 2026-09-03
# ..............Día sin sesión, next please
# 2026-09-04
# ..............Día sin sesión, next please
# 2026-09-05
# ..............Día sin sesión, next please
# 2026-09-06
# ..............Día sin sesión, next please
# 2026-09-07
# ..............Día sin sesión, next please
# 2026-09-08
# ..............Día sin sesión, next please
# 2026-09-09
# ..............Día sin sesión, next please
# 2026-09-10
# ..............Día sin sesión, next please
# 2026-09-11
# ..............Día sin sesión, next please
# 2026-09-12
# ..............Día sin sesión, next please
# 2026-09-13
# ..............Día sin sesión, next please
# 2026-09-14
# ..............Día sin sesión, next please
# 2026-09-15
# ..............Día sin sesión, next please
# 2026-09-16
# ..............Día sin sesión, next please
# 2026-09-17
# ..............Día sin sesión, next please
# 2026-09-18
# ..............Día sin sesión, next please
# 2026-09-19
# ..............Día sin sesión, next please
# 2026-09-20
# ..............Día sin sesión, next please
# 2026-09-21
# ..............Día sin sesión, next please
# 2026-09-22
# ..............Día sin sesión, next please
# 2026-09-23
# ..............Día sin sesión, next please
# 2026-09-24
# ..............Día sin sesión, next please
# 2026-09-25
# ..............Día sin sesión, next please
# 2026-09-26
# ..............Día sin sesión, next please
# 2026-09-27
# ..............Día sin sesión, next please
# 2026-09-28
# ..............Día sin sesión, next please
# 2026-09-29
# ..............Día sin sesión, next please
# 2026-09-30
# ..............Día sin sesión, next please
# 2026-10-01
# ..............Día sin sesión, next please
# 2026-10-02
# ..............Día sin sesión, next please
# 2026-10-03
# ..............Día sin sesión, next please
# 2026-10-04
# ..............Día sin sesión, next please
# 2026-10-05
# ..............Día sin sesión, next please
# 2026-10-06
# ..............Día sin sesión, next please
# 2026-10-07
# ..............Día sin sesión, next please
# 2026-10-08
# ..............Día sin sesión, next please
# 2026-10-09
# ..............Día sin sesión, next please
# 2026-10-10
# ..............Día sin sesión, next please
# 2026-10-11
# ..............Día sin sesión, next please
# 2026-10-12
# ..............Día sin sesión, next please
# 2026-10-13
# ..............Día sin sesión, next please
# 2026-10-14
# ..............Día sin sesión, next please
# 2026-10-15
# ..............Día sin sesión, next please
# 2026-10-16
# ..............Día sin sesión, next please
# 2026-10-17
# ..............Día sin sesión, next please
# 2026-10-18
# ..............Día sin sesión, next please
# 2026-10-19
# ..............Día sin sesión, next please
# 2026-10-20
# ..............Día sin sesión, next please
# 2026-10-21
# ..............Día sin sesión, next please
# 2026-10-22
# ..............Día sin sesión, next please
# 2026-10-23
# ..............Día sin sesión, next please
# 2026-10-24
# ..............Día sin sesión, next please
# 2026-10-25
# ..............Día sin sesión, next please
# 2026-10-26
# ..............Día sin sesión, next please
# 2026-10-27
# ..............Día sin sesión, next please
# 2026-10-28
# ..............Día sin sesión, next please
# 2026-10-29
# ..............Día sin sesión, next please
# 2026-10-30
# ..............Día sin sesión, next please
# 2026-10-31
# ..............Día sin sesión, next please
# 2026-11-01
# ..............Día sin sesión, next please
# 2026-11-02
# ..............Día sin sesión, next please
# 2026-11-03
# ..............Día sin sesión, next please
# 2026-11-04
# ..............Día sin sesión, next please
# 2026-11-05
# ..............Día sin sesión, next please
# 2026-11-06
# ..............Día sin sesión, next please
# 2026-11-07
# ..............Día sin sesión, next please
# 2026-11-08
# ..............Día sin sesión, next please
# 2026-11-09
# ..............Día sin sesión, next please
# 2026-11-10
# ..............Día sin sesión, next please
# 2026-11-11
# ..............Día sin sesión, next please
# 2026-11-12
# ..............Día sin sesión, next please
# 2026-11-13
# ..............Día sin sesión, next please
# 2026-11-14
# ..............Día sin sesión, next please
# 2026-11-15
# ..............Día sin sesión, next please
# 2026-11-16
# ..............Día sin sesión, next please
# 2026-11-17
# ..............Día sin sesión, next please
# 2026-11-18
# ..............Día sin sesión, next please
# 2026-11-19
# ..............Día sin sesión, next please
# 2026-11-20
# ..............Día sin sesión, next please
# 2026-11-21
# ..............Día sin sesión, next please
# 2026-11-22
# ..............Día sin sesión, next please
# 2026-11-23
# ..............Día sin sesión, next please
# 2026-11-24
# ..............Día sin sesión, next please
# 2026-11-25
# ..............Día sin sesión, next please
# 2026-11-26
# ..............Día sin sesión, next please
# 2026-11-27
# ..............Día sin sesión, next please
# 2026-11-28
# ..............Día sin sesión, next please
# 2026-11-29
# ..............Día sin sesión, next please
# 2026-11-30
# ..............Día sin sesión, next please
# 2026-12-01
# ..............Día sin sesión, next please
# 2026-12-02
# ..............Día sin sesión, next please
# 2026-12-03
# ..............Día sin sesión, next please
# 2026-12-04
# ..............Día sin sesión, next please
# 2026-12-05
# ..............Día sin sesión, next please
# 2026-12-06
# ..............Día sin sesión, next please
# 2026-12-07
# ..............Día sin sesión, next please
# 2026-12-08
# ..............Día sin sesión, next please
# 2026-12-09
# ..............Día sin sesión, next please
# 2026-12-10
# ..............Día sin sesión, next please
# 2026-12-11
# ..............Día sin sesión, next please
# 2026-12-12
# ..............Día sin sesión, next please
# 2026-12-13
# ..............Día sin sesión, next please
# 2026-12-14
# ..............Día sin sesión, next please
# 2026-12-15
# ..............Día sin sesión, next please
# 2026-12-16
# ..............Día sin sesión, next please
# 2026-12-17
# ..............Día sin sesión, next please
# 2026-12-18
# ..............Día sin sesión, next please
# 2026-12-19
# ..............Día sin sesión, next please
# 2026-12-20
# ..............Día sin sesión, next please
# 2026-12-21
# ..............Día sin sesión, next please
# 2026-12-22
# ..............Día sin sesión, next please
# 2026-12-23
# ..............Día sin sesión, next please
# 2026-12-24
# ..............Día sin sesión, next please
# 2026-12-25
# ..............Día sin sesión, next please
# 2026-12-26
# ..............Día sin sesión, next please
# 2026-12-27
# ..............Día sin sesión, next please
# 2026-12-28
# ..............Día sin sesión, next please
# 2026-12-29
# ..............Día sin sesión, next please
# 2026-12-30
# ..............Día sin sesión, next please
# 2026-12-31
# ..............Día sin sesión, next please
# 2027-01-01
# ..............Día sin sesión, next please
# 2027-01-02
# ..............Día sin sesión, next please
# 2027-01-03
# ..............Día sin sesión, next please
# 2027-01-04
# ..............Día sin sesión, next please
# 2027-01-05
# ..............Día sin sesión, next please
# 2027-01-06
# ..............Día sin sesión, next please
# 2027-01-07
# ..............Día sin sesión, next please
# 2027-01-08
# ..............Día sin sesión, next please
# 2027-01-09
# ..............Día sin sesión, next please
# 2027-01-10
# ..............Día sin sesión, next please
# 2027-01-11
# ..............Día sin sesión, next please
# 2027-01-12
# ..............Día sin sesión, next please
# 2027-01-13
# ..............Día sin sesión, next please
# 2027-01-14
# ..............Día sin sesión, next please
# 2027-01-15
# ..............Día sin sesión, next please
# 2027-01-16
# ..............Día sin sesión, next please
# 2027-01-17
# ..............Día sin sesión, next please
# 2027-01-18
# ..............Día sin sesión, next please
# 2027-01-19
# ..............Día sin sesión, next please
# 2027-01-20
# ..............Día sin sesión, next please
# 2027-01-21
# ..............Día sin sesión, next please
# 2027-01-22
# ..............Día sin sesión, next please
# 2027-01-23
# ..............Día sin sesión, next please
# 2027-01-24
# ..............Día sin sesión, next please
# 2027-01-25
# ..............Día sin sesión, next please
# 2027-01-26
# ..............Día sin sesión, next please
# 2027-01-27
# ..............Día sin sesión, next please
# 2027-01-28
# ..............Día sin sesión, next please
# 2027-01-29
# ..............Día sin sesión, next please
# 2027-01-30
# ..............Día sin sesión, next please
# 2027-01-31
# ..............Día sin sesión, next please
# 2027-02-01
# ..............Día sin sesión, next please
# 2027-02-02
# ..............Día sin sesión, next please
# 2027-02-03
# ..............Día sin sesión, next please
# 2027-02-04
# ..............Día sin sesión, next please
# 2027-02-05
# ..............Día sin sesión, next please
# 2027-02-06
# ..............Día sin sesión, next please
# 2027-02-07
# ..............Día sin sesión, next please
# 2027-02-08
# ..............Día sin sesión, next please
# 2027-02-09
# ..............Día sin sesión, next please
# 2027-02-10
# ..............Día sin sesión, next please
# 2027-02-11
# ..............Día sin sesión, next please
# 2027-02-12
# ..............Día sin sesión, next please
# 2027-02-13
# ..............Día sin sesión, next please
# 2027-02-14
# ..............Día sin sesión, next please
# 2027-02-15
# ..............Día sin sesión, next please
# 2027-02-16
# ..............Día sin sesión, next please
# 2027-02-17
# ..............Día sin sesión, next please
# 2027-02-18
# ..............Día sin sesión, next please
# 2027-02-19
# ..............Día sin sesión, next please
# 2027-02-20
# ..............Día sin sesión, next please
# 2027-02-21
# ..............Día sin sesión, next please
# 2027-02-22
# ..............Día sin sesión, next please
# 2027-02-23
# ..............Día sin sesión, next please
# 2027-02-24
# ..............Día sin sesión, next please
# 2027-02-25
# ..............Día sin sesión, next please
# 2027-02-26
# ..............Día sin sesión, next please
# 2027-02-27
# ..............Día sin sesión, next please
# 2027-02-28
# ..............Día sin sesión, next please
# 2027-03-01
# ..............Día sin sesión, next please
# 2027-03-02
# ..............Día sin sesión, next please
# 2027-03-03
# ..............Día sin sesión, next please
# 2027-03-04
# ..............Día sin sesión, next please
# 2027-03-05
# ..............Día sin sesión, next please
# 2027-03-06
# ..............Día sin sesión, next please
# 2027-03-07
# ..............Día sin sesión, next please
# 2027-03-08
# ..............Día sin sesión, next please
# 2027-03-09
# ..............Día sin sesión, next please
# 2027-03-10
# ..............Día sin sesión, next please
# 2027-03-11
# ..............Día sin sesión, next please
# 2027-03-12
# ..............Día sin sesión, next please
# 2027-03-13
# ..............Día sin sesión, next please
# 2027-03-14
# ..............Día sin sesión, next please
# 2027-03-15
# ..............Día sin sesión, next please
# 2027-03-16
# ..............Día sin sesión, next please
# 2027-03-17
# ..............Día sin sesión, next please
# 2027-03-18
# ..............Día sin sesión, next please
# 2027-03-19
# ..............Día sin sesión, next please
# 2027-03-20
# ..............Día sin sesión, next please
# 2027-03-21
# ..............Día sin sesión, next please
# 2027-03-22
# ..............Día sin sesión, next please
# 2027-03-23
# ..............Día sin sesión, next please
# 2027-03-24
# ..............Día sin sesión, next please
# 2027-03-25
# ..............Día sin sesión, next please
# 2027-03-26
# ..............Día sin sesión, next please
# 2027-03-27
# ..............Día sin sesión, next please
# 2027-03-28
# ..............Día sin sesión, next please
# 2027-03-29
# ..............Día sin sesión, next please
# 2027-03-30
# ..............Día sin sesión, next please
# 2027-03-31
# ..............Día sin sesión, next please
# 2027-04-01
# ..............Día sin sesión, next please
# 2027-04-02
# ..............Día sin sesión, next please
# 2027-04-03
# ..............Día sin sesión, next please
# 2027-04-04
# ..............Día sin sesión, next please
# 2027-04-05
# ..............Día sin sesión, next please
# 2027-04-06
# ..............Día sin sesión, next please
# 2027-04-07
# ..............Día sin sesión, next please
# 2027-04-08
# ..............Día sin sesión, next please
# 2027-04-09
# ..............Día sin sesión, next please
# 2027-04-10
# ..............Día sin sesión, next please
# 2027-04-11
# ..............Día sin sesión, next please
# 2027-04-12
# ..............Día sin sesión, next please
# 2027-04-13
# ..............Día sin sesión, next please
# 2027-04-14
# ..............Día sin sesión, next please
# 2027-04-15
# ..............Día sin sesión, next please
# 2027-04-16
# ..............Día sin sesión, next please
# 2027-04-17
# ..............Día sin sesión, next please
# 2027-04-18
# ..............Día sin sesión, next please
# 2027-04-19
# ..............Día sin sesión, next please
# 2027-04-20
# ..............Día sin sesión, next please
# 2027-04-21
# ..............Día sin sesión, next please
# 2027-04-22
# ..............Día sin sesión, next please
# 2027-04-23
# ..............Día sin sesión, next please
# 2027-04-24
# ..............Día sin sesión, next please
# 2027-04-25
# ..............Día sin sesión, next please
# 2027-04-26
# ..............Día sin sesión, next please
# 2027-04-27
# ..............Día sin sesión, next please
# 2027-04-28
# ..............Día sin sesión, next please
# 2027-04-29
# ..............Día sin sesión, next please
# 2027-04-30
# ..............Día sin sesión, next please
# 2027-05-01
# ..............Día sin sesión, next please
# 2027-05-02
# ..............Día sin sesión, next please
# 2027-05-03
# ..............Día sin sesión, next please
# 2027-05-04
# ..............Día sin sesión, next please
# 2027-05-05
# ..............Día sin sesión, next please
# 2027-05-06
# ..............Día sin sesión, next please
# 2027-05-07
# ..............Día sin sesión, next please
# 2027-05-08
# ..............Día sin sesión, next please
# 2027-05-09
# ..............Día sin sesión, next please
# 2027-05-10
# ..............Día sin sesión, next please
# 2027-05-11
# ..............Día sin sesión, next please
# 2027-05-12
# ..............Día sin sesión, next please
# 2027-05-13
# ..............Día sin sesión, next please
# 2027-05-14
# ..............Día sin sesión, next please
# 2027-05-15
# ..............Día sin sesión, next please
# 2027-05-16
# ..............Día sin sesión, next please
# 2027-05-17
# ..............Día sin sesión, next please
# 2027-05-18
# ..............Día sin sesión, next please
# 2027-05-19
# ..............Día sin sesión, next please
# 2027-05-20
# ..............Día sin sesión, next please
# 2027-05-21
# ..............Día sin sesión, next please
# 2027-05-22
# ..............Día sin sesión, next please
# 2027-05-23
# ..............Día sin sesión, next please
# 2027-05-24
# ..............Día sin sesión, next please
# 2027-05-25
# ..............Día sin sesión, next please
# 2027-05-26
# ..............Día sin sesión, next please
# 2027-05-27
# ..............Día sin sesión, next please
# 2027-05-28
# ..............Día sin sesión, next please
# 2027-05-29
# ..............Día sin sesión, next please
# 2027-05-30
# ..............Día sin sesión, next please
# 2027-05-31
# ..............Día sin sesión, next please

# %%
dff.loc['2010':'2022','Senal'].plot(title = 'Señales Regresión a la media MTS.MC',xlim=('2010','2022'))
# Out:
# <AxesSubplot:title={'center':'Señales Regresión a la media MTS.MC'}, xlabel='Date'>

# %%
tiempo_final = time() 
 
tiempo_ejecucion = tiempo_final - tiempo_inicial
 
print ('El tiempo de ejecucion fue:',tiempo_ejecucion) #En segundos
# Out:
# El tiempo de ejecucion fue: 113.67719435691833

# %%
dff.tail()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume  \
# Date
# 2021-11-03  29.010000  29.250000  28.575001  28.575001  28.575001  474875
# 2021-11-04  28.870001  28.980000  28.305000  28.415001  28.415001  349120
# 2021-11-05  28.330000  28.420000  27.594999  27.950001  27.950001  639523
# 2021-11-08  28.030001  29.020000  27.975000  28.855000  28.855000  415569
# 2021-11-09  28.580000  28.959999  27.725000  27.725000  27.725000  587832
#
#             Senal
# Date
# 2021-11-03    0.0
# 2021-11-04    0.0
# 2021-11-05    0.0
# 2021-11-08    0.0
# 2021-11-09    0.0

# %%
#Guardamos el resultado del analisis en un pickle
dff.to_pickle("./primerBack3.pkl")

# %% [markdown]
# Como lo que nos interesa es su cruce, para saber cuando se produce calcularemos la diferencia entre ambas medias para cada muestra. Y el signo de la diferencia será la señal para establecer la posición del sistema.
#
# Así cuando la diferencia sea positiva, significará que la media de 20 periodos es mayor que la de 60 periodos, indicando una tendencia alcista y tomando una posición compradora. Con una diferencia negativa, la lógica es justo la inversa y tomaremos posicion vendedora.

# %%
data['Dif_SMA'] = data.SMA_20 - data.SMA_60
data['Senal'] = np.sign(data.Dif_SMA)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\INNOVA~1\AppData\Local\Temp/ipykernel_10364/546538133.py in <module>
# ----> 1 data['Dif_SMA'] = data.SMA_20 - data.SMA_60
#       2 data['Senal'] = np.sign(data.Dif_SMA)
#
# ~\anaconda3\envs\Quant\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'SMA_20'

# %% [markdown]
# Para calcular los retornos del sistema, calculamos la diferencia relativativa entre el precio de cierre y el del día anterior. Para posteriormente multiplicarlo por la señal que del día anterior que nos indicaba la posición a tomar.

# %%
data['Dif_Close'] = data.Close.pct_change()  #calula el incremento porcentual desde la celda del dia anterior

data['Retornos'] = data.Dif_Close * data.Senal.shift(1)

# %%
data.tail()

# %% [markdown]
# El capital, por comodidad, lo calcularemos en base 100, es decir como si iniciaramos la inversión con 100 unidades monetarias. Para su calculo arrastramos el producto acumulado de los retornos mas 1, multiplicados como dijimos por 100.

# %%
data['Capital'] = (data.Retornos + 1).cumprod() * 100

# %% [markdown]
# Veamos como queda la tabla, tras añadir estas columnas.
#
# Observamos de la fila 58 en adelante, pues hasta que no existen 60 filas no es posible calcular el SMA_60, y por tanto no tenemos señal para tomar posición.

# %%
data[:100]

# %% [markdown]
# Veamos gráficamente como evoluciona el precio y las dos medias.

# %%
data[['Close','SMA_20','SMA_60']].plot(color=['0.7','r','g'])
plt.show()

# %% [markdown]
# Pero para observar gráficamente la evolución del sistema necesitamos un gráfico con mas información. Para ello definimos una función que nos mostrará un gráfico con la evolución de nuestra estrategia, comparandola con la del activo. En un subgráfico se visualizará el drawdown del sistema, comparado de nuevo con el del activo. Y por útlimo las posiciones que toma el sistema.

# %%
def grafico (df):
    estudio = df.copy()
    DD_bh, maxDD, maxDD_ini, maxDD_fin = analisis.DrawDown(estudio.Dif_Close[60:], info = False) 
    DD, maxDD, maxDD_ini, maxDD_fin = analisis.DrawDown(estudio.Retornos.fillna(0), info = False) 

    fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True, figsize=(18, 12), gridspec_kw = {'height_ratios':[3, 1, 1]})
    fig.suptitle('Estrategia vs B & H', fontsize=20)

    ax1.plot(estudio.Capital.fillna(100))
    ax1.plot((estudio.Close) *100 / estudio.Close[0])
    ax1.set_title('Capital')
    ax1.legend(['Estrategia','Buy & Hold'])

    ax2.plot(DD*100, c='0.5')
    ax2.plot(DD_bh*100, c='y')
    ax2.fill_between(DD.index, 0, DD*100, color='0.7')
    ax2.set_title('Drawdown')
    ax2.legend(['Estrategia','Buy & Hold'])

    ax3.plot(estudio.Senal, c='orange')
    ax3.fill_between(estudio.index, 0, estudio.Senal*100, color='orange')
    ax3.set_title('Posición')

    plt.show()
    return

# %%
grafico(data)

# %% [markdown]
# ---

# %%
data['Dif_Open'] = data.Close.pct_change()
data['Posicion'] = data.Senal.shift(1)
data['Retornos'] = data.Posicion.shift(1) * data.Dif_Open
data['Capital'] = (data.Retornos.fillna(0) + 1).cumprod() * 100

# %%
data[55:70]

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(18, 12), gridspec_kw = {'height_ratios':[3, 1]})
ax1.plot(data.Capital)
ax1.plot(data.Close *100 / data.Close[0])
ax1.set_title('Estrategia vs B & H')
ax1.legend(['Estrategia','Buy & Hold'])
ax2.plot(data.Posicion, c='y')
ax2.fill_between(data.index, 0, data.Posicion*100, color='y')
ax2.set_title('Posición')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # ANALISIS DEL SISTEMA

# %%
Beneficio_Bruto = data.Capital[-1] - data.Capital[0]
print ('Beneficio Bruto : {:.2f}'.format(Beneficio_Bruto))

# %%
CAGR = analisis.CAGR(data.Retornos)
print ('CAGR : {:.2f}%'.format(CAGR * 100))

# %%
DD, maxDD, maxDD_ini, maxDD_fin = analisis.DrawDown(data.Retornos)

# %%
Sharpe = CAGR / (np.log(data.Retornos + 1).std(skipna=True) * 252 ** 0.5)
print ('Sharpe : {:.3f}'.format(CAGR ))

# %% [markdown]
# --------------------------------------------------------------------

# %% [markdown]
# ---------------------------------------------------------------

# %% [markdown]
# ---

# %% [markdown]
# # OPTIMIZACION DEL SISTEMA

# %%
op_data = qd_data[:'2016'].copy()
op_data['Dif_Close'] = op_data.Close.pct_change()
op_data['Dif_Open'] = op_data.Close.pct_change()  #era Open

# %%
def estrategia_medias (df, periodo_rapido, periodo_lento):
    
    estr = df.copy()
    estr[f'SMA_{periodo_rapido}'] = estr.Close.rolling(periodo_rapido).mean()
    estr[f'SMA_{periodo_lento}'] = estr.Close.rolling(periodo_lento).mean()
    estr['Dif_SMA'] = estr[f'SMA_{periodo_rapido}'] - estr[f'SMA_{periodo_lento}']    
    estr['Senal'] = estr.Dif_SMA / estr.Dif_SMA.abs()
    estr['Posicion'] = estr.Senal.shift(1)    
    estr['Retornos'] = estr.Posicion.shift(1) * estr.Dif_Open    
    estr['Capital'] = (estr.Retornos+1).cumprod() * 100
    
    resultados = {'Rapida' : periodo_rapido, 'Lenta' : periodo_lento}
    resultados['Beneficio Bruto'] = round(estr.Capital[-1]-100,2)
    resultados['CAGR'] = analisis.CAGR(estr.Retornos) 
    resultados['Sharpe'] = resultados['CAGR'] / (np.log(estr.Retornos + 1).std(skipna=True) * 252 ** 0.5)
    resultados['Máximo Drawdown'] = (estr.Capital.div(estr.Capital.cummax()).sub(1)).min()
    
    resultados['Número de trades'] = (np.sign(estr.Posicion * estr.Posicion.shift(1)) == -1).sum() 
    
    return estr, resultados

# %%
periodos_rapido = range (5,160,5)
periodos_lento = range (20,210,5)

# %%
# %%time

coleccion = {}
resultados = {}

for periodo_rapido in periodos_rapido:
    for periodo_lento in periodos_lento:

        
        if periodo_lento <= periodo_rapido:
            continue
        estr, resultado = estrategia_medias (op_data, periodo_rapido, periodo_lento)
        nombre = f'estrategia_{periodo_rapido}_{periodo_lento}'
        coleccion[nombre] = estr
        resultados[nombre] = resultado

# %%
print ('Realizados {} backtests sobre una serie de {} muestras'.format(len(coleccion), op_data.shape[0]))

# %%
clasificacion = pd.DataFrame(resultados).transpose()
clasificacion.head(25)

# %%
pd.DataFrame(clasificacion['Beneficio Bruto'].sort_values(ascending=False).head(10))

# %%
pd.DataFrame(clasificacion.Sharpe.sort_values(ascending=False).head(10))

# %%
pd.DataFrame(clasificacion['Máximo Drawdown'].sort_values(ascending=False).head(10))

# %%
clasificacion['Beneficio Bruto'].sort_values(ascending=False).plot(kind='bar')

# %%
(clasificacion['Beneficio Bruto']/clasificacion['Número de trades']).sort_values(ascending=False).plot(kind='bar')

# %%
ax=sns.heatmap(clasificacion.pivot('Rapida','Lenta','Máximo Drawdown'), annot=False, fmt=".3", linewidths=0, cmap=plt.cm.jet)

# %%
# ax=sns.heatmap(clasificacion.pivot('Rapida','Lenta','Sharpe'), annot=True, fmt=".3f", cmap=plt.cm.jet)
ax=sns.heatmap(clasificacion.pivot('Rapida','Lenta','Sharpe'), annot=False, fmt=".1f", cmap=plt.cm.jet )

# %%
analisis.trisurf_heatmap (clasificacion, 'Rapida', 'Lenta','Sharpe', v1=45, v2=45)

# %%
analisis.trisurf_heatmap (clasificacion, 'Rapida', 'Lenta','Máximo Drawdown',v1= 45, v2=45)

# %% [markdown]
# ---

# %% [markdown]
# # REVISIÓN DE LOS PARÁMETROS SELECCIONADOS

# %%
pd.DataFrame(clasificacion.loc['estrategia_5_140'])

# %%
grafico(coleccion['estrategia_5_140'])

# %% [markdown]
# ---

# %% [markdown]
# # PRUEBA FUERA DE LA MUESTRA

# %%
periodo_rapido = 5

periodo_lento = 140

out_sample= qd_data[data.shape[0]:].copy()

out_sample['Dif_Close'] = out_sample.Close.pct_change()
out_sample['Dif_Open'] = out_sample.Close.pct_change()  #era Cloe


out_estr, out_resultado = estrategia_medias (out_sample, periodo_rapido, periodo_lento)

# %%
grafico(out_estr)

# %% [markdown]
# ---
