# %% [markdown]
# # Backtest vectorizado y optimización de parametros con Pandas.
#
# ## Hackeado by J3viton (learning BackTesting 2021).

# %% [markdown]
# ---

# %% [markdown]
# En este Notebook vamos a realizar un backtest de una estrategia sencilla. Se trata de un cruce de medias, que se puede considerar el "Hello World!" de los sistemas automáticos.
#
# Vamos a usar el módulo Pandas, para realizar un backtest vectorizado, es decir calcular el resultado del backtest sin iterar sobre las filas (barras) de la serie temporal.

# %% [markdown]
# Posteriormente realizarmos una optimización de los parametros del sistema, y veremos como el calculo vectorizador nos permite hacer un gran número de backtests para la optimización en un tiempo muy breve.

# %% [markdown]
# ---

# %% [markdown]
# # IMPORTACIÓN DE MODULOS Y CARGA DE DATOS

# %% [markdown]
# Como es usual, importamos los módulos que vamos a necesitar para las distintas tareas, y preparamos Matplotlib para una mejor visualización de los gráficos en el notebook.
#
# Se importa un modulo llamado **analisis**, en realidad se trata de un archivo .py con algunas funciones de apoyo para el trabajo, debe estar guardado en la misma carpeta que este notebook.

# %%
import pandas as pd
import analisis   
import numpy as np
import itertools
import seaborn as sns
import yfinance as yf

# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = 18, 8
plt.style.use('ggplot')

from IPython.display import display, Markdown

# %% [markdown]
# Importamos el modulo **quandl** que nos proporcionará una descarga de los datos que vamos a necesitar, en este caso la cotización diaria de las acciones de Apple.

# %%
# import quandl
# quandl.ApiConfig.api_key = "Aquí va tu API KEY" # Para una descarga ocasional no necesitas la API KEY.
# qd_data = quandl.get("WIKI/AAPL", start_date= "2000-01-01", end_date= "2018-06-15")

qd_data = yf.download('MTS.MC', '2015-1-1','2021-1-1')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Tambien puedes cargar los datos desde el archivo pickle.

# %%
# qd_data = pd.read_pickle('apple_qd.pkl')

# %% [markdown]
# Veamos la cabecera del dataframe que acabamos de crear con los datos descargados.

# %%
qd_data
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2015-01-02  18.666080  18.892052  18.313890  18.340355  17.308128  571717
# 2015-01-05  18.279282  18.466574  17.629868  17.650225  16.656837  584564
# 2015-01-06  17.739799  18.051273  17.576937  17.646154  16.652994  428394
# 2015-01-07  17.788658  18.026846  17.530113  17.627832  16.635708  440488
# 2015-01-08  17.756086  18.324068  17.713335  18.293531  17.263937  525319
# ...               ...        ...        ...        ...        ...     ...
# 2020-12-24  19.290001  19.299999  19.018000  19.018000  18.633215  123553
# 2020-12-28  19.200001  19.450001  19.025999  19.059999  18.674366  363103
# 2020-12-29  19.166000  19.222000  18.700001  18.980000  18.595984  518981
# 2020-12-30  18.834000  19.284000  18.832001  19.160000  18.772341  362912
# 2020-12-31  19.000000  19.084000  18.834000  19.049999  18.664568  204478
#
# [1535 rows x 6 columns]

# %% [markdown]
# La tabla muestra que tenemos datos sin ajustar y ajustados. Tomaremos solo los datos OHLCV ajustados y el volumen, prescindiremos del resto de columnas, y eliminaremos el prefijo __Adj.__ para mas comodidad de uso.
#
# Estudiar las posibildades de Python en vectorizado ...

# %%
ajustadas = [f for f in qd_data.columns if f.startswith('Adj')]  # guardamos una lista con las cabeceras de las columnas
qd_data = qd_data[ajustadas].copy()    # guardamos la tabla con las cabeceras selecionas arriba
qd_data.columns = [f[4:] for f in qd_data.columns]  #quitamos los literales
qd_data.head()
# Out:
#                 Close
# Date
# 2015-01-02  17.308128
# 2015-01-05  16.656837
# 2015-01-06  16.652994
# 2015-01-07  16.635708
# 2015-01-08  17.263937

# %% [markdown]
# Para usarlo en nuestro backtest vamos a hacer una copia del dataframe pero solo hasta 2017.

# %%
data = qd_data[:-1].copy()

# %%
data.head()
# Out:
#                 Close
# Date
# 2015-01-02  17.308128
# 2015-01-05  16.656837
# 2015-01-06  16.652994
# 2015-01-07  16.635708
# 2015-01-08  17.263937

# %% [markdown]
# ---

# %% [markdown]
# # DEFINICION DEL SISTEMA

# %% [markdown]
# Es importante tener clara la lógica del sistema, pues debemos plasmarla de forma sencilla y correcta en el dataframe para realizar el backtest del mismo.
#
# Esta estrategia utiliza dos medias simples del precio de cierre, de 20 y 60 periodos. Calculemoslas y asignamos sus valores a nuevas columnas de nuestro dataframe.
#
# Para ello usamos la función **rolling** de Pandas, que va _rodando_ una ventana de N valores, sobre la que realiza un calculo, en este caso la media.
# https://github.com/Python-para-Trading/Webinars-Docs/blob/master/Webinar%202/Webinar%202%20-%20Backtest%20con%20Pandas%20v%202.ipynb.

# %%
import analisis
import regresionAMedia_v2 as rg
import pandas as pd
import datetime as dt
from time import time
# Out:
# {'supports_inline_queries': False, 'first_name': 'vital_bot', 'can_join_groups': True, 'username': 'vital_quant_bot', 'is_bot': True, 'can_read_all_group_messages': False, 'id': 1473252352}

# %%
# Rango completo para backTesting
start2 =dt.datetime(2005,1,2)
end2   =dt.datetime(2021,11,18)
start_G= start2.strftime("%Y-%m-%d")
end_G  =   end2.strftime("%Y-%m-%d")
TOTAL_len= (end2-start2).days
print('Tamaño timeseries a analizar:  ', TOTAL_len, 'sesiones')

#ventana de analisis 200 sesiones
startWindow2 =dt.datetime(2010,1,5)
endWindow2   =startWindow2 + dt.timedelta(days=1000) #ventana grande para que se puedan hacer los calculos de EMA
startWindow= startWindow2.strftime("%Y-%m-%d")
endWindow  =   endWindow2.strftime("%Y-%m-%d")
window_len= (endWindow2-startWindow2).days
print('Tamaño de la ventana a analizar paso a paso:  ', window_len, 'sesiones')
# Out:
# Tamaño timeseries a analizar:   6164 sesiones
# Tamaño de la ventana a analizar paso a paso:   1000 sesiones

# %%
 #dff = pd.DataFrame(columns=('Close','Volume', 'Senal', 'Dif_Close', 'Retornos','Capital'))

# %%
instrumento = 'IBE.MC'

# %%
dff = yf.download(instrumento, start_G,end_G)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#dff['Close']= Total_data['Close']
#dff.dropna(inplace=True)  
dff.head()
# Out:
#               Open    High     Low   Close  Adj Close    Volume
# Date
# 2005-01-03  4.6000  4.6300  4.5650  4.6225   2.124917  17417636
# 2005-01-04  4.6350  4.6650  4.6175  4.6500   2.137558  86410008
# 2005-01-05  4.6400  4.6400  4.5825  4.6000   2.114572  91434776
# 2005-01-06  4.6000  4.6000  4.6000  4.6000   2.114572         0
# 2005-01-07  4.5875  4.6275  4.5875  4.6275   2.127215  91201856

# %%
regreMedia= rg.StrategyClass()    #Creamos la clase

# %%
#recogo = regreMedia.analisis_IN('MTS.MC', startWindow, endWindow, dff)
#type(recogo)

# %% [markdown]
# ### Miro si el resultado de la estrategia me da la señal de compra (100) y lo marco en la tabla
# if(recogo['senal'] == 100 ):
#     dff.loc[[start],['Senal']]=100
# else:
#     dff.loc[[start],['Senal']]=1
#
# dff.head()
# dff.tail()

# %% [markdown]
# ## 4.- Recorremos el datafrema con valores buscando las señales de la estrategia

# %%
dff.index
# Out:
# DatetimeIndex(['2005-01-03', '2005-01-04', '2005-01-05', '2005-01-06',
#                '2005-01-07', '2005-01-10', '2005-01-11', '2005-01-12',
#                '2005-01-13', '2005-01-14',
#                ...
#                '2021-11-04', '2021-11-05', '2021-11-08', '2021-11-09',
#                '2021-11-10', '2021-11-11', '2021-11-12', '2021-11-15',
#                '2021-11-16', '2021-11-17'],
#               dtype='datetime64[ns]', name='Date', length=4318, freq=None)

# %% [markdown]
# start ='2010-1-5'
# #dff.loc[start]
# if((start in dff.index)and(end in dff.index)) :
#     print('si')

# %%
#dff.loc[[endWindow],['Close']]

# %% [markdown]
# # Proceso de backTesting
# En este 'for' vamos recorriendo la muestra del historico de datos (TOTAL), desplaznado una sesion hacia el futuro
# en cada iteracion. Marcamos en la columna 'senal' las entradas como 100.

# %%
startWindow
# Out:
# '2010-01-05'

# %%
tiempo_inicial = time()

# %%
dfe = pd.DataFrame({'A' : []})   #df empty

# %%
for i in range(TOTAL_len):
    endWindow3   =endWindow2 + dt.timedelta(days=i) 
    endWindow    =endWindow3.strftime("%Y-%m-%d")
    print ('end date:', endWindow)
    
    if(endWindow in dff.index):
        df_aux= dff.loc[startWindow:endWindow]    #voy pasando los datos desplazando la ventana
        recogo = regreMedia.analisis(instrumento, startWindow, endWindow, df_aux) #Llamada a la clase estrategia. LA CLAVE DE TODO!!!
        print ('.............Analizando, muestra', i, 'fecha', endWindow)
        
        """
        if(recogo['senal'] == 1 ):
            dff.loc[[endWindow],['Senal']]= 1
        elif(recogo['senal'] == 0 ):
            dff.loc[[endWindow],['Senal']]= 0
        elif(recogo['senal'] == -1 ):
            dff.loc[[endWindow],['Senal']]= -1            
        elif(recogo['senal'] == 503 ):
            dff.loc[[endWindow],['Senal']]= 0          
        """
            
    else:
        print('..............Día sin sesión, next please')
# Out:
# end date: 2012-10-01
#  datos desde archivo
# Coefficients:
#  [-0.00401186]
# Independent term:
#  6.56939163019373
# Coefficients:
#  [-0.00911246]
# Independent term:
#  4.722449824418595
# Coefficients:
#  [-0.00870574]
# Independent term:
#  5.439850192894968
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 0 fecha 2012-10-01
# end date: 2012-10-02
#  datos desde archivo
# Coefficients:
#  [-0.00401259]
# Independent term:
#  6.569563795469952
# Coefficients:
#  [-0.00899264]
# Independent term:
#  4.705202363106742
# Coefficients:
#  [-0.00870859]
# Independent term:
#  5.432540264240361
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 1 fecha 2012-10-02
# end date: 2012-10-03
#  datos desde archivo
# Coefficients:
#  [-0.00401266]
# Independent term:
#  6.569579783421163
# Coefficients:
#  [-0.00885501]
# Independent term:
#  4.686153556517701
# Coefficients:
#  [-0.00871005]
# Independent term:
#  5.425113530830185
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 2 fecha 2012-10-03
# end date: 2012-10-04
#  datos desde archivo
# Coefficients:
#  [-0.00401317]
# Independent term:
#  6.569699700352916
# Coefficients:
#  [-0.00871617]
# Independent term:
#  4.666588776538621
# Coefficients:
#  [-0.00871011]
# Independent term:
#  5.417566020837235
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 3 fecha 2012-10-04
# end date: 2012-10-05
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#  datos desde archivo
# Coefficients:
#  [-0.00401247]
# Independent term:
#  6.5695350326100534
# Coefficients:
#  [-0.00856263]
# Independent term:
#  4.646096838089957
# Coefficients:
#  [-0.00870864]
# Independent term:
#  5.409889710561141
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 4 fecha 2012-10-05
# end date: 2012-10-06
# ..............Día sin sesión, next please
# end date: 2012-10-07
# ..............Día sin sesión, next please
# end date: 2012-10-08
#  datos desde archivo
# Coefficients:
#  [-0.00401178]
# Independent term:
#  6.569371486445505
# Coefficients:
#  [-0.0084226]
# Independent term:
#  4.627408624834089
# Coefficients:
#  [-0.00870579]
# Independent term:
#  5.402103829111121
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 7 fecha 2012-10-08
# end date: 2012-10-09
#  datos desde archivo
# Coefficients:
#  [-0.00401195]
# Independent term:
#  6.569413533600376
# Coefficients:
#  [-0.00828344]
# Independent term:
#  4.608116980346281
# Coefficients:
#  [-0.00870159]
# Independent term:
#  5.394203462456746
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 8 fecha 2012-10-09
# end date: 2012-10-10
#  datos desde archivo
# Coefficients:
#  [-0.00401199]
# Independent term:
#  6.569421687042112
# Coefficients:
#  [-0.00813481]
# Independent term:
#  4.587703990616015
# Coefficients:
#  [-0.00869595]
# Independent term:
#  5.386178592090172
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 9 fecha 2012-10-10
# end date: 2012-10-11
#  datos desde archivo
# Coefficients:
#  [-0.00401127]
# Independent term:
#  6.569250981283676
# Coefficients:
#  [-0.00795685]
# Independent term:
#  4.564052054277107
# Coefficients:
#  [-0.0086886]
# Independent term:
#  5.377998228529843
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 10 fecha 2012-10-11
# end date: 2012-10-12
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#  datos desde archivo
# Coefficients:
#  [-0.00401082]
# Independent term:
#  6.569145591819754
# Coefficients:
#  [-0.00780074]
# Independent term:
#  4.543088617680678
# Coefficients:
#  [-0.00867976]
# Independent term:
#  5.369690670212936
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 11 fecha 2012-10-12
# end date: 2012-10-13
# ..............Día sin sesión, next please
# end date: 2012-10-14
# ..............Día sin sesión, next please
# end date: 2012-10-15
#  datos desde archivo
# Coefficients:
#  [-0.00401007]
# Independent term:
#  6.568965699306925
# Coefficients:
#  [-0.00765645]
# Independent term:
#  4.5239765240897
# Coefficients:
#  [-0.00866958]
# Independent term:
#  5.361275604082357
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 14 fecha 2012-10-15
# end date: 2012-10-16
#  datos desde archivo
# Coefficients:
#  [-0.00400729]
# Independent term:
#  6.568305813823987
# Coefficients:
#  [-0.00750148]
# Independent term:
#  4.505177723400628
# Coefficients:
#  [-0.00865796]
# Independent term:
#  5.352757217209903
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 15 fecha 2012-10-16
# end date: 2012-10-17
#  datos desde archivo
# Coefficients:
#  [-0.00400297]
# Independent term:
#  6.56727550184836
# Coefficients:
#  [-0.00733033]
# Independent term:
#  4.485567572792965
# Coefficients:
#  [-0.00864475]
# Independent term:
#  5.344128464529137
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 16 fecha 2012-10-17
# end date: 2012-10-18
#  datos desde archivo
# Coefficients:
#  [-0.00399852]
# Independent term:
#  6.566213504732396
# Coefficients:
#  [-0.00715947]
# Independent term:
#  4.466121906237816
# Coefficients:
#  [-0.00862997]
# Independent term:
#  5.335392080864547
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 17 fecha 2012-10-18
# end date: 2012-10-19
#  datos desde archivo
# Coefficients:
#  [-0.00399522]
# Independent term:
#  6.565424803119043
# Coefficients:
#  [-0.00698486]
# Independent term:
#  4.4452083196213
# Coefficients:
#  [-0.0086136]
# Independent term:
#  5.32653453100143
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 18 fecha 2012-10-19
# end date: 2012-10-20
# ..............Día sin sesión, next please
# end date: 2012-10-21
# ..............Día sin sesión, next please
# end date: 2012-10-22
#  datos desde archivo
# Coefficients:
#  [-0.0039919]
# Independent term:
#  6.564630513267279
# Coefficients:
#  [-0.00680934]
# Independent term:
#  4.4242090694228215
# Coefficients:
#  [-0.00859565]
# Independent term:
#  5.317556168199653
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 21 fecha 2012-10-22
# end date: 2012-10-23
#  datos desde archivo
# Coefficients:
#  [-0.00398973]
# Independent term:
#  6.564109693211324
# Coefficients:
#  [-0.00665175]
# Independent term:
#  4.40461922339539
# Coefficients:
#  [-0.0085763]
# Independent term:
#  5.308472218500109
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 22 fecha 2012-10-23
# end date: 2012-10-24
#  datos desde archivo
# Coefficients:
#  [-0.00398683]
# Independent term:
#  6.563413190712327
# Coefficients:
#  [-0.00648223]
# Independent term:
#  4.3840917612545525
# Coefficients:
#  [-0.00855547]
# Independent term:
#  5.299274403005128
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 23 fecha 2012-10-24
# end date: 2012-10-25
#  datos desde archivo
# Coefficients:
#  [-0.0039835]
# Independent term:
#  6.562614092915169
# Coefficients:
#  [-0.00630729]
# Independent term:
#  4.363230271624095
# Coefficients:
#  [-0.0085331]
# Independent term:
#  5.289960531051088
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 24 fecha 2012-10-25
# end date: 2012-10-26
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#  datos desde archivo
# Coefficients:
#  [-0.00398008]
# Independent term:
#  6.56179028385956
# Coefficients:
#  [-0.0061262]
# Independent term:
#  4.341656691387518
# Coefficients:
#  [-0.00850915]
# Independent term:
#  5.280524671949959
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 25 fecha 2012-10-26
# end date: 2012-10-27
# ..............Día sin sesión, next please
# end date: 2012-10-28
# ..............Día sin sesión, next please
# end date: 2012-10-29
#  datos desde archivo
# Coefficients:
#  [-0.00397702]
# Independent term:
#  6.561051866942304
# Coefficients:
#  [-0.00596781]
# Independent term:
#  4.3228020686889765
# Coefficients:
#  [-0.00848386]
# Independent term:
#  5.270995093808058
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 28 fecha 2012-10-29
# end date: 2012-10-30
#  datos desde archivo
# Coefficients:
#  [-0.00397335]
# Independent term:
#  6.560167695766232
# Coefficients:
#  [-0.00579108]
# Independent term:
#  4.302052667567979
# Coefficients:
#  [-0.00845707]
# Independent term:
#  5.261353875636516
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 29 fecha 2012-10-30
# end date: 2012-10-31
#  datos desde archivo
# Coefficients:
#  [-0.00396979]
# Independent term:
#  6.559306101664804
# Coefficients:
#  [-0.0056259]
# Independent term:
#  4.282767295303629
# Coefficients:
#  [-0.0084289]
# Independent term:
#  5.251616695732707
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 30 fecha 2012-10-31
# end date: 2012-11-01
#  datos desde archivo
# Coefficients:
#  [-0.00396619]
# Independent term:
#  6.558436813619941
# Coefficients:
#  [-0.00546364]
# Independent term:
#  4.2639069988478475
# Coefficients:
#  [-0.00839939]
# Independent term:
#  5.241788738549774
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 31 fecha 2012-11-01
# end date: 2012-11-02
#  datos desde archivo
# Coefficients:
#  [-0.00396249]
# Independent term:
#  6.557538046536596
# Coefficients:
#  [-0.00530057]
# Independent term:
#  4.245056996772538
# Coefficients:
#  [-0.00836856]
# Independent term:
#  5.231871009775871
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 32 fecha 2012-11-02
# end date: 2012-11-03
# ..............Día sin sesión, next please
# end date: 2012-11-04
# ..............Día sin sesión, next please
# end date: 2012-11-05
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#  datos desde archivo
# Coefficients:
#  [-0.00395966]
# Independent term:
#  6.556852887037478
# Coefficients:
#  [-0.00515801]
# Independent term:
#  4.228156700917145
# Coefficients:
#  [-0.00833661]
# Independent term:
#  5.22188380272255
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 35 fecha 2012-11-05
# end date: 2012-11-06
#  datos desde archivo
# Coefficients:
#  [-0.00395682]
# Independent term:
#  6.556161613319565
# Coefficients:
#  [-0.00499443]
# Independent term:
#  4.208495354296557
# Coefficients:
#  [-0.00830336]
# Independent term:
#  5.211800335574033
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 36 fecha 2012-11-06
# end date: 2012-11-07
#  datos desde archivo
# Coefficients:
#  [-0.00395468]
# Independent term:
#  6.555641152018931
# Coefficients:
#  [-0.00484647]
# Independent term:
#  4.190293262040438
# Coefficients:
#  [-0.00826896]
# Independent term:
#  5.201636086086137
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 37 fecha 2012-11-07
# end date: 2012-11-08
#  datos desde archivo
# Coefficients:
#  [-0.00395268]
# Independent term:
#  6.555154246637413
# Coefficients:
#  [-0.00470814]
# Independent term:
#  4.173255056053845
# Coefficients:
#  [-0.00823353]
# Independent term:
#  5.19140343902114
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 38 fecha 2012-11-08
# end date: 2012-11-09
#  datos desde archivo
# Coefficients:
#  [-0.00395127]
# Independent term:
#  6.554809175248023
# Coefficients:
#  [-0.00457599]
# Independent term:
#  4.156520878841628
# Coefficients:
#  [-0.00819714]
# Independent term:
#  5.1811061001138805
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 39 fecha 2012-11-09
# end date: 2012-11-10
# ..............Día sin sesión, next please
# end date: 2012-11-11
# ..............Día sin sesión, next please
# end date: 2012-11-12
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#  datos desde archivo
# Coefficients:
#  [-0.00394999]
# Independent term:
#  6.554496387863646
# Coefficients:
#  [-0.00442992]
# Independent term:
#  4.137827441336504
# Coefficients:
#  [-0.00815965]
# Independent term:
#  5.170725217936992
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 42 fecha 2012-11-12
# end date: 2012-11-13
#  datos desde archivo
# Coefficients:
#  [-0.00394759]
# Independent term:
#  6.553909809764251
# Coefficients:
#  [-0.00426557]
# Independent term:
#  4.11772445518579
# Coefficients:
#  [-0.0081209]
# Independent term:
#  5.16024759840713
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 43 fecha 2012-11-13
# end date: 2012-11-14
#  datos desde archivo
# Coefficients:
#  [-0.00394491]
# Independent term:
#  6.553254370936567
# Coefficients:
#  [-0.00408852]
# Independent term:
#  4.096202963537245
# Coefficients:
#  [-0.00808078]
# Independent term:
#  5.149660089602455
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 44 fecha 2012-11-14
# end date: 2012-11-15
#  datos desde archivo
# Coefficients:
#  [-0.00394201]
# Independent term:
#  6.552541432883111
# Coefficients:
#  [-0.0039055]
# Independent term:
#  4.074117739805534
# Coefficients:
#  [-0.00803924]
# Independent term:
#  5.138958175674127
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 45 fecha 2012-11-15
# end date: 2012-11-16
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#  datos desde archivo
# Coefficients:
#  [-0.00393988]
# Independent term:
#  6.552019445384224
# Coefficients:
#  [-0.00373222]
# Independent term:
#  4.052635950828666
# Coefficients:
#  [-0.00799638]
# Independent term:
#  5.128148999307506
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 46 fecha 2012-11-16
# end date: 2012-11-17
# ..............Día sin sesión, next please
# end date: 2012-11-18
# ..............Día sin sesión, next please
# end date: 2012-11-19
#  datos desde archivo
# Coefficients:
#  [-0.00393644]
# Independent term:
#  6.5511727432099045
# Coefficients:
#  [-0.00353749]
# Independent term:
#  4.029525202352609
# Coefficients:
#  [-0.00795201]
# Independent term:
#  5.117217419238304
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 49 fecha 2012-11-19
# end date: 2012-11-20
#  datos desde archivo
# Coefficients:
#  [-0.00393295]
# Independent term:
#  6.5503130942186
# Coefficients:
#  [-0.00333697]
# Independent term:
#  4.005713411302708
# Coefficients:
#  [-0.00790609]
# Independent term:
#  5.10615767786581
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 50 fecha 2012-11-20
# end date: 2012-11-21
#  datos desde archivo
# Coefficients:
#  [-0.00392899]
# Independent term:
#  6.549335915236229
# Coefficients:
#  [-0.00313837]
# Independent term:
#  3.9826126604293712
# Coefficients:
#  [-0.00785865]
# Independent term:
#  5.094978125453507
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 51 fecha 2012-11-21
# end date: 2012-11-22
#  datos desde archivo
# Coefficients:
#  [-0.00392507]
# Independent term:
#  6.548368167865293
# Coefficients:
#  [-0.00294223]
# Independent term:
#  3.9598214654068453
# Coefficients:
#  [-0.00780973]
# Independent term:
#  5.0836830343087644
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 52 fecha 2012-11-22
# end date: 2012-11-23
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#  datos desde archivo
# Coefficients:
#  [-0.00392085]
# Independent term:
#  6.547324111440648
# Coefficients:
#  [-0.00273549]
# Independent term:
#  3.935926545449157
# Coefficients:
#  [-0.00775924]
# Independent term:
#  5.072262571733049
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 53 fecha 2012-11-23
# end date: 2012-11-24
# ..............Día sin sesión, next please
# end date: 2012-11-25
# ..............Día sin sesión, next please
# end date: 2012-11-26
#  datos desde archivo
# Coefficients:
#  [-0.00391701]
# Independent term:
#  6.546372816800612
# Coefficients:
#  [-0.00253766]
# Independent term:
#  3.912886991073836
# Coefficients:
#  [-0.00770729]
# Independent term:
#  5.060726496303603
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 56 fecha 2012-11-26
# end date: 2012-11-27
#  datos desde archivo
# Coefficients:
#  [-0.00391354]
# Independent term:
#  6.545513550748515
# Coefficients:
#  [-0.00235052]
# Independent term:
#  3.8909419203160414
# Coefficients:
#  [-0.00765399]
# Independent term:
#  5.049086848781339
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 57 fecha 2012-11-27
# end date: 2012-11-28
#  datos desde archivo
# Coefficients:
#  [-0.00391092]
# Independent term:
#  6.544862917772377
# Coefficients:
#  [-0.0021677]
# Independent term:
#  3.8688056541912594
# Coefficients:
#  [-0.0075994]
# Independent term:
#  5.0373427572928815
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 58 fecha 2012-11-28
# end date: 2012-11-29
#  datos desde archivo
# Coefficients:
#  [-0.0039085]
# Independent term:
#  6.544259470059437
# Coefficients:
#  [-0.00197295]
# Independent term:
#  3.844928640002635
# Coefficients:
#  [-0.00754341]
# Independent term:
#  5.025477940205415
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 59 fecha 2012-11-29
# end date: 2012-11-30
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:825: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#  datos desde archivo
# Coefficients:
#  [-0.00390637]
# Independent term:
#  6.543729432512189
# Coefficients:
#  [-0.0017839]
# Independent term:
#  3.8215528235150806
# Coefficients:
#  [-0.0074861]
# Independent term:
#  5.0134985858104875
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 60 fecha 2012-11-30
# end date: 2012-12-01
# ..............Día sin sesión, next please
# end date: 2012-12-02
# ..............Día sin sesión, next please
# end date: 2012-12-03
#  datos desde archivo
# Coefficients:
#  [-0.00390458]
# Independent term:
#  6.543282848979545
# Coefficients:
#  [-0.0016088]
# Independent term:
#  3.799735659770112
# Coefficients:
#  [-0.00742762]
# Independent term:
#  5.00142134276531
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 63 fecha 2012-12-03
# end date: 2012-12-04
#  datos desde archivo
# Coefficients:
#  [-0.00390229]
# Independent term:
#  6.542712165332839
# Coefficients:
#  [-0.00144557]
# Independent term:
#  3.7799738708894646
# Coefficients:
#  [-0.0073681]
# Independent term:
#  4.989267636577491
#   instrumento  long_short_out        date     precio
# 0      TEF.MC               0  2005-04-19  12.902192
# .............Analizando, muestra 64 fecha 2012-12-04
# end date: 2012-12-05
#  datos desde archivo
# Coefficients:
#  [-0.00390009]
# Independent term:
#  6.542161419728736
# Coefficients:
#  [-0.00128669]
# Independent term:
#  3.7607255152090273
# Coefficients:
#  [-0.00730759]
# ...
# ..............Día sin sesión, next please
# end date: 2028-12-07
# ..............Día sin sesión, next please
# end date: 2028-12-08
# ..............Día sin sesión, next please
# end date: 2028-12-09
# ..............Día sin sesión, next please
# end date: 2028-12-10
# ..............Día sin sesión, next please
# end date: 2028-12-11
# ..............Día sin sesión, next please
# end date: 2028-12-12
# ..............Día sin sesión, next please
# end date: 2028-12-13
# ..............Día sin sesión, next please
# end date: 2028-12-14
# ..............Día sin sesión, next please
# end date: 2028-12-15
# ..............Día sin sesión, next please
# end date: 2028-12-16
# ..............Día sin sesión, next please
# end date: 2028-12-17
# ..............Día sin sesión, next please
# end date: 2028-12-18
# ..............Día sin sesión, next please
# end date: 2028-12-19
# ..............Día sin sesión, next please
# end date: 2028-12-20
# ..............Día sin sesión, next please
# end date: 2028-12-21
# ..............Día sin sesión, next please
# end date: 2028-12-22
# ..............Día sin sesión, next please
# end date: 2028-12-23
# ..............Día sin sesión, next please
# end date: 2028-12-24
# ..............Día sin sesión, next please
# end date: 2028-12-25
# ..............Día sin sesión, next please
# end date: 2028-12-26
# ..............Día sin sesión, next please
# end date: 2028-12-27
# ..............Día sin sesión, next please
# end date: 2028-12-28
# ..............Día sin sesión, next please
# end date: 2028-12-29
# ..............Día sin sesión, next please
# end date: 2028-12-30
# ..............Día sin sesión, next please
# end date: 2028-12-31
# ..............Día sin sesión, next please
# end date: 2029-01-01
# ..............Día sin sesión, next please
# end date: 2029-01-02
# ..............Día sin sesión, next please
# end date: 2029-01-03
# ..............Día sin sesión, next please
# end date: 2029-01-04
# ..............Día sin sesión, next please
# end date: 2029-01-05
# ..............Día sin sesión, next please
# end date: 2029-01-06
# ..............Día sin sesión, next please
# end date: 2029-01-07
# ..............Día sin sesión, next please
# end date: 2029-01-08
# ..............Día sin sesión, next please
# end date: 2029-01-09
# ..............Día sin sesión, next please
# end date: 2029-01-10
# ..............Día sin sesión, next please
# end date: 2029-01-11
# ..............Día sin sesión, next please
# end date: 2029-01-12
# ..............Día sin sesión, next please
# end date: 2029-01-13
# ..............Día sin sesión, next please
# end date: 2029-01-14
# ..............Día sin sesión, next please
# end date: 2029-01-15
# ..............Día sin sesión, next please
# end date: 2029-01-16
# ..............Día sin sesión, next please
# end date: 2029-01-17
# ..............Día sin sesión, next please
# end date: 2029-01-18
# ..............Día sin sesión, next please
# end date: 2029-01-19
# ..............Día sin sesión, next please
# end date: 2029-01-20
# ..............Día sin sesión, next please
# end date: 2029-01-21
# ..............Día sin sesión, next please
# end date: 2029-01-22
# ..............Día sin sesión, next please
# end date: 2029-01-23
# ..............Día sin sesión, next please
# end date: 2029-01-24
# ..............Día sin sesión, next please
# end date: 2029-01-25
# ..............Día sin sesión, next please
# end date: 2029-01-26
# ..............Día sin sesión, next please
# end date: 2029-01-27
# ..............Día sin sesión, next please
# end date: 2029-01-28
# ..............Día sin sesión, next please
# end date: 2029-01-29
# ..............Día sin sesión, next please
# end date: 2029-01-30
# ..............Día sin sesión, next please
# end date: 2029-01-31
# ..............Día sin sesión, next please
# end date: 2029-02-01
# ..............Día sin sesión, next please
# end date: 2029-02-02
# ..............Día sin sesión, next please
# end date: 2029-02-03
# ..............Día sin sesión, next please
# end date: 2029-02-04
# ..............Día sin sesión, next please
# end date: 2029-02-05
# ..............Día sin sesión, next please
# end date: 2029-02-06
# ..............Día sin sesión, next please
# end date: 2029-02-07
# ..............Día sin sesión, next please
# end date: 2029-02-08
# ..............Día sin sesión, next please
# end date: 2029-02-09
# ..............Día sin sesión, next please
# end date: 2029-02-10
# ..............Día sin sesión, next please
# end date: 2029-02-11
# ..............Día sin sesión, next please
# end date: 2029-02-12
# ..............Día sin sesión, next please
# end date: 2029-02-13
# ..............Día sin sesión, next please
# end date: 2029-02-14
# ..............Día sin sesión, next please
# end date: 2029-02-15
# ..............Día sin sesión, next please
# end date: 2029-02-16
# ..............Día sin sesión, next please
# end date: 2029-02-17
# ..............Día sin sesión, next please
# end date: 2029-02-18
# ..............Día sin sesión, next please
# end date: 2029-02-19
# ..............Día sin sesión, next please
# end date: 2029-02-20
# ..............Día sin sesión, next please
# end date: 2029-02-21
# ..............Día sin sesión, next please
# end date: 2029-02-22
# ..............Día sin sesión, next please
# end date: 2029-02-23
# ..............Día sin sesión, next please
# end date: 2029-02-24
# ..............Día sin sesión, next please
# end date: 2029-02-25
# ..............Día sin sesión, next please
# end date: 2029-02-26
# ..............Día sin sesión, next please
# end date: 2029-02-27
# ..............Día sin sesión, next please
# end date: 2029-02-28
# ..............Día sin sesión, next please
# end date: 2029-03-01
# ..............Día sin sesión, next please
# end date: 2029-03-02
# ..............Día sin sesión, next please
# end date: 2029-03-03
# ..............Día sin sesión, next please
# end date: 2029-03-04
# ..............Día sin sesión, next please
# end date: 2029-03-05
# ..............Día sin sesión, next please
# end date: 2029-03-06
# ..............Día sin sesión, next please
# end date: 2029-03-07
# ..............Día sin sesión, next please
# end date: 2029-03-08
# ..............Día sin sesión, next please
# end date: 2029-03-09
# ..............Día sin sesión, next please
# end date: 2029-03-10
# ..............Día sin sesión, next please
# end date: 2029-03-11
# ..............Día sin sesión, next please
# end date: 2029-03-12
# ..............Día sin sesión, next please
# end date: 2029-03-13
# ..............Día sin sesión, next please
# end date: 2029-03-14
# ..............Día sin sesión, next please
# end date: 2029-03-15
# ..............Día sin sesión, next please
# end date: 2029-03-16
# ..............Día sin sesión, next please
# end date: 2029-03-17
# ..............Día sin sesión, next please
# end date: 2029-03-18
# ..............Día sin sesión, next please
# end date: 2029-03-19
# ..............Día sin sesión, next please
# end date: 2029-03-20
# ..............Día sin sesión, next please
# end date: 2029-03-21
# ..............Día sin sesión, next please
# end date: 2029-03-22
# ..............Día sin sesión, next please
# end date: 2029-03-23
# ..............Día sin sesión, next please
# end date: 2029-03-24
# ..............Día sin sesión, next please
# end date: 2029-03-25
# ..............Día sin sesión, next please
# end date: 2029-03-26
# ..............Día sin sesión, next please
# end date: 2029-03-27
# ..............Día sin sesión, next please
# end date: 2029-03-28
# ..............Día sin sesión, next please
# end date: 2029-03-29
# ..............Día sin sesión, next please
# end date: 2029-03-30
# ..............Día sin sesión, next please
# end date: 2029-03-31
# ..............Día sin sesión, next please
# end date: 2029-04-01
# ..............Día sin sesión, next please
# end date: 2029-04-02
# ..............Día sin sesión, next please
# end date: 2029-04-03
# ..............Día sin sesión, next please
# end date: 2029-04-04
# ..............Día sin sesión, next please
# end date: 2029-04-05
# ..............Día sin sesión, next please
# end date: 2029-04-06
# ..............Día sin sesión, next please
# end date: 2029-04-07
# ..............Día sin sesión, next please
# end date: 2029-04-08
# ..............Día sin sesión, next please
# end date: 2029-04-09
# ..............Día sin sesión, next please
# end date: 2029-04-10
# ..............Día sin sesión, next please
# end date: 2029-04-11
# ..............Día sin sesión, next please
# end date: 2029-04-12
# ..............Día sin sesión, next please
# end date: 2029-04-13
# ..............Día sin sesión, next please
# end date: 2029-04-14
# ..............Día sin sesión, next please
# end date: 2029-04-15
# ..............Día sin sesión, next please
# end date: 2029-04-16
# ..............Día sin sesión, next please
# end date: 2029-04-17
# ..............Día sin sesión, next please
# end date: 2029-04-18
# ..............Día sin sesión, next please
# end date: 2029-04-19
# ..............Día sin sesión, next please
# end date: 2029-04-20
# ..............Día sin sesión, next please
# end date: 2029-04-21
# ..............Día sin sesión, next please
# end date: 2029-04-22
# ..............Día sin sesión, next please
# end date: 2029-04-23
# ..............Día sin sesión, next please
# end date: 2029-04-24
# ..............Día sin sesión, next please
# end date: 2029-04-25
# ..............Día sin sesión, next please
# end date: 2029-04-26
# ..............Día sin sesión, next please
# end date: 2029-04-27
# ..............Día sin sesión, next please
# end date: 2029-04-28
# ..............Día sin sesión, next please
# end date: 2029-04-29
# ..............Día sin sesión, next please
# end date: 2029-04-30
# ..............Día sin sesión, next please
# end date: 2029-05-01
# ..............Día sin sesión, next please
# end date: 2029-05-02
# ..............Día sin sesión, next please
# end date: 2029-05-03
# ..............Día sin sesión, next please
# end date: 2029-05-04
# ..............Día sin sesión, next please
# end date: 2029-05-05
# ..............Día sin sesión, next please
# end date: 2029-05-06
# ..............Día sin sesión, next please
# end date: 2029-05-07
# ..............Día sin sesión, next please
# end date: 2029-05-08
# ..............Día sin sesión, next please
# end date: 2029-05-09
# ..............Día sin sesión, next please
# end date: 2029-05-10
# ..............Día sin sesión, next please
# end date: 2029-05-11
# ..............Día sin sesión, next please
# end date: 2029-05-12
# ..............Día sin sesión, next please
# end date: 2029-05-13
# ..............Día sin sesión, next please
# end date: 2029-05-14
# ..............Día sin sesión, next please
# end date: 2029-05-15
# ..............Día sin sesión, next please
# end date: 2029-05-16
# ..............Día sin sesión, next please
# end date: 2029-05-17
# ..............Día sin sesión, next please
# end date: 2029-05-18
# ..............Día sin sesión, next please
# end date: 2029-05-19
# ..............Día sin sesión, next please
# end date: 2029-05-20
# ..............Día sin sesión, next please
# end date: 2029-05-21
# ..............Día sin sesión, next please
# end date: 2029-05-22
# ..............Día sin sesión, next please
# end date: 2029-05-23
# ..............Día sin sesión, next please
# end date: 2029-05-24
# ..............Día sin sesión, next please
# end date: 2029-05-25
# ..............Día sin sesión, next please
# end date: 2029-05-26
# ..............Día sin sesión, next please
# end date: 2029-05-27
# ..............Día sin sesión, next please
# end date: 2029-05-28
# ..............Día sin sesión, next please
# end date: 2029-05-29
# ..............Día sin sesión, next please
# end date: 2029-05-30
# ..............Día sin sesión, next please
# end date: 2029-05-31
# ..............Día sin sesión, next please
# end date: 2029-06-01
# ..............Día sin sesión, next please
# end date: 2029-06-02
# ..............Día sin sesión, next please
# end date: 2029-06-03
# ..............Día sin sesión, next please
# end date: 2029-06-04
# ..............Día sin sesión, next please
# end date: 2029-06-05
# ..............Día sin sesión, next please
# end date: 2029-06-06
# ..............Día sin sesión, next please
# end date: 2029-06-07
# ..............Día sin sesión, next please
# end date: 2029-06-08
# ..............Día sin sesión, next please
# end date: 2029-06-09
# ..............Día sin sesión, next please
# end date: 2029-06-10
# ..............Día sin sesión, next please
# end date: 2029-06-11
# ..............Día sin sesión, next please
# end date: 2029-06-12
# ..............Día sin sesión, next please
# end date: 2029-06-13
# ..............Día sin sesión, next please
# end date: 2029-06-14
# ..............Día sin sesión, next please
# end date: 2029-06-15
# ..............Día sin sesión, next please
# end date: 2029-06-16
# ..............Día sin sesión, next please
# end date: 2029-06-17
# ..............Día sin sesión, next please
# end date: 2029-06-18
# ..............Día sin sesión, next please
# end date: 2029-06-19
# ..............Día sin sesión, next please
# end date: 2029-06-20
# ..............Día sin sesión, next please
# end date: 2029-06-21
# ..............Día sin sesión, next please
# end date: 2029-06-22
# ..............Día sin sesión, next please
# end date: 2029-06-23
# ..............Día sin sesión, next please
# end date: 2029-06-24
# ..............Día sin sesión, next please
# end date: 2029-06-25
# ..............Día sin sesión, next please
# end date: 2029-06-26
# ..............Día sin sesión, next please
# end date: 2029-06-27
# ..............Día sin sesión, next please
# end date: 2029-06-28
# ..............Día sin sesión, next please
# end date: 2029-06-29
# ..............Día sin sesión, next please
# end date: 2029-06-30
# ..............Día sin sesión, next please
# end date: 2029-07-01
# ..............Día sin sesión, next please
# end date: 2029-07-02
# ..............Día sin sesión, next please
# end date: 2029-07-03
# ..............Día sin sesión, next please
# end date: 2029-07-04
# ..............Día sin sesión, next please
# end date: 2029-07-05
# ..............Día sin sesión, next please
# end date: 2029-07-06
# ..............Día sin sesión, next please
# end date: 2029-07-07
# ..............Día sin sesión, next please
# end date: 2029-07-08
# ..............Día sin sesión, next please
# end date: 2029-07-09
# ..............Día sin sesión, next please
# end date: 2029-07-10
# ..............Día sin sesión, next please
# end date: 2029-07-11
# ..............Día sin sesión, next please
# end date: 2029-07-12
# ..............Día sin sesión, next please
# end date: 2029-07-13
# ..............Día sin sesión, next please
# end date: 2029-07-14
# ..............Día sin sesión, next please
# end date: 2029-07-15
# ..............Día sin sesión, next please
# end date: 2029-07-16
# ..............Día sin sesión, next please
# end date: 2029-07-17
# ..............Día sin sesión, next please
# end date: 2029-07-18
# ..............Día sin sesión, next please
# end date: 2029-07-19
# ..............Día sin sesión, next please
# end date: 2029-07-20
# ..............Día sin sesión, next please
# end date: 2029-07-21
# ..............Día sin sesión, next please
# end date: 2029-07-22
# ..............Día sin sesión, next please
# end date: 2029-07-23
# ..............Día sin sesión, next please
# end date: 2029-07-24
# ..............Día sin sesión, next please
# end date: 2029-07-25
# ..............Día sin sesión, next please
# end date: 2029-07-26
# ..............Día sin sesión, next please
# end date: 2029-07-27
# ..............Día sin sesión, next please
# end date: 2029-07-28
# ..............Día sin sesión, next please
# end date: 2029-07-29
# ..............Día sin sesión, next please
# end date: 2029-07-30
# ..............Día sin sesión, next please
# end date: 2029-07-31
# ..............Día sin sesión, next please
# end date: 2029-08-01
# ..............Día sin sesión, next please
# end date: 2029-08-02
# ..............Día sin sesión, next please
# end date: 2029-08-03
# ..............Día sin sesión, next please
# end date: 2029-08-04
# ..............Día sin sesión, next please
# end date: 2029-08-05
# ..............Día sin sesión, next please
# end date: 2029-08-06
# ..............Día sin sesión, next please
# end date: 2029-08-07
# ..............Día sin sesión, next please
# end date: 2029-08-08
# ..............Día sin sesión, next please
# end date: 2029-08-09
# ..............Día sin sesión, next please
# end date: 2029-08-10
# ..............Día sin sesión, next please
# end date: 2029-08-11
# ..............Día sin sesión, next please
# end date: 2029-08-12
# ..............Día sin sesión, next please
# end date: 2029-08-13
# ..............Día sin sesión, next please
# end date: 2029-08-14
# ..............Día sin sesión, next please
# end date: 2029-08-15
# ..............Día sin sesión, next please
# end date: 2029-08-16
# ..............Día sin sesión, next please

# %%
data=rg.StrategyClass.dfLog
data.head()
# Out:
#                   Date Senal Price Objetivo ExitReason
# 2012-10-01  2012-10-01     0     0      NaN        NaN
# 2012-10-02  2012-10-02     0     0      NaN        NaN
# 2012-10-03  2012-10-03     0     0      NaN        NaN
# 2012-10-04  2012-10-04     0     0      NaN        NaN
# 2012-10-05  2012-10-05     0     0      NaN        NaN

# %%
data.tail()
# Out:
#                   Date Senal Price Objetivo ExitReason
# 2021-11-11  2021-11-11     0     0      NaN        NaN
# 2021-11-12  2021-11-12     0     0      NaN        NaN
# 2021-11-15  2021-11-15     0     0      NaN        NaN
# 2021-11-16  2021-11-16     0     0      NaN        NaN
# 2021-11-17  2021-11-17     0     0      NaN        NaN

# %%
#data.loc['2010':'2022','Senal'].plot(title = 'Señales Regresión a la media ' +instrumento,xlim=('2010','2022'))
data['Senal'].plot(title = 'Señales Regresión a la media ' )
# Out:
# <AxesSubplot:title={'center':'Señales Regresión a la media '}>

# %%
tiempo_final = time() 
 
tiempo_ejecucion = tiempo_final - tiempo_inicial
 
print ('El tiempo de ejecucion fue:',tiempo_ejecucion,"segundos") #En segundos
# Out:
# El tiempo de ejecucion fue: 556.036146402359 segundos

# %%
data.loc['2011-01-04':'2019-11-04']
# Out:
#                   Date Senal Price Objetivo ExitReason
# 2012-10-01  2012-10-01     0     0      NaN        NaN
# 2012-10-02  2012-10-02     0     0      NaN        NaN
# 2012-10-03  2012-10-03     0     0      NaN        NaN
# 2012-10-04  2012-10-04     0     0      NaN        NaN
# 2012-10-05  2012-10-05     0     0      NaN        NaN
# ...                ...   ...   ...      ...        ...
# 2019-10-29  2019-10-29     0     0      NaN        NaN
# 2019-10-30  2019-10-30     0     0      NaN        NaN
# 2019-10-31  2019-10-31     0     0      NaN        NaN
# 2019-11-01  2019-11-01     0     0      NaN        NaN
# 2019-11-04  2019-11-04     0     0      NaN        NaN
#
# [1812 rows x 5 columns]

# %%
#Guardamos el resultado del analisis en un pickle
dff.to_pickle("./primerBack_IBE.pkl")

# %% [markdown]
# Como lo que nos interesa es su cruce, para saber cuando se produce calcularemos la diferencia entre ambas medias para cada muestra. Y el signo de la diferencia será la señal para establecer la posición del sistema.
#
# Así cuando la diferencia sea positiva, significará que la media de 20 periodos es mayor que la de 60 periodos, indicando una tendencia alcista y tomando una posición compradora. Con una diferencia negativa, la lógica es justo la inversa y tomaremos posicion vendedora.

# %%
data['Dif_Close'] = data.Price.pct_change()
data['Retornos'] = data.Dif_Close * data.Senal.shift(1)   
data['Capital'] = (data.Retornos + 1).cumprod() * 100
    
rg.StrategyClass.dfLog=data

#quant_j.salvarExcel(StrategyClass.dfLog, "log"+instrumento)
    
#data.to_pickle('almacen')    #df = pd.read_pickle(file_name)

# %% [markdown]
# Para calcular los retornos del sistema, calculamos la diferencia relativativa entre el precio de cierre y el del día anterior. Para posteriormente multiplicarlo por la señal que del día anterior que nos indicaba la posición a tomar.

# %%
data.tail()
# Out:
#                   Date Senal Price Objetivo ExitReason  Dif_Close Retornos  \
# 2021-11-11  2021-11-11     0     0      NaN        NaN        NaN      NaN
# 2021-11-12  2021-11-12     0     0      NaN        NaN        NaN      NaN
# 2021-11-15  2021-11-15     0     0      NaN        NaN        NaN      NaN
# 2021-11-16  2021-11-16     0     0      NaN        NaN        NaN      NaN
# 2021-11-17  2021-11-17     0     0      NaN        NaN        NaN      NaN
#
#            Capital
# 2021-11-11     NaN
# 2021-11-12     NaN
# 2021-11-15     NaN
# 2021-11-16     NaN
# 2021-11-17     NaN

# %% [markdown]
# El capital, por comodidad, lo calcularemos en base 100, es decir como si iniciaramos la inversión con 100 unidades monetarias. Para su calculo arrastramos el producto acumulado de los retornos mas 1, multiplicados como dijimos por 100.

# %% [markdown]
# Veamos como queda la tabla, tras añadir estas columnas.
#
# Observamos de la fila 58 en adelante, pues hasta que no existen 60 filas no es posible calcular el SMA_60, y por tanto no tenemos señal para tomar posición.

# %%
data[:100]
# Out:
#                   Date Senal Price Objetivo ExitReason  Dif_Close Retornos  \
# 2012-10-01  2012-10-01     0     0      NaN        NaN        NaN      NaN
# 2012-10-02  2012-10-02     0     0      NaN        NaN        NaN      NaN
# 2012-10-03  2012-10-03     0     0      NaN        NaN        NaN      NaN
# 2012-10-04  2012-10-04     0     0      NaN        NaN        NaN      NaN
# 2012-10-05  2012-10-05     0     0      NaN        NaN        NaN      NaN
# ...                ...   ...   ...      ...        ...        ...      ...
# 2013-02-14  2013-02-14     0     0      NaN        NaN        NaN      NaN
# 2013-02-15  2013-02-15     0     0      NaN        NaN        NaN      NaN
# 2013-02-18  2013-02-18     0     0      NaN        NaN        NaN      NaN
# 2013-02-19  2013-02-19     0     0      NaN        NaN        NaN      NaN
# 2013-02-20  2013-02-20     0     0      NaN        NaN        NaN      NaN
#
#            Capital
# 2012-10-01     NaN
# 2012-10-02     NaN
# 2012-10-03     NaN
# 2012-10-04     NaN
# 2012-10-05     NaN
# ...            ...
# 2013-02-14     NaN
# 2013-02-15     NaN
# 2013-02-18     NaN
# 2013-02-19     NaN
# 2013-02-20     NaN
#
# [100 rows x 8 columns]

# %% [markdown]
# Veamos gráficamente como evoluciona el precio y las dos medias.

# %%
#data[['Close','SMA_20','SMA_60']].plot(color=['0.7','r','g'])
#plt.show()

# %% [markdown]
# Pero para observar gráficamente la evolución del sistema necesitamos un gráfico con mas información. Para ello definimos una función que nos mostrará un gráfico con la evolución de nuestra estrategia, comparandola con la del activo. En un subgráfico se visualizará el drawdown del sistema, comparado de nuevo con el del activo. Y por útlimo las posiciones que toma el sistema.

# %%
def grafico (df):
    estudio = df.copy()
    #DD_bh, maxDD, maxDD_ini, maxDD_fin = analisis.DrawDown(estudio.Dif_Close[60:], info = False) 
    #DD, maxDD, maxDD_ini, maxDD_fin = analisis.DrawDown(estudio.Retornos.fillna(0), info = False) 

    fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True, figsize=(18, 12), gridspec_kw = {'height_ratios':[3, 1, 1]})
    fig.suptitle('Estrategia vs B & H', fontsize=20)

    ax1.plot(estudio.Capital)
    ax1.plot(((estudio.Price) *100) - (estudio.Price[0]))
    ax1.set_title('Capital')
    ax1.legend(['Estrategia','Buy & Hold'])

    #ax2.plot(DD*100, c='0.5')
    #ax2.plot(DD_bh*100, c='y')
    #ax2.fill_between(DD.index, 0, DD*100, color='0.7')
    ax2.set_title('Drawdown')
    #ax2.legend(['Estrategia','Buy & Hold'])

    ax3.plot(estudio.Senal, c='orange')
    #ax3.fill_between(estudio.index, 0, estudio.Senal*100, color='orange')
    ax3.set_title('Posición')

    plt.show()
    return

# %%
grafico(data)

# %% [markdown]
# ---

# %%
data[55:70]
# Out:
#                   Date Senal Price Objetivo ExitReason  Dif_Close Retornos  \
# 2012-12-17  2012-12-17     0     0      NaN        NaN        NaN      NaN
# 2012-12-18  2012-12-18     0     0      NaN        NaN        NaN      NaN
# 2012-12-19  2012-12-19     0     0      NaN        NaN        NaN      NaN
# 2012-12-20  2012-12-20     0     0      NaN        NaN        NaN      NaN
# 2012-12-21  2012-12-21     0     0      NaN        NaN        NaN      NaN
# 2012-12-24  2012-12-24     0     0      NaN        NaN        NaN      NaN
# 2012-12-27  2012-12-27     0     0      NaN        NaN        NaN      NaN
# 2012-12-28  2012-12-28     0     0      NaN        NaN        NaN      NaN
# 2012-12-31  2012-12-31     0     0      NaN        NaN        NaN      NaN
# 2013-01-02  2013-01-02     0     0      NaN        NaN        NaN      NaN
# 2013-01-03  2013-01-03     0     0      NaN        NaN        NaN      NaN
# 2013-01-04  2013-01-04     0     0      NaN        NaN        NaN      NaN
# 2013-01-07  2013-01-07     0     0      NaN        NaN        NaN      NaN
# 2013-01-08  2013-01-08     0     0      NaN        NaN        NaN      NaN
# 2013-01-09  2013-01-09     0     0      NaN        NaN        NaN      NaN
#
#            Capital
# 2012-12-17     NaN
# 2012-12-18     NaN
# 2012-12-19     NaN
# 2012-12-20     NaN
# 2012-12-21     NaN
# 2012-12-24     NaN
# 2012-12-27     NaN
# 2012-12-28     NaN
# 2012-12-31     NaN
# 2013-01-02     NaN
# 2013-01-03     NaN
# 2013-01-04     NaN
# 2013-01-07     NaN
# 2013-01-08     NaN
# 2013-01-09     NaN

# %% [markdown]
# ---

# %% [markdown]
# # ANALISIS DEL SISTEMA

# %%
Beneficio_Bruto = data.Capital[-1] - data.Capital[0]
print ('Beneficio Bruto : {:.2f}'.format(Beneficio_Bruto))
# Out:
# Beneficio Bruto : nan

# %%
CAGR = analisis.CAGR(data.Retornos)
print ('CAGR : {:.2f}%'.format(CAGR * 100))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\INNOVA~1\AppData\Local\Temp/ipykernel_23776/711071882.py in <module>
# ----> 1 CAGR = analisis.CAGR(data.Retornos)
#       2 print ('CAGR : {:.2f}%'.format(CAGR * 100))
#
# ~\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\analisis.py in CAGR(retornos)
#     101     retorno_acumulado = retornos.fillna(0).add(1).cumprod()
#     102     cagr = (retorno_acumulado[-1] / retorno_acumulado[0]) ** (
# --> 103                 365 / (retornos.index[-1] - retornos.index[0]).days ) - 1
#     104     return cagr
#     105
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
DD, maxDD, maxDD_ini, maxDD_fin = analisis.DrawDown(data.Retornos)

# %%
Sharpe = CAGR / (np.log(data.Retornos + 1).std(skipna=True) * 252 ** 0.5)
print ('Sharpe : {:.3f}'.format(CAGR ))

# %% [markdown]
# --------------------------------------------------------------------

# %% [markdown]
# ---------------------------------------------------------------

# %% [markdown]
# ---

# %% [markdown]
# # OPTIMIZACION DEL SISTEMA

# %%
op_data = qd_data[:'2016'].copy()
op_data['Dif_Close'] = op_data.Close.pct_change()
op_data['Dif_Open'] = op_data.Close.pct_change()  #era Open

# %%
def estrategia_medias (df, periodo_rapido, periodo_lento):
    
    estr = df.copy()
    estr[f'SMA_{periodo_rapido}'] = estr.Close.rolling(periodo_rapido).mean()
    estr[f'SMA_{periodo_lento}'] = estr.Close.rolling(periodo_lento).mean()
    estr['Dif_SMA'] = estr[f'SMA_{periodo_rapido}'] - estr[f'SMA_{periodo_lento}']    
    estr['Senal'] = estr.Dif_SMA / estr.Dif_SMA.abs()
    estr['Posicion'] = estr.Senal.shift(1)    
    estr['Retornos'] = estr.Posicion.shift(1) * estr.Dif_Open    
    estr['Capital'] = (estr.Retornos+1).cumprod() * 100
    
    resultados = {'Rapida' : periodo_rapido, 'Lenta' : periodo_lento}
    resultados['Beneficio Bruto'] = round(estr.Capital[-1]-100,2)
    resultados['CAGR'] = analisis.CAGR(estr.Retornos) 
    resultados['Sharpe'] = resultados['CAGR'] / (np.log(estr.Retornos + 1).std(skipna=True) * 252 ** 0.5)
    resultados['Máximo Drawdown'] = (estr.Capital.div(estr.Capital.cummax()).sub(1)).min()
    
    resultados['Número de trades'] = (np.sign(estr.Posicion * estr.Posicion.shift(1)) == -1).sum() 
    
    return estr, resultados

# %%
periodos_rapido = range (5,160,5)
periodos_lento = range (20,210,5)

# %%
# %%time

coleccion = {}
resultados = {}

for periodo_rapido in periodos_rapido:
    for periodo_lento in periodos_lento:

        
        if periodo_lento <= periodo_rapido:
            continue
        estr, resultado = estrategia_medias (op_data, periodo_rapido, periodo_lento)
        nombre = f'estrategia_{periodo_rapido}_{periodo_lento}'
        coleccion[nombre] = estr
        resultados[nombre] = resultado

# %%
print ('Realizados {} backtests sobre una serie de {} muestras'.format(len(coleccion), op_data.shape[0]))

# %%
clasificacion = pd.DataFrame(resultados).transpose()
clasificacion.head(25)

# %%
pd.DataFrame(clasificacion['Beneficio Bruto'].sort_values(ascending=False).head(10))

# %%
pd.DataFrame(clasificacion.Sharpe.sort_values(ascending=False).head(10))

# %%
pd.DataFrame(clasificacion['Máximo Drawdown'].sort_values(ascending=False).head(10))

# %%
clasificacion['Beneficio Bruto'].sort_values(ascending=False).plot(kind='bar')

# %%
(clasificacion['Beneficio Bruto']/clasificacion['Número de trades']).sort_values(ascending=False).plot(kind='bar')

# %%
ax=sns.heatmap(clasificacion.pivot('Rapida','Lenta','Máximo Drawdown'), annot=False, fmt=".3", linewidths=0, cmap=plt.cm.jet)

# %%
# ax=sns.heatmap(clasificacion.pivot('Rapida','Lenta','Sharpe'), annot=True, fmt=".3f", cmap=plt.cm.jet)
ax=sns.heatmap(clasificacion.pivot('Rapida','Lenta','Sharpe'), annot=False, fmt=".1f", cmap=plt.cm.jet )

# %%
analisis.trisurf_heatmap (clasificacion, 'Rapida', 'Lenta','Sharpe', v1=45, v2=45)

# %%
analisis.trisurf_heatmap (clasificacion, 'Rapida', 'Lenta','Máximo Drawdown',v1= 45, v2=45)

# %% [markdown]
# ---

# %% [markdown]
# # REVISIÓN DE LOS PARÁMETROS SELECCIONADOS

# %%
pd.DataFrame(clasificacion.loc['estrategia_5_140'])

# %%
grafico(coleccion['estrategia_5_140'])

# %% [markdown]
# ---

# %% [markdown]
# # PRUEBA FUERA DE LA MUESTRA

# %%
periodo_rapido = 5

periodo_lento = 140

out_sample= qd_data[data.shape[0]:].copy()

out_sample['Dif_Close'] = out_sample.Close.pct_change()
out_sample['Dif_Open'] = out_sample.Close.pct_change()  #era Cloe


out_estr, out_resultado = estrategia_medias (out_sample, periodo_rapido, periodo_lento)

# %%
grafico(out_estr)

# %% [markdown]
# ---
