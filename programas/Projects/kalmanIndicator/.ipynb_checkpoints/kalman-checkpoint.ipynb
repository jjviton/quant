# %% [markdown]
# # <font color='red'>Backtest vectorizado para una estrategia 'X' definida.</font>
#
# ### Hackeado by J3viton (learning BackTesting 2021).

# %% [markdown]
# ---

# %% [markdown]
# En este notebook vamos a automatizar el backtesting para estrategias. Previamente tenemos que definir **la estrategia** usando el template (import estrategia_XX as rg), donde definimos la clase estrategia que contiene los metodos de analisis, entreda y salida de mercado. Este módulo se programa y adapta para cada estrategia. Luego en el metodo 'analisis' se crea un fichero excel con las metricas y rendimientos para evaluar la estrategia.
#
# Vamos a usar el módulo Pandas, para realizar un backtest vectorizado, es decir calcular el resultado del backtest sin iterar sobre las filas (barras) de la serie temporal.

# %% [markdown]
# Posteriormente graficamos y mostramos los parametros generales que nos permiten analizar la estrategia.
#
# #### J3Viton  2021
#
# link a la base:
#
# https://github.com/Python-para-Trading/Webinars-Docs/blob/master/Webinar%202/Webinar%202%20-%20Backtest%20con%20Pandas%20v%202.ipynb.

# %% [markdown]
# ---

# %% [markdown]
# # DEFINICION DEL SISTEMA

# %% [markdown]
# Como es usual, importamos los módulos que vamos a necesitar para las distintas tareas, y preparamos Matplotlib para una mejor visualización de los gráficos en el notebook.
#
# Se importa un modulo llamado analisis, en realidad se trata de un archivo .py con algunas funciones de apoyo para el trabajo, debe estar guardado en la misma carpeta que este notebook.
# Se importa el módulo 'estrategia_XX', donde se define la estrategia de entreda y salida

# %% [markdown]
# Es importante tener clara la lógica del sistema, pues debemos plasmarla de forma sencilla y correcta en el dataframe para realizar el backtest del mismo.

# %%
import analisis
import kalman as rg  #cambiar segun el módulo con la estrategia implementado
import pandas as pd
import datetime as dt
from time import time
import yfinance as yf
import numpy as np
# Out:
# {'can_read_all_group_messages': False, 'id': 1473252352, 'is_bot': True, 'can_join_groups': True, 'supports_inline_queries': False, 'username': 'vital_quant_bot', 'first_name': 'vital_bot'}

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = 18, 8
plt.style.use('ggplot')

from IPython.display import display, Markdown

# %% [markdown]
# ***0.- RECOGIDA DE DATOS INICIALES***
# Introducimos el instrumento y las fechas

# %%
instrumento_ = 'nvda'   # ticker del valor en yahooFinance

Fecha_Cominezo_Backtesting = dt.datetime(2008,1,2)
Fecha_Final_Backtesting    = dt.datetime(2021,11,18)
Fecha_Final_Backtesting    = dt.datetime.today()

# %% [markdown]
# ***1.- Rango fechas a analizar***
#
# Definimos el rango global de datos historicos que vamos a evaluar.
# Definimos la ventana que vamos a ir desplazando por todo el espectro para ir analilazando como se comporta la estrategia. La funion 'analisis' nos vale para tiempo real y para backtesting, para back le pasamos la ventana como si la fecha de fin de la ventana fuera la fecha de hoy.
# Tener en cuenta que la 'ventana' tiene uqe tener una anchura que nos permita hacer los calculos en rolling (ejemplo EMA 200)

# %%
# Rango completo para backTesting
#start2 =dt.datetime(2008,1,2)
start2= Fecha_Cominezo_Backtesting 
#end2   =dt.datetime(2021,11,18)
end2= Fecha_Final_Backtesting 
start_G= start2.strftime("%Y-%m-%d")
end_G  =   end2.strftime("%Y-%m-%d")
TOTAL_len= (end2-start2).days
print('Tamaño timeseries global a analizar:  ', TOTAL_len, 'sesiones')

#ventana de analisis 200 sesiones
startWindow2 =dt.datetime(2008,1,5)
endWindow2   =startWindow2 + dt.timedelta(days=1000) #ventana grande para que se puedan hacer los calculos de EMA200
startWindow= startWindow2.strftime("%Y-%m-%d")
endWindow  =   endWindow2.strftime("%Y-%m-%d")
window_len= (endWindow2-startWindow2).days
print('Tamaño de la ventana a analizar paso a paso:  ', window_len, 'sesiones')
# Out:
# Tamaño timeseries global a analizar:   5116 sesiones
# Tamaño de la ventana a analizar paso a paso:   1000 sesiones

# %%
 #dff = pd.DataFrame(columns=('Close','Volume', 'Senal', 'Dif_Close', 'Retornos','Capital'))

# %% [markdown]
# ***2.- Descargamos los datos para el marco Global***

# %%
instrumento = instrumento_  # 'rovi.mc'  #Vamos título a título. Mejora: Conjunto de títulos

# %%
dff = yf.download(instrumento, start_G,end_G)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
dff.dropna(inplace=True)  
dff.head()
# Out:
#               Open    High     Low   Close  Adj Close     Volume
# Date
# 2008-01-02  8.5300  8.5625  8.1400  8.2525   7.580832   48396400
# 2008-01-03  8.3000  8.4650  8.1575  8.1875   7.521123   47530800
# 2008-01-04  7.9425  7.9825  7.4500  7.5000   6.889579   73609200
# 2008-01-07  7.5500  7.6125  6.5875  6.7250   6.177656  100680000
# 2008-01-08  6.7625  7.3225  6.6050  6.8675   6.308557  110695600

# %% [markdown]
# ***3.- Creamos la clase strategy que tiene toda la lógica***

# %%
regreMedia= rg.StrategyClass(real_back=True)    #Creamos la clase

# %% [markdown]
# ***4.- Recorremos el dataframe con valores buscando las señales de la estrategia***

# %%
dff.index
# Out:
# DatetimeIndex(['2008-01-02', '2008-01-03', '2008-01-04', '2008-01-07',
#                '2008-01-08', '2008-01-09', '2008-01-10', '2008-01-11',
#                '2008-01-14', '2008-01-15',
#                ...
#                '2021-12-14', '2021-12-15', '2021-12-16', '2021-12-17',
#                '2021-12-20', '2021-12-21', '2021-12-22', '2021-12-23',
#                '2021-12-27', '2021-12-28'],
#               dtype='datetime64[ns]', name='Date', length=3523, freq=None)

# %% [markdown]
# ## Proceso de backTesting ##
#
# En este 'for' vamos recorriendo la muestra del historico de datos (TOTAL), desplazando una sesión hacia el futuro
# en cada iteracion. Vamos pasando la movilola del pasado sesión a sesión por el análisis descrito en Strategy class.
#
# Ouput:
# El sistema registra los siguientes parámetros:
#
# .-
# .-
# .-

# %%
startWindow
# Out:
# '2008-01-05'

# %%
tiempo_inicial = time()   # Tomamos tiempos para ver cuanto tarda en hacer la estrategia

# %%
dfe = pd.DataFrame({'A' : []})   #df empty

# %% [markdown]
# ***En este 'for' desplazamos la ventana sesión a sesión a lo largo de todo el rango de fechas. Dejamos que las funciones de la clase estrategia hagan el trabajo de comprar//vender y anotar***

# %%
#Para pruebas
#TOTAL_len =1000

for i in range(TOTAL_len):
    endWindow3   =endWindow2 + dt.timedelta(days=i) 
    endWindow    =endWindow3.strftime("%Y-%m-%d")
    print ('end date:', endWindow)
    
    if(endWindow in dff.index):
        df_aux= dff.loc[startWindow:endWindow]       #voy pasando los datos desplazando la ventana
        
        recogo = regreMedia.analisis(instrumento, startWindow, endWindow, df_aux) #Llamada a la clase estrategia. LA CLAVE DE TODO!!!
        
        print ('................................................Analizando, muestra', i, 'de', TOTAL_len, 'fecha', endWindow)
        
        """
        Tratamiento de los returns, mejor en las funciones de analisis que hacer aquí.
        if(recogo['senal'] == 1 ):
            dff.loc[[endWindow],['Senal']]= 1
        elif(recogo['senal'] == 0 ):
            dff.loc[[endWindow],['Senal']]= 0
        elif(recogo['senal'] == -1 ):
            dff.loc[[endWindow],['Senal']]= -1            
        elif(recogo['senal'] == 503 ):
            dff.loc[[endWindow],['Senal']]= 0          
        """
            
    else:
        print('..............Día sin sesión, next please')
# Out:
# end date: 2010-10-01
#  datos desde archivo
# Coefficients:
#  [-0.00202799]
# Independent term:
#  4.143212540652302
# Coefficients:
#  [-0.01273945]
# Independent term:
#  4.753000706665551
# Coefficients:
#  [-0.00146065]
# Independent term:
#  3.6816018391702934
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 0 de 5110 fecha 2010-10-01
# end date: 2010-10-02
# ..............Día sin sesión, next please
# end date: 2010-10-03
# ..............Día sin sesión, next please
# end date: 2010-10-04
#  datos desde archivo
# Coefficients:
#  [-0.00202714]
# Independent term:
#  4.143016492476577
# Coefficients:
#  [-0.01272839]
# Independent term:
#  4.744812647976093
# Coefficients:
#  [-0.00157277]
# Independent term:
#  3.6921810511982116
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 3 de 5110 fecha 2010-10-04
# end date: 2010-10-05
#  datos desde archivo
# Coefficients:
#  [-0.00202602]
# Independent term:
#  4.142758559596889
# Coefficients:
#  [-0.01271524]
# Independent term:
#  4.736616007000653
# Coefficients:
#  [-0.00168364]
# Independent term:
#  3.7025734388181366
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 4 de 5110 fecha 2010-10-05
# end date: 2010-10-06
#  datos desde archivo
# Coefficients:
#  [-0.00202656]
# Independent term:
#  4.142884036364824
# Coefficients:
#  [-0.01272054]
# Independent term:
#  4.7295936207984814
# Coefficients:
#  [-0.00179346]
# Independent term:
#  3.7127925451064985
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 5 de 5110 fecha 2010-10-06
# end date: 2010-10-07
#  datos desde archivo
# Coefficients:
#  [-0.00202732]
# Independent term:
#  4.143060111890091
# Coefficients:
#  [-0.01270395]
# Independent term:
#  4.719542874293541
# Coefficients:
#  [-0.00190202]
# Independent term:
#  3.7228099613173153
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 6 de 5110 fecha 2010-10-07
# end date: 2010-10-08
#  datos desde archivo
# Coefficients:
#  [-0.00202756]
# Independent term:
#  4.14311467751768
# Coefficients:
#  [-0.01266153]
# Independent term:
#  4.7065473566126474
# Coefficients:
#  [-0.00200908]
# Independent term:
#  3.7325983931112985
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 7 de 5110 fecha 2010-10-08
# end date: 2010-10-09
# ..............Día sin sesión, next please
# end date: 2010-10-10
# ..............Día sin sesión, next please
# end date: 2010-10-11
#  datos desde archivo
# Coefficients:
#  [-0.00202792]
# Independent term:
#  4.143198773069901
# Coefficients:
#  [-0.01260893]
# Independent term:
#  4.692163031101227
# Coefficients:
#  [-0.00211455]
# Independent term:
#  3.7421462999569695
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 10 de 5110 fecha 2010-10-11
# end date: 2010-10-12
#  datos desde archivo
# Coefficients:
#  [-0.00202761]
# Independent term:
#  4.1431266978394605
# Coefficients:
#  [-0.01254725]
# Independent term:
#  4.677188402076266
# Coefficients:
#  [-0.00221836]
# Independent term:
#  3.7514502014705946
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 11 de 5110 fecha 2010-10-12
# end date: 2010-10-13
#  datos desde archivo
# Coefficients:
#  [-0.0020263]
# Independent term:
#  4.142821443028764
# Coefficients:
#  [-0.0124819]
# Independent term:
#  4.662611912720239
# Coefficients:
#  [-0.00232049]
# Independent term:
#  3.760516487154671
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 12 de 5110 fecha 2010-10-13
# end date: 2010-10-14
#  datos desde archivo
# Coefficients:
#  [-0.00202552]
# Independent term:
#  4.142640619778405
# Coefficients:
#  [-0.01241256]
# Independent term:
#  4.64713765685238
# Coefficients:
#  [-0.0024209]
# Independent term:
#  3.7693385883456925
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 13 de 5110 fecha 2010-10-14
# end date: 2010-10-15
#  datos desde archivo
# Coefficients:
#  [-0.00202433]
# Independent term:
#  4.142363000224503
# Coefficients:
#  [-0.0123113]
# Independent term:
#  4.627837283184279
# Coefficients:
#  [-0.00251932]
# Independent term:
#  3.7778808639162267
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 14 de 5110 fecha 2010-10-15
# end date: 2010-10-16
# ..............Día sin sesión, next please
# end date: 2010-10-17
# ..............Día sin sesión, next please
# end date: 2010-10-18
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#  datos desde archivo
# Coefficients:
#  [-0.00202291]
# Independent term:
#  4.142031965679214
# Coefficients:
#  [-0.01220429]
# Independent term:
#  4.608039147925021
# Coefficients:
#  [-0.00261568]
# Independent term:
#  3.78614114534915
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 17 de 5110 fecha 2010-10-18
# end date: 2010-10-19
#  datos desde archivo
# Coefficients:
#  [-0.00202169]
# Independent term:
#  4.141747123256979
# Coefficients:
#  [-0.0121043]
# Independent term:
#  4.589090268291645
# Coefficients:
#  [-0.0027101]
# Independent term:
#  3.794130688861016
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 18 de 5110 fecha 2010-10-19
# end date: 2010-10-20
#  datos desde archivo
# Coefficients:
#  [-0.00202046]
# Independent term:
#  4.141458579699006
# Coefficients:
#  [-0.01199143]
# Independent term:
#  4.568522729660148
# Coefficients:
#  [-0.00280245]
# Independent term:
#  3.8018360823018034
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 19 de 5110 fecha 2010-10-20
# end date: 2010-10-21
#  datos desde archivo
# Coefficients:
#  [-0.00201981]
# Independent term:
#  4.141307610993914
# Coefficients:
#  [-0.01187871]
# Independent term:
#  4.547569001859694
# Coefficients:
#  [-0.00289276]
# Independent term:
#  3.809256310357106
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 20 de 5110 fecha 2010-10-21
# end date: 2010-10-22
#  datos desde archivo
# Coefficients:
#  [-0.00201702]
# Independent term:
#  4.14065131195219
# Coefficients:
#  [-0.01175051]
# Independent term:
#  4.5264260895572495
# Coefficients:
#  [-0.0029809]
# Independent term:
#  3.81639232806059
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 21 de 5110 fecha 2010-10-22
# end date: 2010-10-23
# ..............Día sin sesión, next please
# end date: 2010-10-24
# ..............Día sin sesión, next please
# end date: 2010-10-25
#  datos desde archivo
# Coefficients:
#  [-0.00201389]
# Independent term:
#  4.13991649725904
# Coefficients:
#  [-0.01161419]
# Independent term:
#  4.504561914401267
# Coefficients:
#  [-0.0030668]
# Independent term:
#  3.8232397866311443
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 24 de 5110 fecha 2010-10-25
# end date: 2010-10-26
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#  datos desde archivo
# Coefficients:
#  [-0.00201088]
# Independent term:
#  4.139209322910459
# Coefficients:
#  [-0.01148667]
# Independent term:
#  4.48384847705044
# Coefficients:
#  [-0.00315058]
# Independent term:
#  3.8298130074313357
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 25 de 5110 fecha 2010-10-26
# end date: 2010-10-27
#  datos desde archivo
# Coefficients:
#  [-0.00200737]
# Independent term:
#  4.138382093905314
# Coefficients:
#  [-0.01137376]
# Independent term:
#  4.465576834714235
# Coefficients:
#  [-0.0032324]
# Independent term:
#  3.836139015663007
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 26 de 5110 fecha 2010-10-27
# end date: 2010-10-28
#  datos desde archivo
# Coefficients:
#  [-0.00200384]
# Independent term:
#  4.137548032291236
# Coefficients:
#  [-0.01124933]
# Independent term:
#  4.445870491461967
# Coefficients:
#  [-0.00331217]
# Independent term:
#  3.8422059955217036
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 27 de 5110 fecha 2010-10-28
# end date: 2010-10-29
#  datos desde archivo
# Coefficients:
#  [-0.0020004]
# Independent term:
#  4.136735216296708
# Coefficients:
#  [-0.01113437]
# Independent term:
#  4.427419374878727
# Coefficients:
#  [-0.00339001]
# Independent term:
#  3.8480290142217726
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 28 de 5110 fecha 2010-10-29
# end date: 2010-10-30
# ..............Día sin sesión, next please
# end date: 2010-10-31
# ..............Día sin sesión, next please
# end date: 2010-11-01
#  datos desde archivo
# Coefficients:
#  [-0.00199691]
# Independent term:
#  4.135908512906317
# Coefficients:
#  [-0.01103615]
# Independent term:
#  4.411309670227677
# Coefficients:
#  [-0.00346609]
# Independent term:
#  3.8536337968685985
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 31 de 5110 fecha 2010-11-01
# end date: 2010-11-02
#  datos desde archivo
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# Coefficients:
#  [-0.00199268]
# Independent term:
#  4.1349074354222
# Coefficients:
#  [-0.01091465]
# Independent term:
#  4.3927951163320405
# Coefficients:
#  [-0.0035402]
# Independent term:
#  3.8589985861169906
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 32 de 5110 fecha 2010-11-02
# end date: 2010-11-03
#  datos desde archivo
# Coefficients:
#  [-0.00198821]
# Independent term:
#  4.133845031433074
# Coefficients:
#  [-0.0107905]
# Independent term:
#  4.374217127686117
# Coefficients:
#  [-0.00361235]
# Independent term:
#  3.864125138769421
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 33 de 5110 fecha 2010-11-03
# end date: 2010-11-04
#  datos desde archivo
# Coefficients:
#  [-0.00198369]
# Independent term:
#  4.1327705729793385
# Coefficients:
#  [-0.01067542]
# Independent term:
#  4.356954072482551
# Coefficients:
#  [-0.00368262]
# Independent term:
#  3.869028909254128
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 34 de 5110 fecha 2010-11-04
# end date: 2010-11-05
#  datos desde archivo
# Coefficients:
#  [-0.00197857]
# Independent term:
#  4.131552046569305
# Coefficients:
#  [-0.01057299]
# Independent term:
#  4.341950346320423
# Coefficients:
#  [-0.00375119]
# Independent term:
#  3.873734595195087
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 35 de 5110 fecha 2010-11-05
# end date: 2010-11-06
# ..............Día sin sesión, next please
# end date: 2010-11-07
# ..............Día sin sesión, next please
# end date: 2010-11-08
#  datos desde archivo
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# Coefficients:
#  [-0.00197332]
# Independent term:
#  4.130301778346314
# Coefficients:
#  [-0.01045671]
# Independent term:
#  4.325279825231922
# Coefficients:
#  [-0.00381791]
# Independent term:
#  3.8782275825586376
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 38 de 5110 fecha 2010-11-08
# end date: 2010-11-09
#  datos desde archivo
# Coefficients:
#  [-0.0019683]
# Independent term:
#  4.1291032640622
# Coefficients:
#  [-0.01036148]
# Independent term:
#  4.3112794560816745
# Coefficients:
#  [-0.00388302]
# Independent term:
#  3.8825365564245384
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 39 de 5110 fecha 2010-11-09
# end date: 2010-11-10
#  datos desde archivo
# Coefficients:
#  [-0.00196286]
# Independent term:
#  4.127803734595653
# Coefficients:
#  [-0.01024271]
# Independent term:
#  4.294574607628495
# Coefficients:
#  [-0.0039463]
# Independent term:
#  3.8866364375310463
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 40 de 5110 fecha 2010-11-10
# end date: 2010-11-11
#  datos desde archivo
# Coefficients:
#  [-0.00195782]
# Independent term:
#  4.126597679623067
# Coefficients:
#  [-0.01014843]
# Independent term:
#  4.280844010523896
# Coefficients:
#  [-0.00400801]
# Independent term:
#  3.8905589009439097
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 41 de 5110 fecha 2010-11-11
# end date: 2010-11-12
#  datos desde archivo
# Coefficients:
#  [-0.00195093]
# Independent term:
#  4.124945669027889
# Coefficients:
#  [-0.01005498]
# Independent term:
#  4.268882814023033
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# ...
# ..............Día sin sesión, next please
# end date: 2024-01-18
# ..............Día sin sesión, next please
# end date: 2024-01-19
# ..............Día sin sesión, next please
# end date: 2024-01-20
# ..............Día sin sesión, next please
# end date: 2024-01-21
# ..............Día sin sesión, next please
# end date: 2024-01-22
# ..............Día sin sesión, next please
# end date: 2024-01-23
# ..............Día sin sesión, next please
# end date: 2024-01-24
# ..............Día sin sesión, next please
# end date: 2024-01-25
# ..............Día sin sesión, next please
# end date: 2024-01-26
# ..............Día sin sesión, next please
# end date: 2024-01-27
# ..............Día sin sesión, next please
# end date: 2024-01-28
# ..............Día sin sesión, next please
# end date: 2024-01-29
# ..............Día sin sesión, next please
# end date: 2024-01-30
# ..............Día sin sesión, next please
# end date: 2024-01-31
# ..............Día sin sesión, next please
# end date: 2024-02-01
# ..............Día sin sesión, next please
# end date: 2024-02-02
# ..............Día sin sesión, next please
# end date: 2024-02-03
# ..............Día sin sesión, next please
# end date: 2024-02-04
# ..............Día sin sesión, next please
# end date: 2024-02-05
# ..............Día sin sesión, next please
# end date: 2024-02-06
# ..............Día sin sesión, next please
# end date: 2024-02-07
# ..............Día sin sesión, next please
# end date: 2024-02-08
# ..............Día sin sesión, next please
# end date: 2024-02-09
# ..............Día sin sesión, next please
# end date: 2024-02-10
# ..............Día sin sesión, next please
# end date: 2024-02-11
# ..............Día sin sesión, next please
# end date: 2024-02-12
# ..............Día sin sesión, next please
# end date: 2024-02-13
# ..............Día sin sesión, next please
# end date: 2024-02-14
# ..............Día sin sesión, next please
# end date: 2024-02-15
# ..............Día sin sesión, next please
# end date: 2024-02-16
# ..............Día sin sesión, next please
# end date: 2024-02-17
# ..............Día sin sesión, next please
# end date: 2024-02-18
# ..............Día sin sesión, next please
# end date: 2024-02-19
# ..............Día sin sesión, next please
# end date: 2024-02-20
# ..............Día sin sesión, next please
# end date: 2024-02-21
# ..............Día sin sesión, next please
# end date: 2024-02-22
# ..............Día sin sesión, next please
# end date: 2024-02-23
# ..............Día sin sesión, next please
# end date: 2024-02-24
# ..............Día sin sesión, next please
# end date: 2024-02-25
# ..............Día sin sesión, next please
# end date: 2024-02-26
# ..............Día sin sesión, next please
# end date: 2024-02-27
# ..............Día sin sesión, next please
# end date: 2024-02-28
# ..............Día sin sesión, next please
# end date: 2024-02-29
# ..............Día sin sesión, next please
# end date: 2024-03-01
# ..............Día sin sesión, next please
# end date: 2024-03-02
# ..............Día sin sesión, next please
# end date: 2024-03-03
# ..............Día sin sesión, next please
# end date: 2024-03-04
# ..............Día sin sesión, next please
# end date: 2024-03-05
# ..............Día sin sesión, next please
# end date: 2024-03-06
# ..............Día sin sesión, next please
# end date: 2024-03-07
# ..............Día sin sesión, next please
# end date: 2024-03-08
# ..............Día sin sesión, next please
# end date: 2024-03-09
# ..............Día sin sesión, next please
# end date: 2024-03-10
# ..............Día sin sesión, next please
# end date: 2024-03-11
# ..............Día sin sesión, next please
# end date: 2024-03-12
# ..............Día sin sesión, next please
# end date: 2024-03-13
# ..............Día sin sesión, next please
# end date: 2024-03-14
# ..............Día sin sesión, next please
# end date: 2024-03-15
# ..............Día sin sesión, next please
# end date: 2024-03-16
# ..............Día sin sesión, next please
# end date: 2024-03-17
# ..............Día sin sesión, next please
# end date: 2024-03-18
# ..............Día sin sesión, next please
# end date: 2024-03-19
# ..............Día sin sesión, next please
# end date: 2024-03-20
# ..............Día sin sesión, next please
# end date: 2024-03-21
# ..............Día sin sesión, next please
# end date: 2024-03-22
# ..............Día sin sesión, next please
# end date: 2024-03-23
# ..............Día sin sesión, next please
# end date: 2024-03-24
# ..............Día sin sesión, next please
# end date: 2024-03-25
# ..............Día sin sesión, next please
# end date: 2024-03-26
# ..............Día sin sesión, next please
# end date: 2024-03-27
# ..............Día sin sesión, next please
# end date: 2024-03-28
# ..............Día sin sesión, next please
# end date: 2024-03-29
# ..............Día sin sesión, next please
# end date: 2024-03-30
# ..............Día sin sesión, next please
# end date: 2024-03-31
# ..............Día sin sesión, next please
# end date: 2024-04-01
# ..............Día sin sesión, next please
# end date: 2024-04-02
# ..............Día sin sesión, next please
# end date: 2024-04-03
# ..............Día sin sesión, next please
# end date: 2024-04-04
# ..............Día sin sesión, next please
# end date: 2024-04-05
# ..............Día sin sesión, next please
# end date: 2024-04-06
# ..............Día sin sesión, next please
# end date: 2024-04-07
# ..............Día sin sesión, next please
# end date: 2024-04-08
# ..............Día sin sesión, next please
# end date: 2024-04-09
# ..............Día sin sesión, next please
# end date: 2024-04-10
# ..............Día sin sesión, next please
# end date: 2024-04-11
# ..............Día sin sesión, next please
# end date: 2024-04-12
# ..............Día sin sesión, next please
# end date: 2024-04-13
# ..............Día sin sesión, next please
# end date: 2024-04-14
# ..............Día sin sesión, next please
# end date: 2024-04-15
# ..............Día sin sesión, next please
# end date: 2024-04-16
# ..............Día sin sesión, next please
# end date: 2024-04-17
# ..............Día sin sesión, next please
# end date: 2024-04-18
# ..............Día sin sesión, next please
# end date: 2024-04-19
# ..............Día sin sesión, next please
# end date: 2024-04-20
# ..............Día sin sesión, next please
# end date: 2024-04-21
# ..............Día sin sesión, next please
# end date: 2024-04-22
# ..............Día sin sesión, next please
# end date: 2024-04-23
# ..............Día sin sesión, next please
# end date: 2024-04-24
# ..............Día sin sesión, next please
# end date: 2024-04-25
# ..............Día sin sesión, next please
# end date: 2024-04-26
# ..............Día sin sesión, next please
# end date: 2024-04-27
# ..............Día sin sesión, next please
# end date: 2024-04-28
# ..............Día sin sesión, next please
# end date: 2024-04-29
# ..............Día sin sesión, next please
# end date: 2024-04-30
# ..............Día sin sesión, next please
# end date: 2024-05-01
# ..............Día sin sesión, next please
# end date: 2024-05-02
# ..............Día sin sesión, next please
# end date: 2024-05-03
# ..............Día sin sesión, next please
# end date: 2024-05-04
# ..............Día sin sesión, next please
# end date: 2024-05-05
# ..............Día sin sesión, next please
# end date: 2024-05-06
# ..............Día sin sesión, next please
# end date: 2024-05-07
# ..............Día sin sesión, next please
# end date: 2024-05-08
# ..............Día sin sesión, next please
# end date: 2024-05-09
# ..............Día sin sesión, next please
# end date: 2024-05-10
# ..............Día sin sesión, next please
# end date: 2024-05-11
# ..............Día sin sesión, next please
# end date: 2024-05-12
# ..............Día sin sesión, next please
# end date: 2024-05-13
# ..............Día sin sesión, next please
# end date: 2024-05-14
# ..............Día sin sesión, next please
# end date: 2024-05-15
# ..............Día sin sesión, next please
# end date: 2024-05-16
# ..............Día sin sesión, next please
# end date: 2024-05-17
# ..............Día sin sesión, next please
# end date: 2024-05-18
# ..............Día sin sesión, next please
# end date: 2024-05-19
# ..............Día sin sesión, next please
# end date: 2024-05-20
# ..............Día sin sesión, next please
# end date: 2024-05-21
# ..............Día sin sesión, next please
# end date: 2024-05-22
# ..............Día sin sesión, next please
# end date: 2024-05-23
# ..............Día sin sesión, next please
# end date: 2024-05-24
# ..............Día sin sesión, next please
# end date: 2024-05-25
# ..............Día sin sesión, next please
# end date: 2024-05-26
# ..............Día sin sesión, next please
# end date: 2024-05-27
# ..............Día sin sesión, next please
# end date: 2024-05-28
# ..............Día sin sesión, next please
# end date: 2024-05-29
# ..............Día sin sesión, next please
# end date: 2024-05-30
# ..............Día sin sesión, next please
# end date: 2024-05-31
# ..............Día sin sesión, next please
# end date: 2024-06-01
# ..............Día sin sesión, next please
# end date: 2024-06-02
# ..............Día sin sesión, next please
# end date: 2024-06-03
# ..............Día sin sesión, next please
# end date: 2024-06-04
# ..............Día sin sesión, next please
# end date: 2024-06-05
# ..............Día sin sesión, next please
# end date: 2024-06-06
# ..............Día sin sesión, next please
# end date: 2024-06-07
# ..............Día sin sesión, next please
# end date: 2024-06-08
# ..............Día sin sesión, next please
# end date: 2024-06-09
# ..............Día sin sesión, next please
# end date: 2024-06-10
# ..............Día sin sesión, next please
# end date: 2024-06-11
# ..............Día sin sesión, next please
# end date: 2024-06-12
# ..............Día sin sesión, next please
# end date: 2024-06-13
# ..............Día sin sesión, next please
# end date: 2024-06-14
# ..............Día sin sesión, next please
# end date: 2024-06-15
# ..............Día sin sesión, next please
# end date: 2024-06-16
# ..............Día sin sesión, next please
# end date: 2024-06-17
# ..............Día sin sesión, next please
# end date: 2024-06-18
# ..............Día sin sesión, next please
# end date: 2024-06-19
# ..............Día sin sesión, next please
# end date: 2024-06-20
# ..............Día sin sesión, next please
# end date: 2024-06-21
# ..............Día sin sesión, next please
# end date: 2024-06-22
# ..............Día sin sesión, next please
# end date: 2024-06-23
# ..............Día sin sesión, next please
# end date: 2024-06-24
# ..............Día sin sesión, next please
# end date: 2024-06-25
# ..............Día sin sesión, next please
# end date: 2024-06-26
# ..............Día sin sesión, next please
# end date: 2024-06-27
# ..............Día sin sesión, next please
# end date: 2024-06-28
# ..............Día sin sesión, next please
# end date: 2024-06-29
# ..............Día sin sesión, next please
# end date: 2024-06-30
# ..............Día sin sesión, next please
# end date: 2024-07-01
# ..............Día sin sesión, next please
# end date: 2024-07-02
# ..............Día sin sesión, next please
# end date: 2024-07-03
# ..............Día sin sesión, next please
# end date: 2024-07-04
# ..............Día sin sesión, next please
# end date: 2024-07-05
# ..............Día sin sesión, next please
# end date: 2024-07-06
# ..............Día sin sesión, next please
# end date: 2024-07-07
# ..............Día sin sesión, next please
# end date: 2024-07-08
# ..............Día sin sesión, next please
# end date: 2024-07-09
# ..............Día sin sesión, next please
# end date: 2024-07-10
# ..............Día sin sesión, next please
# end date: 2024-07-11
# ..............Día sin sesión, next please
# end date: 2024-07-12
# ..............Día sin sesión, next please
# end date: 2024-07-13
# ..............Día sin sesión, next please
# end date: 2024-07-14
# ..............Día sin sesión, next please
# end date: 2024-07-15
# ..............Día sin sesión, next please
# end date: 2024-07-16
# ..............Día sin sesión, next please
# end date: 2024-07-17
# ..............Día sin sesión, next please
# end date: 2024-07-18
# ..............Día sin sesión, next please
# end date: 2024-07-19
# ..............Día sin sesión, next please
# end date: 2024-07-20
# ..............Día sin sesión, next please
# end date: 2024-07-21
# ..............Día sin sesión, next please
# end date: 2024-07-22
# ..............Día sin sesión, next please
# end date: 2024-07-23
# ..............Día sin sesión, next please
# end date: 2024-07-24
# ..............Día sin sesión, next please
# end date: 2024-07-25
# ..............Día sin sesión, next please
# end date: 2024-07-26
# ..............Día sin sesión, next please
# end date: 2024-07-27
# ..............Día sin sesión, next please
# end date: 2024-07-28
# ..............Día sin sesión, next please
# end date: 2024-07-29
# ..............Día sin sesión, next please
# end date: 2024-07-30
# ..............Día sin sesión, next please
# end date: 2024-07-31
# ..............Día sin sesión, next please
# end date: 2024-08-01
# ..............Día sin sesión, next please
# end date: 2024-08-02
# ..............Día sin sesión, next please
# end date: 2024-08-03
# ..............Día sin sesión, next please
# end date: 2024-08-04
# ..............Día sin sesión, next please
# end date: 2024-08-05
# ..............Día sin sesión, next please
# end date: 2024-08-06
# ..............Día sin sesión, next please
# end date: 2024-08-07
# ..............Día sin sesión, next please
# end date: 2024-08-08
# ..............Día sin sesión, next please
# end date: 2024-08-09
# ..............Día sin sesión, next please
# end date: 2024-08-10
# ..............Día sin sesión, next please
# end date: 2024-08-11
# ..............Día sin sesión, next please
# end date: 2024-08-12
# ..............Día sin sesión, next please
# end date: 2024-08-13
# ..............Día sin sesión, next please
# end date: 2024-08-14
# ..............Día sin sesión, next please
# end date: 2024-08-15
# ..............Día sin sesión, next please
# end date: 2024-08-16
# ..............Día sin sesión, next please
# end date: 2024-08-17
# ..............Día sin sesión, next please
# end date: 2024-08-18
# ..............Día sin sesión, next please
# end date: 2024-08-19
# ..............Día sin sesión, next please
# end date: 2024-08-20
# ..............Día sin sesión, next please
# end date: 2024-08-21
# ..............Día sin sesión, next please
# end date: 2024-08-22
# ..............Día sin sesión, next please
# end date: 2024-08-23
# ..............Día sin sesión, next please
# end date: 2024-08-24
# ..............Día sin sesión, next please
# end date: 2024-08-25
# ..............Día sin sesión, next please
# end date: 2024-08-26
# ..............Día sin sesión, next please
# end date: 2024-08-27
# ..............Día sin sesión, next please
# end date: 2024-08-28
# ..............Día sin sesión, next please
# end date: 2024-08-29
# ..............Día sin sesión, next please
# end date: 2024-08-30
# ..............Día sin sesión, next please
# end date: 2024-08-31
# ..............Día sin sesión, next please
# end date: 2024-09-01
# ..............Día sin sesión, next please
# end date: 2024-09-02
# ..............Día sin sesión, next please
# end date: 2024-09-03
# ..............Día sin sesión, next please
# end date: 2024-09-04
# ..............Día sin sesión, next please
# end date: 2024-09-05
# ..............Día sin sesión, next please
# end date: 2024-09-06
# ..............Día sin sesión, next please
# end date: 2024-09-07
# ..............Día sin sesión, next please
# end date: 2024-09-08
# ..............Día sin sesión, next please
# end date: 2024-09-09
# ..............Día sin sesión, next please
# end date: 2024-09-10
# ..............Día sin sesión, next please
# end date: 2024-09-11
# ..............Día sin sesión, next please
# end date: 2024-09-12
# ..............Día sin sesión, next please
# end date: 2024-09-13
# ..............Día sin sesión, next please
# end date: 2024-09-14
# ..............Día sin sesión, next please
# end date: 2024-09-15
# ..............Día sin sesión, next please
# end date: 2024-09-16
# ..............Día sin sesión, next please
# end date: 2024-09-17
# ..............Día sin sesión, next please
# end date: 2024-09-18
# ..............Día sin sesión, next please
# end date: 2024-09-19
# ..............Día sin sesión, next please
# end date: 2024-09-20
# ..............Día sin sesión, next please
# end date: 2024-09-21
# ..............Día sin sesión, next please
# end date: 2024-09-22
# ..............Día sin sesión, next please
# end date: 2024-09-23
# ..............Día sin sesión, next please
# end date: 2024-09-24
# ..............Día sin sesión, next please
# end date: 2024-09-25
# ..............Día sin sesión, next please
# end date: 2024-09-26
# ..............Día sin sesión, next please

# %% [markdown]
# ***Recogemos los datos de las entradas que ha realizado la Estrategia***

# %%
data=rg.StrategyClass.dfLog
#data.dropna(inplace=True)

# %%
data.tail()
# Out:
#                   Date Senal       Price Objetivo ExitReason  Beneficio
# 2021-12-21  2021-12-21     0      290.75      NaN        NaN        NaN
# 2021-12-22  2021-12-22     0       294.0      NaN        NaN        NaN
# 2021-12-23  2021-12-23     0  296.399994      NaN        NaN        NaN
# 2021-12-27  2021-12-27     0  309.450012      NaN        NaN        NaN
# 2021-12-28  2021-12-28     0  303.220001      NaN        NaN        NaN

# %%
data['Senal'].plot(title = 'Señales de compra de la estrategia ' )
# Ploteando una parte
#data.loc['2010':'2022','Senal'].plot(title = 'Señales Regresión a la media ' +instrumento,xlim=('2010','2022'))
# Out:
# <AxesSubplot:title={'center':'Señales de compra de la estrategia '}>

# %%
tiempo_final = time() 
 
tiempo_ejecucion = tiempo_final - tiempo_inicial
 
print ('El tiempo de ejecucion fue:',tiempo_ejecucion,"segundos") #En segundos
# Out:
# El tiempo de ejecucion fue: 886.6641092300415 segundos

# %%
data.loc['2011-01-04':'2019-11-04']
# Out:
#                   Date Senal      Price Objetivo ExitReason  Beneficio
# 2011-01-04  2011-01-04     0     3.9425      NaN        NaN        NaN
# 2011-01-05  2011-01-05     0      4.245      NaN        NaN        NaN
# 2011-01-06  2011-01-06     0     4.8325      NaN        NaN        NaN
# 2011-01-07  2011-01-07     0     4.9675      NaN        NaN        NaN
# 2011-01-10  2011-01-10     0     5.1575      NaN        NaN        NaN
# ...                ...   ...        ...      ...        ...        ...
# 2019-10-29  2019-10-29     1      50.73      NaN        NaN        NaN
# 2019-10-30  2019-10-30     1      50.75      NaN        NaN        NaN
# 2019-10-31  2019-10-31     1  50.255001      NaN        NaN        NaN
# 2019-11-01  2019-11-01     1  50.647499      NaN        NaN        NaN
# 2019-11-04  2019-11-04     1     52.625      NaN        NaN        NaN
#
# [2224 rows x 6 columns]

# %%
#Guardamos el resultado del analisis en un pickle
#dff.to_pickle("./primerBack_IBE.pkl")

# %% [markdown]
# ***3.- Ingeniería de datos para calcular la bondad de la estrategia***

# %%
data['Dif_Close'] = data.Price.pct_change()
data['Retornos'] = data.Dif_Close * data.Senal.shift(1)   
data['Capital'] = (data.Retornos + 1).cumprod() * 100
    
rg.StrategyClass.dfLog=data  #Ojo a esta liena, no me cuadra.

#quant_j.salvarExcel(StrategyClass.dfLog, "log"+instrumento)   
#data.to_pickle('almacen')    #df = pd.read_pickle(file_name)

# %% [markdown]
# >Para calcular los retornos del sistema, calculamos la diferencia relativativa entre el precio de cierre y el del día anterior. Para posteriormente multiplicarlo por la señal que del día anterior que nos indicaba la posición a tomar (si estaba comprado, sumo beneficio).

# %%
data.tail()
# Out:
#                   Date Senal       Price Objetivo ExitReason  Beneficio  \
# 2021-12-21  2021-12-21     0      290.75      NaN        NaN        NaN
# 2021-12-22  2021-12-22     0       294.0      NaN        NaN        NaN
# 2021-12-23  2021-12-23     0  296.399994      NaN        NaN        NaN
# 2021-12-27  2021-12-27     0  309.450012      NaN        NaN        NaN
# 2021-12-28  2021-12-28     0  303.220001      NaN        NaN        NaN
#
#             Dif_Close Retornos     Capital
# 2021-12-21   0.048920      0.0  314.576234
# 2021-12-22   0.011178      0.0  314.576234
# 2021-12-23   0.008163      0.0  314.576234
# 2021-12-27   0.044028      0.0  314.576234
# 2021-12-28  -0.020133     -0.0  314.576234

# %%
data[60:]
# Out:
#                   Date Senal       Price Objetivo ExitReason  Beneficio  \
# 2010-12-28  2010-12-28     0       3.735      NaN        NaN        NaN
# 2010-12-29  2010-12-29     0       3.735      NaN        NaN        NaN
# 2010-12-30  2010-12-30     0      3.7475      NaN        NaN        NaN
# 2010-12-31  2010-12-31     0        3.85      NaN        NaN        NaN
# 2011-01-03  2011-01-03     0       3.955      NaN        NaN        NaN
# ...                ...   ...         ...      ...        ...        ...
# 2021-12-21  2021-12-21     0      290.75      NaN        NaN        NaN
# 2021-12-22  2021-12-22     0       294.0      NaN        NaN        NaN
# 2021-12-23  2021-12-23     0  296.399994      NaN        NaN        NaN
# 2021-12-27  2021-12-27     0  309.450012      NaN        NaN        NaN
# 2021-12-28  2021-12-28     0  303.220001      NaN        NaN        NaN
#
#             Dif_Close Retornos     Capital
# 2010-12-28  -0.004000     -0.0       100.0
# 2010-12-29   0.000000      0.0       100.0
# 2010-12-30   0.003347      0.0       100.0
# 2010-12-31   0.027352      0.0       100.0
# 2011-01-03   0.027273      0.0       100.0
# ...               ...      ...         ...
# 2021-12-21   0.048920      0.0  314.576234
# 2021-12-22   0.011178      0.0  314.576234
# 2021-12-23   0.008163      0.0  314.576234
# 2021-12-27   0.044028      0.0  314.576234
# 2021-12-28  -0.020133     -0.0  314.576234
#
# [2770 rows x 9 columns]

# %% [markdown]
# >El capital, por comodidad, lo calcularemos en base 100, es decir como si iniciaramos la inversión con 100 unidades monetarias. Para su calculo arrastramos el producto acumulado de los retornos mas 1, multiplicados como dijimos por 100.

# %% [markdown]
# Pero para observar gráficamente la evolución del sistema necesitamos un gráfico con mas información. Para ello definimos una función que nos mostrará un gráfico con la evolución de nuestra estrategia, comparandola con la del activo. En un subgráfico se visualizará el drawdown del sistema, comparado de nuevo con el del activo. Y por útlimo las posiciones que toma el sistema.

# %%
def grafico (df):
    estudio = df.copy()
    
    DD_bh, maxDD, maxDD_ini, maxDD_fin = analisis.DrawDown(estudio.Dif_Close[60:], info = False) 
    
    DD, maxDD, maxDD_ini, maxDD_fin = analisis.DrawDown(estudio.Retornos.fillna(0), info = False) 

    fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True, figsize=(18, 12), gridspec_kw = {'height_ratios':[3, 1, 1]})
    fig.suptitle('Estrategia vs B & H', fontsize=20)

    #Primer plot analiza la evolcuion de una inversion de 100€ en buy&hold y la estrategia)
    ax1.plot(estudio.Capital)
    ax1.plot((estudio.Price) * (100/estudio.Price[1]))
    ax1.set_title('Capital')
    ax1.legend(['Estrategia','Buy & Hold'])

    ax2.plot(DD*100, c='0.5')
    ax2.plot(DD_bh*100, c='y')
    ax2.fill_between(DD.index, 0, DD*100, color='0.7')
    ax2.set_title('Drawdown')
    ax2.legend(['Estrategia','Buy & Hold'])

    ax3.plot(estudio.Senal, c='orange')
    #ax3.fill_between(estudio.index, 0, estudio.Senal*100, color='orange')
    ax3.set_title('Posición')

    plt.show()
    return

# %%
grafico(data)

# %% [markdown]
# ---

# %%
#data[55:70]

# %% [markdown]
# ---

# %% [markdown]
# # ANALISIS DEL SISTEMA

# %%
Beneficio_Bruto = data.Capital[-1] - data.Capital[1]
print ('Beneficio Bruto : {:.2f} €  con una inverison de 100€'.format(Beneficio_Bruto))
# Out:
# Beneficio Bruto : 214.58 €  con una inverison de 100€

# %%
#Rentabilidad anual compuesta. Calculamos lo que la inversion se ha incrementado cada año con el interes compuesto
CAGR = analisis.CAGR(data.Retornos)
print ('CAGR : {:.2f}%'.format(CAGR * 100))
# Out:
# CAGR : 10.73%

# %%
#Ratio calculado restando una rentabilidad segura a nuestra rentabilidad de estrategia y dividido por el riego (=volatilidad)
data.Retornos=data.Retornos.replace(0,np.e)  #Quito los cero (no sepuede hacer logariotmo de cero), pero no se que poner
Sharpe = CAGR / (np.log(data.Retornos + 1).std(skipna=True) * 252 ** 0.5)
print ('Sharpe : {:.3f}'.format(CAGR ))
# Out:
# Sharpe : 0.107

# %%
# Actualizo la excel con los economic
regreMedia.analisisEconomics(instrumento)
# Out:
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")

# %% [markdown]
# ---

# %% [markdown]
# ---
