# %% [markdown]
# # <font color='red'>Backtest vectorizado para una estrategia 'kalman'.</font>
#
# ### Hackeado by J3viton (learning BackTesting 2021).

# %% [markdown]
# ---

# %% [markdown]
# En este notebook vamos a automatizar el backtesting para estrategias. Previamente tenemos que definir **la estrategia** usando el template (import estrategia_XX as rg), donde definimos la clase estrategia que contiene los metodos de analisis, entreda y salida de mercado. Este módulo se programa y adapta para cada estrategia. Luego en el metodo 'analisis' se crea un fichero excel con las metricas y rendimientos para evaluar la estrategia.
#
# Vamos a usar el módulo Pandas, para realizar un backtest vectorizado, es decir calcular el resultado del backtest sin iterar sobre las filas (barras) de la serie temporal.

# %% [markdown]
# Posteriormente graficamos y mostramos los parametros generales que nos permiten analizar la estrategia.
#
# #### J3Viton  2021
#
# link a la base:
#
# https://github.com/Python-para-Trading/Webinars-Docs/blob/master/Webinar%202/Webinar%202%20-%20Backtest%20con%20Pandas%20v%202.ipynb.

# %% [markdown]
# ---

# %% [markdown]
# # DEFINICION DEL SISTEMA

# %% [markdown]
# Como es usual, importamos los módulos que vamos a necesitar para las distintas tareas, y preparamos Matplotlib para una mejor visualización de los gráficos en el notebook.
#
# Se importa un modulo llamado analisis, en realidad se trata de un archivo .py con algunas funciones de apoyo para el trabajo, debe estar guardado en la misma carpeta que este notebook.
# Se importa el módulo 'estrategia_XX', donde se define la estrategia de entreda y salida

# %% [markdown]
# Es importante tener clara la lógica del sistema, pues debemos plasmarla de forma sencilla y correcta en el dataframe para realizar el backtest del mismo.

# %%
import analisis
import kalman as rg  #cambiar segun el módulo con la estrategia implementado
import pandas as pd
import datetime as dt
from time import time
import yfinance as yf
import numpy as np
# Out:
# {'id': 1473252352, 'first_name': 'vital_bot', 'is_bot': True, 'username': 'vital_quant_bot', 'can_join_groups': True, 'can_read_all_group_messages': False, 'supports_inline_queries': False}

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = 18, 8
plt.style.use('ggplot')

from IPython.display import display, Markdown

# %% [markdown]
# ***0.- RECOGIDA DE DATOS INICIALES***
# Introducimos el instrumento y las fechas

# %%
instrumento_ = 'rovi.mc'   # ticker del valor en yahooFinance

Fecha_Cominezo_Backtesting = dt.datetime(2013,1,2)  #Dejale margen para hacer las medias moviles, como un año antes
Fecha_Final_Backtesting    = dt.datetime(2017,11,11)

# %% [markdown]
# ***1.- Rango fechas a analizar***
#
# Definimos el rango global de datos historicos que vamos a evaluar.
# Definimos la ventana que vamos a ir desplazando por todo el espectro para ir analilazando como se comporta la estrategia. La funion 'analisis' nos vale para tiempo real y para backtesting, para back le pasamos la ventana como si la fecha de fin de la ventana fuera la fecha de hoy.
# Tener en cuenta que la 'ventana' tiene uqe tener una anchura que nos permita hacer los calculos en rolling (ejemplo EMA 200)

# %%
# Rango completo para backTesting
#start2 =dt.datetime(2008,1,2)
start2= Fecha_Cominezo_Backtesting 
#end2   =dt.datetime(2021,11,18)
end2= Fecha_Final_Backtesting 
start_G= start2.strftime("%Y-%m-%d")
end_G  =   end2.strftime("%Y-%m-%d")
TOTAL_len= (end2-start2).days
print('Tamaño timeseries global a analizar:  ', TOTAL_len, 'sesiones')

#ventana de analisis 1000 sesiones
#startWindow2 =dt.datetime(2008,1,5)
startWindow2= Fecha_Cominezo_Backtesting 
endWindow2   =startWindow2 + dt.timedelta(days=600) #ventana grande para que se puedan hacer los calculos de EMA200
startWindow= startWindow2.strftime("%Y-%m-%d")
endWindow  =   endWindow2.strftime("%Y-%m-%d")
window_len= (endWindow2-startWindow2).days
print('Tamaño de la ventana a analizar paso a paso:  ', window_len, 'sesiones')
# Out:
# Tamaño timeseries global a analizar:   1774 sesiones
# Tamaño de la ventana a analizar paso a paso:   600 sesiones

# %%
 #dff = pd.DataFrame(columns=('Close','Volume', 'Senal', 'Dif_Close', 'Retornos','Capital'))

# %% [markdown]
# ***2.- Descargamos los datos para el marco Global***

# %%
instrumento = instrumento_  # 'rovi.mc'  #Vamos título a título. Mejora: Conjunto de títulos

# %%
dff = yf.download(instrumento, start_G,end_G)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
dff.dropna(inplace=True)  
dff.head()
# Out:
#             Open  High   Low  Close  Adj Close  Volume
# Date
# 2013-01-02  5.30  5.35  5.25   5.35   4.875045    3526
# 2013-01-03  5.34  5.35  5.20   5.30   4.829484    8794
# 2013-01-04  5.30  5.49  5.30   5.49   5.002616  154967
# 2013-01-07  5.47  5.71  5.47   5.67   5.166637   46500
# 2013-01-08  5.67  5.73  5.50   5.73   5.221310   52751

# %% [markdown]
# ***3.- Creamos la clase strategy que tiene toda la lógica***

# %%
regreMedia= rg.StrategyClass(real_back=True)    #Creamos la clase

# %% [markdown]
# ***4.- Recorremos el dataframe con valores buscando las señales de la estrategia***

# %%
dff.index
# Out:
# DatetimeIndex(['2013-01-02', '2013-01-03', '2013-01-04', '2013-01-07',
#                '2013-01-08', '2013-01-09', '2013-01-10', '2013-01-11',
#                '2013-01-14', '2013-01-15',
#                ...
#                '2017-10-30', '2017-10-31', '2017-11-01', '2017-11-02',
#                '2017-11-03', '2017-11-06', '2017-11-07', '2017-11-08',
#                '2017-11-09', '2017-11-10'],
#               dtype='datetime64[ns]', name='Date', length=1245, freq=None)

# %%
instrumento
# Out:
# 'rovi.mc'

# %% [markdown]
# ## Proceso de backTesting ##
#
# En este 'for' vamos recorriendo la muestra del historico de datos (TOTAL), desplazando una sesión hacia el futuro
# en cada iteracion. Vamos pasando la movilola del pasado sesión a sesión por el análisis descrito en Strategy class.
#
# Ouput:
# El sistema registra los siguientes parámetros:
#
# .-
# .-
# .-

# %%
startWindow2
# Out:
# datetime.datetime(2013, 1, 2, 0, 0)

# %%
endWindow2
# Out:
# datetime.datetime(2014, 8, 25, 0, 0)

# %%
tiempo_inicial = time()   # Tomamos tiempos para ver cuanto tarda en hacer la estrategia

# %%
dfe = pd.DataFrame({'A' : []})   #df empty

# %% [markdown]
# ***En este 'for' desplazamos la ventana sesión a sesión a lo largo de todo el rango de fechas. Dejamos que las funciones de la clase estrategia hagan el trabajo de comprar//vender y anotar***

# %%
#Para pruebas, ojo que total lengh le sobre mucho al final por lo que quito al pricipio del timeframe
#TOTAL_len =1000

for i in range(TOTAL_len):
    endWindow3   =endWindow2 + dt.timedelta(days=i) # muevo la ventana hacia delante en el tiempo 'dia a dia'
    endWindow    =endWindow3.strftime("%Y-%m-%d")
    print ('end date:', endWindow)
    
    if(endWindow in dff.index):
        df_aux= dff.loc[startWindow:endWindow]       #voy pasando los datos desplazando la ventana
        
        recogo = regreMedia.analisis(instrumento, startWindow, endWindow, df_aux) #Llamada a la clase estrategia. LA CLAVE DE TODO!!!
        
        print ('................................................Analizando, muestra', i, 'de', TOTAL_len, 'fecha', endWindow)
        
        """
        Tratamiento de los returns, mejor en las funciones de analisis que hacer aquí.
        if(recogo['senal'] == 1 ):
            dff.loc[[endWindow],['Senal']]= 1
        elif(recogo['senal'] == 0 ):
            dff.loc[[endWindow],['Senal']]= 0
        elif(recogo['senal'] == -1 ):
            dff.loc[[endWindow],['Senal']]= -1            
        elif(recogo['senal'] == 503 ):
            dff.loc[[endWindow],['Senal']]= 0          
        """
            
    else:
        print('..............Día sin sesión, next please')
# Out:
# end date: 2014-08-25
# fichero no existe
# DDatos desde archivo
# rovi.mc
# Coefficients:
#  [0.01275716]
# Independent term:
#  7.382879768402894
# rovi.mc False
# Precio 8.84000015258789 *************  Kalman 9.019198159579668
# checkIN Time 2014-08-22 00:00:00
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 0 de 1774 fecha 2014-08-25
# end date: 2014-08-26
# DDatos desde archivo
# rovi.mc
# Coefficients:
#  [0.01268498]
# Independent term:
#  7.401981664012441
# rovi.mc False
# Precio 9.029999732971191 *************  Kalman 9.02113639928446
# checkIN Time 2014-08-25 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 1 de 1774 fecha 2014-08-26
# end date: 2014-08-27
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# C:\Users\INNOVACION\anaconda3\envs\trading\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# DDatos desde archivo
# rovi.mc
# Coefficients:
#  [0.01261178]
# Independent term:
#  7.421105462592751
# rovi.mc False
# Precio 8.979999542236328 *************  Kalman 9.031642212058033
# checkIN Time 2014-08-26 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 2 de 1774 fecha 2014-08-27
# end date: 2014-08-28
# DDatos desde archivo
# rovi.mc
# Coefficients:
#  [0.01253749]
# Independent term:
#  7.440268388041097
# rovi.mc False
# Precio 9.09000015258789 *************  Kalman 9.039201935946675
# checkIN Time 2014-08-27 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 3 de 1774 fecha 2014-08-28
# end date: 2014-08-29
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# C:\Users\INNOVACION\anaconda3\envs\trading\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# DDatos desde archivo
# rovi.mc
# Coefficients:
#  [0.01246233]
# Independent term:
#  7.459440350783761
# rovi.mc False
# Precio 9.020000457763672 *************  Kalman 9.05433284400638
# checkIN Time 2014-08-28 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 4 de 1774 fecha 2014-08-29
# end date: 2014-08-30
# ..............Día sin sesión, next please
# end date: 2014-08-31
# ..............Día sin sesión, next please
# end date: 2014-09-01
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# C:\Users\INNOVACION\anaconda3\envs\trading\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# DDatos desde archivo
# rovi.mc
# Coefficients:
#  [0.01238627]
# Independent term:
#  7.4786184254838455
# rovi.mc False
# Precio 8.899999618530273 *************  Kalman 9.069807075928505
# checkIN Time 2014-08-29 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 7 de 1774 fecha 2014-09-01
# end date: 2014-09-02
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# C:\Users\INNOVACION\anaconda3\envs\trading\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# DDatos desde archivo
# rovi.mc
# Coefficients:
#  [0.01230904]
# Independent term:
#  7.497820343476979
# rovi.mc False
# Precio 9.0600004196167 *************  Kalman 9.07428356533282
# checkIN Time 2014-09-01 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 8 de 1774 fecha 2014-09-02
# end date: 2014-09-03
# DDatos desde archivo
# rovi.mc
# Coefficients:
#  [0.01223062]
# Independent term:
#  7.51705033612358
# rovi.mc False
# Precio 9.210000038146973 *************  Kalman 9.076594560817133
# checkIN Time 2014-09-02 00:00:00
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# C:\Users\INNOVACION\anaconda3\envs\trading\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 9 de 1774 fecha 2014-09-03
# end date: 2014-09-04
# DDatos desde archivo
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# C:\Users\INNOVACION\anaconda3\envs\trading\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# rovi.mc
# Coefficients:
#  [0.01215117]
# Independent term:
#  7.536292261610459
# rovi.mc False
# Precio 9.149999618530273 *************  Kalman 9.086227762968617
# checkIN Time 2014-09-03 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 10 de 1774 fecha 2014-09-04
# end date: 2014-09-05
# DDatos desde archivo
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# C:\Users\INNOVACION\anaconda3\envs\trading\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# rovi.mc
# Coefficients:
#  [0.01207074]
# Independent term:
#  7.555538403548767
# rovi.mc False
# Precio 9.289999961853027 *************  Kalman 9.094069056358496
# checkIN Time 2014-09-04 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 11 de 1774 fecha 2014-09-05
# end date: 2014-09-06
# ..............Día sin sesión, next please
# end date: 2014-09-07
# ..............Día sin sesión, next please
# end date: 2014-09-08
# DDatos desde archivo
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# C:\Users\INNOVACION\anaconda3\envs\trading\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# C:\Users\INNOVACION\anaconda3\envs\trading\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# rovi.mc
# Coefficients:
#  [0.01198928]
# Independent term:
#  7.574795970837038
# rovi.mc False
# Precio 9.289999961853027 *************  Kalman 9.096488580145097
# checkIN Time 2014-09-05 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 14 de 1774 fecha 2014-09-08
# end date: 2014-09-09
# DDatos desde archivo
# rovi.mc
# Coefficients:
#  [0.01190678]
# Independent term:
#  7.594063694805174
# rovi.mc False
# Precio 9.069999694824219 *************  Kalman 9.096972990114619
# checkIN Time 2014-09-08 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 15 de 1774 fecha 2014-09-09
# end date: 2014-09-10
# DDatos desde archivo
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# C:\Users\INNOVACION\anaconda3\envs\trading\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# rovi.mc
# Coefficients:
#  [0.0118232]
# Independent term:
#  7.613342202350985
# rovi.mc False
# Precio 9.029999732971191 *************  Kalman 9.094841712556885
# checkIN Time 2014-09-09 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 16 de 1774 fecha 2014-09-10
# end date: 2014-09-11
# DDatos desde archivo
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# C:\Users\INNOVACION\anaconda3\envs\trading\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# C:\Users\INNOVACION\anaconda3\envs\trading\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# rovi.mc
# Coefficients:
#  [0.01173824]
# Independent term:
#  7.632654836792019
# rovi.mc False
# Precio 9.180000305175781 *************  Kalman 9.087010918731702
# checkIN Time 2014-09-10 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 17 de 1774 fecha 2014-09-11
# end date: 2014-09-12
# DDatos desde archivo
# rovi.mc
# Coefficients:
#  [0.01165225]
# Independent term:
#  7.65196161301741
# rovi.mc False
# Precio 9.15999984741211 *************  Kalman 9.090946048133878
# checkIN Time 2014-09-11 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 18 de 1774 fecha 2014-09-12
# end date: 2014-09-13
# ..............Día sin sesión, next please
# end date: 2014-09-14
# ..............Día sin sesión, next please
# end date: 2014-09-15
# DDatos desde archivo
# rovi.mc
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# C:\Users\INNOVACION\anaconda3\envs\trading\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Coefficients:
#  [0.01156493]
# Independent term:
#  7.67128451616088
# rovi.mc False
# Precio 9.100000381469727 *************  Kalman 9.076878171697148
# checkIN Time 2014-09-12 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 21 de 1774 fecha 2014-09-15
# end date: 2014-09-16
# DDatos desde archivo
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# C:\Users\INNOVACION\anaconda3\envs\trading\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# rovi.mc
# Coefficients:
#  [0.01147646]
# Independent term:
#  7.690604620828557
# rovi.mc False
# Precio 9.100000381469727 *************  Kalman 9.070081144397173
# checkIN Time 2014-09-15 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 22 de 1774 fecha 2014-09-16
# end date: 2014-09-17
# DDatos desde archivo
# rovi.mc
# Coefficients:
#  [0.01138683]
# Independent term:
#  7.709928486711944
# rovi.mc False
# Precio 9.050000190734863 *************  Kalman 9.060099504246317
# checkIN Time 2014-09-16 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 23 de 1774 fecha 2014-09-17
# end date: 2014-09-18
# DDatos desde archivo
# rovi.mc
# Coefficients:
#  [0.011296]
# Independent term:
#  7.729268367516106
# rovi.mc False
# Precio 8.9399995803833 *************  Kalman 9.047333491785237
# checkIN Time 2014-09-17 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 24 de 1774 fecha 2014-09-18
# end date: 2014-09-19
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# C:\Users\INNOVACION\anaconda3\envs\trading\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# C:\Users\INNOVACION\anaconda3\envs\trading\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# DDatos desde archivo
# rovi.mc
# Coefficients:
#  [0.01120399]
# Independent term:
#  7.748623203585397
# rovi.mc False
# Precio 9.15999984741211 *************  Kalman 9.036217858506353
# checkIN Time 2014-09-18 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 25 de 1774 fecha 2014-09-19
# end date: 2014-09-20
# ..............Día sin sesión, next please
# end date: 2014-09-21
# ..............Día sin sesión, next please
# end date: 2014-09-22
# DDatos desde archivo
# rovi.mc
# Coefficients:
#  [0.01111082]
# Independent term:
#  7.767980263550247
# rovi.mc False
# Precio 8.859999656677246 *************  Kalman 9.012322778452603
# checkIN Time 2014-09-19 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 28 de 1774 fecha 2014-09-22
# end date: 2014-09-23
# DDatos desde archivo
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# C:\Users\INNOVACION\anaconda3\envs\trading\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# rovi.mc
# Coefficients:
#  [0.01101635]
# Independent term:
#  7.787340875740906
# rovi.mc False
# Precio 8.989999771118164 *************  Kalman 8.976678072456636
# checkIN Time 2014-09-22 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 29 de 1774 fecha 2014-09-23
# end date: 2014-09-24
# DDatos desde archivo
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# C:\Users\INNOVACION\anaconda3\envs\trading\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# rovi.mc
# Coefficients:
#  [0.01092054]
# Independent term:
#  7.806714853612702
# rovi.mc False
# Precio 8.9399995803833 *************  Kalman 8.942054284645225
# checkIN Time 2014-09-23 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 30 de 1774 fecha 2014-09-24
# end date: 2014-09-25
# DDatos desde archivo
# rovi.mc
# Coefficients:
#  [0.0108232]
# Independent term:
#  7.826129129983774
# rovi.mc False
# Precio 8.890000343322754 *************  Kalman 8.893601091613462
# checkIN Time 2014-09-24 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 31 de 1774 fecha 2014-09-25
# end date: 2014-09-26
# DDatos desde archivo
# rovi.mc
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# C:\Users\INNOVACION\anaconda3\envs\trading\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\quant_j3_lib.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman'] = state_meansS
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kalman']=    quant_j.kalmanIndicator(df,paraA_=200,paraB_=50,instrumento=instrumento)
# Coefficients:
#  [0.01072452]
# Independent term:
#  7.8455842198112125
# rovi.mc False
# Precio 8.899999618530273 *************  Kalman 8.858456763224583
# checkIN Time 2014-09-25 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 32 de 1774 fecha 2014-09-26
# end date: 2014-09-27
# ..............Día sin sesión, next please
# end date: 2014-09-28
# ..............Día sin sesión, next please
# end date: 2014-09-29
# DDatos desde archivo
# rovi.mc
# Coefficients:
#  [0.01062433]
# Independent term:
#  7.865087108159777
# rovi.mc False
# Precio 8.699999809265137 *************  Kalman 8.818857450631317
# checkIN Time 2014-09-26 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 35 de 1774 fecha 2014-09-29
# end date: 2014-09-30
# DDatos desde archivo
# rovi.mc
# Coefficients:
#  [0.01052283]
# Independent term:
#  7.884617824824532
# rovi.mc False
# Precio 8.470000267028809 *************  Kalman 8.78564046030903
# checkIN Time 2014-09-29 00:00:00
#   instrumento  long_short_out        date  precio  beneficio  stoploss
# 0      ACX.MC               0  2012-09-27    8.96   0.604945        99
# 1        FTNT               0  2017-10-31   39.50   0.934737        99
# ................................................Analizando, muestra 36 de 1774 fecha 2014-09-30
# end date: 2014-10-01
# ...
# ..............Día sin sesión, next please
# end date: 2018-10-24
# ..............Día sin sesión, next please
# end date: 2018-10-25
# ..............Día sin sesión, next please
# end date: 2018-10-26
# ..............Día sin sesión, next please
# end date: 2018-10-27
# ..............Día sin sesión, next please
# end date: 2018-10-28
# ..............Día sin sesión, next please
# end date: 2018-10-29
# ..............Día sin sesión, next please
# end date: 2018-10-30
# ..............Día sin sesión, next please
# end date: 2018-10-31
# ..............Día sin sesión, next please
# end date: 2018-11-01
# ..............Día sin sesión, next please
# end date: 2018-11-02
# ..............Día sin sesión, next please
# end date: 2018-11-03
# ..............Día sin sesión, next please
# end date: 2018-11-04
# ..............Día sin sesión, next please
# end date: 2018-11-05
# ..............Día sin sesión, next please
# end date: 2018-11-06
# ..............Día sin sesión, next please
# end date: 2018-11-07
# ..............Día sin sesión, next please
# end date: 2018-11-08
# ..............Día sin sesión, next please
# end date: 2018-11-09
# ..............Día sin sesión, next please
# end date: 2018-11-10
# ..............Día sin sesión, next please
# end date: 2018-11-11
# ..............Día sin sesión, next please
# end date: 2018-11-12
# ..............Día sin sesión, next please
# end date: 2018-11-13
# ..............Día sin sesión, next please
# end date: 2018-11-14
# ..............Día sin sesión, next please
# end date: 2018-11-15
# ..............Día sin sesión, next please
# end date: 2018-11-16
# ..............Día sin sesión, next please
# end date: 2018-11-17
# ..............Día sin sesión, next please
# end date: 2018-11-18
# ..............Día sin sesión, next please
# end date: 2018-11-19
# ..............Día sin sesión, next please
# end date: 2018-11-20
# ..............Día sin sesión, next please
# end date: 2018-11-21
# ..............Día sin sesión, next please
# end date: 2018-11-22
# ..............Día sin sesión, next please
# end date: 2018-11-23
# ..............Día sin sesión, next please
# end date: 2018-11-24
# ..............Día sin sesión, next please
# end date: 2018-11-25
# ..............Día sin sesión, next please
# end date: 2018-11-26
# ..............Día sin sesión, next please
# end date: 2018-11-27
# ..............Día sin sesión, next please
# end date: 2018-11-28
# ..............Día sin sesión, next please
# end date: 2018-11-29
# ..............Día sin sesión, next please
# end date: 2018-11-30
# ..............Día sin sesión, next please
# end date: 2018-12-01
# ..............Día sin sesión, next please
# end date: 2018-12-02
# ..............Día sin sesión, next please
# end date: 2018-12-03
# ..............Día sin sesión, next please
# end date: 2018-12-04
# ..............Día sin sesión, next please
# end date: 2018-12-05
# ..............Día sin sesión, next please
# end date: 2018-12-06
# ..............Día sin sesión, next please
# end date: 2018-12-07
# ..............Día sin sesión, next please
# end date: 2018-12-08
# ..............Día sin sesión, next please
# end date: 2018-12-09
# ..............Día sin sesión, next please
# end date: 2018-12-10
# ..............Día sin sesión, next please
# end date: 2018-12-11
# ..............Día sin sesión, next please
# end date: 2018-12-12
# ..............Día sin sesión, next please
# end date: 2018-12-13
# ..............Día sin sesión, next please
# end date: 2018-12-14
# ..............Día sin sesión, next please
# end date: 2018-12-15
# ..............Día sin sesión, next please
# end date: 2018-12-16
# ..............Día sin sesión, next please
# end date: 2018-12-17
# ..............Día sin sesión, next please
# end date: 2018-12-18
# ..............Día sin sesión, next please
# end date: 2018-12-19
# ..............Día sin sesión, next please
# end date: 2018-12-20
# ..............Día sin sesión, next please
# end date: 2018-12-21
# ..............Día sin sesión, next please
# end date: 2018-12-22
# ..............Día sin sesión, next please
# end date: 2018-12-23
# ..............Día sin sesión, next please
# end date: 2018-12-24
# ..............Día sin sesión, next please
# end date: 2018-12-25
# ..............Día sin sesión, next please
# end date: 2018-12-26
# ..............Día sin sesión, next please
# end date: 2018-12-27
# ..............Día sin sesión, next please
# end date: 2018-12-28
# ..............Día sin sesión, next please
# end date: 2018-12-29
# ..............Día sin sesión, next please
# end date: 2018-12-30
# ..............Día sin sesión, next please
# end date: 2018-12-31
# ..............Día sin sesión, next please
# end date: 2019-01-01
# ..............Día sin sesión, next please
# end date: 2019-01-02
# ..............Día sin sesión, next please
# end date: 2019-01-03
# ..............Día sin sesión, next please
# end date: 2019-01-04
# ..............Día sin sesión, next please
# end date: 2019-01-05
# ..............Día sin sesión, next please
# end date: 2019-01-06
# ..............Día sin sesión, next please
# end date: 2019-01-07
# ..............Día sin sesión, next please
# end date: 2019-01-08
# ..............Día sin sesión, next please
# end date: 2019-01-09
# ..............Día sin sesión, next please
# end date: 2019-01-10
# ..............Día sin sesión, next please
# end date: 2019-01-11
# ..............Día sin sesión, next please
# end date: 2019-01-12
# ..............Día sin sesión, next please
# end date: 2019-01-13
# ..............Día sin sesión, next please
# end date: 2019-01-14
# ..............Día sin sesión, next please
# end date: 2019-01-15
# ..............Día sin sesión, next please
# end date: 2019-01-16
# ..............Día sin sesión, next please
# end date: 2019-01-17
# ..............Día sin sesión, next please
# end date: 2019-01-18
# ..............Día sin sesión, next please
# end date: 2019-01-19
# ..............Día sin sesión, next please
# end date: 2019-01-20
# ..............Día sin sesión, next please
# end date: 2019-01-21
# ..............Día sin sesión, next please
# end date: 2019-01-22
# ..............Día sin sesión, next please
# end date: 2019-01-23
# ..............Día sin sesión, next please
# end date: 2019-01-24
# ..............Día sin sesión, next please
# end date: 2019-01-25
# ..............Día sin sesión, next please
# end date: 2019-01-26
# ..............Día sin sesión, next please
# end date: 2019-01-27
# ..............Día sin sesión, next please
# end date: 2019-01-28
# ..............Día sin sesión, next please
# end date: 2019-01-29
# ..............Día sin sesión, next please
# end date: 2019-01-30
# ..............Día sin sesión, next please
# end date: 2019-01-31
# ..............Día sin sesión, next please
# end date: 2019-02-01
# ..............Día sin sesión, next please
# end date: 2019-02-02
# ..............Día sin sesión, next please
# end date: 2019-02-03
# ..............Día sin sesión, next please
# end date: 2019-02-04
# ..............Día sin sesión, next please
# end date: 2019-02-05
# ..............Día sin sesión, next please
# end date: 2019-02-06
# ..............Día sin sesión, next please
# end date: 2019-02-07
# ..............Día sin sesión, next please
# end date: 2019-02-08
# ..............Día sin sesión, next please
# end date: 2019-02-09
# ..............Día sin sesión, next please
# end date: 2019-02-10
# ..............Día sin sesión, next please
# end date: 2019-02-11
# ..............Día sin sesión, next please
# end date: 2019-02-12
# ..............Día sin sesión, next please
# end date: 2019-02-13
# ..............Día sin sesión, next please
# end date: 2019-02-14
# ..............Día sin sesión, next please
# end date: 2019-02-15
# ..............Día sin sesión, next please
# end date: 2019-02-16
# ..............Día sin sesión, next please
# end date: 2019-02-17
# ..............Día sin sesión, next please
# end date: 2019-02-18
# ..............Día sin sesión, next please
# end date: 2019-02-19
# ..............Día sin sesión, next please
# end date: 2019-02-20
# ..............Día sin sesión, next please
# end date: 2019-02-21
# ..............Día sin sesión, next please
# end date: 2019-02-22
# ..............Día sin sesión, next please
# end date: 2019-02-23
# ..............Día sin sesión, next please
# end date: 2019-02-24
# ..............Día sin sesión, next please
# end date: 2019-02-25
# ..............Día sin sesión, next please
# end date: 2019-02-26
# ..............Día sin sesión, next please
# end date: 2019-02-27
# ..............Día sin sesión, next please
# end date: 2019-02-28
# ..............Día sin sesión, next please
# end date: 2019-03-01
# ..............Día sin sesión, next please
# end date: 2019-03-02
# ..............Día sin sesión, next please
# end date: 2019-03-03
# ..............Día sin sesión, next please
# end date: 2019-03-04
# ..............Día sin sesión, next please
# end date: 2019-03-05
# ..............Día sin sesión, next please
# end date: 2019-03-06
# ..............Día sin sesión, next please
# end date: 2019-03-07
# ..............Día sin sesión, next please
# end date: 2019-03-08
# ..............Día sin sesión, next please
# end date: 2019-03-09
# ..............Día sin sesión, next please
# end date: 2019-03-10
# ..............Día sin sesión, next please
# end date: 2019-03-11
# ..............Día sin sesión, next please
# end date: 2019-03-12
# ..............Día sin sesión, next please
# end date: 2019-03-13
# ..............Día sin sesión, next please
# end date: 2019-03-14
# ..............Día sin sesión, next please
# end date: 2019-03-15
# ..............Día sin sesión, next please
# end date: 2019-03-16
# ..............Día sin sesión, next please
# end date: 2019-03-17
# ..............Día sin sesión, next please
# end date: 2019-03-18
# ..............Día sin sesión, next please
# end date: 2019-03-19
# ..............Día sin sesión, next please
# end date: 2019-03-20
# ..............Día sin sesión, next please
# end date: 2019-03-21
# ..............Día sin sesión, next please
# end date: 2019-03-22
# ..............Día sin sesión, next please
# end date: 2019-03-23
# ..............Día sin sesión, next please
# end date: 2019-03-24
# ..............Día sin sesión, next please
# end date: 2019-03-25
# ..............Día sin sesión, next please
# end date: 2019-03-26
# ..............Día sin sesión, next please
# end date: 2019-03-27
# ..............Día sin sesión, next please
# end date: 2019-03-28
# ..............Día sin sesión, next please
# end date: 2019-03-29
# ..............Día sin sesión, next please
# end date: 2019-03-30
# ..............Día sin sesión, next please
# end date: 2019-03-31
# ..............Día sin sesión, next please
# end date: 2019-04-01
# ..............Día sin sesión, next please
# end date: 2019-04-02
# ..............Día sin sesión, next please
# end date: 2019-04-03
# ..............Día sin sesión, next please
# end date: 2019-04-04
# ..............Día sin sesión, next please
# end date: 2019-04-05
# ..............Día sin sesión, next please
# end date: 2019-04-06
# ..............Día sin sesión, next please
# end date: 2019-04-07
# ..............Día sin sesión, next please
# end date: 2019-04-08
# ..............Día sin sesión, next please
# end date: 2019-04-09
# ..............Día sin sesión, next please
# end date: 2019-04-10
# ..............Día sin sesión, next please
# end date: 2019-04-11
# ..............Día sin sesión, next please
# end date: 2019-04-12
# ..............Día sin sesión, next please
# end date: 2019-04-13
# ..............Día sin sesión, next please
# end date: 2019-04-14
# ..............Día sin sesión, next please
# end date: 2019-04-15
# ..............Día sin sesión, next please
# end date: 2019-04-16
# ..............Día sin sesión, next please
# end date: 2019-04-17
# ..............Día sin sesión, next please
# end date: 2019-04-18
# ..............Día sin sesión, next please
# end date: 2019-04-19
# ..............Día sin sesión, next please
# end date: 2019-04-20
# ..............Día sin sesión, next please
# end date: 2019-04-21
# ..............Día sin sesión, next please
# end date: 2019-04-22
# ..............Día sin sesión, next please
# end date: 2019-04-23
# ..............Día sin sesión, next please
# end date: 2019-04-24
# ..............Día sin sesión, next please
# end date: 2019-04-25
# ..............Día sin sesión, next please
# end date: 2019-04-26
# ..............Día sin sesión, next please
# end date: 2019-04-27
# ..............Día sin sesión, next please
# end date: 2019-04-28
# ..............Día sin sesión, next please
# end date: 2019-04-29
# ..............Día sin sesión, next please
# end date: 2019-04-30
# ..............Día sin sesión, next please
# end date: 2019-05-01
# ..............Día sin sesión, next please
# end date: 2019-05-02
# ..............Día sin sesión, next please
# end date: 2019-05-03
# ..............Día sin sesión, next please
# end date: 2019-05-04
# ..............Día sin sesión, next please
# end date: 2019-05-05
# ..............Día sin sesión, next please
# end date: 2019-05-06
# ..............Día sin sesión, next please
# end date: 2019-05-07
# ..............Día sin sesión, next please
# end date: 2019-05-08
# ..............Día sin sesión, next please
# end date: 2019-05-09
# ..............Día sin sesión, next please
# end date: 2019-05-10
# ..............Día sin sesión, next please
# end date: 2019-05-11
# ..............Día sin sesión, next please
# end date: 2019-05-12
# ..............Día sin sesión, next please
# end date: 2019-05-13
# ..............Día sin sesión, next please
# end date: 2019-05-14
# ..............Día sin sesión, next please
# end date: 2019-05-15
# ..............Día sin sesión, next please
# end date: 2019-05-16
# ..............Día sin sesión, next please
# end date: 2019-05-17
# ..............Día sin sesión, next please
# end date: 2019-05-18
# ..............Día sin sesión, next please
# end date: 2019-05-19
# ..............Día sin sesión, next please
# end date: 2019-05-20
# ..............Día sin sesión, next please
# end date: 2019-05-21
# ..............Día sin sesión, next please
# end date: 2019-05-22
# ..............Día sin sesión, next please
# end date: 2019-05-23
# ..............Día sin sesión, next please
# end date: 2019-05-24
# ..............Día sin sesión, next please
# end date: 2019-05-25
# ..............Día sin sesión, next please
# end date: 2019-05-26
# ..............Día sin sesión, next please
# end date: 2019-05-27
# ..............Día sin sesión, next please
# end date: 2019-05-28
# ..............Día sin sesión, next please
# end date: 2019-05-29
# ..............Día sin sesión, next please
# end date: 2019-05-30
# ..............Día sin sesión, next please
# end date: 2019-05-31
# ..............Día sin sesión, next please
# end date: 2019-06-01
# ..............Día sin sesión, next please
# end date: 2019-06-02
# ..............Día sin sesión, next please
# end date: 2019-06-03
# ..............Día sin sesión, next please
# end date: 2019-06-04
# ..............Día sin sesión, next please
# end date: 2019-06-05
# ..............Día sin sesión, next please
# end date: 2019-06-06
# ..............Día sin sesión, next please
# end date: 2019-06-07
# ..............Día sin sesión, next please
# end date: 2019-06-08
# ..............Día sin sesión, next please
# end date: 2019-06-09
# ..............Día sin sesión, next please
# end date: 2019-06-10
# ..............Día sin sesión, next please
# end date: 2019-06-11
# ..............Día sin sesión, next please
# end date: 2019-06-12
# ..............Día sin sesión, next please
# end date: 2019-06-13
# ..............Día sin sesión, next please
# end date: 2019-06-14
# ..............Día sin sesión, next please
# end date: 2019-06-15
# ..............Día sin sesión, next please
# end date: 2019-06-16
# ..............Día sin sesión, next please
# end date: 2019-06-17
# ..............Día sin sesión, next please
# end date: 2019-06-18
# ..............Día sin sesión, next please
# end date: 2019-06-19
# ..............Día sin sesión, next please
# end date: 2019-06-20
# ..............Día sin sesión, next please
# end date: 2019-06-21
# ..............Día sin sesión, next please
# end date: 2019-06-22
# ..............Día sin sesión, next please
# end date: 2019-06-23
# ..............Día sin sesión, next please
# end date: 2019-06-24
# ..............Día sin sesión, next please
# end date: 2019-06-25
# ..............Día sin sesión, next please
# end date: 2019-06-26
# ..............Día sin sesión, next please
# end date: 2019-06-27
# ..............Día sin sesión, next please
# end date: 2019-06-28
# ..............Día sin sesión, next please
# end date: 2019-06-29
# ..............Día sin sesión, next please
# end date: 2019-06-30
# ..............Día sin sesión, next please
# end date: 2019-07-01
# ..............Día sin sesión, next please
# end date: 2019-07-02
# ..............Día sin sesión, next please
# end date: 2019-07-03
# ..............Día sin sesión, next please

# %% [markdown]
# ***Recogemos los datos de las entradas que ha realizado la Estrategia***

# %%
data=rg.StrategyClass.dfLog
#data.dropna(inplace=True)

# %%
data.tail()
# Out:
#                   Date Senal      Price Objetivo ExitReason  Beneficio
# 2017-11-06  2017-11-06     1      16.33      NaN        NaN        NaN
# 2017-11-07  2017-11-07     1  16.190001      NaN        NaN        NaN
# 2017-11-08  2017-11-08     0       16.6      NaN          1        NaN
# 2017-11-09  2017-11-09     0       16.6      NaN        NaN        NaN
# 2017-11-10  2017-11-10     0  16.360001      NaN        NaN        NaN

# %%
data['Senal'].plot(title = 'Señales de compra de la estrategia ' )
# Ploteando una parte
#data.loc['2010':'2022','Senal'].plot(title = 'Señales Regresión a la media ' +instrumento,xlim=('2010','2022'))
# Out:
# <AxesSubplot:title={'center':'Señales de compra de la estrategia '}>

# %%
tiempo_final = time() 
 
tiempo_ejecucion = (tiempo_final - tiempo_inicial)/60
 
print ('El tiempo de ejecucion fue:',tiempo_ejecucion,"minutos") #En
# Out:
# El tiempo de ejecucion fue: 8.276844747861226 minutos

# %%
data.loc['2011-01-04':'2019-11-04']
# Out:
#                   Date Senal      Price Objetivo ExitReason  Beneficio
# 2014-08-25  2014-08-25     0       9.02      NaN        NaN        NaN
# 2014-08-26  2014-08-26     0        8.9      NaN        NaN        NaN
# 2014-08-27  2014-08-27     0       9.06      NaN        NaN        NaN
# 2014-08-28  2014-08-28     0       9.21      NaN        NaN        NaN
# 2014-08-29  2014-08-29     0       9.15      NaN        NaN        NaN
# ...                ...   ...        ...      ...        ...        ...
# 2017-11-06  2017-11-06     1      16.33      NaN        NaN        NaN
# 2017-11-07  2017-11-07     1  16.190001      NaN        NaN        NaN
# 2017-11-08  2017-11-08     0       16.6      NaN          1        NaN
# 2017-11-09  2017-11-09     0       16.6      NaN        NaN        NaN
# 2017-11-10  2017-11-10     0  16.360001      NaN        NaN        NaN
#
# [826 rows x 6 columns]

# %%
#Guardamos el resultado del analisis en un pickle
#data.to_pickle("./primerBack_FTNT.pkl")

# %% [markdown]
# ***3.- Ingeniería de datos para calcular la bondad de la estrategia***

# %%
data['Dif_Close'] = data.Price.pct_change()
data['Retornos'] = data.Dif_Close * data.Senal.shift(1)   
data['Capital'] = (data.Retornos + 1).cumprod() * 100
    
rg.StrategyClass.dfLog=data  #Ojo a esta liena, no me cuadra.

#quant_j.salvarExcel(StrategyClass.dfLog, "log"+instrumento)   
#data.to_pickle('almacen')    #df = pd.read_pickle(file_name)

# %% [markdown]
# >Para calcular los retornos del sistema, calculamos la diferencia relativativa entre el precio de cierre y el del día anterior. Para posteriormente multiplicarlo por la señal que del día anterior que nos indicaba la posición a tomar (si estaba comprado, sumo beneficio).

# %%
data.tail()
# Out:
#                   Date Senal      Price Objetivo ExitReason  Beneficio  \
# 2017-11-06  2017-11-06     1      16.33      NaN        NaN        NaN
# 2017-11-07  2017-11-07     1  16.190001      NaN        NaN        NaN
# 2017-11-08  2017-11-08     0       16.6      NaN          1        NaN
# 2017-11-09  2017-11-09     0       16.6      NaN        NaN        NaN
# 2017-11-10  2017-11-10     0  16.360001      NaN        NaN        NaN
#
#             Dif_Close  Retornos    Capital
# 2017-11-06   0.020625  0.020625  92.810895
# 2017-11-07  -0.008573 -0.008573  92.015214
# 2017-11-08   0.025324  0.025324  94.345432
# 2017-11-09   0.000000       0.0  94.345432
# 2017-11-10  -0.014458      -0.0  94.345432

# %%
data[60:]
# Out:
#                   Date Senal      Price Objetivo ExitReason  Beneficio  \
# 2014-11-17  2014-11-17     0       8.65      NaN        NaN        NaN
# 2014-11-18  2014-11-18     0       8.75      NaN        NaN        NaN
# 2014-11-19  2014-11-19     0       8.77      NaN        NaN        NaN
# 2014-11-20  2014-11-20     0       9.17      NaN        NaN        NaN
# 2014-11-21  2014-11-21     0       8.95      NaN        NaN        NaN
# ...                ...   ...        ...      ...        ...        ...
# 2017-11-06  2017-11-06     1      16.33      NaN        NaN        NaN
# 2017-11-07  2017-11-07     1  16.190001      NaN        NaN        NaN
# 2017-11-08  2017-11-08     0       16.6      NaN          1        NaN
# 2017-11-09  2017-11-09     0       16.6      NaN        NaN        NaN
# 2017-11-10  2017-11-10     0  16.360001      NaN        NaN        NaN
#
#             Dif_Close  Retornos    Capital
# 2014-11-17  -0.011429      -0.0      100.0
# 2014-11-18   0.011561       0.0      100.0
# 2014-11-19   0.002286       0.0      100.0
# 2014-11-20   0.045610       0.0      100.0
# 2014-11-21  -0.023991      -0.0      100.0
# ...               ...       ...        ...
# 2017-11-06   0.020625  0.020625  92.810895
# 2017-11-07  -0.008573 -0.008573  92.015214
# 2017-11-08   0.025324  0.025324  94.345432
# 2017-11-09   0.000000       0.0  94.345432
# 2017-11-10  -0.014458      -0.0  94.345432
#
# [766 rows x 9 columns]

# %% [markdown]
# >El capital, por comodidad, lo calcularemos en base 100, es decir como si iniciaramos la inversión con 100 unidades monetarias. Para su calculo arrastramos el producto acumulado de los retornos mas 1, multiplicados como dijimos por 100.

# %% [markdown]
# Pero para observar gráficamente la evolución del sistema necesitamos un gráfico con mas información. Para ello definimos una función que nos mostrará un gráfico con la evolución de nuestra estrategia, comparandola con la del activo. En un subgráfico se visualizará el drawdown del sistema, comparado de nuevo con el del activo. Y por útlimo las posiciones que toma el sistema.

# %%
def grafico (df):
    estudio = df.copy()
    
    DD_bh, maxDD, maxDD_ini, maxDD_fin = analisis.DrawDown(estudio.Dif_Close[60:], info = False) 
    
    DD, maxDD, maxDD_ini, maxDD_fin = analisis.DrawDown(estudio.Retornos.fillna(0), info = False) 

    fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True, figsize=(18, 12), gridspec_kw = {'height_ratios':[3, 1, 1]})
    fig.suptitle('Estrategia vs B & H', fontsize=20)

    #Primer plot analiza la evolcuion de una inversion de 100€ en buy&hold y la estrategia)
    ax1.plot(estudio.Capital)
    ax1.plot((estudio.Price) * (100/estudio.Price[1]))
    ax1.set_title('Capital')
    ax1.legend(['Estrategia','Buy & Hold'])

    ax2.plot(DD*100, c='0.5')
    ax2.plot(DD_bh*100, c='y')
    ax2.fill_between(DD.index, 0, DD*100, color='0.7')
    ax2.set_title('Drawdown')
    ax2.legend(['Estrategia','Buy & Hold'])

    ax3.plot(estudio.Senal, c='orange')
    #ax3.fill_between(estudio.index, 0, estudio.Senal*100, color='orange')
    ax3.set_title('Posición')

    plt.show()
    return

# %%
grafico(data)

# %% [markdown]
# ---

# %%
#data[55:70]

# %% [markdown]
# ---

# %% [markdown]
# # ANALISIS DEL SISTEMA

# %%
Beneficio_Bruto = data.Capital[-1] - data.Capital[1]
print ('Beneficio Bruto : {:.2f} €  con una inverison de 100€'.format(Beneficio_Bruto))
# Out:
# Beneficio Bruto : -5.65 €  con una inverison de 100€

# %%
#Rentabilidad anual compuesta. Calculamos lo que la inversion se ha incrementado cada año con el interes compuesto
CAGR = analisis.CAGR(data.Retornos)
print ('CAGR : {:.2f}%'.format(CAGR * 100))
# Out:
# CAGR : -1.80%

# %%
#Ratio calculado restando una rentabilidad segura a nuestra rentabilidad de estrategia y dividido por el riego (=volatilidad)
data.Retornos=data.Retornos.replace(0,np.e)  #Quito los cero (no sepuede hacer logariotmo de cero), pero no se que poner
Sharpe = CAGR / (np.log(data.Retornos + 1).std(skipna=True) * 252 ** 0.5)
print ('Sharpe : {:.3f}'.format(CAGR ))
# Out:
# Sharpe : -0.018

# %%
# Actualizo la excel con los economic
regreMedia.analisisEconomics(instrumento)

# %%
# Calculo el numero de operaciones

data[55:70]
# Out:
#                   Date Senal Price Objetivo ExitReason  Beneficio  Dif_Close  \
# 2014-11-10  2014-11-10     0  8.83      NaN        NaN        NaN   0.013777
# 2014-11-11  2014-11-11     0  8.78      NaN        NaN        NaN  -0.005663
# 2014-11-12  2014-11-12     0  8.75      NaN        NaN        NaN  -0.003417
# 2014-11-13  2014-11-13     0   8.8      NaN        NaN        NaN   0.005714
# 2014-11-14  2014-11-14     0  8.75      NaN        NaN        NaN  -0.005682
# 2014-11-17  2014-11-17     0  8.65      NaN        NaN        NaN  -0.011429
# 2014-11-18  2014-11-18     0  8.75      NaN        NaN        NaN   0.011561
# 2014-11-19  2014-11-19     0  8.77      NaN        NaN        NaN   0.002286
# 2014-11-20  2014-11-20     0  9.17      NaN        NaN        NaN   0.045610
# 2014-11-21  2014-11-21     0  8.95      NaN        NaN        NaN  -0.023991
# 2014-11-24  2014-11-24     0  8.93      NaN        NaN        NaN  -0.002235
# 2014-11-25  2014-11-25     0  8.93      NaN        NaN        NaN   0.000000
# 2014-11-26  2014-11-26     0  8.95      NaN        NaN        NaN   0.002240
# 2014-11-27  2014-11-27     0   9.1      NaN        NaN        NaN   0.016760
# 2014-11-28  2014-11-28     0  9.06      NaN        NaN        NaN  -0.004396
#
#            Retornos Capital
# 2014-11-10      0.0   100.0
# 2014-11-11     -0.0   100.0
# 2014-11-12     -0.0   100.0
# 2014-11-13      0.0   100.0
# 2014-11-14     -0.0   100.0
# 2014-11-17     -0.0   100.0
# 2014-11-18      0.0   100.0
# 2014-11-19      0.0   100.0
# 2014-11-20      0.0   100.0
# 2014-11-21     -0.0   100.0
# 2014-11-24     -0.0   100.0
# 2014-11-25      0.0   100.0
# 2014-11-26      0.0   100.0
# 2014-11-27      0.0   100.0
# 2014-11-28     -0.0   100.0

# %% [markdown]
# ---

# %% [markdown]
# ## Cálculo esperanza matemática
#
# (%Aciertos * beneficioMedio )-(%Errores * perdidaMedia)

# %%
print("Numero operaciones con beneficio ->", 
      data[data['ExitReason'] > 0]['ExitReason'].count()) 
print("Numero operaciones con perdidas ->", 
      data[data['ExitReason'] < 0]['ExitReason'].count()) 
  
data[data['ExitReason']>0]['ExitReason']
# Out:
# Numero operaciones con beneficio -> 5
# Numero operaciones con perdidas -> 9
# 2014-12-31    1
# 2015-01-28    1
# 2016-03-31    1
# 2016-04-18    1
# 2017-11-08    1
# Name: ExitReason, dtype: object

# %%
data[data['Senal']>0][1:10]
# Out:
#                   Date Senal Price Objetivo ExitReason  Beneficio  Dif_Close  \
# 2014-12-16  2014-12-16     1  9.98      NaN        NaN        NaN   0.009100
# 2014-12-17  2014-12-17     1  9.98      NaN        NaN        NaN   0.000000
# 2014-12-18  2014-12-18     1  10.0      NaN        NaN        NaN   0.002004
# 2014-12-19  2014-12-19     1  10.0      NaN        NaN        NaN   0.000000
# 2014-12-22  2014-12-22     1  9.96      NaN        NaN        NaN  -0.004000
# 2014-12-23  2014-12-23     1  9.93      NaN        NaN        NaN  -0.003012
# 2014-12-24  2014-12-24     1  10.0      NaN        NaN        NaN   0.007049
# 2014-12-29  2014-12-29     1  10.0      NaN        NaN        NaN   0.000000
# 2014-12-30  2014-12-30     1  10.0      NaN        NaN        NaN   0.000000
#
#             Retornos     Capital
# 2014-12-16    0.0091  100.910002
# 2014-12-17       0.0  100.910002
# 2014-12-18  0.002004  101.112231
# 2014-12-19       0.0  101.112231
# 2014-12-22    -0.004  100.707783
# 2014-12-23 -0.003012  100.404449
# 2014-12-24  0.007049  101.112231
# 2014-12-29       0.0  101.112231
# 2014-12-30       0.0  101.112231

# %% [markdown]
# ---

# %%
data[data['Senal']>0].index[1]
# Out:
# '2014-12-16'

# %%
# ENTRADAS
print (data[(data['Senal']>0) & (data['Beneficio']>0)].index[0])
data[(data['Senal']>0) & (data['Beneficio']>0) ][0:5]
# Out:
# 2014-12-15
#                   Date Senal      Price Objetivo ExitReason  Beneficio  \
# 2014-12-15  2014-12-15     1       9.89      NaN        NaN   0.318658
# 2015-01-02  2015-01-02     1       10.3      NaN        NaN   0.294968
# 2015-03-31  2015-03-31     1  16.219999      NaN        NaN   0.569552
# 2015-04-20  2015-04-20     1      15.92      NaN        NaN   0.664675
# 2015-10-23  2015-10-23     1       14.1      NaN        NaN   0.464820
#
#             Dif_Close Retornos     Capital
# 2014-12-15  -0.011000     -0.0       100.0
# 2015-01-02   0.000000      0.0    104.1456
# 2015-03-31   0.014384      0.0  107.178969
# 2015-04-20   0.040523      0.0  101.099773
# 2015-10-23   0.000000      0.0   99.448644

# %%
# SALIDA PERDIDAS
print (data[(data['Senal'].shift(1) >0) & (data['ExitReason']== -1)].index[0])
data[(data['Senal'].shift(1) >0) & (data['ExitReason']== -1)][0:5]
# Out:
# 2015-04-16
#                   Date Senal  Price Objetivo ExitReason  Beneficio  Dif_Close  \
# 2015-04-16  2015-04-16     0   15.3      NaN         -1        NaN  -0.065364
# 2015-04-22  2015-04-22     0  15.66      NaN         -1        NaN  -0.007605
# 2015-10-28  2015-10-28     0  13.82      NaN         -1        NaN  -0.007184
# 2015-11-19  2015-11-19     0  14.11      NaN         -1        NaN  -0.009129
# 2016-01-13  2016-01-13     0  14.24      NaN         -1        NaN  -0.011111
#
#             Retornos     Capital
# 2015-04-16 -0.065364  101.099773
# 2015-04-22 -0.007605   99.448644
# 2015-10-28 -0.007184   97.473773
# 2015-11-19 -0.009129   95.246187
# 2016-01-13 -0.011111   94.187897

# %%
# SALIDA GANANCIAS
data[(data['Senal'].shift(1) >0) & (data['ExitReason']== 1)][0:5]
# Out:
#                   Date Senal  Price Objetivo ExitReason  Beneficio  Dif_Close  \
# 2014-12-31  2014-12-31     0   10.3      NaN          1        NaN   0.030000
# 2015-01-28  2015-01-28     0   10.6      NaN          1        NaN   0.015326
# 2016-03-31  2016-03-31     0  14.77      NaN          1        NaN   0.017919
# 2016-04-18  2016-04-18     0  15.33      NaN          1        NaN   0.027480
# 2017-11-08  2017-11-08     0   16.6      NaN          1        NaN   0.025324
#
#             Retornos     Capital
# 2014-12-31      0.03    104.1456
# 2015-01-28  0.015326  107.178969
# 2016-03-31  0.017919    97.69349
# 2016-04-18   0.02748  101.397505
# 2017-11-08  0.025324   94.345432

# %%
serieIndicesENTRADA=data[(data['Senal']>0) & (data['Beneficio']>0)].index

# %%
serieIndicesENTRADA.size
# Out:
# 14

# %%
serieIndicesENTRADA
# Out:
# Index(['2014-12-15', '2015-01-02', '2015-03-31', '2015-04-20', '2015-10-23',
#        '2015-11-16', '2016-01-12', '2016-03-11', '2016-04-01', '2016-04-19',
#        '2017-08-04', '2017-08-25', '2017-09-04', '2017-11-03'],
#       dtype='object')

# %%
serieIndicesEXIT=data[(data['ExitReason']==1) | (data['ExitReason']==-1)].index

# %%
serieIndicesEXIT
# Out:
# Index(['2014-12-31', '2015-01-28', '2015-04-16', '2015-04-22', '2015-10-28',
#        '2015-11-19', '2016-01-13', '2016-03-31', '2016-04-18', '2016-04-29',
#        '2017-08-07', '2017-08-28', '2017-09-05', '2017-11-08'],
#       dtype='object')

# %%
data['ExitReason'][serieIndicesEXIT[2]]
# Out:
# -1

# %%
#Cálculo Esperanza Matemática
countGanando=0
countPerdiendo=0

bolsaGanando=0
bolsaPerdiendo=0

for i in range(serieIndicesENTRADA.size):
    if(data['ExitReason'][serieIndicesEXIT[i]] == -1):
        ref1  = data['Price'][serieIndicesEXIT[i]]
        ref2 = data['Price'][serieIndicesENTRADA[i]]
        print (ref1, ref2)
        countPerdiendo= 1+countPerdiendo
        bolsaPerdiendo= bolsaPerdiendo + (ref1-ref2)

    
    if(data['ExitReason'][serieIndicesEXIT[i]] == 1):
        ref1  = data['Price'][serieIndicesEXIT[i]]
        ref2 = data['Price'][serieIndicesENTRADA[i]]
        print (ref1, ref2)
        countGanando= 1+countGanando
        bolsaGanando= bolsaGanando + (ref1-ref2)
print ("bolsa ganando   --> ", bolsaGanando, "   numero operaciones ganando   ", countGanando)   
print ("bolsa perdiendo -->", bolsaPerdiendo, "   numero operaciones perdiendo", countPerdiendo)
# Out:
# 10.300000190734863 9.890000343322754
# 10.600000381469727 10.300000190734863
# 15.300000190734863 16.219999313354492
# 15.65999984741211 15.920000076293945
# 13.819999694824219 14.100000381469727
# 14.109999656677246 14.4399995803833
# 14.239999771118164 14.399999618530273
# 14.770000457763672 14.239999771118164
# 15.329999923706055 14.770000457763672
# 14.770000457763672 15.329999923706055
# 15.829999923706055 16.059999465942383
# 16.030000686645508 16.3799991607666
# 15.699999809265137 16.270000457763672
# 16.600000381469727 16.0
# bolsa ganando   -->  2.40000057220459    numero operaciones ganando    5
# bolsa perdiendo --> -3.6599979400634766    numero operaciones perdiendo 9

# %%
#(%Aciertos * beneficioMedio )-(%Errores * perdidaMedia)

count=countGanando+countPerdiendo

esperanza = (countGanando/count *(bolsaGanando/countGanando))+(countPerdiendo/count *(bolsaPerdiendo/countPerdiendo))
print("ESPERANZA MATEMATICA ES: ", esperanza)
print ("bolsa ganando   --> ", bolsaGanando, "   numero operaciones ganando   ", countGanando)   
print ("bolsa perdiendo -->", bolsaPerdiendo, "   numero operaciones perdiendo", countPerdiendo) 
print ("media perdiendo --> ", (bolsaPerdiendo/countPerdiendo), "  media ganando", (bolsaGanando/countGanando))
# Out:
# ESPERANZA MATEMATICA ES:  -0.08999981198992052
# bolsa ganando   -->  2.40000057220459    numero operaciones ganando    5
# bolsa perdiendo --> -3.6599979400634766    numero operaciones perdiendo 9
# media perdiendo -->  -0.40666643778483075   media ganando 0.48000011444091795

# %%
countGanando/count
# Out:
# 0.35714285714285715

# %%
countPerdiendo/count
# Out:
# 0.6428571428571429

# %%
bolsaGanando/countGanando
# Out:
# 0.48000011444091795

# %%
(bolsaPerdiendo/countPerdiendo)
# Out:
# -0.40666643778483075
