# %% [markdown]
# # KALMAN REAL TIME con Telegram

# %% [markdown]
# Este cuaderno implementa una estrategia de inversion basada en Kalman como indicador.
#
# Busca señales de entrada y las envía el Telegram para su analisis.
#
# GRAFICADOR PLOTLY:  muy bueno como hace velas ( esta abajo desconectado del resto)

# %% [markdown]
# Status: <font color='red'>Funcionando !!!  v0.0    10/01/2022<font>

# %%
# Raw Package
import numpy as np
import pandas as pd

#Data Source
import yfinance as yf

#Data viz
import plotly.graph_objs as go

# %%
import analisis
import kalman as kl  #cambiar segun el módulo con la estrategia implementado
import pandas as pd
import datetime as dt
from time import time
from time import sleep
import yfinance as yf
import numpy as np
from telegram_bot import *

dentro =True
fuera  =False
# Out:
# {'first_name': 'vital_bot', 'is_bot': True, 'can_join_groups': True, 'supports_inline_queries': False, 'id': 1473252352, 'can_read_all_group_messages': False, 'username': 'vital_quant_bot'}

# %%
kalman= kl.StrategyClass(real_back=True)    #Creamos la clase
import quant_j3_lib as quant_j3

# %%
telegram_send("3.- Señal Kalman RealTime b0.1n  ")

# %%
#Interval required 1 minute
data = yf.download(tickers='corn', period='1mo', interval='15m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                                 Open       High        Low      Close  \
# Datetime
# 2021-12-14 09:30:00-05:00  21.340000  21.340000  21.330000  21.340000
# 2021-12-14 09:45:00-05:00  21.352501  21.370001  21.330000  21.370001
# 2021-12-14 10:00:00-05:00  21.400000  21.459999  21.389999  21.389999
# 2021-12-14 10:15:00-05:00  21.400101  21.419901  21.400000  21.400000
# 2021-12-14 10:30:00-05:00  21.400000  21.420000  21.370001  21.420000
# ...                              ...        ...        ...        ...
# 2022-01-13 15:15:00-05:00  21.530001  21.530001  21.530001  21.530001
# 2022-01-13 15:30:00-05:00  21.530001  21.540001  21.530001  21.530001
# 2022-01-13 15:45:00-05:00  21.530001  21.540001  21.520000  21.520000
# 2022-01-14 09:30:00-05:00  21.610800  21.620001  21.610800  21.620001
# 2022-01-14 09:38:01-05:00  21.610001  21.610001  21.610001  21.610001
#
#                            Adj Close  Volume
# Datetime
# 2021-12-14 09:30:00-05:00  21.340000       0
# 2021-12-14 09:45:00-05:00  21.370001    2381
# 2021-12-14 10:00:00-05:00  21.389999    5277
# 2021-12-14 10:15:00-05:00  21.400000    2546
# 2021-12-14 10:30:00-05:00  21.420000    3102
# ...                              ...     ...
# 2022-01-13 15:15:00-05:00  21.530001     100
# 2022-01-13 15:30:00-05:00  21.530001    1165
# 2022-01-13 15:45:00-05:00  21.520000    6009
# 2022-01-14 09:30:00-05:00  21.620001     611
# 2022-01-14 09:38:01-05:00  21.610001       0
#
# [546 rows x 6 columns]

# %%
data['Kalman']= quant_j3.kalmanIndicator(data,paraA_=200,paraB_=50,instrumento="_")

# %%
data2= quant_j3.MovingAverage(data,long_=200,short_=50)

# %%
data2.head()
# Out:
#                                 Open       High        Low      Close  \
# Datetime
# 2021-12-14 09:30:00-05:00  21.340000  21.340000  21.330000  21.340000
# 2021-12-14 09:45:00-05:00  21.352501  21.370001  21.330000  21.370001
# 2021-12-14 10:00:00-05:00  21.400000  21.459999  21.389999  21.389999
# 2021-12-14 10:15:00-05:00  21.400101  21.419901  21.400000  21.400000
# 2021-12-14 10:30:00-05:00  21.400000  21.420000  21.370001  21.420000
#
#                            Adj Close  Volume     Kalman  MA_200  MA_50
# Datetime
# 2021-12-14 09:30:00-05:00  21.340000       0  19.601118     NaN    NaN
# 2021-12-14 09:45:00-05:00  21.370001    2381  19.779740     NaN    NaN
# 2021-12-14 10:00:00-05:00  21.389999    5277  19.942460     NaN    NaN
# 2021-12-14 10:15:00-05:00  21.400000    2546  20.090704     NaN    NaN
# 2021-12-14 10:30:00-05:00  21.420000    3102  20.225856     NaN    NaN

# %%
data= quant_j3.MovingAverage(data,long_=200,short_=50)

# %%
# 1.- MEDIA DE 200 SESIONES ACCENDENTE
#   Calculamos de la media aritmetica la regresion lineal para ver la esencia
ma200_=data.columns.get_loc("MA_200")
data_aux2= data.iloc[-200:, ma200_]
data_aux2.dropna(inplace=True)  
# 3.1.- Calculamos media de las ultimas 'n' sesiones y la regresion lineal
coef_ema200_, intercept_ema200_ =quant_j3.linearRegresion_J3(data_aux2) #+'  de ema200')
# Out:
# Coefficients:
#  [-0.00028649]
# Independent term:
#  21.844675026583314

# %%
data.tail()
# Out:
#                                 Open       High        Low      Close  \
# Datetime
# 2022-01-13 15:15:00-05:00  21.530001  21.530001  21.530001  21.530001
# 2022-01-13 15:30:00-05:00  21.530001  21.540001  21.530001  21.530001
# 2022-01-13 15:45:00-05:00  21.530001  21.540001  21.520000  21.520000
# 2022-01-14 09:30:00-05:00  21.610800  21.620001  21.610800  21.620001
# 2022-01-14 09:38:01-05:00  21.610001  21.610001  21.610001  21.610001
#
#                            Adj Close  Volume     Kalman     MA_200      MA_50
# Datetime
# 2022-01-13 15:15:00-05:00  21.530001     100  21.583477  21.825037  21.713674
# 2022-01-13 15:30:00-05:00  21.530001    1165  21.582945  21.824990  21.706874
# 2022-01-13 15:45:00-05:00  21.520000    6009  21.582941  21.825040  21.700274
# 2022-01-14 09:30:00-05:00  21.620001     611  21.583567  21.825640  21.695992
# 2022-01-14 09:38:01-05:00  21.610001       0  21.583829  21.826190  21.691794

# %%
# borrar una columna  
del data["Adj Close"]

# %%
print (data)
# Out:
#                                 Open       High        Low      Close  Volume  \
# Datetime
# 2021-12-14 09:30:00-05:00  21.340000  21.340000  21.330000  21.340000       0
# 2021-12-14 09:45:00-05:00  21.352501  21.370001  21.330000  21.370001    2381
# 2021-12-14 10:00:00-05:00  21.400000  21.459999  21.389999  21.389999    5277
# 2021-12-14 10:15:00-05:00  21.400101  21.419901  21.400000  21.400000    2546
# 2021-12-14 10:30:00-05:00  21.400000  21.420000  21.370001  21.420000    3102
# ...                              ...        ...        ...        ...     ...
# 2022-01-13 15:15:00-05:00  21.530001  21.530001  21.530001  21.530001     100
# 2022-01-13 15:30:00-05:00  21.530001  21.540001  21.530001  21.530001    1165
# 2022-01-13 15:45:00-05:00  21.530001  21.540001  21.520000  21.520000    6009
# 2022-01-14 09:30:00-05:00  21.610800  21.620001  21.610800  21.620001     611
# 2022-01-14 09:38:01-05:00  21.610001  21.610001  21.610001  21.610001       0
#
#                               Kalman     MA_200      MA_50
# Datetime
# 2021-12-14 09:30:00-05:00  19.601118        NaN        NaN
# 2021-12-14 09:45:00-05:00  19.779740        NaN        NaN
# 2021-12-14 10:00:00-05:00  19.942460        NaN        NaN
# 2021-12-14 10:15:00-05:00  20.090704        NaN        NaN
# 2021-12-14 10:30:00-05:00  20.225856        NaN        NaN
# ...                              ...        ...        ...
# 2022-01-13 15:15:00-05:00  21.583477  21.825037  21.713674
# 2022-01-13 15:30:00-05:00  21.582945  21.824990  21.706874
# 2022-01-13 15:45:00-05:00  21.582941  21.825040  21.700274
# 2022-01-14 09:30:00-05:00  21.583567  21.825640  21.695992
# 2022-01-14 09:38:01-05:00  21.583829  21.826190  21.691794
#
# [546 rows x 8 columns]

# %%
indiceLast_ = (len(data)-1)

# %%
indiceLast_
# Out:
# 545

# %%
#print (data.iloc[indiceLast_][kalman_])

# %%
price_ = data.columns.get_loc("Close")  
kalman_ = data.columns.get_loc("Kalman")  
volumen_ = data.columns.get_loc("Volume")

# %%
contador =0
señal =False
for i in range(5):
    #Precio por encima de Kalman cuento uno en el contador
    if (data.iloc[(indiceLast_-i),price_] > data.iloc[(indiceLast_),kalman_]):
        contador += 1
        data.iloc[(indiceLast_-i),volumen_] =99.0

if (contador > 2): 
    señal=True

# %%
def checkKalman(instrumento_ ='app'):
    #Interval required 1 minute
    try:
        data = yf.download(tickers=instrumento_, period='1mo', interval='15m')  #  1h 3mo 15m https://algotrading101.com/learn/yfinance-guide/
    except:
        print('instrumento no existe')
    
    del data["Adj Close"]
    data['Kalman']= quant_j3.kalmanIndicator(data,paraA_=200,paraB_=50,instrumento=instrumento_)

    indiceLast_ = (len(data)-2)    ### ojo parece que da la ultima version cotizada, no la ultima hora
    price_ = data.columns.get_loc("Close")  
    kalman_ = data.columns.get_loc("Kalman")  
    volumen_ = data.columns.get_loc("Volume") 
    open_ = data.columns.get_loc("Open")  


    print(instrumento_)
    
    contador =0
    señal =fuera
    
    # Compruebo Kalman
    # Según la estrategia tenemos que buscar, dos velas alcistas no necesariamente consecutivas entre una ventana anterior. 
    # estas velas alcistas detras de una condicion de reset (dos velas rojas por debajo kalman)
    
    for i in range(5):
        #vela verde por encima de kalman entera
        if (data.iloc[(indiceLast_-i),price_] > data.iloc[(indiceLast_),kalman_]  and  
            data.iloc[(indiceLast_-i),open_] > data.iloc[(indiceLast_),kalman_]  and
            data.iloc[(indiceLast_-i),price_] > data.iloc[(indiceLast_),open_]):
            contador += 1
            data.iloc[(indiceLast_-i),volumen_] =99.0
    #tres velas verdes y la ultima verde
    if (contador > 2  and
       data.iloc[(indiceLast_),price_] > data.iloc[(indiceLast_),kalman_]  and 
       data.iloc[(indiceLast_-i),open_] > data.iloc[(indiceLast_),kalman_] ): 
        señal=dentro 
    
    #Compruebo Media 200 velas positiva
    #quant_j3.MovingAverage(data,long_=200,short_=50)
    data2= quant_j3.MovingAverage(data,long_=200,short_=50)
    # 1.- MEDIA DE 200 SESIONES ACCENDENTE
    #   Calculamos de la media aritmetica la regresion lineal para ver la esencia
    ma200_=data2.columns.get_loc("MA_200")
    data_aux2= data2.iloc[-200:, ma200_]
    data_aux2.dropna(inplace=True)  
    # 3.1.- Calculamos media de las ultimas 'n' sesiones y la regresion lineal
    coef_ema200_, intercept_ema200_ =quant_j3.linearRegresion_J3(data_aux2) #+'  de ema200') 
    
    if (señal ==dentro):
        if (coef_ema200_ > 0): 
            señal=dentro     
        else:
            señal =fuera
    
   
    print(instrumento_,señal)
    print ('Precio', data.iloc[(indiceLast_-i),price_], '*************  ''Kalman', data.iloc[(indiceLast_-i),kalman_])
    print ('checkIN Time',data.index[indiceLast_])
    
    if (señal ==dentro):
        print ('Entramos del mercado')
        telegram_send("3.Señal Kalman (15min)b1.0.\n"+ instrumento_ +"\nPrecio = " + str(data.iloc[(indiceLast_-i),price_]) + "\n***  Kalman level = "+ str(data.iloc[(indiceLast_-i),kalman_])+
                     "\nTime: " + str(data.index[indiceLast_]))
        sleep(5)
        
        
    
    return señal

# %%
def checkKalman_OUT(instrumento_ ='app'):
    #Interval required 1 minute
    try:
        data = yf.download(tickers=instrumento_, period='1mo', interval='15m')  #5m
    except:
        print('instrumento no existe')
    
    del data["Adj Close"]
    data['Kalman']= quant_j3.kalmanIndicator(data,paraA_=200,paraB_=50,instrumento=instrumento_)

    indiceLast_ = (len(data)-2)    ### ojo parece que da la ultima version cotizada, no la ultima hora
    price_ = data.columns.get_loc("Close")  
    kalman_ = data.columns.get_loc("Kalman")  
    volumen_ = data.columns.get_loc("Volume") 
    open_ = data.columns.get_loc("Open")  

    print(instrumento_)
    
    contador =0
    señal =dentro
    
    # Compruebo Kalman
    # Borro la señal si dos velas por debajo de kalman
    
    for i in range(5):
        #Precio por debajo de Kalman cuento uno en el contador
        if (data.iloc[(indiceLast_-i),price_] < data.iloc[(indiceLast_),kalman_] and
           data.iloc[(indiceLast_-i),open_] < data.iloc[(indiceLast_),kalman_] and
           data.iloc[(indiceLast_-i),price_] < data.iloc[(indiceLast_),open_]):
            contador += 1
            data.iloc[(indiceLast_-i),volumen_] =99.0
    if (contador > 3): 
        señal=fuera
        print ('Salimos del mercado')
    
    
    
    print(instrumento_,señal)

    print ('checkOUT Time',data.index[indiceLast_])

    return señal

# %%
print(checkKalman('corn'))
# Out:
# [*********************100%***********************]  1 of 1 completed
# corn
# Coefficients:
#  [-0.00028649]
# Independent term:
#  21.844675026583314
# corn False
# Precio 21.540000915527344 *************  Kalman 21.584544947650116
# checkIN Time 2022-01-14 09:30:00-05:00
# False

# %%
print(checkKalman_OUT('corn'))
# Out:
# [*********************100%***********************]  1 of 1 completed
# corn
# Salimos del mercado
# corn False
# checkOUT Time 2022-01-14 09:30:00-05:00
# False

# %%
data
# Out:
#                                 Open       High        Low      Close  Volume  \
# Datetime
# 2021-12-14 09:30:00-05:00  21.340000  21.340000  21.330000  21.340000       0
# 2021-12-14 09:45:00-05:00  21.352501  21.370001  21.330000  21.370001    2381
# 2021-12-14 10:00:00-05:00  21.400000  21.459999  21.389999  21.389999    5277
# 2021-12-14 10:15:00-05:00  21.400101  21.419901  21.400000  21.400000    2546
# 2021-12-14 10:30:00-05:00  21.400000  21.420000  21.370001  21.420000    3102
# ...                              ...        ...        ...        ...     ...
# 2022-01-13 15:15:00-05:00  21.530001  21.530001  21.530001  21.530001     100
# 2022-01-13 15:30:00-05:00  21.530001  21.540001  21.530001  21.530001    1165
# 2022-01-13 15:45:00-05:00  21.530001  21.540001  21.520000  21.520000    6009
# 2022-01-14 09:30:00-05:00  21.610800  21.620001  21.610800  21.620001      99
# 2022-01-14 09:38:01-05:00  21.610001  21.610001  21.610001  21.610001      99
#
#                               Kalman     MA_200      MA_50
# Datetime
# 2021-12-14 09:30:00-05:00  19.601118        NaN        NaN
# 2021-12-14 09:45:00-05:00  19.779740        NaN        NaN
# 2021-12-14 10:00:00-05:00  19.942460        NaN        NaN
# 2021-12-14 10:15:00-05:00  20.090704        NaN        NaN
# 2021-12-14 10:30:00-05:00  20.225856        NaN        NaN
# ...                              ...        ...        ...
# 2022-01-13 15:15:00-05:00  21.583477  21.825037  21.713674
# 2022-01-13 15:30:00-05:00  21.582945  21.824990  21.706874
# 2022-01-13 15:45:00-05:00  21.582941  21.825040  21.700274
# 2022-01-14 09:30:00-05:00  21.583567  21.825640  21.695992
# 2022-01-14 09:38:01-05:00  21.583829  21.826190  21.691794
#
# [546 rows x 8 columns]

# %%
#TICKERS
tickers5 = ['AAPL', 'MSFT', '^GSPC', 'ELE.MC','SAN.MC', 'BBVA.MC']  #,'ANA.MC','MTS.MC','GRF.MC']  # apple,microsfoft,sp500, endesa
tickers__ = ['MTS.MC'] 
tickers = ['FER.MC','COL.MC','IBE.MC','NTGY.MC','SAB.MC','ACX.MC','PHM.MC','SAN.MC','MRL.MC','TEF.MC','AMS.MC','VIS.MC','MTS.MC','MAP.MC','CLNX.MC','BBVA.MC','CABK.MC','MEL.MC','AENA.MC','BKT.MC','REE.MC','FDR.MC','ACS.MC','ITX.MC','ENG.MC','ANA.MC','ELE.MC','GRF.MC','IAG.MC','SGRE.MC']
tickersCurrencies =['EURUSD=X', 'EURGBP=X' ,'EURCHF=X', 'EURJPY=X', 'EURNZD=X', 'EURCAD=X', 'EURAUD=X','USDCHF=X', 
         'USDJPY=X','GBPCAD=X', 'GBPUSD=X', 'GBPJPY=X', 'GBPCHF=X', 'GBPNZD=X', 'GBPAUD=X',
         'NZDCAD=X', 'NZDUSD=X', 'NZDCHF=X', 'NZDJPY=X','JPY=X','EURSEK=X','USDCAD=X','AUDCAD=X',
         'KC=F','HG=F', 'CORN', 'CL=F', 'ZS=F','ZW=F','GC=F','X','ZW=F',
         'ETH-USD','PFE',
        '^IXIC', '^GSPC', '^GDAXI'
         ]
Currencies_dict = dict.fromkeys(tickersCurrencies, True) #convertir el array en un diccionario


while(True):
    #VALORES DEL IBEX 
    #for i in range(len(tickers)): 
                    #print(tickers[i])
        #checkKalman(tickers[i])
        #sleep(1)


    #CURRENCIES
    for i in range(len(tickersCurrencies)): 
                #print(tickersCurrencies[i])
        if (Currencies_dict[tickersCurrencies[i]]==fuera):
            señal= checkKalman(tickersCurrencies[i])     
            Currencies_dict[tickersCurrencies[i]]=señal
            sleep(1)
        else: 
            señal= checkKalman_OUT(tickersCurrencies[i])     
            Currencies_dict[tickersCurrencies[i]]=señal
            sleep(1)            
        
"""
VALORES DEL SP50
sp_url= 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
sp=pd.read_html(sp_url,header=0)[0]
print (sp.info())

for i in range(len(sp)):
     symbol=sp.iloc[i,0] 
     #df = yf.download(symbol, start, end)
     print(symbol)
     checkKalman(symbol)
     #time.sleep (1)
"""
# Out:
# [*********************100%***********************]  1 of 1 completed
# EURUSD=X
# EURUSD=X True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURGBP=X
# EURGBP=X True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCHF=X
# EURCHF=X True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURJPY=X
# Salimos del mercado
# EURJPY=X False
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURNZD=X
# EURNZD=X True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCAD=X
# EURCAD=X True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURAUD=X
# EURAUD=X True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCHF=X
# USDCHF=X True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDJPY=X
# USDJPY=X True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCAD=X
# GBPCAD=X True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPUSD=X
# GBPUSD=X True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPJPY=X
# GBPJPY=X True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCHF=X
# GBPCHF=X True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPNZD=X
# GBPNZD=X True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPAUD=X
# GBPAUD=X True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCAD=X
# NZDCAD=X True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDUSD=X
# NZDUSD=X True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCHF=X
# NZDCHF=X True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDJPY=X
# NZDJPY=X True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# JPY=X
# JPY=X True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURSEK=X
# EURSEK=X True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCAD=X
# USDCAD=X True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# AUDCAD=X
# AUDCAD=X True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# KC=F
# Salimos del mercado
# KC=F False
# checkOUT Time 2022-01-14 09:15:00-05:00
# [*********************100%***********************]  1 of 1 completed
# HG=F
# HG=F True
# checkOUT Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CORN
# Salimos del mercado
# CORN False
# checkOUT Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CL=F
# CL=F True
# checkOUT Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZS=F
# ZS=F True
# checkOUT Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# GC=F
# GC=F True
# checkOUT Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# X
# X True
# checkOUT Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ETH-USD
# ETH-USD True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# PFE
# PFE True
# checkOUT Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^IXIC
# ^IXIC True
# checkOUT Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GSPC
# ^GSPC True
# checkOUT Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GDAXI
# Salimos del mercado
# ^GDAXI False
# checkOUT Time 2022-01-14 15:15:00+01:00
# [*********************100%***********************]  1 of 1 completed
# EURUSD=X
# EURUSD=X True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURGBP=X
# EURGBP=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCHF=X
# Salimos del mercado
# EURCHF=X False
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURJPY=X
# Coefficients:
#  [0.00023334]
# Independent term:
#  130.99660652985074
# EURJPY=X False
# Precio 129.89999389648438 *************  Kalman 130.21467259752473
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURNZD=X
# EURNZD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCAD=X
# EURCAD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURAUD=X
# EURAUD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCHF=X
# USDCHF=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDJPY=X
# USDJPY=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCAD=X
# GBPCAD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPUSD=X
# GBPUSD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPJPY=X
# GBPJPY=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCHF=X
# GBPCHF=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPNZD=X
# GBPNZD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPAUD=X
# GBPAUD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCAD=X
# NZDCAD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDUSD=X
# NZDUSD=X True
# checkOUT Time 2022-01-14 14:30:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCHF=X
# NZDCHF=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDJPY=X
# NZDJPY=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# JPY=X
# JPY=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURSEK=X
# EURSEK=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCAD=X
# USDCAD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# AUDCAD=X
# Salimos del mercado
# AUDCAD=X False
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# KC=F
# Coefficients:
#  [0.0528333]
# Independent term:
#  228.14600887097032
# KC=F False
# Precio 235.6999969482422 *************  Kalman 237.0328269030634
# checkIN Time 2022-01-14 09:15:00-05:00
# [*********************100%***********************]  1 of 1 completed
# HG=F
# HG=F True
# checkOUT Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CORN
# Coefficients:
#  [-0.00028649]
# Independent term:
#  21.844675026583314
# CORN False
# Precio 21.540000915527344 *************  Kalman 21.584544947650116
# checkIN Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CL=F
# CL=F True
# checkOUT Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZS=F
# ZS=F True
# checkOUT Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# GC=F
# GC=F True
# checkOUT Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# X
# X True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ETH-USD
# ETH-USD True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# PFE
# PFE True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^IXIC
# ^IXIC True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GSPC
# ^GSPC True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GDAXI
# Coefficients:
#  [-0.53781389]
# Independent term:
#  16081.009798646659
# ^GDAXI False
# Precio 15857.7001953125 *************  Kalman 15897.59535525673
# checkIN Time 2022-01-14 15:30:00+01:00
# [*********************100%***********************]  1 of 1 completed
# EURUSD=X
# EURUSD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURGBP=X
# EURGBP=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCHF=X
# Coefficients:
#  [-2.46385127e-05]
# Independent term:
#  1.0500669561631646
# EURCHF=X False
# Precio 1.0422999858856201 *************  Kalman 1.0430215804443563
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURJPY=X
# Coefficients:
#  [0.00023324]
# Independent term:
#  130.9966130039158
# EURJPY=X False
# Precio 129.89999389648438 *************  Kalman 130.20911224052847
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURNZD=X
# EURNZD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCAD=X
# EURCAD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURAUD=X
# EURAUD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCHF=X
# USDCHF=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDJPY=X
# Salimos del mercado
# USDJPY=X False
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCAD=X
# GBPCAD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPUSD=X
# GBPUSD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPJPY=X
# Salimos del mercado
# GBPJPY=X False
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCHF=X
# GBPCHF=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPNZD=X
# GBPNZD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPAUD=X
# GBPAUD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCAD=X
# NZDCAD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDUSD=X
# Salimos del mercado
# NZDUSD=X False
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCHF=X
# Salimos del mercado
# NZDCHF=X False
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDJPY=X
# Salimos del mercado
# NZDJPY=X False
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# JPY=X
# Salimos del mercado
# JPY=X False
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURSEK=X
# EURSEK=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCAD=X
# USDCAD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# AUDCAD=X
# Coefficients:
#  [1.51937183e-05]
# Independent term:
#  0.9069730412991632
# AUDCAD=X False
# Precio 0.9066200256347656 *************  Kalman 0.907337613839582
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# KC=F
# Coefficients:
#  [0.05275488]
# Independent term:
#  228.20333991407708
# KC=F False
# Precio 236.1999969482422 *************  Kalman 236.92258491840627
# checkIN Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# HG=F
# HG=F True
# checkOUT Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CORN
# Coefficients:
#  [-0.00028649]
# Independent term:
#  21.844675026583314
# CORN False
# Precio 21.540000915527344 *************  Kalman 21.584544947650116
# checkIN Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CL=F
# CL=F True
# checkOUT Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZS=F
# ZS=F True
# checkOUT Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# GC=F
# GC=F True
# checkOUT Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# X
# X True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ETH-USD
# ETH-USD True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# PFE
# PFE True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^IXIC
# ^IXIC True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GSPC
# ^GSPC True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GDAXI
# Coefficients:
#  [-0.53778051]
# Independent term:
#  16081.007597200036
# ^GDAXI False
# Precio 15857.7001953125 *************  Kalman 15899.829286046066
# checkIN Time 2022-01-14 15:30:00+01:00
# [*********************100%***********************]  1 of 1 completed
# EURUSD=X
# EURUSD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURGBP=X
# EURGBP=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCHF=X
# Coefficients:
#  [-2.46394931e-05]
# Independent term:
#  1.0500670207156175
# EURCHF=X False
# Precio 1.0422999858856201 *************  Kalman 1.0429808270927319
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURJPY=X
# Coefficients:
#  [0.00023315]
# Independent term:
#  130.99661892790152
# EURJPY=X False
# Precio 129.89999389648438 *************  Kalman 130.20492860812604
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURNZD=X
# EURNZD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCAD=X
# EURCAD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURAUD=X
# EURAUD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCHF=X
# USDCHF=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDJPY=X
# Coefficients:
#  [-0.00537381]
# Independent term:
#  115.45018261616836
# USDJPY=X False
# Precio 113.56999969482422 *************  Kalman 113.72890671163873
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCAD=X
# GBPCAD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPUSD=X
# GBPUSD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPJPY=X
# Coefficients:
#  [-0.00062637]
# Independent term:
#  157.0897663109623
# GBPJPY=X False
# Precio 155.57000732421875 *************  Kalman 155.92420029906555
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCHF=X
# Salimos del mercado
# GBPCHF=X False
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPNZD=X
# GBPNZD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPAUD=X
# GBPAUD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCAD=X
# NZDCAD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDUSD=X
# Coefficients:
#  [4.65923934e-05]
# Independent term:
#  0.6772640708160934
# NZDUSD=X False
# Precio 0.6833868622779846 *************  Kalman 0.684357273146349
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCHF=X
# Coefficients:
#  [-2.34905222e-06]
# Independent term:
#  0.6265082974092729
# NZDCHF=X False
# Precio 0.6223400235176086 *************  Kalman 0.6231993869264543
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDJPY=X
# Coefficients:
#  [0.00168795]
# Independent term:
#  78.15775461486132
# NZDJPY=X False
# Precio 77.56099700927734 *************  Kalman 77.796165776799
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# JPY=X
# Coefficients:
#  [-0.00537377]
# Independent term:
#  115.45018007651942
# JPY=X False
# Precio 113.56999969482422 *************  Kalman 113.73019423139652
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURSEK=X
# EURSEK=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCAD=X
# USDCAD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# AUDCAD=X
# Coefficients:
#  [1.51939265e-05]
# Independent term:
#  0.9069730275861807
# AUDCAD=X False
# Precio 0.9066200256347656 *************  Kalman 0.9073474907320127
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# KC=F
# Coefficients:
#  [0.05275603]
# Independent term:
#  228.20326394377747
# KC=F False
# Precio 236.1999969482422 *************  Kalman 236.98346723440207
# checkIN Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# HG=F
# HG=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CORN
# Coefficients:
#  [-0.00028654]
# Independent term:
#  21.844678860961857
# CORN False
# Precio 21.540000915527344 *************  Kalman 21.580614974026577
# checkIN Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CL=F
# CL=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZS=F
# ZS=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# GC=F
# GC=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# X
# X True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ETH-USD
# ETH-USD True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# PFE
# PFE True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^IXIC
# ^IXIC True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GSPC
# ^GSPC True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GDAXI
# Coefficients:
#  [-0.53770471]
# Independent term:
#  16081.002604438989
# ^GDAXI False
# Precio 15857.7001953125 *************  Kalman 15903.333143027325
# checkIN Time 2022-01-14 15:30:00+01:00
# [*********************100%***********************]  1 of 1 completed
# EURUSD=X
# EURUSD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURGBP=X
# EURGBP=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCHF=X
# Coefficients:
#  [-2.4639464e-05]
# Independent term:
#  1.050067018817432
# EURCHF=X False
# Precio 1.0422999858856201 *************  Kalman 1.0429774244963068
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURJPY=X
# Coefficients:
#  [0.00023324]
# Independent term:
#  130.99661318962893
# EURJPY=X False
# Precio 129.89999389648438 *************  Kalman 130.20979512135747
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURNZD=X
# EURNZD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCAD=X
# EURCAD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURAUD=X
# EURAUD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCHF=X
# USDCHF=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDJPY=X
# Coefficients:
#  [-0.00537377]
# Independent term:
#  115.45018021860265
# USDJPY=X False
# Precio 113.56999969482422 *************  Kalman 113.73047799532162
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCAD=X
# GBPCAD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPUSD=X
# GBPUSD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPJPY=X
# Coefficients:
#  [-0.00062632]
# Independent term:
#  157.0897627733487
# GBPJPY=X False
# Precio 155.57000732421875 *************  Kalman 155.92766957952855
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCHF=X
# Coefficients:
#  [-3.69525114e-05]
# Independent term:
#  1.2592374189675741
# GBPCHF=X False
# Precio 1.2485599517822266 *************  Kalman 1.249013472409474
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPNZD=X
# GBPNZD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPAUD=X
# GBPAUD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCAD=X
# NZDCAD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDUSD=X
# Coefficients:
#  [4.65923941e-05]
# Independent term:
#  0.6772640707463916
# NZDUSD=X False
# Precio 0.6833868622779846 *************  Kalman 0.6843626092191253
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCHF=X
# Coefficients:
#  [-2.34855371e-06]
# Independent term:
#  0.6265082645577726
# NZDCHF=X False
# Precio 0.6223400235176086 *************  Kalman 0.6232266242082989
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDJPY=X
# Coefficients:
#  [0.00168805]
# Independent term:
#  78.15774795209971
# NZDJPY=X False
# Precio 77.56099700927734 *************  Kalman 77.8012716518643
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# JPY=X
# Coefficients:
#  [-0.00537379]
# Independent term:
#  115.45018164319849
# JPY=X False
# Precio 113.56999969482422 *************  Kalman 113.72908999519427
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURSEK=X
# EURSEK=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCAD=X
# USDCAD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# AUDCAD=X
# Coefficients:
#  [1.51934351e-05]
# Independent term:
#  0.9069730599847302
# AUDCAD=X False
# Precio 0.9066200256347656 *************  Kalman 0.9073179708466891
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# KC=F
# Coefficients:
#  [0.05275733]
# Independent term:
#  228.2031781601977
# KC=F False
# Precio 236.1999969482422 *************  Kalman 237.0530342824504
# checkIN Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# HG=F
# HG=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CORN
# Coefficients:
#  [-0.00028657]
# Independent term:
#  21.844680816230493
# CORN False
# Precio 21.540000915527344 *************  Kalman 21.579449241918528
# checkIN Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CL=F
# CL=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZS=F
# ZS=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# GC=F
# GC=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# X
# X True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ETH-USD
# ETH-USD True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# PFE
# PFE True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^IXIC
# ^IXIC True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GSPC
# ^GSPC True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GDAXI
# Coefficients:
#  [-0.5377135]
# Independent term:
#  16081.003182811772
# ^GDAXI False
# Precio 15857.7001953125 *************  Kalman 15903.016106407233
# checkIN Time 2022-01-14 15:30:00+01:00
# [*********************100%***********************]  1 of 1 completed
# EURUSD=X
# EURUSD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURGBP=X
# EURGBP=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCHF=X
# Coefficients:
#  [-2.46389059e-05]
# Independent term:
#  1.0500669820472377
# EURCHF=X False
# Precio 1.0422999858856201 *************  Kalman 1.043006999794813
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURJPY=X
# Coefficients:
#  [0.00023324]
# Independent term:
#  130.9966131646569
# EURJPY=X False
# Precio 129.89999389648438 *************  Kalman 130.2080242946324
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURNZD=X
# EURNZD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCAD=X
# EURCAD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURAUD=X
# EURAUD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCHF=X
# USDCHF=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDJPY=X
# Coefficients:
#  [-0.00537379]
# Independent term:
#  115.45018179945875
# USDJPY=X False
# Precio 113.56999969482422 *************  Kalman 113.72828842847784
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCAD=X
# GBPCAD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPUSD=X
# GBPUSD=X True
# checkOUT Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPJPY=X
# Coefficients:
#  [-0.00069599]
# Independent term:
#  157.0959152878149
# GBPJPY=X False
# Precio 155.572998046875 *************  Kalman 155.89093386718918
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCHF=X
# Coefficients:
#  [-3.72040135e-05]
# Independent term:
#  1.2592281242036998
# GBPCHF=X False
# Precio 1.2472800016403198 *************  Kalman 1.2488434681539886
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPNZD=X
# GBPNZD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPAUD=X
# GBPAUD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCAD=X
# NZDCAD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDUSD=X
# Coefficients:
#  [4.65930184e-05]
# Independent term:
#  0.6772640296484107
# NZDUSD=X False
# Precio 0.6833868622779846 *************  Kalman 0.6843871118552535
# checkIN Time 2022-01-14 14:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCHF=X
# Coefficients:
#  [-2.45830159e-06]
# Independent term:
#  0.6265164274751696
# NZDCHF=X False
# Precio 0.6218400001525879 *************  Kalman 0.6231545425982353
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDJPY=X
# Coefficients:
#  [0.00165532]
# Independent term:
#  78.16240013178925
# NZDJPY=X False
# Precio 77.56400299072266 *************  Kalman 77.78539790525166
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# JPY=X
# Coefficients:
#  [-0.00540967]
# Independent term:
#  115.44841448523678
# JPY=X False
# Precio 113.53399658203125 *************  Kalman 113.72733539346054
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURSEK=X
# EURSEK=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCAD=X
# USDCAD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# AUDCAD=X
# Coefficients:
#  [1.52593619e-05]
# Independent term:
#  0.9069802082634238
# AUDCAD=X False
# Precio 0.9067599773406982 *************  Kalman 0.9072329677849559
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# KC=F
# Coefficients:
#  [0.0527567]
# Independent term:
#  228.20321980228707
# KC=F False
# Precio 236.1999969482422 *************  Kalman 237.0211214758044
# checkIN Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# HG=F
# HG=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CORN
# Coefficients:
#  [-0.00028657]
# Independent term:
#  21.844680816230493
# CORN False
# Precio 21.540000915527344 *************  Kalman 21.579449241918528
# checkIN Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CL=F
# CL=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZS=F
# ZS=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# GC=F
# GC=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# X
# Salimos del mercado
# X False
# checkOUT Time 2022-01-14 10:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ETH-USD
# ETH-USD True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# PFE
# PFE True
# checkOUT Time 2022-01-14 10:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^IXIC
# Salimos del mercado
# ^IXIC False
# checkOUT Time 2022-01-14 10:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GSPC
# ^GSPC True
# checkOUT Time 2022-01-14 10:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GDAXI
# Coefficients:
#  [-0.54575646]
# Independent term:
#  16081.327644198926
# ^GDAXI False
# Precio 15857.08984375 *************  Kalman 15904.284185448232
# checkIN Time 2022-01-14 15:45:00+01:00
# [*********************100%***********************]  1 of 1 completed
# EURUSD=X
# EURUSD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURGBP=X
# EURGBP=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCHF=X
# Coefficients:
#  [-2.47865318e-05]
# Independent term:
#  1.0500590665635778
# EURCHF=X False
# Precio 1.0421799421310425 *************  Kalman 1.0429250308644717
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURJPY=X
# Coefficients:
#  [0.00018323]
# Independent term:
#  131.0016811407744
# EURJPY=X False
# Precio 129.98599243164062 *************  Kalman 130.19129202256417
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURNZD=X
# EURNZD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCAD=X
# EURCAD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURAUD=X
# EURAUD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCHF=X
# USDCHF=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDJPY=X
# Coefficients:
#  [-0.00540941]
# Independent term:
#  115.44839734202712
# USDJPY=X False
# Precio 113.53399658203125 *************  Kalman 113.7401638290543
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCAD=X
# GBPCAD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPUSD=X
# GBPUSD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPJPY=X
# Coefficients:
#  [-0.00069573]
# Independent term:
#  157.09589808194744
# GBPJPY=X False
# Precio 155.572998046875 *************  Kalman 155.9049048652326
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCHF=X
# Coefficients:
#  [-3.72022067e-05]
# Independent term:
#  1.2592280051757152
# GBPCHF=X False
# Precio 1.2472800016403198 *************  Kalman 1.2489334213259518
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPNZD=X
# GBPNZD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPAUD=X
# GBPAUD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCAD=X
# NZDCAD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDUSD=X
# Coefficients:
#  [4.65209103e-05]
# Independent term:
#  0.677314981268413
# NZDUSD=X False
# Precio 0.6834335923194885 *************  Kalman 0.6841875097809813
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCHF=X
# Coefficients:
#  [-2.45876253e-06]
# Independent term:
#  0.6265164578366635
# NZDCHF=X False
# Precio 0.6218400001525879 *************  Kalman 0.6231324727074494
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDJPY=X
# Coefficients:
#  [0.00165531]
# Independent term:
#  78.16240106598013
# NZDJPY=X False
# Precio 77.56400299072266 *************  Kalman 77.78447246616655
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# JPY=X
# Coefficients:
#  [-0.00540939]
# Independent term:
#  115.44839632878659
# JPY=X False
# Precio 113.53399658203125 *************  Kalman 113.73977581157249
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURSEK=X
# EURSEK=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCAD=X
# USDCAD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# AUDCAD=X
# Coefficients:
#  [1.52600469e-05]
# Independent term:
#  0.9069801631142844
# AUDCAD=X False
# Precio 0.9067599773406982 *************  Kalman 0.9072734902999151
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# KC=F
# Coefficients:
#  [0.05267135]
# Independent term:
#  228.26125233889908
# KC=F False
# Precio 235.9499969482422 *************  Kalman 236.95642555239462
# checkIN Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# HG=F
# HG=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CORN
# Coefficients:
#  [-0.00028657]
# Independent term:
#  21.844680816230493
# CORN False
# Precio 21.540000915527344 *************  Kalman 21.579449241918528
# checkIN Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CL=F
# CL=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZS=F
# ZS=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# GC=F
# GC=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# X
# Coefficients:
#  [0.00694922]
# Independent term:
#  23.70497128854581
# X False
# Precio 25.3700008392334 *************  Kalman 25.567998431576324
# checkIN Time 2022-01-14 10:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ETH-USD
# ETH-USD True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# PFE
# PFE True
# checkOUT Time 2022-01-14 10:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^IXIC
# Coefficients:
#  [-3.67971834]
# Independent term:
#  15827.282444790693
# ^IXIC False
# Precio 14853.6845703125 *************  Kalman 14938.272537385672
# checkIN Time 2022-01-14 10:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GSPC
# ^GSPC True
# checkOUT Time 2022-01-14 10:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GDAXI
# Coefficients:
#  [-0.5457623]
# Independent term:
#  16081.328027925314
# ^GDAXI False
# Precio 15857.08984375 *************  Kalman 15904.092801648017
# checkIN Time 2022-01-14 15:45:00+01:00
# [*********************100%***********************]  1 of 1 completed
# EURUSD=X
# EURUSD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURGBP=X
# EURGBP=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCHF=X
# Coefficients:
#  [-2.47867398e-05]
# Independent term:
#  1.0500590802694436
# EURCHF=X False
# Precio 1.0421799421310425 *************  Kalman 1.0429145922729286
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURJPY=X
# Coefficients:
#  [0.00018333]
# Independent term:
#  131.00167457199095
# EURJPY=X False
# Precio 129.98599243164062 *************  Kalman 130.19668179804094
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURNZD=X
# EURNZD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCAD=X
# EURCAD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURAUD=X
# EURAUD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCHF=X
# USDCHF=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDJPY=X
# Coefficients:
#  [-0.00540952]
# Independent term:
#  115.44840455337639
# USDJPY=X False
# Precio 113.53399658203125 *************  Kalman 113.73390873893058
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCAD=X
# GBPCAD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPUSD=X
# GBPUSD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPJPY=X
# Coefficients:
#  [-0.00069564]
# Independent term:
#  157.0958925924159
# GBPJPY=X False
# Precio 155.572998046875 *************  Kalman 155.90931169244067
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCHF=X
# Coefficients:
#  [-3.72021827e-05]
# Independent term:
#  1.2592280035335626
# GBPCHF=X False
# Precio 1.2472800016403198 *************  Kalman 1.2489471551960245
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPNZD=X
# GBPNZD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPAUD=X
# GBPAUD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCAD=X
# NZDCAD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDUSD=X
# Coefficients:
#  [4.65208774e-05]
# Independent term:
#  0.6773149833786398
# NZDUSD=X False
# Precio 0.6834335923194885 *************  Kalman 0.6841981381394567
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCHF=X
# Coefficients:
#  [-2.45832336e-06]
# Independent term:
#  0.6265164288921587
# NZDCHF=X False
# Precio 0.6218400001525879 *************  Kalman 0.6231573823260578
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDJPY=X
# Coefficients:
#  [0.00165538]
# Independent term:
#  78.16239615523496
# NZDJPY=X False
# Precio 77.56400299072266 *************  Kalman 77.78910077109397
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# JPY=X
# Coefficients:
#  [-0.0054095]
# Independent term:
#  115.44840357667724
# JPY=X False
# Precio 113.53399658203125 *************  Kalman 113.7344341761519
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURSEK=X
# EURSEK=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCAD=X
# USDCAD=X True
# checkOUT Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# AUDCAD=X
# Coefficients:
#  [1.52611843e-05]
# Independent term:
#  0.9069800881938703
# AUDCAD=X False
# Precio 0.9067599773406982 *************  Kalman 0.907328077925759
# checkIN Time 2022-01-14 15:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# KC=F
# Coefficients:
#  [0.0526709]
# Independent term:
#  228.26128177875123
# KC=F False
# Precio 235.9499969482422 *************  Kalman 236.93037048448534
# checkIN Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# HG=F
# HG=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CORN
# Coefficients:
#  [-0.00028662]
# Independent term:
#  21.844683749133438
# CORN False
# Precio 21.540000915527344 *************  Kalman 21.57770064375645
# checkIN Time 2022-01-14 09:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CL=F
# CL=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZS=F
# ZS=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# GC=F
# GC=F True
# checkOUT Time 2022-01-14 09:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# X
# Coefficients:
#  [0.00694933]
# Independent term:
#  23.704964035619195
# X False
# ...
# HG=F
# Coefficients:
#  [0.00067914]
# Independent term:
#  4.424209934042817
# HG=F False
# Precio 4.454999923706055 *************  Kalman 4.464587904910768
# checkIN Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CORN
# Coefficients:
#  [-0.00025544]
# Independent term:
#  21.84094231932341
# CORN False
# Precio 21.552000045776367 *************  Kalman 21.56763076880759
# checkIN Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CL=F
# CL=F True
# checkOUT Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZS=F
# ZS=F True
# checkOUT Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# GC=F
# GC=F True
# checkOUT Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# X
# Coefficients:
#  [0.00687012]
# Independent term:
#  23.73501532714189
# X False
# Precio 25.469999313354492 *************  Kalman 25.45397121588328
# checkIN Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ETH-USD
# ETH-USD True
# checkOUT Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# PFE
# PFE True
# checkOUT Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^IXIC
# Coefficients:
#  [-3.71079998]
# Independent term:
#  15820.519862219424
# ^IXIC False
# Precio 14872.6064453125 *************  Kalman 14901.301652393015
# checkIN Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GSPC
# ^GSPC True
# checkOUT Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GDAXI
# Coefficients:
#  [-0.56909394]
# Independent term:
#  16082.188576028308
# ^GDAXI False
# Precio 15931.169921875 *************  Kalman 15905.438431592544
# checkIN Time 2022-01-14 16:30:00+01:00
# [*********************100%***********************]  1 of 1 completed
# EURUSD=X
# EURUSD=X True
# checkOUT Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURGBP=X
# EURGBP=X True
# checkOUT Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCHF=X
# Coefficients:
#  [-2.51932675e-05]
# Independent term:
#  1.0500300712779387
# EURCHF=X False
# Precio 1.0424400568008423 *************  Kalman 1.042764877371832
# checkIN Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURJPY=X
# Coefficients:
#  [3.10208109e-05]
# Independent term:
#  131.01679588818905
# EURJPY=X False
# Precio 130.0919952392578 *************  Kalman 130.161278417209
# checkIN Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURNZD=X
# EURNZD=X True
# checkOUT Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCAD=X
# EURCAD=X True
# checkOUT Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURAUD=X
# EURAUD=X True
# checkOUT Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCHF=X
# USDCHF=X True
# checkOUT Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDJPY=X
# Coefficients:
#  [-0.00551381]
# Independent term:
#  115.44258528416762
# USDJPY=X False
# Precio 113.70099639892578 *************  Kalman 113.74581849131606
# checkIN Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCAD=X
# GBPCAD=X True
# checkOUT Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPUSD=X
# GBPUSD=X True
# checkOUT Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPJPY=X
# Coefficients:
#  [-0.00090655]
# Independent term:
#  157.1141527183191
# GBPJPY=X False
# Precio 155.6790008544922 *************  Kalman 155.8571326750963
# checkIN Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCHF=X
# Coefficients:
#  [-3.79115219e-05]
# Independent term:
#  1.259193393838139
# GBPCHF=X False
# Precio 1.2474299669265747 *************  Kalman 1.2486137908836916
# checkIN Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPNZD=X
# GBPNZD=X True
# checkOUT Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPAUD=X
# GBPAUD=X True
# checkOUT Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCAD=X
# Coefficients:
#  [1.58840077e-05]
# Independent term:
#  0.8535410427833671
# NZDCAD=X False
# Precio 0.8550800085067749 *************  Kalman 0.8554381106475789
# checkIN Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDUSD=X
# Coefficients:
#  [4.62519996e-05]
# Independent term:
#  0.6774727664675286
# NZDUSD=X False
# Precio 0.6836204528808594 *************  Kalman 0.683790237577617
# checkIN Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCHF=X
# Coefficients:
#  [-2.79198989e-06]
# Independent term:
#  0.62654033972403
# NZDCHF=X False
# Precio 0.6226800084114075 *************  Kalman 0.622873210881359
# checkIN Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDJPY=X
# Coefficients:
#  [0.00155286]
# Independent term:
#  78.1766021553438
# NZDJPY=X False
# Precio 77.70999908447266 *************  Kalman 77.74674603325353
# checkIN Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# JPY=X
# Coefficients:
#  [-0.00551381]
# Independent term:
#  115.4425853333943
# JPY=X False
# Precio 113.70099639892578 *************  Kalman 113.74576081482667
# checkIN Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURSEK=X
# EURSEK=X True
# checkOUT Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCAD=X
# USDCAD=X True
# checkOUT Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# AUDCAD=X
# Coefficients:
#  [1.54292658e-05]
# Independent term:
#  0.9070046453291355
# AUDCAD=X False
# Precio 0.9073899984359741 *************  Kalman 0.9072265576580729
# checkIN Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# KC=F
# Coefficients:
#  [0.0523884]
# Independent term:
#  228.43863509366616
# KC=F False
# Precio 236.4499969482422 *************  Kalman 237.45226259304562
# checkIN Time 2022-01-14 10:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# HG=F
# Coefficients:
#  [0.00067914]
# Independent term:
#  4.424209517993144
# HG=F False
# Precio 4.454999923706055 *************  Kalman 4.464878472240091
# checkIN Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CORN
# Coefficients:
#  [-0.0002554]
# Independent term:
#  21.840939219789362
# CORN False
# Precio 21.552000045776367 *************  Kalman 21.568896913779497
# checkIN Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CL=F
# CL=F True
# checkOUT Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZS=F
# ZS=F True
# checkOUT Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# GC=F
# GC=F True
# checkOUT Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# X
# Coefficients:
#  [0.00687025]
# Independent term:
#  23.735006980205647
# X False
# Precio 25.469999313354492 *************  Kalman 25.460656775146113
# checkIN Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ETH-USD
# ETH-USD True
# checkOUT Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# PFE
# PFE True
# checkOUT Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^IXIC
# Coefficients:
#  [-3.71082801]
# Independent term:
#  15820.521708806553
# ^IXIC False
# Precio 14872.6064453125 *************  Kalman 14899.888277956423
# checkIN Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GSPC
# ^GSPC True
# checkOUT Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GDAXI
# Coefficients:
#  [-0.56911132]
# Independent term:
#  16082.189721470528
# ^GDAXI False
# Precio 15931.169921875 *************  Kalman 15904.451383731854
# checkIN Time 2022-01-14 16:30:00+01:00
# [*********************100%***********************]  1 of 1 completed
# EURUSD=X
# EURUSD=X True
# checkOUT Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURGBP=X
# EURGBP=X True
# checkOUT Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCHF=X
# Coefficients:
#  [-2.51924863e-05]
# Independent term:
#  1.0500300198005206
# EURCHF=X False
# Precio 1.0424400568008423 *************  Kalman 1.0428071911669314
# checkIN Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURJPY=X
# Coefficients:
#  [3.11405668e-05]
# Independent term:
#  131.0167879973682
# EURJPY=X False
# Precio 130.0919952392578 *************  Kalman 130.16759824588996
# checkIN Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURNZD=X
# EURNZD=X True
# checkOUT Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCAD=X
# EURCAD=X True
# checkOUT Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURAUD=X
# EURAUD=X True
# checkOUT Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCHF=X
# USDCHF=X True
# checkOUT Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDJPY=X
# Coefficients:
#  [-0.00551375]
# Independent term:
#  115.44258131544767
# USDJPY=X False
# Precio 113.70099639892578 *************  Kalman 113.7488932645915
# checkIN Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCAD=X
# GBPCAD=X True
# checkOUT Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPUSD=X
# GBPUSD=X True
# checkOUT Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPJPY=X
# Coefficients:
#  [-0.00097756]
# Independent term:
#  157.12015894381395
# GBPJPY=X False
# Precio 155.75799560546875 *************  Kalman 155.8381373526003
# checkIN Time 2022-01-14 16:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCHF=X
# Coefficients:
#  [-3.81336611e-05]
# Independent term:
#  1.2591796156959747
# GBPCHF=X False
# Precio 1.2480299472808838 *************  Kalman 1.2485096888315845
# checkIN Time 2022-01-14 16:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPNZD=X
# GBPNZD=X True
# checkOUT Time 2022-01-14 16:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPAUD=X
# GBPAUD=X True
# checkOUT Time 2022-01-14 16:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCAD=X
# Coefficients:
#  [1.60467066e-05]
# Independent term:
#  0.8535393754885713
# NZDCAD=X False
# Precio 0.8545799851417542 *************  Kalman 0.8554245728712012
# checkIN Time 2022-01-14 16:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDUSD=X
# Coefficients:
#  [4.62518958e-05]
# Independent term:
#  0.6774727733112538
# NZDUSD=X False
# Precio 0.6836204528808594 *************  Kalman 0.6837848379396255
# checkIN Time 2022-01-14 15:45:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCHF=X
# Coefficients:
#  [-2.904033e-06]
# Independent term:
#  0.6265479912684035
# NZDCHF=X False
# Precio 0.6225200295448303 *************  Kalman 0.6227800984662315
# checkIN Time 2022-01-14 16:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDJPY=X
# Coefficients:
#  [0.00151739]
# Independent term:
#  78.18139566184085
# NZDJPY=X False
# Precio 77.69100189208984 *************  Kalman 77.73468483557721
# checkIN Time 2022-01-14 16:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# JPY=X
# Coefficients:
#  [-0.00554747]
# Independent term:
#  115.4404698255852
# JPY=X False
# Precio 113.82099914550781 *************  Kalman 113.75183117595618
# checkIN Time 2022-01-14 16:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURSEK=X
# EURSEK=X True
# checkOUT Time 2022-01-14 16:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCAD=X
# USDCAD=X True
# checkOUT Time 2022-01-14 16:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# AUDCAD=X
# Coefficients:
#  [1.54746552e-05]
# Independent term:
#  0.9070138343417377
# AUDCAD=X False
# Precio 0.9067699909210205 *************  Kalman 0.907167708718295
# checkIN Time 2022-01-14 16:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# KC=F
# Coefficients:
#  [0.0523887]
# Independent term:
#  228.4386155417257
# KC=F False
# Precio 236.4499969482422 *************  Kalman 237.4639194694448
# checkIN Time 2022-01-14 10:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# HG=F
# Coefficients:
#  [0.00067913]
# Independent term:
#  4.424210081396886
# HG=F False
# Precio 4.454999923706055 *************  Kalman 4.464443370269983
# checkIN Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CORN
# Coefficients:
#  [-0.00025545]
# Independent term:
#  21.840942464765863
# CORN False
# Precio 21.552000045776367 *************  Kalman 21.567571356255854
# checkIN Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CL=F
# CL=F True
# checkOUT Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZS=F
# ZS=F True
# checkOUT Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# GC=F
# GC=F True
# checkOUT Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# X
# Coefficients:
#  [0.00684313]
# Independent term:
#  23.745013921585368
# X False
# Precio 25.299999237060547 *************  Kalman 25.434140072534024
# checkIN Time 2022-01-14 11:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-14 10:45:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ETH-USD
# ETH-USD True
# checkOUT Time 2022-01-14 16:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# PFE
# PFE True
# checkOUT Time 2022-01-14 11:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^IXIC
# Coefficients:
#  [-3.72021035]
# Independent term:
#  15818.127382890481
# ^IXIC False
# Precio 14821.0986328125 *************  Kalman 14890.30097439276
# checkIN Time 2022-01-14 11:00:00-05:00

# %%
tickersCurrencies =['EURUSD=X', 'EURGBP=X' ,'EURCHF=X', 'EURJPY=X', 'EURNZD=X', 'EURCAD=X', 'EURAUD=X','USDCHF=X', 
         'USDJPY=X','GBPCAD=X', 'GBPUSD=X', 'GBPJPY=X', 'GBPCHF=X', 'GBPNZD=X', 'GBPAUD=X',
         'NZDCAD=X', 'NZDUSD=X', 'NZDCHF=X', 'NZDJPY=X','JPY=X','EURSEK=X','USDCAD=X','AUDCAD=X',
         'KC=F','HG=F', 'CORN', 'CL=F', 'ZS=F','ZW=F','GC=F','X','ZW=F',
         'ETH-USD','PFE',
        '^IXIC', '^GSPC', '^GDAXI'
         ]

Currencies_dict = dict.fromkeys(tickersCurrencies, "out")

# %%
Currencies_dict[tickersCurrencies[2]]=2

# %%
Currencies_dict

# %% [markdown]
# # GRAFICADOR

# %%
#Interval required 1 minute
data = yf.download(tickers='UBER', period='1d', interval='1m')

#declare figure
fig = go.Figure()

#Candlestick
fig.add_trace(go.Candlestick(x=data.index,
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close'], name = 'market data'))

# Add titles

fig.layout.update(
    title='Uber live share price evolution',
    yaxis_title='Stock Price (USD per Shares)')

# X-Axes

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=15, label="15m", step="minute", stepmode="backward"),
            dict(count=45, label="45m", step="minute", stepmode="backward"),
            dict(count=1, label="HTD", step="hour", stepmode="todate"),
            dict(count=3, label="3h", step="hour", stepmode="backward"),
            dict(step="all")
        ])
    )
)

#Show
fig.show()
