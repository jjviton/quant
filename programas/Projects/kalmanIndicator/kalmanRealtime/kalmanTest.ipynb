# %% [markdown]
# # KALMAN REAL TIME con Telegram

# %% [markdown]
# Este cuaderno implementa una estrategia de inversion basada en Kalman como indicador.
#
# Busca señales de entrada y las envía el Telegram para su analisis.
#
# GRAFICADOR PLOTLY:  muy bueno como hace velas ( esta abajo desconectado del resto)

# %% [markdown]
# Status: <font color='red'>Funcionando !!!  v0.0    10/01/2022<font>

# %%
# Raw Package
import numpy as np
import pandas as pd

#Data Source
import yfinance as yf

#Data viz
import plotly.graph_objs as go

# %%
import analisis
import kalman as kl  #cambiar segun el módulo con la estrategia implementado
import pandas as pd
import datetime as dt
from time import time
from time import sleep
import yfinance as yf
import numpy as np
from telegram_bot import *

dentro =True
fuera  =False
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\INNOVA~1\AppData\Local\Temp/ipykernel_36852/1960111592.py in <module>
#       1 import analisis
# ----> 2 import kalman as kl  #cambiar segun el módulo con la estrategia implementado
#       3 import pandas as pd
#       4 import datetime as dt
#       5 from time import time
#
# ~\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\kalmanIndicator\kalmanRealtime\kalman.py in <module>
#      39 import datetime as dt
#      40 import yfinance as yf
# ---> 41 import matplotlib.pyplot as plt
#      42
#      43 import statsmodels.api as sm
#
# ~\anaconda3\envs\trading\lib\site-packages\matplotlib\pyplot.py in <module>
#    2228     dict.__setitem__(rcParams, "backend", rcsetup._auto_backend_sentinel)
#    2229 # Set up the backend.
# -> 2230 switch_backend(rcParams["backend"])
#    2231
#    2232 # Just to be safe.  Interactive mode can be turned on without
#
# ~\anaconda3\envs\trading\lib\site-packages\matplotlib\pyplot.py in switch_backend(newbackend)
#     265     backend_name = cbook._backend_module_name(newbackend)
#     266
# --> 267     class backend_mod(matplotlib.backend_bases._Backend):
#     268         locals().update(vars(importlib.import_module(backend_name)))
#     269
#
# ~\anaconda3\envs\trading\lib\site-packages\matplotlib\pyplot.py in backend_mod()
#     266
#     267     class backend_mod(matplotlib.backend_bases._Backend):
# --> 268         locals().update(vars(importlib.import_module(backend_name)))
#     269
#     270     required_framework = _get_required_interactive_framework(backend_mod)
#
# ~\anaconda3\envs\trading\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ModuleNotFoundError: No module named 'matplotlib_inline'

# %%
kalman= kl.StrategyClass(real_back=True)    #Creamos la clase
import quant_j3_lib as quant_j3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\INNOVA~1\AppData\Local\Temp/ipykernel_36852/993367759.py in <module>
# ----> 1 kalman= kl.StrategyClass(real_back=True)    #Creamos la clase
#       2 import quant_j3_lib as quant_j3
#
# NameError: name 'kl' is not defined

# %%
telegram_send("3.- Señal Kalman RealTime b0.1n  ")

# %%
#Interval required 1 minute
data = yf.download(tickers='USDCAD=X', period='1mo', interval='15m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                               Open     High      Low    Close  Adj Close  \
# Datetime
# 2021-12-27 00:00:00+00:00  1.28150  1.28171  1.28080  1.28154    1.28154
# 2021-12-27 00:15:00+00:00  1.28160  1.28166  1.28090  1.28128    1.28128
# 2021-12-27 00:30:00+00:00  1.28124  1.28160  1.28090  1.28152    1.28152
# 2021-12-27 00:45:00+00:00  1.28150  1.28177  1.28110  1.28145    1.28145
# 2021-12-27 01:00:00+00:00  1.28143  1.28180  1.28100  1.28139    1.28139
# ...                            ...      ...      ...      ...        ...
# 2022-01-25 07:30:00+00:00  1.26428  1.26458  1.26340  1.26400    1.26400
# 2022-01-25 07:45:00+00:00  1.26407  1.26427  1.26340  1.26370    1.26370
# 2022-01-25 08:00:00+00:00  1.26381  1.26493  1.26290  1.26320    1.26320
# 2022-01-25 08:15:00+00:00  1.26337  1.26498  1.26290  1.26472    1.26472
# 2022-01-25 08:30:50+00:00  1.26447  1.26447  1.26447  1.26447    1.26447
#
#                            Volume
# Datetime
# 2021-12-27 00:00:00+00:00       0
# 2021-12-27 00:15:00+00:00       0
# 2021-12-27 00:30:00+00:00       0
# 2021-12-27 00:45:00+00:00       0
# 2021-12-27 01:00:00+00:00       0
# ...                           ...
# 2022-01-25 07:30:00+00:00       0
# 2022-01-25 07:45:00+00:00       0
# 2022-01-25 08:00:00+00:00       0
# 2022-01-25 08:15:00+00:00       0
# 2022-01-25 08:30:50+00:00       0
#
# [2025 rows x 6 columns]

# %%
data['Kalman']= quant_j3.kalmanIndicator(data,paraA_=200,paraB_=50,instrumento="_")

# %%
data2= quant_j3.MovingAverage(data,long_=200,short_=50)

# %%
data2.tail()
# Out:
#                               Open     High      Low    Close  Adj Close  \
# Datetime
# 2022-01-25 07:30:00+00:00  1.26428  1.26458  1.26340  1.26400    1.26400
# 2022-01-25 07:45:00+00:00  1.26407  1.26427  1.26340  1.26370    1.26370
# 2022-01-25 08:00:00+00:00  1.26381  1.26493  1.26290  1.26320    1.26320
# 2022-01-25 08:15:00+00:00  1.26337  1.26498  1.26290  1.26472    1.26472
# 2022-01-25 08:30:50+00:00  1.26447  1.26447  1.26447  1.26447    1.26447
#
#                            Volume    Kalman    MA_200     MA_50
# Datetime
# 2022-01-25 07:30:00+00:00       0  1.264164  1.258992  1.263985
# 2022-01-25 07:45:00+00:00       0  1.264158  1.259047  1.263955
# 2022-01-25 08:00:00+00:00       0  1.264157  1.259100  1.263910
# 2022-01-25 08:15:00+00:00       0  1.264166  1.259160  1.263910
# 2022-01-25 08:30:50+00:00       0  1.264169  1.259224  1.263919

# %%
data= quant_j3.MovingAverage(data,long_=200,short_=50)

# %%
# 1.- MEDIA DE 200 SESIONES ACCENDENTE
#   Calculamos de la media aritmetica la regresion lineal para ver la esencia
ma200_=data.columns.get_loc("MA_200")
data_aux2= data.iloc[-200:, ma200_]
data_aux2.dropna(inplace=True)  
# 3.1.- Calculamos media de las ultimas 'n' sesiones y la regresion lineal
coef_ema200_, intercept_ema200_ =quant_j3.linearRegresion_J3(data_aux2) #+'  de ema200')
# Out:
# Coefficients:
#  [5.17434765e-05]
# Independent term:
#  1.2479828106604407

# %%
data_aux2[-1]
# Out:
# 1.2592236012220384

# %%
data.tail()
# Out:
#                               Open     High      Low    Close  Adj Close  \
# Datetime
# 2022-01-25 07:30:00+00:00  1.26428  1.26458  1.26340  1.26400    1.26400
# 2022-01-25 07:45:00+00:00  1.26407  1.26427  1.26340  1.26370    1.26370
# 2022-01-25 08:00:00+00:00  1.26381  1.26493  1.26290  1.26320    1.26320
# 2022-01-25 08:15:00+00:00  1.26337  1.26498  1.26290  1.26472    1.26472
# 2022-01-25 08:30:50+00:00  1.26447  1.26447  1.26447  1.26447    1.26447
#
#                            Volume    Kalman    MA_200     MA_50
# Datetime
# 2022-01-25 07:30:00+00:00       0  1.264164  1.258992  1.263985
# 2022-01-25 07:45:00+00:00       0  1.264158  1.259047  1.263955
# 2022-01-25 08:00:00+00:00       0  1.264157  1.259100  1.263910
# 2022-01-25 08:15:00+00:00       0  1.264166  1.259160  1.263910
# 2022-01-25 08:30:50+00:00       0  1.264169  1.259224  1.263919

# %%
# borrar una columna  
del data["Adj Close"]

# %%
print (data)
# Out:
#                               Open     High      Low    Close  Volume  \
# Datetime
# 2021-12-27 00:00:00+00:00  1.28150  1.28171  1.28080  1.28154       0
# 2021-12-27 00:15:00+00:00  1.28160  1.28166  1.28090  1.28128       0
# 2021-12-27 00:30:00+00:00  1.28124  1.28160  1.28090  1.28152       0
# 2021-12-27 00:45:00+00:00  1.28150  1.28177  1.28110  1.28145       0
# 2021-12-27 01:00:00+00:00  1.28143  1.28180  1.28100  1.28139       0
# ...                            ...      ...      ...      ...     ...
# 2022-01-25 07:30:00+00:00  1.26428  1.26458  1.26340  1.26400       0
# 2022-01-25 07:45:00+00:00  1.26407  1.26427  1.26340  1.26370       0
# 2022-01-25 08:00:00+00:00  1.26381  1.26493  1.26290  1.26320       0
# 2022-01-25 08:15:00+00:00  1.26337  1.26498  1.26290  1.26472       0
# 2022-01-25 08:30:50+00:00  1.26447  1.26447  1.26447  1.26447       0
#
#                              Kalman    MA_200     MA_50
# Datetime
# 2021-12-27 00:00:00+00:00  1.169961       NaN       NaN
# 2021-12-27 00:15:00+00:00  1.180545       NaN       NaN
# 2021-12-27 00:30:00+00:00  1.190121       NaN       NaN
# 2021-12-27 00:45:00+00:00  1.198784       NaN       NaN
# 2021-12-27 01:00:00+00:00  1.206620       NaN       NaN
# ...                             ...       ...       ...
# 2022-01-25 07:30:00+00:00  1.264164  1.258992  1.263985
# 2022-01-25 07:45:00+00:00  1.264158  1.259047  1.263955
# 2022-01-25 08:00:00+00:00  1.264157  1.259100  1.263910
# 2022-01-25 08:15:00+00:00  1.264166  1.259160  1.263910
# 2022-01-25 08:30:50+00:00  1.264169  1.259224  1.263919
#
# [2025 rows x 8 columns]

# %%
indiceLast_ = (len(data)-1)

# %%
indiceLast_
# Out:
# 2024

# %%
#print (data.iloc[indiceLast_][kalman_])

# %%
price_ = data.columns.get_loc("Close")  
kalman_ = data.columns.get_loc("Kalman")  
volumen_ = data.columns.get_loc("Volume")

# %%
contador =0
señal =False
for i in range(5):
    #Precio por encima de Kalman cuento uno en el contador
    if (data.iloc[(indiceLast_-i),price_] > data.iloc[(indiceLast_),kalman_]):
        contador += 1
        data.iloc[(indiceLast_-i),volumen_] =99.0

if (contador > 2): 
    señal=True

# %%
def checkKalman(instrumento_ ='app'):
    #Interval required 1 minute
    try:
        data = yf.download(tickers=instrumento_, period='6mo', interval='1h')  #  1h 3mo 15m https://algotrading101.com/learn/yfinance-guide/
    except:
        print('instrumento no existe')
    
    del data["Adj Close"]
    data['Kalman']= quant_j3.kalmanIndicator(data,paraA_=200,paraB_=50,instrumento=instrumento_)

    indiceLast_ = (len(data)-2)    ### ojo parece que da la ultima version cotizada, no la ultima hora
    price_ = data.columns.get_loc("Close")  
    kalman_ = data.columns.get_loc("Kalman")  
    volumen_ = data.columns.get_loc("Volume") 
    open_ = data.columns.get_loc("Open")  


    print(instrumento_)
    
    contador =0
    señal =fuera
    
    # Compruebo Kalman
    # Según la estrategia tenemos que buscar, dos velas alcistas no necesariamente consecutivas entre una ventana anterior. 
    # estas velas alcistas detras de una condicion de reset (dos velas rojas por debajo kalman)
    
    for i in range(5):
        #vela verde por encima de kalman entera
        if (data.iloc[(indiceLast_-i),price_] > data.iloc[(indiceLast_),kalman_]  and  
            data.iloc[(indiceLast_-i),open_] > data.iloc[(indiceLast_),kalman_]  and
            data.iloc[(indiceLast_-i),price_] > data.iloc[(indiceLast_),open_]):
            contador += 1
            data.iloc[(indiceLast_-i),volumen_] =99.0
    #tres velas verdes y la ultima verde
    if (contador > 2  and
       data.iloc[(indiceLast_),price_] > data.iloc[(indiceLast_),kalman_]  and 
       data.iloc[(indiceLast_-i),open_] > data.iloc[(indiceLast_),kalman_] ): 
        señal=dentro 
    
    #Compruebo Media 200 velas positiva
    #quant_j3.MovingAverage(data,long_=200,short_=50)
    data2= quant_j3.MovingAverage(data,long_=200,short_=50)
    # 1.- MEDIA DE 200 SESIONES ACCENDENTE
    #   Calculamos de la media aritmetica la regresion lineal para ver la esencia
    ma200_=data2.columns.get_loc("MA_200")
    data_aux2= data2.iloc[-200:, ma200_]
    data_aux2.dropna(inplace=True)  
    # 3.1.- Calculamos media de las ultimas 'n' sesiones y la regresion lineal
    coef_ema200_, intercept_ema200_ =quant_j3.linearRegresion_J3(data_aux2) #+'  de ema200') 
    
    if (señal ==dentro):
        if (coef_ema200_ > 0): 
            señal=dentro     
        else:
            señal =fuera
    
   
    print(instrumento_,señal)
    print ('Precio', data.iloc[(indiceLast_-i),price_], '*************  ''Kalman', data.iloc[(indiceLast_-i),kalman_])
    print ('checkIN Time',data.index[indiceLast_])
    
    if (señal ==dentro):
        print ('Entramos del mercado')
        telegram_send("3.Señal Kalman (15min)b1.0.\n"+ instrumento_ +"\nPrecio = " + str(data.iloc[(indiceLast_-i),price_]) + "\n***  Kalman level = "+ str(data.iloc[(indiceLast_-i),kalman_])+
                     "\nTime: " + str(data.index[indiceLast_]))
        sleep(5)
        
        
    
    return señal

# %%
def checkKalman_OUT(instrumento_ ='app'):
    #Interval required 1 minute
    try:
        data = yf.download(tickers=instrumento_, period='6mo', interval='1h')  #5m
    except:
        print('instrumento no existe')
    
    del data["Adj Close"]
    data['Kalman']= quant_j3.kalmanIndicator(data,paraA_=200,paraB_=50,instrumento=instrumento_)

    indiceLast_ = (len(data)-2)    ### ojo parece que da la ultima version cotizada, no la ultima hora
    price_ = data.columns.get_loc("Close")  
    kalman_ = data.columns.get_loc("Kalman")  
    volumen_ = data.columns.get_loc("Volume") 
    open_ = data.columns.get_loc("Open")  

    print(instrumento_)
    
    contador =0
    señal =dentro
    
    # Compruebo Kalman
    # Borro la señal si dos velas por debajo de kalman
    
    for i in range(5):
        #Precio por debajo de Kalman cuento uno en el contador
        if (data.iloc[(indiceLast_-i),price_] < data.iloc[(indiceLast_),kalman_] and
           data.iloc[(indiceLast_-i),open_] < data.iloc[(indiceLast_),kalman_] and
           data.iloc[(indiceLast_-i),price_] < data.iloc[(indiceLast_),open_]):
            contador += 1
            data.iloc[(indiceLast_-i),volumen_] =99.0
    if (contador > 3): 
        señal=fuera
        print ('Salimos del mercado')
    
    
    
    print(instrumento_,señal)

    print ('checkOUT Time',data.index[indiceLast_])

    return señal

# %%
print(checkKalman('corn'))
# Out:
# [*********************100%***********************]  1 of 1 completed
# corn
# Coefficients:
#  [0.00217119]
# Independent term:
#  21.356339135318017
# corn False
# Precio 22.100000381469727 *************  Kalman 22.147446021321354
# checkIN Time 2022-01-24 14:30:00-05:00
# False

# %%
print(checkKalman_OUT('corn'))
# Out:
# [*********************100%***********************]  1 of 1 completed
# corn
# corn True
# checkOUT Time 2022-01-24 14:30:00-05:00
# True

# %%
data
# Out:
#                               Open     High      Low    Close  Volume  \
# Datetime
# 2021-12-27 00:00:00+00:00  1.28150  1.28171  1.28080  1.28154       0
# 2021-12-27 00:15:00+00:00  1.28160  1.28166  1.28090  1.28128       0
# 2021-12-27 00:30:00+00:00  1.28124  1.28160  1.28090  1.28152       0
# 2021-12-27 00:45:00+00:00  1.28150  1.28177  1.28110  1.28145       0
# 2021-12-27 01:00:00+00:00  1.28143  1.28180  1.28100  1.28139       0
# ...                            ...      ...      ...      ...     ...
# 2022-01-25 07:30:00+00:00  1.26428  1.26458  1.26340  1.26400       0
# 2022-01-25 07:45:00+00:00  1.26407  1.26427  1.26340  1.26370       0
# 2022-01-25 08:00:00+00:00  1.26381  1.26493  1.26290  1.26320       0
# 2022-01-25 08:15:00+00:00  1.26337  1.26498  1.26290  1.26472      99
# 2022-01-25 08:30:50+00:00  1.26447  1.26447  1.26447  1.26447      99
#
#                              Kalman    MA_200     MA_50
# Datetime
# 2021-12-27 00:00:00+00:00  1.169961       NaN       NaN
# 2021-12-27 00:15:00+00:00  1.180545       NaN       NaN
# 2021-12-27 00:30:00+00:00  1.190121       NaN       NaN
# 2021-12-27 00:45:00+00:00  1.198784       NaN       NaN
# 2021-12-27 01:00:00+00:00  1.206620       NaN       NaN
# ...                             ...       ...       ...
# 2022-01-25 07:30:00+00:00  1.264164  1.258992  1.263985
# 2022-01-25 07:45:00+00:00  1.264158  1.259047  1.263955
# 2022-01-25 08:00:00+00:00  1.264157  1.259100  1.263910
# 2022-01-25 08:15:00+00:00  1.264166  1.259160  1.263910
# 2022-01-25 08:30:50+00:00  1.264169  1.259224  1.263919
#
# [2025 rows x 8 columns]

# %%
#TICKERS
tickers5 = ['AAPL', 'MSFT', '^GSPC', 'ELE.MC','SAN.MC', 'BBVA.MC']  #,'ANA.MC','MTS.MC','GRF.MC']  # apple,microsfoft,sp500, endesa
tickers__ = ['MTS.MC'] 
tickers = ['FER.MC','COL.MC','IBE.MC','NTGY.MC','SAB.MC','ACX.MC','PHM.MC','SAN.MC','MRL.MC','TEF.MC','AMS.MC','VIS.MC','MTS.MC','MAP.MC','CLNX.MC','BBVA.MC','CABK.MC','MEL.MC','AENA.MC','BKT.MC','REE.MC','FDR.MC','ACS.MC','ITX.MC','ENG.MC','ANA.MC','ELE.MC','GRF.MC','IAG.MC','SGRE.MC']
tickersCurrencies =['EURUSD=X', 'EURGBP=X' ,'EURCHF=X', 'EURJPY=X', 'EURNZD=X', 'EURCAD=X', 'EURAUD=X','USDCHF=X', 
         'USDJPY=X','GBPCAD=X', 'GBPUSD=X', 'GBPJPY=X', 'GBPCHF=X', 'GBPNZD=X', 'GBPAUD=X',
         'NZDCAD=X', 'NZDUSD=X', 'NZDCHF=X', 'NZDJPY=X','JPY=X','EURSEK=X','USDCAD=X','AUDCAD=X',
         'KC=F','HG=F', 'CORN', 'CL=F', 'ZS=F','ZW=F','GC=F','X','ZW=F',
         'ETH-USD','PFE',
        '^IXIC', '^GSPC', '^GDAXI'
         ]
Currencies_dict = dict.fromkeys(tickersCurrencies, True) #convertir el array en un diccionario


while(True):
    #VALORES DEL IBEX 
    #for i in range(len(tickers)): 
                    #print(tickers[i])
        #checkKalman(tickers[i])
        #sleep(1)


    #CURRENCIES
    for i in range(len(tickersCurrencies)): 
                #print(tickersCurrencies[i])
        if (Currencies_dict[tickersCurrencies[i]]==fuera):
            señal= checkKalman(tickersCurrencies[i])     
            Currencies_dict[tickersCurrencies[i]]=señal
            sleep(1)
        else: 
            señal= checkKalman_OUT(tickersCurrencies[i])     
            Currencies_dict[tickersCurrencies[i]]=señal
            sleep(1)            
        
"""
VALORES DEL SP50
sp_url= 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
sp=pd.read_html(sp_url,header=0)[0]
print (sp.info())

for i in range(len(sp)):
     symbol=sp.iloc[i,0] 
     #df = yf.download(symbol, start, end)
     print(symbol)
     checkKalman(symbol)
     #time.sleep (1)
"""
# Out:
# [*********************100%***********************]  1 of 1 completed
# EURUSD=X
# EURUSD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURGBP=X
# EURGBP=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCHF=X
# EURCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURJPY=X
# EURJPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURNZD=X
# EURNZD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCAD=X
# EURCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURAUD=X
# EURAUD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCHF=X
# USDCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDJPY=X
# USDJPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCAD=X
# GBPCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPUSD=X
# Salimos del mercado
# GBPUSD=X False
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPJPY=X
# GBPJPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCHF=X
# GBPCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPNZD=X
# GBPNZD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPAUD=X
# GBPAUD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCAD=X
# NZDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDUSD=X
# NZDUSD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCHF=X
# NZDCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDJPY=X
# Salimos del mercado
# NZDJPY=X False
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# JPY=X
# JPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURSEK=X
# EURSEK=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCAD=X
# USDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# AUDCAD=X
# AUDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# KC=F
# KC=F True
# checkOUT Time 2022-01-24 13:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# HG=F
# HG=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CORN
# CORN True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CL=F
# CL=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZS=F
# ZS=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# GC=F
# GC=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# X
# X True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ETH-USD
# ETH-USD True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# PFE
# PFE True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^IXIC
# ^IXIC True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GSPC
# Salimos del mercado
# ^GSPC False
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GDAXI
# Salimos del mercado
# ^GDAXI False
# checkOUT Time 2022-01-25 09:00:00+01:00
# [*********************100%***********************]  1 of 1 completed
# EURUSD=X
# EURUSD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURGBP=X
# EURGBP=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCHF=X
# EURCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURJPY=X
# Salimos del mercado
# EURJPY=X False
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURNZD=X
# EURNZD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCAD=X
# EURCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURAUD=X
# EURAUD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCHF=X
# USDCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDJPY=X
# USDJPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCAD=X
# GBPCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPUSD=X
# Coefficients:
#  [3.51163721e-05]
# Independent term:
#  1.3588334164296512
# GBPUSD=X False
# Precio 1.3470009565353394 *************  Kalman 1.348735884125272
# checkIN Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPJPY=X
# GBPJPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCHF=X
# GBPCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPNZD=X
# GBPNZD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPAUD=X
# GBPAUD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCAD=X
# NZDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDUSD=X
# NZDUSD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCHF=X
# NZDCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDJPY=X
# Coefficients:
#  [-0.00480817]
# Independent term:
#  78.53928219320952
# NZDJPY=X False
# Precio 75.86499786376953 *************  Kalman 76.11657016163709
# checkIN Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# JPY=X
# JPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURSEK=X
# EURSEK=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCAD=X
# USDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# AUDCAD=X
# AUDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# KC=F
# KC=F True
# checkOUT Time 2022-01-24 13:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# HG=F
# HG=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CORN
# CORN True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CL=F
# CL=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZS=F
# ZS=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# GC=F
# GC=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# X
# X True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ETH-USD
# ETH-USD True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# PFE
# PFE True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^IXIC
# ^IXIC True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GSPC
# Coefficients:
#  [0.21846259]
# Independent term:
#  4652.628173087686
# ^GSPC False
# Precio 4289.85009765625 *************  Kalman 4418.331241673213
# checkIN Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GDAXI
# Coefficients:
#  [2.09102872]
# Independent term:
#  15491.13269561203
# ^GDAXI False
# Precio 15166.650390625 *************  Kalman 15388.313085134338
# checkIN Time 2022-01-25 09:00:00+01:00
# [*********************100%***********************]  1 of 1 completed
# EURUSD=X
# EURUSD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURGBP=X
# EURGBP=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCHF=X
# EURCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURJPY=X
# Coefficients:
#  [-0.00533244]
# Independent term:
#  131.16986714544723
# EURJPY=X False
# Precio 128.6300048828125 *************  Kalman 128.80376250856517
# checkIN Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURNZD=X
# EURNZD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCAD=X
# EURCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURAUD=X
# EURAUD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCHF=X
# USDCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDJPY=X
# USDJPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCAD=X
# GBPCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPUSD=X
# Coefficients:
#  [3.51161833e-05]
# Independent term:
#  1.3588334288490351
# GBPUSD=X False
# Precio 1.3470009565353394 *************  Kalman 1.3487305407259855
# checkIN Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPJPY=X
# GBPJPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCHF=X
# GBPCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPNZD=X
# GBPNZD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPAUD=X
# GBPAUD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCAD=X
# NZDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDUSD=X
# NZDUSD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCHF=X
# NZDCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDJPY=X
# Coefficients:
#  [-0.00480819]
# Independent term:
#  78.539283024842
# NZDJPY=X False
# Precio 75.86499786376953 *************  Kalman 76.11598935938872
# checkIN Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# JPY=X
# JPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURSEK=X
# EURSEK=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCAD=X
# USDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# AUDCAD=X
# AUDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# KC=F
# KC=F True
# checkOUT Time 2022-01-24 13:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# HG=F
# HG=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CORN
# CORN True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CL=F
# CL=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZS=F
# ZS=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# GC=F
# GC=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# X
# X True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ETH-USD
# ETH-USD True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# PFE
# PFE True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^IXIC
# ^IXIC True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GSPC
# Coefficients:
#  [0.21846259]
# Independent term:
#  4652.628173087686
# ^GSPC False
# Precio 4289.85009765625 *************  Kalman 4418.331241673213
# checkIN Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GDAXI
# Coefficients:
#  [2.09106482]
# Independent term:
#  15491.130315668726
# ^GDAXI False
# Precio 15166.650390625 *************  Kalman 15390.42981870609
# checkIN Time 2022-01-25 09:00:00+01:00
# [*********************100%***********************]  1 of 1 completed
# EURUSD=X
# EURUSD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURGBP=X
# EURGBP=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCHF=X
# EURCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURJPY=X
# Coefficients:
#  [-0.00533254]
# Independent term:
#  131.1698736601531
# EURJPY=X False
# Precio 128.6300048828125 *************  Kalman 128.7987734482035
# checkIN Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURNZD=X
# EURNZD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCAD=X
# EURCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURAUD=X
# EURAUD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCHF=X
# USDCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDJPY=X
# USDJPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCAD=X
# GBPCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPUSD=X
# Coefficients:
#  [3.51157497e-05]
# Independent term:
#  1.35883345743996
# GBPUSD=X False
# Precio 1.3470009565353394 *************  Kalman 1.348702159063891
# checkIN Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPJPY=X
# GBPJPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCHF=X
# GBPCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPNZD=X
# GBPNZD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPAUD=X
# GBPAUD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCAD=X
# NZDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDUSD=X
# NZDUSD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCHF=X
# NZDCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDJPY=X
# Coefficients:
#  [-0.00480819]
# Independent term:
#  78.53928361332454
# NZDJPY=X False
# Precio 75.86499786376953 *************  Kalman 76.11552519573254
# checkIN Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# JPY=X
# JPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURSEK=X
# EURSEK=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCAD=X
# USDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# AUDCAD=X
# AUDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# KC=F
# KC=F True
# checkOUT Time 2022-01-24 13:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# HG=F
# HG=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CORN
# CORN True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CL=F
# CL=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZS=F
# ZS=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# GC=F
# GC=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# X
# X True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ETH-USD
# ETH-USD True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# PFE
# PFE True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^IXIC
# ^IXIC True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GSPC
# Coefficients:
#  [0.21846259]
# Independent term:
#  4652.628173087686
# ^GSPC False
# Precio 4289.85009765625 *************  Kalman 4418.331241673213
# checkIN Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GDAXI
# Coefficients:
#  [2.09099117]
# Independent term:
#  15491.13517052166
# ^GDAXI False
# Precio 15166.650390625 *************  Kalman 15386.054703317499
# checkIN Time 2022-01-25 09:00:00+01:00
# [*********************100%***********************]  1 of 1 completed
# EURUSD=X
# EURUSD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURGBP=X
# EURGBP=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCHF=X
# EURCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURJPY=X
# Coefficients:
#  [-0.00533259]
# Independent term:
#  131.16987660928982
# EURJPY=X False
# Precio 128.6300048828125 *************  Kalman 128.79582455056408
# checkIN Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURNZD=X
# EURNZD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCAD=X
# EURCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURAUD=X
# EURAUD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCHF=X
# USDCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDJPY=X
# USDJPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCAD=X
# GBPCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPUSD=X
# Coefficients:
#  [3.51151955e-05]
# Independent term:
#  1.3588334939605267
# GBPUSD=X False
# Precio 1.3470009565353394 *************  Kalman 1.3486726616396525
# checkIN Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPJPY=X
# GBPJPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCHF=X
# GBPCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPNZD=X
# GBPNZD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPAUD=X
# GBPAUD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCAD=X
# NZDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDUSD=X
# NZDUSD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCHF=X
# NZDCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDJPY=X
# Coefficients:
#  [-0.00480816]
# Independent term:
#  78.53928121128368
# NZDJPY=X False
# Precio 75.86499786376953 *************  Kalman 76.11743907776255
# checkIN Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# JPY=X
# JPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURSEK=X
# EURSEK=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCAD=X
# USDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# AUDCAD=X
# AUDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# KC=F
# KC=F True
# checkOUT Time 2022-01-24 13:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# HG=F
# HG=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CORN
# CORN True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CL=F
# CL=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZS=F
# ZS=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# GC=F
# GC=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# X
# X True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ETH-USD
# ETH-USD True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# PFE
# PFE True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^IXIC
# ^IXIC True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GSPC
# Coefficients:
#  [0.21846259]
# Independent term:
#  4652.628173087686
# ^GSPC False
# Precio 4289.85009765625 *************  Kalman 4418.331241673213
# checkIN Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GDAXI
# Coefficients:
#  [2.09097165]
# Independent term:
#  15491.136454331856
# ^GDAXI False
# Precio 15166.650390625 *************  Kalman 15385.566498233755
# checkIN Time 2022-01-25 09:00:00+01:00
# [*********************100%***********************]  1 of 1 completed
# EURUSD=X
# EURUSD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURGBP=X
# EURGBP=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCHF=X
# EURCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURJPY=X
# Coefficients:
#  [-0.00533253]
# Independent term:
#  131.16987257044778
# EURJPY=X False
# Precio 128.6300048828125 *************  Kalman 128.80055666436684
# checkIN Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURNZD=X
# EURNZD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCAD=X
# EURCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURAUD=X
# EURAUD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCHF=X
# USDCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDJPY=X
# USDJPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCAD=X
# GBPCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPUSD=X
# Coefficients:
#  [3.51148721e-05]
# Independent term:
#  1.3588335152351145
# GBPUSD=X False
# Precio 1.3470009565353394 *************  Kalman 1.348663065906349
# checkIN Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPJPY=X
# GBPJPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCHF=X
# GBPCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPNZD=X
# GBPNZD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPAUD=X
# GBPAUD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCAD=X
# NZDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDUSD=X
# NZDUSD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCHF=X
# NZDCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDJPY=X
# Coefficients:
#  [-0.00480809]
# Independent term:
#  78.5392769956845
# NZDJPY=X False
# Precio 75.86499786376953 *************  Kalman 76.12091598825273
# checkIN Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# JPY=X
# JPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURSEK=X
# EURSEK=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCAD=X
# USDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# AUDCAD=X
# AUDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# KC=F
# KC=F True
# checkOUT Time 2022-01-24 13:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# HG=F
# HG=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CORN
# CORN True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CL=F
# CL=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZS=F
# ZS=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# GC=F
# GC=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# X
# X True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ETH-USD
# ETH-USD True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# PFE
# PFE True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^IXIC
# ^IXIC True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GSPC
# Coefficients:
#  [0.21846259]
# Independent term:
#  4652.628173087686
# ^GSPC False
# Precio 4289.85009765625 *************  Kalman 4418.331241673213
# checkIN Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GDAXI
# Coefficients:
#  [2.09093981]
# Independent term:
#  15491.138552904178
# ^GDAXI False
# Precio 15166.650390625 *************  Kalman 15383.789541915508
# checkIN Time 2022-01-25 09:00:00+01:00
# [*********************100%***********************]  1 of 1 completed
# EURUSD=X
# EURUSD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURGBP=X
# EURGBP=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCHF=X
# EURCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURJPY=X
# Coefficients:
#  [-0.00533252]
# Independent term:
#  131.16987223369543
# EURJPY=X False
# Precio 128.6300048828125 *************  Kalman 128.80033230722583
# checkIN Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURNZD=X
# EURNZD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCAD=X
# EURCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURAUD=X
# EURAUD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCHF=X
# USDCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDJPY=X
# USDJPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCAD=X
# GBPCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPUSD=X
# Coefficients:
#  [3.51154263e-05]
# Independent term:
#  1.3588334787203307
# GBPUSD=X False
# Precio 1.3470009565353394 *************  Kalman 1.348692563261794
# checkIN Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPJPY=X
# GBPJPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCHF=X
# GBPCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPNZD=X
# GBPNZD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPAUD=X
# GBPAUD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCAD=X
# NZDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDUSD=X
# NZDUSD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCHF=X
# NZDCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDJPY=X
# Coefficients:
#  [-0.00480805]
# Independent term:
#  78.53927405550374
# NZDJPY=X False
# Precio 75.86499786376953 *************  Kalman 76.12317925332219
# checkIN Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# JPY=X
# JPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURSEK=X
# EURSEK=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCAD=X
# USDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# AUDCAD=X
# AUDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# KC=F
# KC=F True
# checkOUT Time 2022-01-24 13:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# HG=F
# HG=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CORN
# CORN True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CL=F
# CL=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZS=F
# ZS=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# GC=F
# GC=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# X
# X True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ETH-USD
# ETH-USD True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# PFE
# PFE True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^IXIC
# ^IXIC True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GSPC
# Coefficients:
#  [0.21846259]
# Independent term:
#  4652.628173087686
# ^GSPC False
# Precio 4289.85009765625 *************  Kalman 4418.331241673213
# checkIN Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GDAXI
# Coefficients:
#  [2.09089612]
# Independent term:
#  15491.141431393567
# ^GDAXI False
# Precio 15166.650390625 *************  Kalman 15381.556704989409
# checkIN Time 2022-01-25 09:00:00+01:00
# [*********************100%***********************]  1 of 1 completed
# EURUSD=X
# EURUSD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURGBP=X
# EURGBP=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCHF=X
# EURCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURJPY=X
# Coefficients:
#  [-0.00533242]
# Independent term:
#  131.16986586629383
# EURJPY=X False
# Precio 128.6300048828125 *************  Kalman 128.80514877839784
# checkIN Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURNZD=X
# EURNZD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCAD=X
# EURCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURAUD=X
# EURAUD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCHF=X
# USDCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDJPY=X
# USDJPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCAD=X
# GBPCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPUSD=X
# Coefficients:
#  [3.51158593e-05]
# Independent term:
#  1.358833450175933
# GBPUSD=X False
# Precio 1.3470009565353394 *************  Kalman 1.3487178256191898
# checkIN Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPJPY=X
# GBPJPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCHF=X
# GBPCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPNZD=X
# GBPNZD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPAUD=X
# GBPAUD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCAD=X
# NZDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDUSD=X
# NZDUSD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCHF=X
# NZDCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDJPY=X
# Coefficients:
#  [-0.00480801]
# Independent term:
#  78.53927160647378
# NZDJPY=X False
# Precio 75.86499786376953 *************  Kalman 76.12503616771124
# checkIN Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# JPY=X
# JPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURSEK=X
# EURSEK=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCAD=X
# USDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# AUDCAD=X
# AUDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# KC=F
# KC=F True
# checkOUT Time 2022-01-24 13:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# HG=F
# HG=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CORN
# CORN True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CL=F
# CL=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZS=F
# ZS=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# GC=F
# GC=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# X
# X True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ETH-USD
# ETH-USD True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# PFE
# PFE True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^IXIC
# ^IXIC True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GSPC
# Coefficients:
#  [0.21846259]
# Independent term:
#  4652.628173087686
# ^GSPC False
# Precio 4289.85009765625 *************  Kalman 4418.331241673213
# checkIN Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GDAXI
# Coefficients:
#  [2.09084403]
# Independent term:
#  15491.1448655186
# ^GDAXI False
# Precio 15166.650390625 *************  Kalman 15378.412394825
# checkIN Time 2022-01-25 09:00:00+01:00
# [*********************100%***********************]  1 of 1 completed
# EURUSD=X
# EURUSD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURGBP=X
# EURGBP=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCHF=X
# EURCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURJPY=X
# Coefficients:
#  [-0.00533236]
# Independent term:
#  131.16986134936204
# EURJPY=X False
# Precio 128.6300048828125 *************  Kalman 128.80931567141
# checkIN Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURNZD=X
# EURNZD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCAD=X
# EURCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURAUD=X
# EURAUD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCHF=X
# USDCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDJPY=X
# USDJPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCAD=X
# GBPCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPUSD=X
# Coefficients:
#  [3.51171167e-05]
# Independent term:
#  1.358833367346027
# GBPUSD=X False
# Precio 1.3470009565353394 *************  Kalman 1.3487790682960206
# checkIN Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPJPY=X
# GBPJPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCHF=X
# GBPCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPNZD=X
# GBPNZD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPAUD=X
# GBPAUD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCAD=X
# NZDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDUSD=X
# NZDUSD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCHF=X
# NZDCHF=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDJPY=X
# Coefficients:
#  [-0.00480792]
# Independent term:
#  78.53926548595143
# NZDJPY=X False
# Precio 75.86499786376953 *************  Kalman 76.12945050166852
# checkIN Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# JPY=X
# JPY=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURSEK=X
# EURSEK=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCAD=X
# USDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# AUDCAD=X
# AUDCAD=X True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# KC=F
# KC=F True
# checkOUT Time 2022-01-24 13:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# HG=F
# HG=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CORN
# CORN True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CL=F
# CL=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZS=F
# ZS=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# GC=F
# GC=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# X
# X True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-25 03:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ETH-USD
# ETH-USD True
# checkOUT Time 2022-01-25 08:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# PFE
# PFE True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^IXIC
# ^IXIC True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GSPC
# Coefficients:
#  [0.21846259]
# Independent term:
#  4652.628173087686
# ^GSPC False
# Precio 4289.85009765625 *************  Kalman 4418.331241673213
# checkIN Time 2022-01-24 14:30:00-05:00
# ...
# EURGBP=X
# EURGBP=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCHF=X
# Coefficients:
#  [-9.24732145e-06]
# Independent term:
#  1.043941892920501
# EURCHF=X False
# Precio 1.0362299680709839 *************  Kalman 1.0355300037137753
# checkIN Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURJPY=X
# Coefficients:
#  [-0.00547557]
# Independent term:
#  131.1732911091819
# EURJPY=X False
# Precio 128.73500061035156 *************  Kalman 128.7845768916722
# checkIN Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURNZD=X
# EURNZD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCAD=X
# EURCAD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURAUD=X
# EURAUD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCHF=X
# Coefficients:
#  [-2.65972063e-05]
# Independent term:
#  0.9198825288946059
# USDCHF=X False
# Precio 0.9165400266647339 *************  Kalman 0.9157003465208768
# checkIN Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDJPY=X
# USDJPY=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCAD=X
# GBPCAD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPUSD=X
# Coefficients:
#  [3.30491916e-05]
# Independent term:
#  1.3590970112692955
# GBPUSD=X False
# Precio 1.3481813669204712 *************  Kalman 1.3484151844735568
# checkIN Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPJPY=X
# Coefficients:
#  [-0.00594712]
# Independent term:
#  157.08129837393693
# GBPJPY=X False
# Precio 153.50599670410156 *************  Kalman 153.55329104161734
# checkIN Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCHF=X
# Coefficients:
#  [-6.27305147e-06]
# Independent term:
#  1.250135345177241
# GBPCHF=X False
# Precio 1.2356699705123901 *************  Kalman 1.2347406668182055
# checkIN Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPNZD=X
# GBPNZD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPAUD=X
# GBPAUD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCAD=X
# NZDCAD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDUSD=X
# Coefficients:
#  [-4.8621493e-07]
# Independent term:
#  0.6797860294699223
# NZDUSD=X False
# Precio 0.6677796840667725 *************  Kalman 0.6687543431666271
# checkIN Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCHF=X
# NZDCHF=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDJPY=X
# Coefficients:
#  [-0.00489893]
# Independent term:
#  78.53785510868813
# NZDJPY=X False
# Precio 76.01599884033203 *************  Kalman 76.13026664128627
# checkIN Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# JPY=X
# JPY=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURSEK=X
# EURSEK=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCAD=X
# USDCAD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# AUDCAD=X
# AUDCAD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# KC=F
# Coefficients:
#  [-0.01863152]
# Independent term:
#  235.27627754218256
# KC=F False
# Precio 233.75 *************  Kalman 236.4921343198812
# checkIN Time 2022-01-25 05:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# HG=F
# HG=F True
# checkOUT Time 2022-01-25 05:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CORN
# CORN True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CL=F
# Coefficients:
#  [0.03579118]
# Independent term:
#  77.01277496362373
# CL=F False
# Precio 83.95999908447266 *************  Kalman 84.00531352167282
# checkIN Time 2022-01-25 05:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZS=F
# ZS=F True
# checkOUT Time 2022-01-25 05:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-25 05:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# GC=F
# GC=F True
# checkOUT Time 2022-01-25 05:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# X
# X True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-25 05:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ETH-USD
# ETH-USD True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# PFE
# PFE True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^IXIC
# ^IXIC True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GSPC
# Coefficients:
#  [0.21846259]
# Independent term:
#  4652.628173087686
# ^GSPC False
# Precio 4289.85009765625 *************  Kalman 4418.331241673213
# checkIN Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GDAXI
# Coefficients:
#  [2.09795624]
# Independent term:
#  15493.248769871587
# ^GDAXI False
# Precio 15062.26953125 *************  Kalman 15342.87802102584
# checkIN Time 2022-01-25 11:00:00+01:00
# [*********************100%***********************]  1 of 1 completed
# EURUSD=X
# EURUSD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURGBP=X
# EURGBP=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCHF=X
# Coefficients:
#  [-9.24648872e-06]
# Independent term:
#  1.0439418380636776
# EURCHF=X False
# Precio 1.0362299680709839 *************  Kalman 1.0355712137168036
# checkIN Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURJPY=X
# Coefficients:
#  [-0.0054755]
# Independent term:
#  131.17328654936603
# EURJPY=X False
# Precio 128.73500061035156 *************  Kalman 128.78840087814228
# checkIN Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURNZD=X
# EURNZD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCAD=X
# EURCAD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURAUD=X
# EURAUD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCHF=X
# Coefficients:
#  [-2.65964548e-05]
# Independent term:
#  0.9198824793676387
# USDCHF=X False
# Precio 0.9165400266647339 *************  Kalman 0.9157420617091387
# checkIN Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDJPY=X
# USDJPY=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCAD=X
# GBPCAD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPUSD=X
# Coefficients:
#  [3.30495424e-05]
# Independent term:
#  1.3590969881557706
# GBPUSD=X False
# Precio 1.3481813669204712 *************  Kalman 1.348434103861782
# checkIN Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPJPY=X
# Coefficients:
#  [-0.00594707]
# Independent term:
#  157.08129558554123
# GBPJPY=X False
# Precio 153.50599670410156 *************  Kalman 153.55515199336068
# checkIN Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCHF=X
# Coefficients:
#  [-6.27255359e-06]
# Independent term:
#  1.2501353123899714
# GBPCHF=X False
# Precio 1.2356699705123901 *************  Kalman 1.234762765567874
# checkIN Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPNZD=X
# GBPNZD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPAUD=X
# GBPAUD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCAD=X
# NZDCAD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDUSD=X
# Coefficients:
#  [-4.86081754e-07]
# Independent term:
#  0.6797860206802835
# NZDUSD=X False
# Precio 0.6677796840667725 *************  Kalman 0.668764641556971
# checkIN Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCHF=X
# NZDCHF=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDJPY=X
# Coefficients:
#  [-0.00489891]
# Independent term:
#  78.53785417822654
# NZDJPY=X False
# Precio 76.01599884033203 *************  Kalman 76.1309065817488
# checkIN Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# JPY=X
# JPY=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURSEK=X
# EURSEK=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCAD=X
# USDCAD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# AUDCAD=X
# AUDCAD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# KC=F
# Coefficients:
#  [-0.01863163]
# Independent term:
#  235.27628489337752
# KC=F False
# Precio 233.75 *************  Kalman 236.4863342928561
# checkIN Time 2022-01-25 05:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# HG=F
# HG=F True
# checkOUT Time 2022-01-25 05:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CORN
# CORN True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# CL=F
# Coefficients:
#  [0.03579109]
# Independent term:
#  77.01278133699786
# CL=F False
# Precio 83.95999908447266 *************  Kalman 84.0000964718721
# checkIN Time 2022-01-25 05:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZS=F
# ZS=F True
# checkOUT Time 2022-01-25 05:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-25 05:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# GC=F
# GC=F True
# checkOUT Time 2022-01-25 05:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# X
# X True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ZW=F
# ZW=F True
# checkOUT Time 2022-01-25 05:00:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ETH-USD
# ETH-USD True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# PFE
# PFE True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^IXIC
# ^IXIC True
# checkOUT Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GSPC
# Coefficients:
#  [0.21846259]
# Independent term:
#  4652.628173087686
# ^GSPC False
# Precio 4289.85009765625 *************  Kalman 4418.331241673213
# checkIN Time 2022-01-24 14:30:00-05:00
# [*********************100%***********************]  1 of 1 completed
# ^GDAXI
# Coefficients:
#  [2.09792061]
# Independent term:
#  15493.251116863192
# ^GDAXI False
# Precio 15062.26953125 *************  Kalman 15341.235280769062
# checkIN Time 2022-01-25 11:00:00+01:00
# [*********************100%***********************]  1 of 1 completed
# EURUSD=X
# EURUSD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURGBP=X
# EURGBP=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCHF=X
# Coefficients:
#  [-9.24660751e-06]
# Independent term:
#  1.0439418458835403
# EURCHF=X False
# Precio 1.0362299680709839 *************  Kalman 1.0355665515109787
# checkIN Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURJPY=X
# Coefficients:
#  [-0.00547548]
# Independent term:
#  131.17328556781598
# EURJPY=X False
# Precio 128.73500061035156 *************  Kalman 128.78932600903238
# checkIN Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURNZD=X
# EURNZD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURCAD=X
# EURCAD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# EURAUD=X
# EURAUD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDCHF=X
# Coefficients:
#  [-2.65967898e-05]
# Independent term:
#  0.9198825014520938
# USDCHF=X False
# Precio 0.9165400266647339 *************  Kalman 0.9157218096871895
# checkIN Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# USDJPY=X
# USDJPY=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCAD=X
# GBPCAD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPUSD=X
# Coefficients:
#  [3.30499474e-05]
# Independent term:
#  1.3590969614587614
# GBPUSD=X False
# Precio 1.3481813669204712 *************  Kalman 1.348458247911673
# checkIN Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPJPY=X
# Coefficients:
#  [-0.00594701]
# Independent term:
#  157.08129141208022
# GBPJPY=X False
# Precio 153.50599670410156 *************  Kalman 153.5590855651606
# checkIN Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPCHF=X
# Coefficients:
#  [-6.27232213e-06]
# Independent term:
#  1.2501352971091197
# GBPCHF=X False
# Precio 1.2356699705123901 *************  Kalman 1.234781796057638
# checkIN Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPNZD=X
# GBPNZD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# GBPAUD=X
# GBPAUD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCAD=X
# NZDCAD=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDUSD=X
# Coefficients:
#  [-4.85750107e-07]
# Independent term:
#  0.6797859988364265
# NZDUSD=X False
# Precio 0.6677796840667725 *************  Kalman 0.6687801955660667
# checkIN Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed
# NZDCHF=X
# NZDCHF=X True
# checkOUT Time 2022-01-25 10:00:00+00:00
# [*********************100%***********************]  1 of 1 completed

# %%
tickersCurrencies =['EURUSD=X', 'EURGBP=X' ,'EURCHF=X', 'EURJPY=X', 'EURNZD=X', 'EURCAD=X', 'EURAUD=X','USDCHF=X', 
         'USDJPY=X','GBPCAD=X', 'GBPUSD=X', 'GBPJPY=X', 'GBPCHF=X', 'GBPNZD=X', 'GBPAUD=X',
         'NZDCAD=X', 'NZDUSD=X', 'NZDCHF=X', 'NZDJPY=X','JPY=X','EURSEK=X','USDCAD=X','AUDCAD=X',
         'KC=F','HG=F', 'CORN', 'CL=F', 'ZS=F','ZW=F','GC=F','X','ZW=F',
         'ETH-USD','PFE',
        '^IXIC', '^GSPC', '^GDAXI'
         ]

Currencies_dict = dict.fromkeys(tickersCurrencies, "out")

# %%
Currencies_dict[tickersCurrencies[2]]=2

# %%
Currencies_dict

# %% [markdown]
# # GRAFICADOR

# %%
#Interval required 1 minute
data = yf.download(tickers='UBER', period='1d', interval='1m')

#declare figure
fig = go.Figure()

#Candlestick
fig.add_trace(go.Candlestick(x=data.index,
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close'], name = 'market data'))

# Add titles

fig.layout.update(
    title='Uber live share price evolution',
    yaxis_title='Stock Price (USD per Shares)')

# X-Axes

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=15, label="15m", step="minute", stepmode="backward"),
            dict(count=45, label="45m", step="minute", stepmode="backward"),
            dict(count=1, label="HTD", step="hour", stepmode="todate"),
            dict(count=3, label="3h", step="hour", stepmode="backward"),
            dict(step="all")
        ])
    )
)

#Show
fig.show()
