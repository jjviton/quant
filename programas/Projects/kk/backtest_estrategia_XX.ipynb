# %% [markdown]
# # <font color='red'>Backtest vectorizado para una estrategia 'Regresion lineal' definida.</font>
#
# ### Hackeado by J3viton (learning BackTesting 2021).

# %% [markdown]
# ---

# %% [markdown]
# En este notebook vamos a automatizar el backtesting para estrategias. Previamente tenemos que definir **la estrategia** usando el template (import estrategia_XX as rg), donde definimos la clase estrategia que contiene los metodos de analisis, entreda y salida de mercado. Este módulo se programa y adapta para cada estrategia. Luego en el metodo 'analisis' se crea un fichero excel con las metricas y rendimientos para evaluar la estrategia.
#
# Vamos a usar el módulo Pandas, para realizar un backtest vectorizado, es decir calcular el resultado del backtest sin iterar sobre las filas (barras) de la serie temporal.

# %% [markdown]
# Posteriormente graficamos y mostramos los parametros generales que nos permiten analizar la estrategia.
#
# #### J3Viton  2021
#
# link a la base:
#
# https://github.com/Python-para-Trading/Webinars-Docs/blob/master/Webinar%202/Webinar%202%20-%20Backtest%20con%20Pandas%20v%202.ipynb.

# %% [markdown]
# ---

# %% [markdown]
# # DEFINICION DEL SISTEMA

# %% [markdown]
# Como es usual, importamos los módulos que vamos a necesitar para las distintas tareas, y preparamos Matplotlib para una mejor visualización de los gráficos en el notebook.
#
# Se importa un modulo llamado analisis, en realidad se trata de un archivo .py con algunas funciones de apoyo para el trabajo, debe estar guardado en la misma carpeta que este notebook.
# Se importa el módulo 'estrategia_XX', donde se define la estrategia de entreda y salida

# %% [markdown]
# Es importante tener clara la lógica del sistema, pues debemos plasmarla de forma sencilla y correcta en el dataframe para realizar el backtest del mismo.

# %%
import analisis
import regresionAMedia as rg  #cambiar segun el módulo con la estrategia implementado
import pandas as pd
import datetime as dt
from time import time
import yfinance as yf
import numpy as np
# Out:
# {'first_name': 'vital_bot', 'username': 'vital_quant_bot', 'is_bot': True, 'can_read_all_group_messages': False, 'supports_inline_queries': False, 'can_join_groups': True, 'id': 1473252352}

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = 18, 8
plt.style.use('ggplot')

from IPython.display import display, Markdown

# %% [markdown]
# ***0.- RECOGIDA DE DATOS INICIALES***
# Introducimos el instrumento y las fechas

# %%
instrumento_ = 'mts.mc'   # ticker del valor en yahooFinance

Fecha_Cominezo_Backtesting = dt.datetime(2018,1,2)
Fecha_Final_Backtesting    = dt.datetime(2021,11,18)
Fecha_Final_Backtesting    = dt.datetime.today()

# %% [markdown]
# ***1.- Rango fechas a analizar***
#
# Definimos el rango global de datos historicos que vamos a evaluar.
# Definimos la ventana que vamos a ir desplazando por todo el espectro para ir analilazando como se comporta la estrategia. La funion 'analisis' nos vale para tiempo real y para backtesting, para back le pasamos la ventana como si la fecha de fin de la ventana fuera la fecha de hoy.
# Tener en cuenta que la 'ventana' tiene uqe tener una anchura que nos permita hacer los calculos en rolling (ejemplo EMA 200)

# %%
# Rango completo para backTesting
#start2 =dt.datetime(2008,1,2)
start2= Fecha_Cominezo_Backtesting 
#end2   =dt.datetime(2021,11,18)
end2= Fecha_Final_Backtesting 
start_G= start2.strftime("%Y-%m-%d")
end_G  =   end2.strftime("%Y-%m-%d")
TOTAL_len= (end2-start2).days
print('Tamaño timeseries global a analizar:  ', TOTAL_len, 'sesiones')

#ventana de analisis 200 sesiones
startWindow2 = start2  #dt.datetime(2008,1,5)
endWindow2   =startWindow2 + dt.timedelta(days=500) #ventana grande para que se puedan hacer los calculos de EMA200
startWindow= startWindow2.strftime("%Y-%m-%d")
endWindow  =   endWindow2.strftime("%Y-%m-%d")
window_len= (endWindow2-startWindow2).days
print('Tamaño de la ventana a analizar paso a paso:  ', window_len, 'sesiones')
# Out:
# Tamaño timeseries global a analizar:   1464 sesiones
# Tamaño de la ventana a analizar paso a paso:   1000 sesiones

# %%
 #dff = pd.DataFrame(columns=('Close','Volume', 'Senal', 'Dif_Close', 'Retornos','Capital'))

# %% [markdown]
# ***2.- Descargamos los datos para el marco Global***

# %%
instrumento = instrumento_  # 'rovi.mc'  #Vamos título a título. Mejora: Conjunto de títulos

# %%
dff = yf.download(instrumento, start_G,end_G)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
dff.dropna(inplace=True)  
dff.head()
# Out:
#               Open       High        Low      Close  Adj Close  Volume
# Date
# 2018-01-02  27.115  27.990000  26.865000  27.990000  26.990908  672626
# 2018-01-03  28.100  28.799999  28.045000  28.730000  27.704494  804532
# 2018-01-04  29.020  29.049999  28.549999  28.655001  27.632170  457767
# 2018-01-05  28.600  28.650000  28.330000  28.389999  27.376629  528866
# 2018-01-08  28.695  29.215000  28.695000  29.215000  28.172180  758128

# %% [markdown]
# ***3.- Creamos la clase strategy que tiene toda la lógica***

# %%
regreMedia= rg.StrategyClass(real_back=True)    #Creamos la clase

# %% [markdown]
# ***4.- Recorremos el dataframe con valores buscando las señales de la estrategia***

# %%
dff.index
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05',
#                '2018-01-08', '2018-01-09', '2018-01-10', '2018-01-11',
#                '2018-01-12', '2018-01-15',
#                ...
#                '2021-12-20', '2021-12-21', '2021-12-22', '2021-12-23',
#                '2021-12-27', '2021-12-28', '2021-12-29', '2021-12-30',
#                '2022-01-03', '2022-01-04'],
#               dtype='datetime64[ns]', name='Date', length=1025, freq=None)

# %% [markdown]
# ## Proceso de backTesting ##
#
# En este 'for' vamos recorriendo la muestra del historico de datos (TOTAL), desplazando una sesión hacia el futuro
# en cada iteracion. Vamos pasando la movilola del pasado sesión a sesión por el análisis descrito en Strategy class.
#
# Ouput:
# El sistema registra los siguientes parámetros:
#
# .-
# .-
# .-

# %%
startWindow
# Out:
# '2018-01-02'

# %%
tiempo_inicial = time()   # Tomamos tiempos para ver cuanto tarda en hacer la estrategia

# %%
dfe = pd.DataFrame({'A' : []})   #df empty

# %% [markdown]
# ***En este 'for' desplazamos la ventana sesión a sesión a lo largo de todo el rango de fechas. Dejamos que las funciones de la clase estrategia hagan el trabajo de comprar//vender y anotar***

# %%
#Para pruebas
#TOTAL_len =1000

for i in range(TOTAL_len):
    endWindow3   =endWindow2 + dt.timedelta(days=i) 
    endWindow    =endWindow3.strftime("%Y-%m-%d")
    print ('end date:', endWindow)
    
    if(endWindow in dff.index):
        df_aux= dff.loc[startWindow:endWindow]       #voy pasando los datos desplazando la ventana
        
        recogo = regreMedia.analisis(instrumento, startWindow, endWindow, df_aux) #Llamada a la clase estrategia. LA CLAVE DE TODO!!!
        
        print ('................................................Analizando, muestra', i, 'de', TOTAL_len, 'fecha', endWindow)
        
        """
        Tratamiento de los returns, mejor en las funciones de analisis que hacer aquí.
        if(recogo['senal'] == 1 ):
            dff.loc[[endWindow],['Senal']]= 1
        elif(recogo['senal'] == 0 ):
            dff.loc[[endWindow],['Senal']]= 0
        elif(recogo['senal'] == -1 ):
            dff.loc[[endWindow],['Senal']]= -1            
        elif(recogo['senal'] == 503 ):
            dff.loc[[endWindow],['Senal']]= 0          
        """
            
    else:
        print('..............Día sin sesión, next please')
# Out:
# end date: 2020-09-28
#  datos desde archivo
# Coefficients:
#  [-0.0318043]
# Independent term:
#  29.32474356619627
# Coefficients:
#  [-0.0264184]
# Independent term:
#  13.639965935465115
# Coefficients:
#  [-0.02992653]
# Independent term:
#  16.306013234180888
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 0 de 1464 fecha 2020-09-28
# end date: 2020-09-29
#  datos desde archivo
# Coefficients:
#  [-0.0317505]
# Independent term:
#  29.312208875336623
# Coefficients:
#  [-0.02554452]
# Independent term:
#  13.528635032354897
# Coefficients:
#  [-0.02988293]
# Independent term:
#  16.278377630182625
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 1 de 1464 fecha 2020-09-29
# end date: 2020-09-30
#  datos desde archivo
# Coefficients:
#  [-0.0316979]
# Independent term:
#  29.299934152816633
# Coefficients:
#  [-0.02466591]
# Independent term:
#  13.416002648624021
# Coefficients:
#  [-0.02983102]
# Independent term:
#  16.24989628708254
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 2 de 1464 fecha 2020-09-30
# end date: 2020-10-01
#  datos desde archivo
# Coefficients:
#  [-0.03164276]
# Independent term:
#  29.287050490636467
# Coefficients:
#  [-0.02373723]
# Independent term:
#  13.29910967648919
# Coefficients:
#  [-0.02977038]
# Independent term:
#  16.220535226280617
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 3 de 1464 fecha 2020-10-01
# end date: 2020-10-02
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#  datos desde archivo
# Coefficients:
#  [-0.03158783]
# Independent term:
#  29.27419687259359
# Coefficients:
#  [-0.02284853]
# Independent term:
#  13.18766413887935
# Coefficients:
#  [-0.02970151]
# Independent term:
#  16.190357404515424
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 4 de 1464 fecha 2020-10-02
# end date: 2020-10-03
# ..............Día sin sesión, next please
# end date: 2020-10-04
# ..............Día sin sesión, next please
# end date: 2020-10-05
#  datos desde archivo
# Coefficients:
#  [-0.03152944]
# Independent term:
#  29.26051445492851
# Coefficients:
#  [-0.02194402]
# Independent term:
#  13.077275327924474
# Coefficients:
#  [-0.02962432]
# Independent term:
#  16.15938146345482
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 7 de 1464 fecha 2020-10-05
# end date: 2020-10-06
#  datos desde archivo
# Coefficients:
#  [-0.03147078]
# Independent term:
#  29.246749486274027
# Coefficients:
#  [-0.02104339]
# Independent term:
#  12.96792265094928
# Coefficients:
#  [-0.02953894]
# Independent term:
#  16.127625654375166
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 8 de 1464 fecha 2020-10-06
# end date: 2020-10-07
#  datos desde archivo
# Coefficients:
#  [-0.03140747]
# Independent term:
#  29.231871853483355
# Coefficients:
#  [-0.02007744]
# Independent term:
#  12.854060116170057
# Coefficients:
#  [-0.02944479]
# Independent term:
#  16.095052862950237
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 9 de 1464 fecha 2020-10-07
# end date: 2020-10-08
#  datos desde archivo
# Coefficients:
#  [-0.03134492]
# Independent term:
#  29.21715132154145
# Coefficients:
#  [-0.01914045]
# Independent term:
#  12.743720259879952
# Coefficients:
#  [-0.02934226]
# Independent term:
#  16.061706269884866
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 10 de 1464 fecha 2020-10-08
# end date: 2020-10-09
#  datos desde archivo
# Coefficients:
#  [-0.03128407]
# Independent term:
#  29.20281145637312
# Coefficients:
#  [-0.01821684]
# Independent term:
#  12.634030264171203
# Coefficients:
#  [-0.02923156]
# Independent term:
#  16.02760004097229
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 11 de 1464 fecha 2020-10-09
# end date: 2020-10-10
# ..............Día sin sesión, next please
# end date: 2020-10-11
# ..............Día sin sesión, next please
# end date: 2020-10-12
#  datos desde archivo
# Coefficients:
#  [-0.03122477]
# Independent term:
#  29.188815560139403
# Coefficients:
#  [-0.01731574]
# Independent term:
#  12.526331608900383
# Coefficients:
#  [-0.029113]
# Independent term:
#  15.992761549110881
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 14 de 1464 fecha 2020-10-12
# end date: 2020-10-13
#  datos desde archivo
# Coefficients:
#  [-0.03116834]
# Independent term:
#  29.175480229029567
# Coefficients:
#  [-0.0164104]
# Independent term:
#  12.415939820346548
# Coefficients:
#  [-0.0289866]
# Independent term:
#  15.957171283153023
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 15 de 1464 fecha 2020-10-13
# end date: 2020-10-14
#  datos desde archivo
# Coefficients:
#  [-0.03110831]
# Independent term:
#  29.16127281368783
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# Coefficients:
#  [-0.01553652]
# Independent term:
#  12.313048635881337
# Coefficients:
#  [-0.02885277]
# Independent term:
#  15.9209113563145
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 16 de 1464 fecha 2020-10-14
# end date: 2020-10-15
#  datos desde archivo
# Coefficients:
#  [-0.03105195]
# Independent term:
#  29.14791586420238
# Coefficients:
#  [-0.01474454]
# Independent term:
#  12.218196853879672
# Coefficients:
#  [-0.02871239]
# Independent term:
#  15.884068425942015
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 17 de 1464 fecha 2020-10-15
# end date: 2020-10-16
#  datos desde archivo
# Coefficients:
#  [-0.03099081]
# Independent term:
#  29.133405222095746
# Coefficients:
#  [-0.01387812]
# Independent term:
#  12.117768049524791
# Coefficients:
#  [-0.02856479]
# Independent term:
#  15.846592800306023
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 18 de 1464 fecha 2020-10-16
# end date: 2020-10-17
# ..............Día sin sesión, next please
# end date: 2020-10-18
# ..............Día sin sesión, next please
# end date: 2020-10-19
#  datos desde archivo
# Coefficients:
#  [-0.03092907]
# Independent term:
#  29.118731202288245
# Coefficients:
#  [-0.01296984]
# Independent term:
#  12.01256432113363
# Coefficients:
#  [-0.02840961]
# Independent term:
#  15.808443263199832
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 21 de 1464 fecha 2020-10-19
# end date: 2020-10-20
#  datos desde archivo
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# Coefficients:
#  [-0.03086713]
# Independent term:
#  29.103989917347363
# Coefficients:
#  [-0.01205535]
# Independent term:
#  11.906982379457844
# Coefficients:
#  [-0.02824688]
# Independent term:
#  15.769622756893941
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 22 de 1464 fecha 2020-10-20
# end date: 2020-10-21
#  datos desde archivo
# Coefficients:
#  [-0.03080505]
# Independent term:
#  29.089193210577427
# Coefficients:
#  [-0.01117692]
# Independent term:
#  11.806588789171247
# Coefficients:
#  [-0.02807703]
# Independent term:
#  15.730189583085755
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 23 de 1464 fecha 2020-10-21
# end date: 2020-10-22
#  datos desde archivo
# Coefficients:
#  [-0.0307418]
# Independent term:
#  29.074097612401903
# Coefficients:
#  [-0.01022874]
# Independent term:
#  11.698204461282758
# Coefficients:
#  [-0.02789944]
# Independent term:
#  15.690070328142442
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 24 de 1464 fecha 2020-10-22
# end date: 2020-10-23
#  datos desde archivo
# Coefficients:
#  [-0.03067881]
# Independent term:
#  29.059043733223646
# Coefficients:
#  [-0.00929321]
# Independent term:
#  11.591559840458542
# Coefficients:
#  [-0.0277143]
# Independent term:
#  15.64928912926002
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 25 de 1464 fecha 2020-10-23
# end date: 2020-10-24
# ..............Día sin sesión, next please
# end date: 2020-10-25
# ..............Día sin sesión, next please
# end date: 2020-10-26
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#  datos desde archivo
# Coefficients:
#  [-0.03061592]
# Independent term:
#  29.04399267079595
# Coefficients:
#  [-0.00842479]
# Independent term:
#  11.494011327686595
# Coefficients:
#  [-0.02752237]
# Independent term:
#  15.607943081483167
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 28 de 1464 fecha 2020-10-26
# end date: 2020-10-27
#  datos desde archivo
# Coefficients:
#  [-0.0305607]
# Independent term:
#  29.030756712045022
# Coefficients:
#  [-0.00765244]
# Independent term:
#  11.402853264239297
# Coefficients:
#  [-0.02732466]
# Independent term:
#  15.566101391759348
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 29 de 1464 fecha 2020-10-27
# end date: 2020-10-28
#  datos desde archivo
# Coefficients:
#  [-0.03050744]
# Independent term:
#  29.01797477304617
# Coefficients:
#  [-0.00690029]
# Independent term:
#  11.312903851608732
# Coefficients:
#  [-0.02712143]
# Independent term:
#  15.523781018225513
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 30 de 1464 fecha 2020-10-28
# end date: 2020-10-29
#  datos desde archivo
# Coefficients:
#  [-0.03045462]
# Independent term:
#  29.005279610808763
# Coefficients:
#  [-0.00615893]
# Independent term:
#  11.224238923983787
# Coefficients:
#  [-0.02691285]
# Independent term:
#  15.480999504849972
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 31 de 1464 fecha 2020-10-29
# end date: 2020-10-30
#  datos desde archivo
# Coefficients:
#  [-0.03040097]
# Independent term:
#  28.992368044210952
# Coefficients:
#  [-0.00545393]
# Independent term:
#  11.141341168987218
# Coefficients:
#  [-0.02669933]
# Independent term:
#  15.43781882489114
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 32 de 1464 fecha 2020-10-30
# end date: 2020-10-31
# ..............Día sin sesión, next please
# end date: 2020-11-01
# ..............Día sin sesión, next please
# end date: 2020-11-02
#  datos desde archivo
# Coefficients:
#  [-0.03034434]
# Independent term:
#  28.978720035514932
# Coefficients:
#  [-0.00470541]
# Independent term:
#  11.055483114683806
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# Coefficients:
#  [-0.02648048]
# Independent term:
#  15.394213494441317
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 35 de 1464 fecha 2020-11-02
# end date: 2020-11-03
#  datos desde archivo
# Coefficients:
#  [-0.03028423]
# Independent term:
#  28.96421560926627
# Coefficients:
#  [-0.0039458]
# Independent term:
#  10.971412524892322
# Coefficients:
#  [-0.02625625]
# Independent term:
#  15.350205524595058
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 36 de 1464 fecha 2020-11-03
# end date: 2020-11-04
#  datos desde archivo
# Coefficients:
#  [-0.03022118]
# Independent term:
#  28.948977045261334
# Coefficients:
#  [-0.00312406]
# Independent term:
#  10.881909385154495
# Coefficients:
#  [-0.02602608]
# Independent term:
#  15.305744866491173
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 37 de 1464 fecha 2020-11-04
# end date: 2020-11-05
#  datos desde archivo
# Coefficients:
#  [-0.03016067]
# Independent term:
#  28.934334748765863
# Coefficients:
#  [-0.00240974]
# Independent term:
#  10.804643866837916
# Coefficients:
#  [-0.0257911]
# Independent term:
#  15.260957791867758
# bye
#   instrumento  long_short_out        date      precio  beneficio  stoploss
# 0      IBE.MC               1  2011-08-10    4.776000        NaN       NaN
# 1        MSFT               0  2014-01-08   35.759998   1.350209      99.0
# 2      san.mc               1  2021-07-08    3.057500   0.532204      99.0
# 3      ibe.mc               0  2021-06-25   10.355000   0.797811      99.0
# 4      REE.MC               0  2019-07-08   17.695000   1.585407      99.0
# 5     ntgy.MC               1  2013-06-25   15.020000   1.652717      99.0
# 6      mts.MC               1  2021-09-21   24.670000   5.460217      99.0
# 7        nvda               0  2021-09-29  205.169998  13.604359      99.0
# ................................................Analizando, muestra 38 de 1464 fecha 2020-11-05
# end date: 2020-11-06
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")
#  datos desde archivo
# Coefficients:
#  [-0.03009701]
# ...
# ..............Día sin sesión, next please
# end date: 2024-01-22
# ..............Día sin sesión, next please
# end date: 2024-01-23
# ..............Día sin sesión, next please
# end date: 2024-01-24
# ..............Día sin sesión, next please
# end date: 2024-01-25
# ..............Día sin sesión, next please
# end date: 2024-01-26
# ..............Día sin sesión, next please
# end date: 2024-01-27
# ..............Día sin sesión, next please
# end date: 2024-01-28
# ..............Día sin sesión, next please
# end date: 2024-01-29
# ..............Día sin sesión, next please
# end date: 2024-01-30
# ..............Día sin sesión, next please
# end date: 2024-01-31
# ..............Día sin sesión, next please
# end date: 2024-02-01
# ..............Día sin sesión, next please
# end date: 2024-02-02
# ..............Día sin sesión, next please
# end date: 2024-02-03
# ..............Día sin sesión, next please
# end date: 2024-02-04
# ..............Día sin sesión, next please
# end date: 2024-02-05
# ..............Día sin sesión, next please
# end date: 2024-02-06
# ..............Día sin sesión, next please
# end date: 2024-02-07
# ..............Día sin sesión, next please
# end date: 2024-02-08
# ..............Día sin sesión, next please
# end date: 2024-02-09
# ..............Día sin sesión, next please
# end date: 2024-02-10
# ..............Día sin sesión, next please
# end date: 2024-02-11
# ..............Día sin sesión, next please
# end date: 2024-02-12
# ..............Día sin sesión, next please
# end date: 2024-02-13
# ..............Día sin sesión, next please
# end date: 2024-02-14
# ..............Día sin sesión, next please
# end date: 2024-02-15
# ..............Día sin sesión, next please
# end date: 2024-02-16
# ..............Día sin sesión, next please
# end date: 2024-02-17
# ..............Día sin sesión, next please
# end date: 2024-02-18
# ..............Día sin sesión, next please
# end date: 2024-02-19
# ..............Día sin sesión, next please
# end date: 2024-02-20
# ..............Día sin sesión, next please
# end date: 2024-02-21
# ..............Día sin sesión, next please
# end date: 2024-02-22
# ..............Día sin sesión, next please
# end date: 2024-02-23
# ..............Día sin sesión, next please
# end date: 2024-02-24
# ..............Día sin sesión, next please
# end date: 2024-02-25
# ..............Día sin sesión, next please
# end date: 2024-02-26
# ..............Día sin sesión, next please
# end date: 2024-02-27
# ..............Día sin sesión, next please
# end date: 2024-02-28
# ..............Día sin sesión, next please
# end date: 2024-02-29
# ..............Día sin sesión, next please
# end date: 2024-03-01
# ..............Día sin sesión, next please
# end date: 2024-03-02
# ..............Día sin sesión, next please
# end date: 2024-03-03
# ..............Día sin sesión, next please
# end date: 2024-03-04
# ..............Día sin sesión, next please
# end date: 2024-03-05
# ..............Día sin sesión, next please
# end date: 2024-03-06
# ..............Día sin sesión, next please
# end date: 2024-03-07
# ..............Día sin sesión, next please
# end date: 2024-03-08
# ..............Día sin sesión, next please
# end date: 2024-03-09
# ..............Día sin sesión, next please
# end date: 2024-03-10
# ..............Día sin sesión, next please
# end date: 2024-03-11
# ..............Día sin sesión, next please
# end date: 2024-03-12
# ..............Día sin sesión, next please
# end date: 2024-03-13
# ..............Día sin sesión, next please
# end date: 2024-03-14
# ..............Día sin sesión, next please
# end date: 2024-03-15
# ..............Día sin sesión, next please
# end date: 2024-03-16
# ..............Día sin sesión, next please
# end date: 2024-03-17
# ..............Día sin sesión, next please
# end date: 2024-03-18
# ..............Día sin sesión, next please
# end date: 2024-03-19
# ..............Día sin sesión, next please
# end date: 2024-03-20
# ..............Día sin sesión, next please
# end date: 2024-03-21
# ..............Día sin sesión, next please
# end date: 2024-03-22
# ..............Día sin sesión, next please
# end date: 2024-03-23
# ..............Día sin sesión, next please
# end date: 2024-03-24
# ..............Día sin sesión, next please
# end date: 2024-03-25
# ..............Día sin sesión, next please
# end date: 2024-03-26
# ..............Día sin sesión, next please
# end date: 2024-03-27
# ..............Día sin sesión, next please
# end date: 2024-03-28
# ..............Día sin sesión, next please
# end date: 2024-03-29
# ..............Día sin sesión, next please
# end date: 2024-03-30
# ..............Día sin sesión, next please
# end date: 2024-03-31
# ..............Día sin sesión, next please
# end date: 2024-04-01
# ..............Día sin sesión, next please
# end date: 2024-04-02
# ..............Día sin sesión, next please
# end date: 2024-04-03
# ..............Día sin sesión, next please
# end date: 2024-04-04
# ..............Día sin sesión, next please
# end date: 2024-04-05
# ..............Día sin sesión, next please
# end date: 2024-04-06
# ..............Día sin sesión, next please
# end date: 2024-04-07
# ..............Día sin sesión, next please
# end date: 2024-04-08
# ..............Día sin sesión, next please
# end date: 2024-04-09
# ..............Día sin sesión, next please
# end date: 2024-04-10
# ..............Día sin sesión, next please
# end date: 2024-04-11
# ..............Día sin sesión, next please
# end date: 2024-04-12
# ..............Día sin sesión, next please
# end date: 2024-04-13
# ..............Día sin sesión, next please
# end date: 2024-04-14
# ..............Día sin sesión, next please
# end date: 2024-04-15
# ..............Día sin sesión, next please
# end date: 2024-04-16
# ..............Día sin sesión, next please
# end date: 2024-04-17
# ..............Día sin sesión, next please
# end date: 2024-04-18
# ..............Día sin sesión, next please
# end date: 2024-04-19
# ..............Día sin sesión, next please
# end date: 2024-04-20
# ..............Día sin sesión, next please
# end date: 2024-04-21
# ..............Día sin sesión, next please
# end date: 2024-04-22
# ..............Día sin sesión, next please
# end date: 2024-04-23
# ..............Día sin sesión, next please
# end date: 2024-04-24
# ..............Día sin sesión, next please
# end date: 2024-04-25
# ..............Día sin sesión, next please
# end date: 2024-04-26
# ..............Día sin sesión, next please
# end date: 2024-04-27
# ..............Día sin sesión, next please
# end date: 2024-04-28
# ..............Día sin sesión, next please
# end date: 2024-04-29
# ..............Día sin sesión, next please
# end date: 2024-04-30
# ..............Día sin sesión, next please
# end date: 2024-05-01
# ..............Día sin sesión, next please
# end date: 2024-05-02
# ..............Día sin sesión, next please
# end date: 2024-05-03
# ..............Día sin sesión, next please
# end date: 2024-05-04
# ..............Día sin sesión, next please
# end date: 2024-05-05
# ..............Día sin sesión, next please
# end date: 2024-05-06
# ..............Día sin sesión, next please
# end date: 2024-05-07
# ..............Día sin sesión, next please
# end date: 2024-05-08
# ..............Día sin sesión, next please
# end date: 2024-05-09
# ..............Día sin sesión, next please
# end date: 2024-05-10
# ..............Día sin sesión, next please
# end date: 2024-05-11
# ..............Día sin sesión, next please
# end date: 2024-05-12
# ..............Día sin sesión, next please
# end date: 2024-05-13
# ..............Día sin sesión, next please
# end date: 2024-05-14
# ..............Día sin sesión, next please
# end date: 2024-05-15
# ..............Día sin sesión, next please
# end date: 2024-05-16
# ..............Día sin sesión, next please
# end date: 2024-05-17
# ..............Día sin sesión, next please
# end date: 2024-05-18
# ..............Día sin sesión, next please
# end date: 2024-05-19
# ..............Día sin sesión, next please
# end date: 2024-05-20
# ..............Día sin sesión, next please
# end date: 2024-05-21
# ..............Día sin sesión, next please
# end date: 2024-05-22
# ..............Día sin sesión, next please
# end date: 2024-05-23
# ..............Día sin sesión, next please
# end date: 2024-05-24
# ..............Día sin sesión, next please
# end date: 2024-05-25
# ..............Día sin sesión, next please
# end date: 2024-05-26
# ..............Día sin sesión, next please
# end date: 2024-05-27
# ..............Día sin sesión, next please
# end date: 2024-05-28
# ..............Día sin sesión, next please
# end date: 2024-05-29
# ..............Día sin sesión, next please
# end date: 2024-05-30
# ..............Día sin sesión, next please
# end date: 2024-05-31
# ..............Día sin sesión, next please
# end date: 2024-06-01
# ..............Día sin sesión, next please
# end date: 2024-06-02
# ..............Día sin sesión, next please
# end date: 2024-06-03
# ..............Día sin sesión, next please
# end date: 2024-06-04
# ..............Día sin sesión, next please
# end date: 2024-06-05
# ..............Día sin sesión, next please
# end date: 2024-06-06
# ..............Día sin sesión, next please
# end date: 2024-06-07
# ..............Día sin sesión, next please
# end date: 2024-06-08
# ..............Día sin sesión, next please
# end date: 2024-06-09
# ..............Día sin sesión, next please
# end date: 2024-06-10
# ..............Día sin sesión, next please
# end date: 2024-06-11
# ..............Día sin sesión, next please
# end date: 2024-06-12
# ..............Día sin sesión, next please
# end date: 2024-06-13
# ..............Día sin sesión, next please
# end date: 2024-06-14
# ..............Día sin sesión, next please
# end date: 2024-06-15
# ..............Día sin sesión, next please
# end date: 2024-06-16
# ..............Día sin sesión, next please
# end date: 2024-06-17
# ..............Día sin sesión, next please
# end date: 2024-06-18
# ..............Día sin sesión, next please
# end date: 2024-06-19
# ..............Día sin sesión, next please
# end date: 2024-06-20
# ..............Día sin sesión, next please
# end date: 2024-06-21
# ..............Día sin sesión, next please
# end date: 2024-06-22
# ..............Día sin sesión, next please
# end date: 2024-06-23
# ..............Día sin sesión, next please
# end date: 2024-06-24
# ..............Día sin sesión, next please
# end date: 2024-06-25
# ..............Día sin sesión, next please
# end date: 2024-06-26
# ..............Día sin sesión, next please
# end date: 2024-06-27
# ..............Día sin sesión, next please
# end date: 2024-06-28
# ..............Día sin sesión, next please
# end date: 2024-06-29
# ..............Día sin sesión, next please
# end date: 2024-06-30
# ..............Día sin sesión, next please
# end date: 2024-07-01
# ..............Día sin sesión, next please
# end date: 2024-07-02
# ..............Día sin sesión, next please
# end date: 2024-07-03
# ..............Día sin sesión, next please
# end date: 2024-07-04
# ..............Día sin sesión, next please
# end date: 2024-07-05
# ..............Día sin sesión, next please
# end date: 2024-07-06
# ..............Día sin sesión, next please
# end date: 2024-07-07
# ..............Día sin sesión, next please
# end date: 2024-07-08
# ..............Día sin sesión, next please
# end date: 2024-07-09
# ..............Día sin sesión, next please
# end date: 2024-07-10
# ..............Día sin sesión, next please
# end date: 2024-07-11
# ..............Día sin sesión, next please
# end date: 2024-07-12
# ..............Día sin sesión, next please
# end date: 2024-07-13
# ..............Día sin sesión, next please
# end date: 2024-07-14
# ..............Día sin sesión, next please
# end date: 2024-07-15
# ..............Día sin sesión, next please
# end date: 2024-07-16
# ..............Día sin sesión, next please
# end date: 2024-07-17
# ..............Día sin sesión, next please
# end date: 2024-07-18
# ..............Día sin sesión, next please
# end date: 2024-07-19
# ..............Día sin sesión, next please
# end date: 2024-07-20
# ..............Día sin sesión, next please
# end date: 2024-07-21
# ..............Día sin sesión, next please
# end date: 2024-07-22
# ..............Día sin sesión, next please
# end date: 2024-07-23
# ..............Día sin sesión, next please
# end date: 2024-07-24
# ..............Día sin sesión, next please
# end date: 2024-07-25
# ..............Día sin sesión, next please
# end date: 2024-07-26
# ..............Día sin sesión, next please
# end date: 2024-07-27
# ..............Día sin sesión, next please
# end date: 2024-07-28
# ..............Día sin sesión, next please
# end date: 2024-07-29
# ..............Día sin sesión, next please
# end date: 2024-07-30
# ..............Día sin sesión, next please
# end date: 2024-07-31
# ..............Día sin sesión, next please
# end date: 2024-08-01
# ..............Día sin sesión, next please
# end date: 2024-08-02
# ..............Día sin sesión, next please
# end date: 2024-08-03
# ..............Día sin sesión, next please
# end date: 2024-08-04
# ..............Día sin sesión, next please
# end date: 2024-08-05
# ..............Día sin sesión, next please
# end date: 2024-08-06
# ..............Día sin sesión, next please
# end date: 2024-08-07
# ..............Día sin sesión, next please
# end date: 2024-08-08
# ..............Día sin sesión, next please
# end date: 2024-08-09
# ..............Día sin sesión, next please
# end date: 2024-08-10
# ..............Día sin sesión, next please
# end date: 2024-08-11
# ..............Día sin sesión, next please
# end date: 2024-08-12
# ..............Día sin sesión, next please
# end date: 2024-08-13
# ..............Día sin sesión, next please
# end date: 2024-08-14
# ..............Día sin sesión, next please
# end date: 2024-08-15
# ..............Día sin sesión, next please
# end date: 2024-08-16
# ..............Día sin sesión, next please
# end date: 2024-08-17
# ..............Día sin sesión, next please
# end date: 2024-08-18
# ..............Día sin sesión, next please
# end date: 2024-08-19
# ..............Día sin sesión, next please
# end date: 2024-08-20
# ..............Día sin sesión, next please
# end date: 2024-08-21
# ..............Día sin sesión, next please
# end date: 2024-08-22
# ..............Día sin sesión, next please
# end date: 2024-08-23
# ..............Día sin sesión, next please
# end date: 2024-08-24
# ..............Día sin sesión, next please
# end date: 2024-08-25
# ..............Día sin sesión, next please
# end date: 2024-08-26
# ..............Día sin sesión, next please
# end date: 2024-08-27
# ..............Día sin sesión, next please
# end date: 2024-08-28
# ..............Día sin sesión, next please
# end date: 2024-08-29
# ..............Día sin sesión, next please
# end date: 2024-08-30
# ..............Día sin sesión, next please
# end date: 2024-08-31
# ..............Día sin sesión, next please
# end date: 2024-09-01
# ..............Día sin sesión, next please
# end date: 2024-09-02
# ..............Día sin sesión, next please
# end date: 2024-09-03
# ..............Día sin sesión, next please
# end date: 2024-09-04
# ..............Día sin sesión, next please
# end date: 2024-09-05
# ..............Día sin sesión, next please
# end date: 2024-09-06
# ..............Día sin sesión, next please
# end date: 2024-09-07
# ..............Día sin sesión, next please
# end date: 2024-09-08
# ..............Día sin sesión, next please
# end date: 2024-09-09
# ..............Día sin sesión, next please
# end date: 2024-09-10
# ..............Día sin sesión, next please
# end date: 2024-09-11
# ..............Día sin sesión, next please
# end date: 2024-09-12
# ..............Día sin sesión, next please
# end date: 2024-09-13
# ..............Día sin sesión, next please
# end date: 2024-09-14
# ..............Día sin sesión, next please
# end date: 2024-09-15
# ..............Día sin sesión, next please
# end date: 2024-09-16
# ..............Día sin sesión, next please
# end date: 2024-09-17
# ..............Día sin sesión, next please
# end date: 2024-09-18
# ..............Día sin sesión, next please
# end date: 2024-09-19
# ..............Día sin sesión, next please
# end date: 2024-09-20
# ..............Día sin sesión, next please
# end date: 2024-09-21
# ..............Día sin sesión, next please
# end date: 2024-09-22
# ..............Día sin sesión, next please
# end date: 2024-09-23
# ..............Día sin sesión, next please
# end date: 2024-09-24
# ..............Día sin sesión, next please
# end date: 2024-09-25
# ..............Día sin sesión, next please
# end date: 2024-09-26
# ..............Día sin sesión, next please
# end date: 2024-09-27
# ..............Día sin sesión, next please
# end date: 2024-09-28
# ..............Día sin sesión, next please
# end date: 2024-09-29
# ..............Día sin sesión, next please
# end date: 2024-09-30
# ..............Día sin sesión, next please

# %% [markdown]
# ***Recogemos los datos de las entradas que ha realizado la Estrategia***

# %%
data=rg.StrategyClass.dfLog
#data.dropna(inplace=True)

# %%
data.tail()
# Out:
#                   Date Senal      Price Objetivo ExitReason  Beneficio
# 2021-12-28  2021-12-28     1      28.65      NaN        NaN        NaN
# 2021-12-29  2021-12-29     1      28.73      NaN        NaN        NaN
# 2021-12-30  2021-12-30     1     28.375      NaN        NaN        NaN
# 2022-01-03  2022-01-03     1     28.635      NaN        NaN        NaN
# 2022-01-04  2022-01-04     1  28.959999      NaN        NaN        NaN

# %%
data['Senal'].plot(title = 'Señales de compra de la estrategia ' )
# Ploteando una parte
#data.loc['2010':'2022','Senal'].plot(title = 'Señales Regresión a la media ' +instrumento,xlim=('2010','2022'))
# Out:
# <AxesSubplot:title={'center':'Señales de compra de la estrategia '}>

# %%
tiempo_final = time() 
 
tiempo_ejecucion = tiempo_final - tiempo_inicial
 
print ('El tiempo de ejecucion fue:',tiempo_ejecucion,"segundos") #En segundos
# Out:
# El tiempo de ejecucion fue: 31.88503098487854 segundos

# %%
data.loc['2011-01-04':'2019-11-04']
# Out:
# Empty DataFrame
# Columns: [Date, Senal, Price, Objetivo, ExitReason, Beneficio]
# Index: []

# %%
#Guardamos el resultado del analisis en un pickle
#dff.to_pickle("./primerBack_IBE.pkl")

# %% [markdown]
# ***3.- Ingeniería de datos para calcular la bondad de la estrategia***

# %%
data['Dif_Close'] = data.Price.pct_change()
data['Retornos'] = data.Dif_Close * data.Senal.shift(1)   
data['Capital'] = (data.Retornos + 1).cumprod() * 100
    
rg.StrategyClass.dfLog=data  #Ojo a esta liena, no me cuadra.

#quant_j.salvarExcel(StrategyClass.dfLog, "log"+instrumento)   
#data.to_pickle('almacen')    #df = pd.read_pickle(file_name)

# %% [markdown]
# >Para calcular los retornos del sistema, calculamos la diferencia relativativa entre el precio de cierre y el del día anterior. Para posteriormente multiplicarlo por la señal que del día anterior que nos indicaba la posición a tomar (si estaba comprado, sumo beneficio).

# %%
data.tail()
# Out:
#                   Date Senal      Price Objetivo ExitReason  Beneficio  \
# 2021-12-28  2021-12-28     1      28.65      NaN        NaN        NaN
# 2021-12-29  2021-12-29     1      28.73      NaN        NaN        NaN
# 2021-12-30  2021-12-30     1     28.375      NaN        NaN        NaN
# 2022-01-03  2022-01-03     1     28.635      NaN        NaN        NaN
# 2022-01-04  2022-01-04     1  28.959999      NaN        NaN        NaN
#
#             Dif_Close  Retornos     Capital
# 2021-12-28  -0.000698 -0.000698  124.399362
# 2021-12-29   0.002792  0.002792  124.746725
# 2021-12-30  -0.012356 -0.012356  123.205303
# 2022-01-03   0.009163  0.009163  124.334234
# 2022-01-04   0.011350   0.01135  125.745391

# %%
data[60:]
# Out:
#                   Date Senal      Price Objetivo ExitReason  Beneficio  \
# 2020-12-21  2020-12-21     0     18.656      NaN        NaN        NaN
# 2020-12-22  2020-12-22     0     18.954      NaN        NaN        NaN
# 2020-12-23  2020-12-23     0  19.191999      NaN        NaN        NaN
# 2020-12-24  2020-12-24     0     19.018      NaN        NaN        NaN
# 2020-12-28  2020-12-28     0  19.059999      NaN        NaN        NaN
# ...                ...   ...        ...      ...        ...        ...
# 2021-12-28  2021-12-28     1      28.65      NaN        NaN        NaN
# 2021-12-29  2021-12-29     1      28.73      NaN        NaN        NaN
# 2021-12-30  2021-12-30     1     28.375      NaN        NaN        NaN
# 2022-01-03  2022-01-03     1     28.635      NaN        NaN        NaN
# 2022-01-04  2022-01-04     1  28.959999      NaN        NaN        NaN
#
#             Dif_Close  Retornos     Capital
# 2020-12-21  -0.006920      -0.0       100.0
# 2020-12-22   0.015973       0.0       100.0
# 2020-12-23   0.012557       0.0       100.0
# 2020-12-24  -0.009066      -0.0       100.0
# 2020-12-28   0.002208       0.0       100.0
# ...               ...       ...         ...
# 2021-12-28  -0.000698 -0.000698  124.399362
# 2021-12-29   0.002792  0.002792  124.746725
# 2021-12-30  -0.012356 -0.012356  123.205303
# 2022-01-03   0.009163  0.009163  124.334234
# 2022-01-04   0.011350   0.01135  125.745391
#
# [266 rows x 9 columns]

# %% [markdown]
# >El capital, por comodidad, lo calcularemos en base 100, es decir como si iniciaramos la inversión con 100 unidades monetarias. Para su calculo arrastramos el producto acumulado de los retornos mas 1, multiplicados como dijimos por 100.

# %% [markdown]
# Pero para observar gráficamente la evolución del sistema necesitamos un gráfico con mas información. Para ello definimos una función que nos mostrará un gráfico con la evolución de nuestra estrategia, comparandola con la del activo. En un subgráfico se visualizará el drawdown del sistema, comparado de nuevo con el del activo. Y por útlimo las posiciones que toma el sistema.

# %%
def grafico (df):
    estudio = df.copy()
    
    DD_bh, maxDD, maxDD_ini, maxDD_fin = analisis.DrawDown(estudio.Dif_Close[60:], info = False) 
    
    DD, maxDD, maxDD_ini, maxDD_fin = analisis.DrawDown(estudio.Retornos.fillna(0), info = False) 

    fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True, figsize=(18, 12), gridspec_kw = {'height_ratios':[3, 1, 1]})
    fig.suptitle('Estrategia vs B & H', fontsize=20)

    #Primer plot analiza la evolcuion de una inversion de 100€ en buy&hold y la estrategia)
    ax1.plot(estudio.Capital)
    ax1.plot((estudio.Price) * (100/estudio.Price[1]))
    ax1.set_title('Capital')
    ax1.legend(['Estrategia','Buy & Hold'])

    ax2.plot(DD*100, c='0.5')
    ax2.plot(DD_bh*100, c='y')
    ax2.fill_between(DD.index, 0, DD*100, color='0.7')
    ax2.set_title('Drawdown')
    ax2.legend(['Estrategia','Buy & Hold'])

    ax3.plot(estudio.Senal, c='orange')
    #ax3.fill_between(estudio.index, 0, estudio.Senal*100, color='orange')
    ax3.set_title('Posición')

    plt.show()
    return

# %%
grafico(data)

# %% [markdown]
# ---

# %%
#data[55:70]

# %% [markdown]
# ---

# %% [markdown]
# # ANALISIS DEL SISTEMA

# %%
Beneficio_Bruto = data.Capital[-1] - data.Capital[1]
print ('Beneficio Bruto : {:.2f} €  con una inverison de 100€'.format(Beneficio_Bruto))
# Out:
# Beneficio Bruto : 25.75 €  con una inverison de 100€

# %%
#Rentabilidad anual compuesta. Calculamos lo que la inversion se ha incrementado cada año con el interes compuesto
CAGR = analisis.CAGR(data.Retornos)
print ('CAGR : {:.2f}%'.format(CAGR * 100))
# Out:
# CAGR : 19.84%

# %%
#Ratio calculado restando una rentabilidad segura a nuestra rentabilidad de estrategia y dividido por el riego (=volatilidad)
data.Retornos=data.Retornos.replace(0,np.e)  #Quito los cero (no sepuede hacer logariotmo de cero), pero no se que poner
Sharpe = CAGR / (np.log(data.Retornos + 1).std(skipna=True) * 252 ** 0.5)
print ('Sharpe : {:.3f}'.format(CAGR ))
# Out:
# Sharpe : 0.198

# %%
# Actualizo la excel con los economic
regreMedia.analisisEconomics(instrumento)
# Out:
# C:\Users\INNOVACION\Documents\J3\100.- cursos\Quant_udemy\programas\Projects\regresionLineal_MediaMovil\quant_j3_lib.py:870: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   sheet_name="data")

# %% [markdown]
# ---

# %% [markdown]
# ---
